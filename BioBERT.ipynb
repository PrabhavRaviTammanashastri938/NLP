# %% [markdown]
# #### Prabhav Ravi Tammanashastri - BL.EN.U4CSE21162
# #### Vijayakumar Soorya - BL.EN.U4CSE21220
# #### Kandukuri Jashwanth - BL.EN.U4CSE21088

# %% [markdown]
# <a href="https://colab.research.google.com/github/PieterDujardin/NER/blob/master/ColabNotebooks/i2b2_2010/BERT_on_i2b2_2010.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import statements

# %%
# %reload_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
# %pip install transformers
# %pip install seqeval
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.11.17)
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 460.9 kB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from seqeval) (1.23.5)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.10/dist-packages (from seqeval) (1.2.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval) (3.2.0)
# Building wheels for collected packages: seqeval
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16162 sha256=7874d9088c3a1c5001b5b6945746dd1a415ddfe97cd0b027304493a5087e5895
#   Stored in directory: /root/.cache/pip/wheels/1a/67/4a/ad4082dd7dfc30f2abfe4d80a2ed5926a506eb8a972b4767fa
# Successfully built seqeval
# Installing collected packages: seqeval
# Successfully installed seqeval-1.2.2

# %%
# %pip list | grep -E 'transformers|torch|Keras'

# %%
# %pip list

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import itertools
import csv
import time
import datetime
import io
import math
import os
import numpy as np
import torch
from sklearn.model_selection import train_test_split
from tqdm import tqdm,trange
from seqeval.metrics import f1_score
from seqeval.metrics import classification_report,accuracy_score,f1_score
# from sklearn.metrics import f1_score
from transformers import BertTokenizer, BertConfig, AutoConfig, AutoTokenizer
from transformers import BertForTokenClassification, AdamW, AutoModel, CamembertTokenizer, CamembertForTokenClassification
from keras.preprocessing.sequence import pad_sequences
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
from torch.optim import Adam
import torch.nn.functional as F
from transformers import get_linear_schedule_with_warmup

# %% [markdown]
# # Cuda

# %%
torch.cuda.is_available()
# Out:
# True

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
n_gpu = torch.cuda.device_count()

# %%
n_gpu
# Out:
# 1

# %%
# torch.cuda.get_device_name()
#tesla K80 is used by pytorch

# %%
torch.cuda.get_device_properties('cuda')
# Out:
# _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15102MB, multi_processor_count=40)

# %%
torch.cuda.current_device()
# Out:
# 0

# %%
torch.cuda.device(0)

# %%
#free memory
torch.cuda.empty_cache()

# %% [markdown]
# # 1. Functions

# %%
def loadandformat(datasets):

    # data=[]
    # for dataset in datasets:
    #   # the training, dev and test set in one file
    #   with open('drive/My Drive/Colab Notebooks/BERTwithNER3/conll2003format/{}'.format(dataset),'r') as f:
    #       data +=  f.readlines()
    sentence=[]
    sentences=[]
    for dataset in datasets:
      with open('/content/{}'.format(dataset),'r') as f:
        for line in f:
          if line == '\n':
              sentences.append(sentence)
              sentence=[]
          else:
              sentence.append(line)

    for sent in range(len(sentences)):
      for word in range(len(sentences[sent])):
          sentences[sent][word] = str(sentences[sent][word]).replace('\t',' ')
          sentences[sent][word] = str(sentences[sent][word]).rstrip('\n')
          sentences[sent][word]= str(sentences[sent][word]).split()

    sentenceslabels =[]
    sentencestext =[]

    placeholder0=[]
    placeholder1=[]

    for sent in range(len(sentences)):
      for word in range(len(sentences[sent])):
          placeholder0.append(sentences[sent][word][1])
          placeholder1.append(sentences[sent][word][0])

      sentenceslabels.append(placeholder0)
      sentencestext.append(placeholder1)
      placeholder0=[]
      placeholder1=[]

    joinedlist =[]
    for i in range(len(sentenceslabels)-1):
      joinedlist.extend(sentenceslabels[i])

    tags_vals = list(set(joinedlist))

    tags_vals.append('X')
    tags_vals.append('[CLS]')
    tags_vals.append('[SEP]')

    tag2idx = {t: i for i, t in enumerate(tags_vals)}
    tag2name={tag2idx[key] : key for key in tag2idx.keys()}


    return (sentencestext,sentenceslabels,tags_vals,tag2idx,tag2name)

# %%
def format_time(elapsed):
    '''
    Takes a time in seconds and returns a string hh:mm:ss
    '''
    # Round to the nearest second.
    elapsed_rounded = int(round((elapsed)))

    # Format as hh:mm:ss
    return str(datetime.timedelta(seconds=elapsed_rounded))

# %%
def extract_dict_with_frequency_of_UNKwords():
    '''return a dict with frequency of UNKwords that satisfy a condition'''

    my_list = []
    for word_list,label in (zip(sentences,labels)):
        for word,lab in zip(word_list,label):
            token_list = tokenizer.tokenize(word)
            if token_list == ['[UNK]'] and lab != 'O' and len(word)>= 6:
                my_list.append(word)
    freq = {}
    for item in my_list:
        if (item in freq):
            freq[item] += 1
        else:
            freq[item] = 1

    for key, value in freq.items():
        print ("% s : % d"%(key, value))
    return freq

# %%
def addUNKtokenstovocab(freqdict):
    '''add the words of freq dict to vocab'''
    list1 = list(freqdict.keys())
    for word in list1:
        tokenizer.add_tokens(word)
    print(list1)

# %%
def maketextuallyreadforinput(sentences,labels):
    tokenized_texts = []
    word_piece_labels = []

    i_inc = 0

    for word_list,label in (zip(sentences,labels)):
    #temp label and temp token are the 1 sentence labels and tokens

        temp_label = []
        temp_token = []

        # Add [CLS] at the front
        temp_label.append('[CLS]')
        temp_token.append('[CLS]')

        for word,lab in zip(word_list,label):
            token_list = tokenizer.tokenize(word)
            for m,token in enumerate(token_list):
                temp_token.append(token)
                if m==0:
                    temp_label.append(lab)
                else:
                    temp_label.append('X')

        # Add [SEP] at the end
        temp_label.append('[SEP]')
        temp_token.append('[SEP]')

        tokenized_texts.append(temp_token)
        word_piece_labels.append(temp_label)

        if 50 > i_inc >= 0:
            print("No.%d,len:%d"%(i_inc,len(temp_token)))
            print("texts:%s"%(" ".join(temp_token)))
            print("No.%d,len:%d"%(i_inc,len(temp_label)))
            print("lables:%s"%(" ".join(temp_label)))
        i_inc +=1

    return (tokenized_texts,word_piece_labels)

# %%
def convertokens(max_len,tokenized_texts,word_piece_labels,sentences):
    # Do-something if <condition>, else do-something else.
    input_ids = pad_sequences([tokenizer.convert_tokens_to_ids(txt) for txt in tokenized_texts],
                        maxlen=max_len, dtype="long", truncating="post", padding="post")

    tags = pad_sequences([[tag2idx.get(l) for l in lab] for lab in word_piece_labels],
                  maxlen=max_len, value=tag2idx["O"], padding="post",
                  dtype="long", truncating="post")


    attention_masks_deprecated = [[int(i>0) for i in ii] for ii in input_ids]
    segment_ids = [[0] * len(input_id) for input_id in input_ids]

    allsentences = []
    for sentence in sentences:
        sentence = ' '.join(sentence)
    #     print(sentence)
        allsentences.append(sentence)

    attention_masks = pad_sequences(tokenizer.batch_encode_plus(allsentences)['attention_mask'],
                            maxlen=max_len, dtype="long", truncating="post", padding="post")

#     print(pad_sequences(tokenizer.batch_encode_plus(sentences)['input_ids'][0:2],
#                             maxlen=max_len, dtype="long", truncating="post", padding="post"))

    return (input_ids,tags,attention_masks,segment_ids, attention_masks_deprecated)

# %%
def split_tensor_dataloader(input_ids, tags, attention_masks, segment_ids,batch_num, sizeoftest, sizeofdev):

    tr_inputs, test_inputs, tr_tags, test_tags,tr_masks, test_masks,tr_segs, test_segs = train_test_split(input_ids, tags, attention_masks, segment_ids,
                                                            random_state=1, test_size=sizeoftest)

    tr_inputs, val_inputs, tr_tags, val_tags,tr_masks, val_masks,tr_segs, val_segs = train_test_split(tr_inputs, tr_tags, tr_masks, tr_segs,
                                                            random_state=1, test_size=sizeofdev)

    tr_inputs = torch.tensor(tr_inputs)
    val_inputs = torch.tensor(val_inputs)
    test_inputs = torch.tensor(test_inputs)

    tr_tags = torch.tensor(tr_tags)
    val_tags = torch.tensor(val_tags)
    test_tags = torch.tensor(test_tags)

    tr_masks = torch.tensor(tr_masks)
    val_masks = torch.tensor(val_masks)
    test_masks = torch.tensor(test_masks)

    tr_segs = torch.tensor(tr_segs)
    val_segs = torch.tensor(val_segs)
    test_segs = torch.tensor(test_segs)




    # Only set token embedding, attention embedding, no segment embedding
    train_data = TensorDataset(tr_inputs, tr_masks, tr_tags)
    train_sampler = RandomSampler(train_data)
    # Drop last can make batch training better for the last one
    train_dataloader = DataLoader(train_data, sampler=train_sampler, batch_size=batch_num,drop_last=True)

    #same for validation data
    valid_data = TensorDataset(val_inputs, val_masks, val_tags)
    valid_sampler = SequentialSampler(valid_data)
    valid_dataloader = DataLoader(valid_data, sampler=valid_sampler, batch_size=batch_num)

    test_data = TensorDataset(test_inputs, test_masks, test_tags)
    test_sampler = RandomSampler(test_data)
    # Drop last can make batch training better for the last one
    test_dataloader = DataLoader(test_data, sampler=test_sampler, batch_size=batch_num,drop_last=True)



    return (train_dataloader,valid_dataloader,test_dataloader,tr_inputs,val_inputs,test_inputs)

# %%
def makemodelreadyfortraining(FULL_FINETUNING):


    # Cacluate train optimization num
    num_train_optimization_steps = int( math.ceil(len(tr_inputs) / batch_num) / 1) * epochs


    # True: fine tuning all the layers
    # False: only fine tuning the classifier layers
    if FULL_FINETUNING:
      # Fine tune model all layer parameters
        param_optimizer = list(model.named_parameters()) # list with named parameters and parameters themselves
        no_decay = ['bias', 'gamma', 'beta']

        # list of 2 dicts; only weight decay rate is different : dict_keys(['params', 'weight_decay_rate', 'lr', 'betas', 'eps', 'weight_decay', 'correct_bias'])
        optimizer_grouped_parameters = [
          {'params': [p for n, p in param_optimizer if not any(nd in n for nd in no_decay)],
          'weight_decay_rate': 0.01},
          {'params': [p for n, p in param_optimizer if any(nd in n for nd in no_decay)],
          'weight_decay_rate': 0.0}]

    else:
      # Only fine tune classifier parameters
        param_optimizer = list(model.classifier.named_parameters())
        optimizer_grouped_parameters = [{"params": [p for n, p in param_optimizer]}]

    return (optimizer_grouped_parameters, num_train_optimization_steps)

# %% [markdown]
# # 2. Load data, load model and parameter specification

# %%
#load data:
(sentences,labels,tags_vals,tag2idx,tag2name) = loadandformat(['train.txt','dev.txt','test.txt']) # 'train.txt' 'dev.txt','test.txt'

# %%
tag2name
# Out:
# {0: 'O',
#  1: 'I-treatment',
#  2: 'B-treatment',
#  3: 'B-problem',
#  4: 'B-test',
#  5: 'I-test',
#  6: 'I-problem',
#  7: 'X',
#  8: '[CLS]',
#  9: '[SEP]'}

# %%
#set parameters
epochs = 2
batch_num = 8
learningrate=5e-5

max_grad_norm = 1.0
sizeoftest =0.25#size of test set (first split)
sizeofdev =0.2 #size of dev set (second split)
FULL_FINETUNING = True #Whether to tune all or last layer(s)

# %%
#model

# Load model directly
from transformers import AutoTokenizer, AutoModelForMaskedLM

tokenizer = AutoTokenizer.from_pretrained("dmis-lab/biobert-base-cased-v1.2")
model = AutoModelForMaskedLM.from_pretrained("dmis-lab/biobert-base-cased-v1.2")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:72: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.11k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/436M [00:00<?, ?B/s]
# Some weights of the model checkpoint at dmis-lab/biobert-base-cased-v1.2 were not used when initializing BertForMaskedLM: ['bert.pooler.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'bert.pooler.dense.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
import re

text = '''
Admission   O
Date   O
:   O

2012-10-31   O
PAD-WORD   O

Discharge   O
Date   O
:   O

2012-11-07   O
PAD-WORD   O

Date   O
of   O
Birth   O
:   O

1941-03-23   O
PAD-WORD   O

Sex   O
:   O

M   O
PAD-WORD   O

Service   O
:   O

MEDICINE   O
PAD-WORD   O

Allergies   O
:   O

Nsaids/Anti-Inflammatory   B-treatment
Classifier   I-treatment
/   O
Vancomycin   B-treatment

Attending   O
:   O

Kristie   O
R.   O
Hamby   O
,   O
M.D.   O

Chief   O
Complaint   O
:   O

CC   O
:   O
Antonio   O
M.   O
Z.   O
Eddings   O
,   O
M.D.   O

Major   O
Surgical   O
or   O
Invasive   O
Procedure   O
:   O

Mesenteric   B-test
angiograpm   I-test
w/   O
coil   B-treatment
embolization   I-treatment
of   O
bleeding   B-problem
vessel   I-problem
.   O

Sigmoidoscopy   B-test
.   O

Colonoscopy   B-test
.   O
'''

text = re.sub(r'\s+', ' ', text).strip()

tokens = text.split(' ')

result = []
for i in range(len(tokens)):
  if i % 2 == 0:
    result.append((tokens[i], 'O'))
  else:
    result.append((tokens[i], tokens[i-1]))

print(result)
# Out:
# [('Admission', 'O'), ('O', 'Admission'), ('Date', 'O'), ('O', 'Date'), (':', 'O'), ('O', ':'), ('2012-10-31', 'O'), ('O', '2012-10-31'), ('PAD-WORD', 'O'), ('O', 'PAD-WORD'), ('Discharge', 'O'), ('O', 'Discharge'), ('Date', 'O'), ('O', 'Date'), (':', 'O'), ('O', ':'), ('2012-11-07', 'O'), ('O', '2012-11-07'), ('PAD-WORD', 'O'), ('O', 'PAD-WORD'), ('Date', 'O'), ('O', 'Date'), ('of', 'O'), ('O', 'of'), ('Birth', 'O'), ('O', 'Birth'), (':', 'O'), ('O', ':'), ('1941-03-23', 'O'), ('O', '1941-03-23'), ('PAD-WORD', 'O'), ('O', 'PAD-WORD'), ('Sex', 'O'), ('O', 'Sex'), (':', 'O'), ('O', ':'), ('M', 'O'), ('O', 'M'), ('PAD-WORD', 'O'), ('O', 'PAD-WORD'), ('Service', 'O'), ('O', 'Service'), (':', 'O'), ('O', ':'), ('MEDICINE', 'O'), ('O', 'MEDICINE'), ('PAD-WORD', 'O'), ('O', 'PAD-WORD'), ('Allergies', 'O'), ('O', 'Allergies'), (':', 'O'), ('O', ':'), ('Nsaids/Anti-Inflammatory', 'O'), ('B-treatment', 'Nsaids/Anti-Inflammatory'), ('Classifier', 'O'), ('I-treatment', 'Classifier'), ('/', 'O'), ('O', '/'), ('Vancomycin', 'O'), ('B-treatment', 'Vancomycin'), ('Attending', 'O'), ('O', 'Attending'), (':', 'O'), ('O', ':'), ('Kristie', 'O'), ('O', 'Kristie'), ('R.', 'O'), ('O', 'R.'), ('Hamby', 'O'), ('O', 'Hamby'), (',', 'O'), ('O', ','), ('M.D.', 'O'), ('O', 'M.D.'), ('Chief', 'O'), ('O', 'Chief'), ('Complaint', 'O'), ('O', 'Complaint'), (':', 'O'), ('O', ':'), ('CC', 'O'), ('O', 'CC'), (':', 'O'), ('O', ':'), ('Antonio', 'O'), ('O', 'Antonio'), ('M.', 'O'), ('O', 'M.'), ('Z.', 'O'), ('O', 'Z.'), ('Eddings', 'O'), ('O', 'Eddings'), (',', 'O'), ('O', ','), ('M.D.', 'O'), ('O', 'M.D.'), ('Major', 'O'), ('O', 'Major'), ('Surgical', 'O'), ('O', 'Surgical'), ('or', 'O'), ('O', 'or'), ('Invasive', 'O'), ('O', 'Invasive'), ('Procedure', 'O'), ('O', 'Procedure'), (':', 'O'), ('O', ':'), ('Mesenteric', 'O'), ('B-test', 'Mesenteric'), ('angiograpm', 'O'), ('I-test', 'angiograpm'), ('w/', 'O'), ('O', 'w/'), ('coil', 'O'), ('B-treatment', 'coil'), ('embolization', 'O'), ('I-treatment', 'embolization'), ('of', 'O'), ('O', 'of'), ('bleeding', 'O'), ('B-problem', 'bleeding'), ('vessel', 'O'), ('I-problem', 'vessel'), ('.', 'O'), ('O', '.'), ('Sigmoidoscopy', 'O'), ('B-test', 'Sigmoidoscopy'), ('.', 'O'), ('O', '.'), ('Colonoscopy', 'O'), ('B-test', 'Colonoscopy'), ('.', 'O'), ('O', '.')]

# %%
a=[result[i] for i in range(0,len(result),2)]
a
# Out:
# [('Admission', 'O'),
#  ('Date', 'O'),
#  (':', 'O'),
#  ('2012-10-31', 'O'),
#  ('PAD-WORD', 'O'),
#  ('Discharge', 'O'),
#  ('Date', 'O'),
#  (':', 'O'),
#  ('2012-11-07', 'O'),
#  ('PAD-WORD', 'O'),
#  ('Date', 'O'),
#  ('of', 'O'),
#  ('Birth', 'O'),
#  (':', 'O'),
#  ('1941-03-23', 'O'),
#  ('PAD-WORD', 'O'),
#  ('Sex', 'O'),
#  (':', 'O'),
#  ('M', 'O'),
#  ('PAD-WORD', 'O'),
#  ('Service', 'O'),
#  (':', 'O'),
#  ('MEDICINE', 'O'),
#  ('PAD-WORD', 'O'),
#  ('Allergies', 'O'),
#  (':', 'O'),
#  ('Nsaids/Anti-Inflammatory', 'O'),
#  ('Classifier', 'O'),
#  ('/', 'O'),
#  ('Vancomycin', 'O'),
#  ('Attending', 'O'),
#  (':', 'O'),
#  ('Kristie', 'O'),
#  ('R.', 'O'),
#  ('Hamby', 'O'),
#  (',', 'O'),
#  ('M.D.', 'O'),
#  ('Chief', 'O'),
#  ('Complaint', 'O'),
#  (':', 'O'),
#  ('CC', 'O'),
#  (':', 'O'),
#  ('Antonio', 'O'),
#  ('M.', 'O'),
#  ('Z.', 'O'),
#  ('Eddings', 'O'),
#  (',', 'O'),
#  ('M.D.', 'O'),
#  ('Major', 'O'),
#  ('Surgical', 'O'),
#  ('or', 'O'),
#  ('Invasive', 'O'),
#  ('Procedure', 'O'),
#  (':', 'O'),
#  ('Mesenteric', 'O'),
#  ('angiograpm', 'O'),
#  ('w/', 'O'),
#  ('coil', 'O'),
#  ('embolization', 'O'),
#  ('of', 'O'),
#  ('bleeding', 'O'),
#  ('vessel', 'O'),
#  ('.', 'O'),
#  ('Sigmoidoscopy', 'O'),
#  ('.', 'O'),
#  ('Colonoscopy', 'O'),
#  ('.', 'O')]

# %% [markdown]
# # 3. Function calls

# %%
# extract frequent OOV words and add them to vocab of tokenizer
freq_dict = extract_dict_with_frequency_of_UNKwords()
addUNKtokenstovocab(freq_dict)
# Out:
# []

# %%
(tokenized_texts,word_piece_labels) = maketextuallyreadforinput(sentences,labels)
max_len  = len(max(tokenized_texts, key=len))
# max_len = 150
# Out:
# No.0,len:31
# texts:[CLS] after being transferred from the intervention ##al radio ##logy table to the stretch ##er , one of his lateral per ##cut ##aneous drains had been pulled out inadvertently . [SEP]
# No.0,len:31
# lables:[CLS] O O O O O O X O X O O O O X O O O B-treatment I-treatment I-treatment X X I-treatment O O O O O O [SEP]
# No.1,len:28
# texts:[CLS] he was admitted to the re ##tel ##k county medical center at that time and was treated with b ##act ##rim and s ##tero ##ids . [SEP]
# No.1,len:28
# lables:[CLS] O O O O O O X X O O O O O O O O O O B-treatment X X O B-treatment X X O [SEP]
# No.2,len:13
# texts:[CLS] she was seen by the ps ##ych ##ia ##try service . [SEP]
# No.2,len:13
# lables:[CLS] O O O O O B-treatment X X X I-treatment O [SEP]
# No.3,len:10
# texts:[CLS] 1958 - 03 - 17 pad - word [SEP]
# No.3,len:10
# lables:[CLS] O X X X X O X X [SEP]
# No.4,len:8
# texts:[CLS] 435 ##13 ##42 pad - word [SEP]
# No.4,len:8
# lables:[CLS] O X X O X X [SEP]
# No.5,len:15
# texts:[CLS] - al ##but ##ero ##l / at ##rove ##nt ne ##bs q ##4 [SEP]
# No.5,len:15
# lables:[CLS] O B-treatment X X X O B-treatment X X O X O X [SEP]
# No.6,len:20
# texts:[CLS] patient was also found to have abnormal t ##fts on su ##ten ##t and was started on replacement [SEP]
# No.6,len:20
# lables:[CLS] O O O O O O B-problem I-problem X O B-treatment X X O O O O B-treatment [SEP]
# No.7,len:23
# texts:[CLS] she has on her right ankle anterior ##ly a four cent ##imeter ul ##cer with ne ##c ##rot ##ic base . [SEP]
# No.7,len:23
# lables:[CLS] O O O O O O O X B-problem I-problem I-problem X I-problem X I-problem I-problem X X X I-problem O [SEP]
# No.8,len:6
# texts:[CLS] signed pad - word [SEP]
# No.8,len:6
# lables:[CLS] O O X X [SEP]
# No.9,len:28
# texts:[CLS] he had a left pupil that was in une ##qua ##l in size with a key ##hole appearance consistent with a co ##lo ##bo ##ma . [SEP]
# No.9,len:28
# lables:[CLS] O O O O O O O O B-problem X X I-problem I-problem O B-problem I-problem X I-problem O O B-problem I-problem X X X O [SEP]
# No.10,len:9
# texts:[CLS] 38 ##38 ##55 ##6 pad - word [SEP]
# No.10,len:9
# lables:[CLS] O X X X O X X [SEP]
# No.11,len:7
# texts:[CLS] reason for over ##ride : [SEP]
# No.11,len:7
# lables:[CLS] O O O X O [SEP]
# No.12,len:22
# texts:[CLS] the was trace mit ##ral re ##gu ##rg ##itation and trace t ##ric ##us ##pid re ##gu ##rg ##itation . [SEP]
# No.12,len:22
# lables:[CLS] O O B-problem I-problem X I-problem X X X O B-problem I-problem X X X I-problem X X X O [SEP]
# No.13,len:21
# texts:[CLS] 3rd floor he ##nders ##on building with d ##r . black ( 650 ) 86 ##6 - 136 ##1 [SEP]
# No.13,len:21
# lables:[CLS] O O O X X O O O X X O O O O O X X X X [SEP]
# No.14,len:12
# texts:[CLS] full term male infant with c ##yan ##osis episodes . [SEP]
# No.14,len:12
# lables:[CLS] O O O O O B-problem X X I-problem O [SEP]
# No.15,len:20
# texts:[CLS] the patient had no blood cultures to grow co ##ryn ##eb ##act ##eri ##um while hospital ##ized . [SEP]
# No.15,len:20
# lables:[CLS] O O O O B-test I-test O O B-problem X X X X X O O X O [SEP]
# No.16,len:20
# texts:[CLS] there is a linear right temporal ca ##l ##var ##ial fracture extending into the right temporal bones . [SEP]
# No.16,len:20
# lables:[CLS] O O B-problem I-problem I-problem I-problem I-problem X X X I-problem O O O O O O O [SEP]
# No.17,len:8
# texts:[CLS] there was no he ##ave . [SEP]
# No.17,len:8
# lables:[CLS] O O O B-problem X O [SEP]
# No.18,len:12
# texts:[CLS] 4 . non ##ins ##ulin dependent diabetes me ##lli ##tus [SEP]
# No.18,len:12
# lables:[CLS] O X B-problem X X I-problem I-problem I-problem X X [SEP]
# No.19,len:13
# texts:[CLS] 6 / 15 / 1994 12 : 00 : 00 am [SEP]
# No.19,len:13
# lables:[CLS] O X X X X O X X X X O [SEP]
# No.20,len:32
# texts:[CLS] on 2014 - 04 - 09 , patient continued to do very well , am ##bula ##ting , to ##ler ##ating a diet , u ##rina ##ting without difficulty . [SEP]
# No.20,len:32
# lables:[CLS] O O X X X X O O O O O O O O O X X O O X X O O O O X X O B-problem O [SEP]
# No.21,len:28
# texts:[CLS] c ##i ##wa scale over night was 1 for t ##rem ##or and the patient did not require any v ##ali ##um for alcohol withdrawal . [SEP]
# No.21,len:28
# lables:[CLS] B-test X X I-test O O O O O B-problem X X O O O O O O O B-treatment X X O B-problem I-problem O [SEP]
# No.22,len:17
# texts:[CLS] patient has a history of su ##icidal idea ##tions and self m ##uti ##lation . [SEP]
# No.22,len:17
# lables:[CLS] O O O O O B-problem X I-problem X O B-problem I-problem X X O [SEP]
# No.23,len:49
# texts:[CLS] 9 . i ##pra ##tro ##pi ##um br ##omi ##de 17 m ##c ##g / act ##uation a ##ero ##sol si ##g : two ( 2 ) pu ##ff in ##hala ##tion q ##4 - 6 ##h ( every 4 to 6 hours ) as needed . [SEP]
# No.23,len:49
# lables:[CLS] O X B-treatment X X X X I-treatment X X O O X X O O X O X X O X O O O O O O X O X X O X X X X O O O O O O O O O O [SEP]
# No.24,len:8
# texts:[CLS] h / o et ##oh abuse [SEP]
# No.24,len:8
# lables:[CLS] O X X O X O [SEP]
# No.25,len:4
# texts:[CLS] batch : [SEP]
# No.25,len:4
# lables:[CLS] O O [SEP]
# No.26,len:4
# texts:[CLS] provider : [SEP]
# No.26,len:4
# lables:[CLS] O O [SEP]
# No.27,len:10
# texts:[CLS] 2013 - 12 - 24 pad - word [SEP]
# No.27,len:10
# lables:[CLS] O X X X X O X X [SEP]
# No.28,len:51
# texts:[CLS] the patient is a 40 year old male with a history of prior anterior my ##oc ##ard ##ial in ##far ##ction and insulin dependent diabetes me ##lli ##tus who was transferred from an outside hospital after an episode of acute short ##ness of breath and pulmonary ed ##ema . [SEP]
# No.28,len:51
# lables:[CLS] O O O O O O O O O O O O B-problem I-problem I-problem X X X I-problem X X O B-problem I-problem I-problem I-problem X X O O O O O O O O O O O B-problem I-problem X I-problem I-problem O B-problem I-problem X O [SEP]
# No.29,len:13
# texts:[CLS] 05 / 09 / 2004 12 : 00 : 00 am [SEP]
# No.29,len:13
# lables:[CLS] O X X X X O X X X X O [SEP]
# No.30,len:26
# texts:[CLS] the patient was corrected to a normal p ##h of 7 . 41 by the first post ##oper ##ative night and remained stable . [SEP]
# No.30,len:26
# lables:[CLS] O O O O O O O O X O O X X O O O O X X O O O O O [SEP]
# No.31,len:6
# texts:[CLS] past medical history : [SEP]
# No.31,len:6
# lables:[CLS] O O O O [SEP]
# No.32,len:11
# texts:[CLS] 64 ##2 - 07 - 90 pad - word [SEP]
# No.32,len:11
# lables:[CLS] O X X X X X O X X [SEP]
# No.33,len:22
# texts:[CLS] he was admitted on 06 / 07 / 00 for a matched , unrelated donor bone ma ##rrow transplant . [SEP]
# No.33,len:22
# lables:[CLS] O O O O O X X X X O B-treatment I-treatment I-treatment I-treatment I-treatment I-treatment I-treatment X I-treatment O [SEP]
# No.34,len:27
# texts:[CLS] a ##b ##d : soft , + di ##sten ##sion with t ##ym ##pan ##y , no h ##sm , h ##yper ##active b ##s [SEP]
# No.34,len:27
# lables:[CLS] O X X O O O B-problem X X X O B-problem X X X O O B-problem X O B-problem X X I-problem X [SEP]
# No.35,len:9
# texts:[CLS] the patient is hard of hearing . [SEP]
# No.35,len:9
# lables:[CLS] O O O B-problem I-problem I-problem O [SEP]
# No.36,len:12
# texts:[CLS] d : 2016 - 11 - 10 18 : 28 [SEP]
# No.36,len:12
# lables:[CLS] O O O X X X X O X X [SEP]
# No.37,len:7
# texts:[CLS] ( end of report ) [SEP]
# No.37,len:7
# lables:[CLS] O O O O O [SEP]
# No.38,len:8
# texts:[CLS] major surgical or invasive procedure : [SEP]
# No.38,len:8
# lables:[CLS] O O O O O O [SEP]
# No.39,len:7
# texts:[CLS] ne ##uro ##log ##ic : [SEP]
# No.39,len:7
# lables:[CLS] O X X X O [SEP]
# No.40,len:4
# texts:[CLS] general : [SEP]
# No.40,len:4
# lables:[CLS] O O [SEP]
# No.41,len:44
# texts:[CLS] he had a past history of is ##che ##mic card ##io ##my ##op ##athy with an e ##jection fraction of 10 , mild a ##ort ##ic s ##ten ##osis and a right middle cerebral artery territory stroke in 07 / 94 . [SEP]
# No.41,len:44
# lables:[CLS] O O O O O O B-problem X X I-problem X X X X O B-test I-test X I-test O O O B-problem I-problem X X I-problem X X O B-problem I-problem I-problem I-problem I-problem I-problem I-problem O O X X O [SEP]
# No.42,len:18
# texts:[CLS] the patient was discharged to home for ho ##sp ##ice on march 8 , 1999 . [SEP]
# No.42,len:18
# lables:[CLS] O O O O O O O B-treatment X X O O O O O O [SEP]
# No.43,len:23
# texts:[CLS] the cause of this er ##yt ##hem ##a is not know at this time but has not shown extensive progression . [SEP]
# No.43,len:23
# lables:[CLS] O O O B-problem I-problem X X X O O O O O O O O O O O O O [SEP]
# No.44,len:30
# texts:[CLS] in regards to his rhythm , he has an underlying right bundle branch block and first - degree a ##v block which were stable throughout this admission . [SEP]
# No.44,len:30
# lables:[CLS] O O O O O O O O B-problem I-problem I-problem I-problem I-problem I-problem O B-problem X X I-problem X I-problem O O O O O O O [SEP]
# No.45,len:5
# texts:[CLS] job # : [SEP]
# No.45,len:5
# lables:[CLS] O O X [SEP]
# No.46,len:12
# texts:[CLS] na ##ncy lo ##is m ##d 88 - 44 ##9 [SEP]
# No.46,len:12
# lables:[CLS] O X O X O X O X X X [SEP]
# No.47,len:14
# texts:[CLS] c ##rani ##al nerves notable for bilateral es ##ot ##rop ##ia . [SEP]
# No.47,len:14
# lables:[CLS] O X X O O O B-problem I-problem X X X O [SEP]
# No.48,len:15
# texts:[CLS] he is admitted at this time because of significant g ##i bleeding . [SEP]
# No.48,len:15
# lables:[CLS] O O O O O O O O B-problem I-problem X I-problem O [SEP]
# No.49,len:5
# texts:[CLS] code status : [SEP]
# No.49,len:5
# lables:[CLS] O O O [SEP]

# %%
(input_ids,tags,attention_masks,segment_ids,attention_masks_deprecated) = convertokens(max_len,tokenized_texts,word_piece_labels,sentences)

# %%
(train_dataloader,valid_dataloader,test_dataloader,tr_inputs,val_inputs,test_inputs) = split_tensor_dataloader(input_ids, tags, attention_masks, segment_ids,batch_num, sizeoftest, sizeofdev)

# %%
optimizer = AdamW(model.parameters(), lr=learningrate)
total_steps = len(train_dataloader) * epochs
scheduler = get_linear_schedule_with_warmup(optimizer,
                                            num_warmup_steps = 0, # default
                                            num_training_steps = total_steps)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %% [markdown]
# # 4. Training

# %%
#extend embedding matrix with new vocab
model.resize_token_embeddings(len(tokenizer))
# Out:
# Embedding(28996, 768, padding_idx=0)

# %%
if n_gpu >1:
    model = torch.nn.DataParallel(model)

# %%
print("***** Training Info *****")
print("  Num examples = %d"%(len(tr_inputs)))
print("  Batch size = %d"%(batch_num))
print("  Num steps = %d"%(total_steps))
# Out:
# ***** Training Info *****
#   Num examples = 9800
#   Batch size = 8
#   Num steps = 2450

# %%
seed_val = 10
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)

loss_values = []
training_stats = []

total_t0 = time.time()
# for _ in trange(epochs,desc=" Epoch"):
for _ in range(epochs):

    print("")
    print('======== Epoch {:} / {:} ========'.format(_+1, epochs))
    print('\033[1m'+'Training...'+ '\033[0m')

    model.train()
    # Set model to GPU,if you are using GPU machine
    model.cuda()

    t0 = time.time()


    tr_loss = 0 # total training loss for one epoch
    nb_tr_examples, nb_tr_steps = 0, 0

    for step, batch in enumerate(train_dataloader):
        # add batch to gpu
        batch = tuple(t.to(device) for t in batch)
        b_input_ids, b_input_mask, b_labels = batch

        model.zero_grad()

        # forward pass
        outputs = model(b_input_ids, token_type_ids=None,
        attention_mask=b_input_mask, labels=b_labels)

        loss, scores = outputs[:2]
        if n_gpu>1:
            # When multi gpu, average it
            loss = loss.mean()

        # backward pass
        loss.backward()

        # track train loss:
        #Accumulate the training loss over all of the batches so that we can calculate the average loss at the end.
        tr_loss += loss.item()
        nb_tr_steps += 1

        # gradient clipping
        torch.nn.utils.clip_grad_norm_(parameters=model.parameters(), max_norm=max_grad_norm)

        # update parameters
        optimizer.step()
        # Update the learning rate.
        scheduler.step()

        optimizer.zero_grad()


    print("")
    print("Epoch finished (training progress):")
    # average the training loss
    avg_train_loss = tr_loss/nb_tr_steps
    print("   Train loss: {}".format(avg_train_loss))
    training_time = format_time(time.time() - t0)
    print("   Training epoch took: {:}".format(training_time))

    # Store the loss value for plotting the learning curve.
    loss_values.append(avg_train_loss)


    #eval LOOP
    total_eval_loss, eval_accuracy = 0, 0
    nb_eval_steps, nb_eval_examples = 0, 0
    y_true = []
    y_pred = []
    valdataset = []

    y_true_full = []
    y_pred_full = []
    valdataset_full = []

    t0 = time.time()

    model.eval()

    for step, batch in enumerate(valid_dataloader):
        batch = tuple(t.to(device) for t in batch)
        input_ids, input_mask, label_ids = batch #same as we did in training loop but only 1 epoch now


        with torch.no_grad(): #means we don't care about gradients and updating tensors
            outputs = model(input_ids, token_type_ids=None,
            attention_mask=input_mask,labels=label_ids)
            # For eval mode, the first result of outputs is logits (for training mode this was loss)
#             logits = outputs[0]
            loss, logits = outputs[:2]#  In context of deep learning the logits layer means the layer that feeds in to softmax (or other such normalization).

        loss = loss.mean()
        total_eval_loss += loss.item()


        # Get NER predict result
        logits = torch.argmax(F.log_softmax(logits,dim=2),dim=2)#feed logits into softmax and take the prediction that is maximal
        logits = logits.detach().cpu().numpy()

        # Get NER true result
        label_ids = label_ids.to('cpu').numpy()

        # Only predict the real word, mark=0, will not calculate
        input_mask = input_mask.to('cpu').numpy()


        # Compare the valuable predict result
        for i,mask in enumerate(input_mask):
            # Real one
            temp_1 = []
            # Predicted one
            temp_2 = []
            valtemp = []

            temp_1_full = []
            # Predicted one
            temp_2_full = []
            valtemp_full = []

            for j, m in enumerate(mask):
                # Mark=0, meaning its a pad word, dont compare
                if m :
                    if tag2name[label_ids[i][j]] != "X" and tag2name[label_ids[i][j]] != "[CLS]" and tag2name[label_ids[i][j]] != "[SEP]" : # Exclude the X label
                        temp_1.append(tag2name[label_ids[i][j]])
                        temp_2.append(tag2name[logits[i][j]])
                        valtemp.append(input_ids[i][j].item())

                    if tag2name[label_ids[i][j]] != "[CLS]" and tag2name[label_ids[i][j]] != "[SEP]" : # Exclude the X label
                        temp_1_full.append(tag2name[label_ids[i][j]])
                        temp_2_full.append(tag2name[logits[i][j]])
                        valtemp_full.append(input_ids[i][j].item())

                else:
                    break

            #here are the two lists that contain true and pred labels.
            y_true.append(temp_1)
            y_pred.append(temp_2)
            valdataset.append(valtemp)


            y_true_full.append(temp_1_full)
            y_pred_full.append(temp_2_full)
            valdataset_full.append(valtemp_full)


    avg_val_loss = total_eval_loss / len(valid_dataloader)
    validation_time = format_time(time.time() - t0)

    print("")
    print('\033[1m'+"Running Validation..."+ '\033[0m')
    print("  (Num examples ={})".format(len(val_inputs)))
    print("  (Batch size = {})\n".format(batch_num))
    print("   Validation loss: {}".format(avg_val_loss))
    print("   F1-score: %f"%(f1_score(y_true, y_pred)))
    print("   Accuracy: %f"%(accuracy_score(y_true, y_pred)))
    print("   Validation took: {:}".format(validation_time))

    training_stats.append(
        {   'epoch': _ + 1,
            'Training Loss': avg_train_loss,
            'Valid. Loss': avg_val_loss,
            'Valid. Accur.': accuracy_score(y_true, y_pred),
            'Training Time' : training_time,
            'Validation Time' : validation_time })


print('Training complete')
print("Total training took {:} (h:mm:ss)".format(format_time(time.time()-total_t0)))
# Out:
# ======== Epoch 1 / 2 ========
# Training...
#
# Epoch finished (training progress):
#    Train loss: 0.06792500809046478
#    Training epoch took: 0:10:57
#
# Running Validation...
#   (Num examples =2450)
#   (Batch size = 8)
#
#    Validation loss: 0.006450671389212086
#    F1-score: 0.813394
#    Accuracy: 0.944531
#    Validation took: 0:01:00
#
# ======== Epoch 2 / 2 ========
# Training...
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: X seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: [SEP] seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# Epoch finished (training progress):
#    Train loss: 0.003447266717441974
#    Training epoch took: 0:11:10
#
# Running Validation...
#   (Num examples =2450)
#   (Batch size = 8)
#
#    Validation loss: 0.005641483895739723
#    F1-score: 0.841638
#    Accuracy: 0.952511
#    Validation took: 0:00:59
# Training complete
# Total training took 0:24:06 (h:mm:ss)

# %% [markdown]
# # 5. Evaluation on Validation set

# %%
report = classification_report(y_true, y_pred,digits=4)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            _     0.0000    0.0000    0.0000         0
#      problem     0.8327    0.8836    0.8574      1065
#         test     0.8435    0.8525    0.8480       746
#    treatment     0.8059    0.8396    0.8224       717
#
#    micro avg     0.8223    0.8619    0.8416      2528
#    macro avg     0.6205    0.6439    0.6320      2528
# weighted avg     0.8283    0.8619    0.8447      2528
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# without 'O' label
f1_score(y_true,y_pred, average='micro')
# Out:
# 0.8416376979528775

# %%
#table

#pd.set_option('precision', 2)
df_stats = pd.DataFrame(data=training_stats)

# use epoch as row index
df_stats = df_stats.set_index('epoch')

# hack to force the column headers to wrap.
#df = df.style.set_table_styles([dict(selector="th",props=[('max-width', '70px')])])

df_stats
# Out:
#        Training Loss  Valid. Loss  Valid. Accur. Training Time Validation Time
# epoch
# 1           0.067925     0.006451       0.944531       0:10:57         0:01:00
# 2           0.003447     0.005641       0.952511       0:11:10         0:00:59

# %%
#plotting
sns.set(style='darkgrid')
sns.set_palette('plasma')
sns.set(font_scale=1.5)
plt.rcParams["figure.figsize"] = (12,6)


plt.plot(df_stats['Training Loss'], 'b-o', label="Training",marker = 's',markerfacecolor='green',linestyle='--',color='blue')
plt.plot(df_stats['Valid. Loss'], 'g-o', label="Validation",marker = 's',markerfacecolor='green',linestyle='--',color='orange')

plt.title("Training & Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

ls=[]
for i in range(epochs):
    ls.append(i+1)
plt.xticks(ls)

plt.show()
# Out:
# <ipython-input-40-cd185a1fcfb6>:8: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "b-o" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(df_stats['Training Loss'], 'b-o', label="Training",marker = 's',markerfacecolor='green',linestyle='--',color='blue')
# <ipython-input-40-cd185a1fcfb6>:8: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "b-o" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot(df_stats['Training Loss'], 'b-o', label="Training",marker = 's',markerfacecolor='green',linestyle='--',color='blue')
# <ipython-input-40-cd185a1fcfb6>:8: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-o" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(df_stats['Training Loss'], 'b-o', label="Training",marker = 's',markerfacecolor='green',linestyle='--',color='blue')
# <ipython-input-40-cd185a1fcfb6>:9: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "g-o" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(df_stats['Valid. Loss'], 'g-o', label="Validation",marker = 's',markerfacecolor='green',linestyle='--',color='orange')
# <ipython-input-40-cd185a1fcfb6>:9: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "g-o" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot(df_stats['Valid. Loss'], 'g-o', label="Validation",marker = 's',markerfacecolor='green',linestyle='--',color='orange')
# <ipython-input-40-cd185a1fcfb6>:9: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "g-o" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(df_stats['Valid. Loss'], 'g-o', label="Validation",marker = 's',markerfacecolor='green',linestyle='--',color='orange')

# %% [markdown]
# # 6. Evaluation on test set

# %%
print("")
print('\033[1m'+"Running Test..."+ '\033[0m')
t0 = time.time()

y_test_true = []
y_test_pred = []
testdataset = []

y_test_true_full = []
y_test_pred_full = []
testdataset_full = []

model.eval()

for step, batch in enumerate(test_dataloader):
    batch = tuple(t.to(device) for t in batch)
    input_ids, input_mask, label_ids = batch #same as we did in training loop but only 1 epoch now


    with torch.no_grad(): #means we don't care about gradients and updating tensors
        outputs = model(input_ids, token_type_ids=None,
        attention_mask=input_mask,labels=label_ids)
        # For eval mode, the first result of outputs is logits (for training mode this was loss)
#             logits = outputs[0]
        loss, logits = outputs[:2]#  In context of deep learning the logits layer means the layer that feeds in to softmax (or other such normalization).

    loss = loss.mean()
    total_eval_loss += loss.item()


    # Get NER predict result
    logits = torch.argmax(F.log_softmax(logits,dim=2),dim=2)#feed logits into softmax and take the prediction that is maximal
    logits = logits.detach().cpu().numpy()

    # Get NER true result
    label_ids = label_ids.to('cpu').numpy()

    # Only predict the real word, mark=0, will not calculate
    input_mask = input_mask.to('cpu').numpy()


    # Compare the valuable predict result
    for i,mask in enumerate(input_mask):
        # Real one
        temp_1 = []
        # Predicted one
        temp_2 = []
        valtemp = []

        temp_1_full = []
        # Predicted one
        temp_2_full = []
        valtemp_full = []

        for j, m in enumerate(mask):
            # Mark=0, meaning its a pad word, dont compare
            if m :
                if tag2name[label_ids[i][j]] != "X" and tag2name[label_ids[i][j]] != "[CLS]" and tag2name[label_ids[i][j]] != "[SEP]" : # Exclude the X label
                    temp_1.append(tag2name[label_ids[i][j]])
                    temp_2.append(tag2name[logits[i][j]])
                    valtemp.append(input_ids[i][j].item())

                if tag2name[label_ids[i][j]] != "[CLS]" and tag2name[label_ids[i][j]] != "[SEP]" : # Exclude the X label
                    temp_1_full.append(tag2name[label_ids[i][j]])
                    temp_2_full.append(tag2name[logits[i][j]])
                    valtemp_full.append(input_ids[i][j].item())

            else:
                break

        #here are the two lists that contain true and pred labels.
        y_test_true.append(temp_1)
        y_test_pred.append(temp_2)
        testdataset.append(valtemp)

        y_test_true_full.append(temp_1_full)
        y_test_pred_full.append(temp_2_full)
        testdataset_full.append(valtemp_full)


avg_test_loss = total_eval_loss / len(test_dataloader)
test_time = format_time(time.time() - t0)

print("  (Num examples ={})".format(len(test_inputs)))
print("  (Batch size = {})\n".format(batch_num))
print("   Test loss: {}".format(avg_test_loss))
print("   F1-score: %f"%(f1_score(y_test_true, y_test_pred)))
print("   Accuracy: %f"%(accuracy_score(y_test_true, y_test_pred)))
print("   Test took: {:}".format(test_time))
# Out:
# Running Test...
#   (Num examples =4084)
#   (Batch size = 8)
#
#    Test loss: 0.00842615101840541
#    F1-score: 0.844824
#    Accuracy: 0.955847
#    Test took: 0:01:40
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: X seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))

# %%
# classification report is meant for evaluation of tasks like NER (see doc)
# difference between f1_score of scikit-learn and classification_report is that classification_report
# merges B and I, resulting in lower f1
report = classification_report(y_test_true, y_test_pred)
print(report)
# Out:
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            _       0.00      0.00      0.00         0
#      problem       0.83      0.86      0.84      1824
#         test       0.84      0.88      0.86      1182
#    treatment       0.83      0.86      0.84      1233
#
#    micro avg       0.83      0.86      0.84      4239
#    macro avg       0.62      0.65      0.64      4239
# weighted avg       0.83      0.86      0.85      4239

# %%
from sklearn.preprocessing import MultiLabelBinarizer

# %%
mlb = MultiLabelBinarizer()
binary_labels = mlb.fit_transform(labels)

# %%
y_test_true_binary = mlb.fit_transform(y_test_true)

# %%
y_test_true_binary.shape
# Out:
# (4080, 7)

# %%
y_test_pred_binary = mlb.fit_transform(y_test_pred)

# %%
y_test_pred_binary.shape
# Out:
# (4080, 8)

# %%
y_test_pred_binary = y_test_pred_binary[:, :7]

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test_true_binary, y_test_pred_binary))
# Out:
# 0.9144607843137255

# %% [markdown]
# # 7. Predictions of test set - examples

# %%
len(y_test_true[0]),len(y_test_pred[0]), len(testdataset[0])
# Out:
# (19, 19, 19)

# %%
text= [tokenizer.decode(test) for test in testdataset]
tokenized_text_converted = [tokenizer.convert_ids_to_tokens(test) for test in testdataset]

# %%
text_full= [tokenizer.decode(test) for test in testdataset_full]
tokenized_text_converted_full = [tokenizer.convert_ids_to_tokens(test) for test in testdataset_full]

# %%
a = 2
print( '\n' + text_full[a])
print('\033[1m' + "Labels:      " + '\033[0m', y_test_true[a])
print('\033[1m' + "Predictions: "+ '\033[0m',y_test_pred[a])
print('\n')

print(tokenized_text_converted_full[a])
# Out:
# 2019 - 06 - 18 07 : 55 am blood caltibc - 229 ferritn - greater th trf - 176 *
# Labels:       ['O', 'O', 'O', 'O', 'B-test', 'O', 'O', 'B-test', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Predictions:  ['O', 'O', 'O', 'B-test', 'B-test', 'O', 'O', 'B-test', 'O', 'O', 'B-test', 'B-test', 'O', 'O', 'O']
#
#
# ['2019', '-', '06', '-', '18', '07', ':', '55', 'am', 'blood', 'ca', '##lt', '##ib', '##c', '-', '229', 'f', '##er', '##rit', '##n', '-', 'greater', 'th', 't', '##rf', '-', '176', '*']

# %%
a = 7
print( '\n' +text_full[a])
print('\033[1m' + "Labels:      " + '\033[0m', y_test_true[a])
print('\033[1m' + "Predictions: "+ '\033[0m',y_test_pred[a])
print('\n')

print(tokenized_text_converted_full[a])
# Out:
# sigmoidoscopy.
# Labels:       ['B-test', 'O']
# Predictions:  ['B-test', 'O']
#
#
# ['si', '##g', '##mo', '##ido', '##sco', '##py', '.']

# %%
a = 11
print( '\n' +text_full[a])
print('\033[1m' + "Labels:      " + '\033[0m', y_test_true[a])
print('\033[1m' + "Predictions: "+ '\033[0m',y_test_pred[a])
print('\n')

print(tokenized_text_converted_full[a])
# Out:
# initial newborn exam :
# Labels:       ['B-test', 'I-test', 'I-test', 'O']
# Predictions:  ['O', 'O', 'O', 'O']
#
#
# ['initial', 'newborn', 'exam', ':']

# %%
a = 12
print( '\n' +text_full[a])
print('\033[1m' + "Labels:      " + '\033[0m', y_test_true[a])
print('\033[1m' + "Predictions: "+ '\033[0m',y_test_pred[a])
print('\n')

print(tokenized_text_converted_full[a])
# Out:
# 64 - year - old g5p5 postmenopausal for 10 years with a history of two months of progressive abdominal distention, crampy abdominal pain, urinary frequency and diarrhea.
# Labels:       ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-problem', 'I-problem', 'I-problem', 'O', 'B-problem', 'I-problem', 'I-problem', 'O', 'B-problem', 'I-problem', 'O', 'B-problem', 'O']
# Predictions:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-problem', 'I-problem', 'I-problem', 'O', 'B-problem', 'I-problem', 'I-problem', 'O', 'B-problem', 'I-problem', 'O', 'B-problem', 'O']
#
#
# ['64', '-', 'year', '-', 'old', 'g', '##5', '##p', '##5', 'post', '##men', '##op', '##aus', '##al', 'for', '10', 'years', 'with', 'a', 'history', 'of', 'two', 'months', 'of', 'progressive', 'abdominal', 'di', '##sten', '##tion', ',', 'c', '##ram', '##py', 'abdominal', 'pain', ',', 'u', '##rina', '##ry', 'frequency', 'and', 'di', '##ar', '##r', '##hea', '.']

# %%
a = 14
print( '\n' +text_full[a])
print('\033[1m' + "Labels:      " + '\033[0m', y_test_true[a])
print('\033[1m' + "Predictions: "+ '\033[0m',y_test_pred[a])
print('\n')

print(tokenized_text_converted_full[a])
# Out:
# the patient was given printed instructions for motor vehicle accident - trauma ( english ).
# Labels:       ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-problem', 'O', 'O', 'O', 'O']
# Predictions:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'X', 'O', 'O', 'O', 'O']
#
#
# ['the', 'patient', 'was', 'given', 'printed', 'instructions', 'for', 'motor', 'vehicle', 'accident', '-', 'trauma', '(', 'en', '##gli', '##sh', ')', '.']

# %%
a = 17
print( '\n' +text_full[a])
print('\033[1m' + "Labels:      " + '\033[0m', y_test_true[a])
print('\033[1m' + "Predictions: "+ '\033[0m',y_test_pred[a])
print('\n')

print(tokenized_text_converted_full[a])
# Out:
# 3. hydrochlorothiazide question of dosage.
# Labels:       ['O', 'B-treatment', 'O', 'O', 'O', 'O']
# Predictions:  ['O', 'B-treatment', 'O', 'O', 'O', 'O']
#
#
# ['3', '.', 'h', '##ydro', '##ch', '##lor', '##oth', '##ia', '##zi', '##de', 'question', 'of', 'dos', '##age', '.']

# %%
a = 25
print( '\n' +text_full[a])
print('\033[1m' + "Labels:      " + '\033[0m', y_test_true[a])
print('\033[1m' + "Predictions: "+ '\033[0m',y_test_pred[a])
print('\n')

print(tokenized_text_converted_full[a])
# Out:
# 3. acetaminophen 500 mg tablet sig : two ( 2 ) tablet po q6h ( every 6 hours ).
# Labels:       ['O', 'B-treatment', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Predictions:  ['O', 'B-treatment', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
# ['3', '.', 'ace', '##tam', '##ino', '##phe', '##n', '500', 'mg', 'tablet', 'si', '##g', ':', 'two', '(', '2', ')', 'tablet', 'p', '##o', 'q', '##6', '##h', '(', 'every', '6', 'hours', ')', '.']

# %%
a = 37
print( '\n' +text_full[a])
print('\033[1m' + "Labels:      " + '\033[0m', y_test_true[a])
print('\033[1m' + "Predictions: "+ '\033[0m',y_test_pred[a])
print('\n')

print(tokenized_text_converted_full[a])
# Out:
# please refer to the previously dictated operative note of 2016 - 12 - 30 by dr. lawrence.
# Labels:       ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Predictions:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
# ['please', 'refer', 'to', 'the', 'previously', 'dictated', 'operative', 'note', 'of', '2016', '-', '12', '-', '30', 'by', 'd', '##r', '.', 'law', '##ren', '##ce', '.']

# %%
# text = [tokenizer.convert_tokens_to_string(i) for i in tokenized_text_converted]

# %%
for a in range(1,len(y_test_pred)):
    print(tokenized_text_converted_full[a])
# Out:
# ['reason', 'for', 'this', 'examination', ':']
# ['2019', '-', '06', '-', '18', '07', ':', '55', 'am', 'blood', 'ca', '##lt', '##ib', '##c', '-', '229', 'f', '##er', '##rit', '##n', '-', 'greater', 'th', 't', '##rf', '-', '176', '*']
# ['hem', '##ody', '##nam', '##ics', ':']
# ['m', '##r', '.', 'br', '##eu', '##tz', '##far', '##st', '##xe', '##i', 'was', 'recently', 'diagnosed', 'with', 'acquired', 'im', '##mu', '##no', '##de', '##ficiency', 'syndrome', 'when', 'he', 'had', 'p', '##ne', '##um', '##oc', '##ys', '##tis', 'car', '##ini', '##i', 'pneumonia', 'on', '01', '/', '17', '/', '91', '.']
# ['c', '##b', '##c', ':', 'white', 'blood', 'cell', 'count', 'is', '8', '.', '8', ',', 'hem', '##ato', '##c', '##rit', '35', '.', '5', 'plate', '##lets', '26', '##6', ',', 'p', '##t', '13', ',', 'p', '##t', '-', 't', '23', '.', '3', ',', 'in', '##r', 'was', '1', '.', '1', '.']
# ['diagnosis', ':']
# ['si', '##g', '##mo', '##ido', '##sco', '##py', '.']
# ['discharge', 'instructions', ':']
# ['dictated', 'by', ':', 'she', '##rry', 'g', 'ch', '##rist', '##ie', ',', 'm', '.', 'd', '.']
# ['reason', 'for', 'this', 'examination', ':']
# ['initial', 'newborn', 'exam', ':']
# ['64', '-', 'year', '-', 'old', 'g', '##5', '##p', '##5', 'post', '##men', '##op', '##aus', '##al', 'for', '10', 'years', 'with', 'a', 'history', 'of', 'two', 'months', 'of', 'progressive', 'abdominal', 'di', '##sten', '##tion', ',', 'c', '##ram', '##py', 'abdominal', 'pain', ',', 'u', '##rina', '##ry', 'frequency', 'and', 'di', '##ar', '##r', '##hea', '.']
# ['per', '##rl', ',', 'e', '##omi', '.']
# ['the', 'patient', 'was', 'given', 'printed', 'instructions', 'for', 'motor', 'vehicle', 'accident', '-', 'trauma', '(', 'en', '##gli', '##sh', ')', '.']
# ['ex', '##tre', '##mit', '##ies', ':']
# ['white', 'blood', 'cell', 'count', '7', '.', '8', 'with', '86', '%', 'p', '##oly', '##mor', '##phon', '##uc', '##lea', '##r', 'cells', ',', '11', '.', '1', 'l', '##ymph', '##ocytes', ',', 'hem', '##og', '##lo', '##bin', '14', '.', '3', ',', 'hem', '##ato', '##c', '##rit', '40', '.', '5', ',', 'm', '##c', '##v', '88', ',', 'in', '##r', '1', '.', '0', ',', 'p', '##tt', '24', '.', '7', ',', 'p', '##t', '12', '.', '3', ',', 'plate', '##let', 'count', '295', ',', '000', ',', 'glucose', '81', ',', 'b', '##un', '15', ',', 'c', '##rea', '##tin', '##ine', '0', '.', '8', ',', 'sodium', '142', ',', 'potassium', '4', '.', '2', ',', 'chloride', '104', ',', 'co', '##2', '26', ',', 'calcium', '9', '.', '3', ',', 'phosphate', '4', '.', '8', ',', 'ma', '##gnesium', '2', '.', '3', '.']
# ['3', '.', 'h', '##ydro', '##ch', '##lor', '##oth', '##ia', '##zi', '##de', 'question', 'of', 'dos', '##age', '.']
# ['going', 'to', 'um', '##ass', 'memorial', 'medical', 'center', '4', '.']
# ['-', 'c', '##lar', '##iti', '##n', 'p', '##rn']
# ['discharge', 'date', ':']
# ['di', '##s', 'pad', '-', 'word']
# ['date', 'of', 'birth', ':']
# ['cat', '##ara', '##cts', ',', 's', '/', 'p', 'cat', '##ara', '##ct', 'surgery']
# ['her', 'white', 'blood', 'cell', 'count', 'was', '12', '.', '8', ',', 'with', 'a', 'normal', 'differential', '.']
# ['3', '.', 'ace', '##tam', '##ino', '##phe', '##n', '500', 'mg', 'tablet', 'si', '##g', ':', 'two', '(', '2', ')', 'tablet', 'p', '##o', 'q', '##6', '##h', '(', 'every', '6', 'hours', ')', '.']
# ['her', 'e', '##pid', '##ural', 'cat', '##he', '##ter', 'was', 'removed', 'on', '6', '/', '29', '.']
# ['the', 'cause', 'of', 'death', 'was', 'a', 'combination', 'of', 'g', '##i', 'bleeding', 'felt', 'to', 'be', 'ultimately', 'related', 'to', 'his', 'known', 'meta', '##static', 'pan', '##cre', '##atic', 'cancer', '.']
# ['7', '.', 'follow', 'up', '-', 'follow', 'up', 'appointment', 'with', 'primary', 'p', '##ediatric', '##ian', 'within', 'five', 'days', 'of', 'discharge', '.']
# ['di', '##sp', ':', '*', '30', 'tablet', '(', 's', ')', '*', 're', '##fill', '##s', ':', '*', '0', '*']
# ['denies', 'any', 'recent', 'use', 'of', 'et', '##oh', 'or', 'ill', '##icit', 'drugs', '.']
# ['6', '.', 'h', '##x', 'of', 'foot', 'ul', '##cer']
# ['p', '##t', '-', '12', '.', '7', 'p', '##tt', '-', '23', '.', '8', 'in', '##r', '(', 'p', '##t', ')', '-', '1', '.', '1']
# ['3', '.', 'met', '##op', '##rol', '##ol', 'ta', '##rt', '##rate', '50', 'mg', 'tablet', 'si', '##g', ':', 'one', '(', '1', ')', 'tablet', 'p', '##o', 'bid', '(', '2', 'times', 'a', 'day', ')', '.']
# ['2', '.', 'exposure', 'and', 'wide', 'drainage', 'of', 'per', '##fo', '##rated', 'posterior', 'duo', '##den', '##al', 'ul', '##cer', 'with', 'internal', 'and', 'external', 'drainage', '.']
# ['11', '.', 'co', '##lace', '100', 'mg', 'p', '.', 'o', '.', 'b', '.', 'i', '.', 'd', '.']
# ['underlying', 'medical', 'condition', ':']
# ['please', 'refer', 'to', 'the', 'previously', 'dictated', 'operative', 'note', 'of', '2016', '-', '12', '-', '30', 'by', 'd', '##r', '.', 'law', '##ren', '##ce', '.']
# ['tag', '##ged', 'r', '##b', '##c', '+', 'activity', 'in', 'r', '##l', '##q', '.']
# ['general', ':', 'patient', 'is', 'in', 'no', 'acute', 'distress', '.']
# ['1', '#', 'cardiac', ':']
# ['un', '##signed', 'pad', '-', 'word']
# ['card', '##iovascular', ':', 'complained', 'of', 'chest', 'pain', 'during', 'first', 'few', 'days', 'of', 'admission', ',', 'a', 'card', '##iology', 'consult', 'was', 'obtained', '.']
# ['medications', 'on', 'admission', ':']
# ['p', '##c', '##p', 'name', ':']
# ['brief', 'resume', 'of', 'hospital', 'course', ':']
# ['brief', 'hospital', 'course', ':']
# ['plate', '##let', 'count', 'was', '75', '##9', ',', '000', '.']
# ['neck', ':', 'su', '##pp', '##le', ',', 'no', 'j', '##v', '##d']
# ['post', '##par', '##tum', 'she', 'encountered', 'the', 'following', 'com', '##plication', '(', 's', ')', ':']
# ['the', 'patient', 'is', 'a', '1', ',', '77', '##0', 'gram', 'male', 'infant', 'born', 'by', 's', '##tat', 'c', '##es', '##are', '##an', 'section', 'for', 'f', '##etal', 'bra', '##dy', '##card', '##ia', 'at', '30', '-', '6', '/', '7', 'weeks', 'g', '##esta', '##tion', 'to', 'a', '29', '-', 'year', '-', 'old', 'g', '##ra', '##vid', '##a', '3', ',', 'para', '0', 'now', '1', 'mother', '.']
# ['patient', 'was', 'also', 'found', 'to', 'have', 'abnormal', 't', '##fts', 'on', 'su', '##ten', '##t', 'and', 'was', 'started', 'on', 'replacement']
# ['the', 'patient', 'tolerate', '##d', 'this', 'procedure', 'well', 'and', 'had', 'no', 'complications', '.']
# ['for', 'surgical', 'in', '##cision', 'and', 'left', 'arm']
# ['2015', '-', '10', '-', '05', '09', ':', '00', '##pm', 'blood']
# ['chronic', 'kidney', 'disease', '-', 'on', 'hem', '##od', '##ial', '##ys', '##is', 'type', '2', 'diabetes', 'h', '##yper', '##cho', '##les', '##tro', '##lem', '##ia', 'an', '##emia', 'of', 'ch', '##orn', '##ic', 'disease', 'h', '/', 'o', 'p', '##e', ',', 's', '/', 'p', 'p', '##ea', 'arrest', '11', '-', '14']
# ['his', 'temperature', 'was', '98', '##f', '.']
# ['summary', 'of', 'hospital', 'course', ':']
# ['as', '##t', '82', '.']
# ['there', 'are', 'simple', 'at', '##her', '##oma', 'in', 'the', 'ascending', 'a', '##ort', '##a', '.']
# ['patient', 'recorded', 'as', 'having', 'no', 'known', 'all', '##er', '##gies', 'to', 'drugs']
# ['difficulty', 'with', 'word', 'finding', 'at', 'times', '.']
# ['vital', 'signs', ':']
# ['finger', 'sticks', 'were', 'in', 'the', '150', 's', 'when', 'acute', '##ly', 'agitated', ',', 'therefore', ',', 'it', 'was', 'not', 'determined', 'that', 'glucose', 'levels', 'were', 'contributor', '##y', '.']
# ['family', 'history', ':']
# ['06', '/', '05', '/', '2002', '02', ':', '46', 'pm']
# ['laboratories', ':']
# ['11', '/', '02', '/', '99', 'k', '##e', '##9']
# ['there', 'is', 'a', 'small', 'amount', 'of', 'blood', 'layer', '##ing', 'in', 'both', 'lateral', 'vent', '##ric', '##les', ',', 'and', 'this', 'has', 'decreased', 'since', 'the', 'previous', 'study', '.']
# ['also', 'has', 'h', '/', 'o', 'anxiety', 'and', 'g', '##erd', '.']
# ['4', '.', 'new', 'j', '##ej', '##una', '##l', 'wall', 'thick', '##ening', 'with', 'persistent', 'di', '##stal', 'il', '##eal', 'wall', 'thick', '##ening', 'and', 'di', '##ff', '##use', 'me', '##sent', '##eric', 'strand', '##ing', ',', 'most', 'likely', 'reflecting', 'an', 'infectious', 'et', '##iology', '.']
# ['1', ')', 'al', '##but', '##ero', '##l', 'in', '##hale', '##r', 'two', 'pu', '##ffs', 'q', '.', 'i', '.', 'd', '.', 'p', '.', 'r', '.', 'n', '.', 'breathing', 'difficulties', '.']
# ['on', 'admission', 'the', 'patient', '&', 'a', '##po', '##s', ';', 's', 'bio', '##chemistry', 'showed', 'sodium', 'of', '140', ',', 'potassium', '4', '.', '0', ',', 'chloride', '107', ',', 'bi', '##car', '##b', '14', ',', 'b', '##un', '63', ',', 'c', '##rea', '##tin', '##ine', '5', '.', '8', ',', 'blood', 'sugar', '133', '.']
# ['technique', ':', 'a', '##xial', 'non', '##con', '##tras', '##t', 'c', '##t', 'scan', '##s', 'of', 'the', 'brain', 'were', 'obtained', '.']
# ['di', '##abe', '##tic', 're', '##tino', '##pathy', 'with', 'the', 'patient', 'blind', 'in', 'right', 'eye', '.']
# ['all', '##er', '##gies', ':']
# ['full', 'term', 'well', 'appearing', 'infant', 'with', 'some', 'facial', 'j', '##au', '##ndi', '##ce', ',', 'overall', 'pink', ',', 'warm', 'and', 'well', 'per', '##fused', ',', 'alert', 'and', 're', '##sp', '##ons', '##ive', '.']
# ['ex', '##t', ':', 'without', 'ed', '##ema', '.']
# ['due', 'to', 'persistent', 'gas', '##tric', 'secret', '##ions', ',', 'an', 'na', '##so', '##gas', '##tric', 'tube', 'was', 'placed', 'for', 'de', '##com', '##press', '##ion', '.']
# ['he', 'underwent', 'a', 'joint', 'procedure', 'by', 'o', '##to', '##lary', '##ngo', '##logy', 'and', 'plastic', 'surgery', '.']
# ['2013', '-', '05', '-', '11', 'pad', '-', 'word']
# ['repeated', 'three', 'times', 'and', 'remained', 'flat', '.']
# ['le', '##vo', '##f', '##lo', '##xa', '##cin', '500', 'mg', 'p', '##o', 'q', '##24', '##h']
# ['s', '##co', '##be', ',', 'r', '##yla', '##lon']
# ['no', 'spontaneous', 'echo', 'contrast', 'or', 'th', '##rom', '##bus', 'is', 'seen', 'in', 'the', 'body', 'of', 'the', 'left', 'at', '##rium', 'or', 'left', 'at', '##rial', 'app', '##end', '##age', '.']
# ['the', 'patient', 'is', 'admitted', 'for', 'pre', '##oper', '##ative', 'and', 'or', '##th', '##oped', '##ic', 'evaluation', '##s', '.']
# ['van', '##com', '##y', '##cin', 'and', 'z', '##osy', '##n', 'were', 'started', '.']
# ['other', 'diagnosis', ';', 'conditions', ',', 'infections', ',', 'complications', ',', 'affecting', 'treatment', '/', 'stay', 's', '/', 'p', 'c', '##es', '##are', '##an']
# ['discharge', 'summary']
# ['a', '##ort', '##a', 'is', 'unchanged', '.']
# ['66', '##18', '##2', 'pad', '-', 'word']
# ['blood', 'type', 'a', 'positive', ',', 'anti', '##body', 'negative', ',', 'rub', '##ella', 'immune', ',', 'r', '##p', '##r', 'non', '##rea', '##ctive', ',', 'he', '##pa', '##titis', 'b', 'surface', 'anti', '##gen', 'negative', ',', 'group', 'beta', 's', '##tre', '##p', 'status', 'unknown', '.']
# ['she', 'was', 'maintained', 'on', 'he', '##par', '##in', 'therapy', 'initially', 'but', 'this', 'was', 'quickly', 'switched', 'over', 'to', 'co', '##uma', '##din', 'anti', '##coa', '##gu', '##lation', 'therapy', 'which', 'she', 'will', 'need', 'to', 'be', 'on', 'long', '-', 'term', 'for', 'her', 'a', '##ort', '##ic', 'valve', 'replacement', '.']
# ['in', 'emergency', 'room', ',', 'he', 'was', 'noted', 'to', 'be', 'a', '##fe', '##bri', '##le', 'with', 'stable', 'vital', 'signs', ',', 'was', 'treated', 'with', 'i', '##v', 'fluids', ',', 'a', '##zi', '##th', '##rom', '##y', '##cin', ',', 'and', 'c', '##ef', '##uro', '##xi', '##me', '.']
# ['t', '##d', ':']
# ['registration', 'date', ':']
# ['un', '##signed', 'pad', '-', 'word']
# ['11', '.', 'bi', '##sa', '##co', '##dy', '##l', '5', 'mg', 'tablet', 'si', '##g', ':', 'one', '(', '1', ')', 'tablet', 'p', '##o', 'once', 'a', 'day', 'as', 'needed', 'for', 'con', '##st', '##ip', '##ation', '.']
# ['7', '.', 'c', '##lo', '##za', '##pine', '25', 'mg', 'tablet', 'si', '##g', ':', 'one', '(', '1', ')', 'tablet', 'p', '##o', 'h', '##s', '(', 'at', 'bed', '##time', ')', '.']
# ['m', '##ri', 'showed', 'a', 'large', 'fluid', 'filled', 'abdomen', 'with', 'a', 'relatively', 'small', 'mass', 'measuring', 'about', '5', 'to', '6', 'cm', 'in', 'the', 'right', 'p', '##el', '##vis', '.']
# ['ed', 'discharge', 'summary']
# ['physical', 'examination', ':']
# ['at', '##rial', 'fi', '##bri', '##lla', '##tion', '.']
# ['he', 'was', 'we', '##ane', '##d', 'from', 'his', 'v', '##as', '##oa', '##ctive', 'd', '##rip', '##s', 'and', 'transferred', 'to', 'the', 'floor', 'on', 'pod', '#', '2', '.']
# ['completed', 'by', ':', 'mark', 'y', '##von', '##ne', 'n', '##p', '80', '-', 'au', '##o', '2018', '-', '05', '-', '29', '@', '155', '##2']
# ['te', '##ls', '##hey', 'k', '.', 's', '##wat', '##lle', '##eb', '##ti', '##k', ',', 'm', '.', 'd', '.', 'n', '##j', '##38', 'me', '##0', '##8', '##9', '/', '69', '##22']
# ['12', '/', '26', '/', '1996', '12', ':', '00', ':', '00', 'am']
# ['medications', 'on', 'discharge', ':']
# ['report', 'status', ':']
# ['the', 'patient', 'is', 'hard', 'of', 'hearing', '.']
# ['a', 'ni', '##tro', 'd', '##rip', 'was', 'started', 'in', 'an', 'effort', 'to', 'decrease', 'her', 'pre', '##load', 'and', 'after', '##load', '.']
# ['hospital', 'course', ':']
# ['condition', 'on', 'discharge', ':']
# ['scheduled', 'pad', '-', 'word']
# ['food', '/', 'drug', 'interaction', 'instruction']
# ['it', 'initially', 'started', 'one', 'day', 'previously', 'but', 'has', 'gotten', 'significantly', 'worse', 'over', 'last', '12', 'hours', '.']
# ['p', '##rg', '##h', 'pad', '-', 'word']
# ['l', '##isi', '##no', '##p', '##ril', '5', 'mg', 'q', '##day']
# ['follow', 'up', 'service', ':']
# ['ka', '##thy', 'till', '##is', ',', 'm', '.', 'd', '.']
# ['lungs', ':']
# ['42', 'pad', '-', 'word']
# ['code', 'status', '-', 'the', 'patient', 'is', 'a', 'd', '##n', '##r', '/', 'd', '##ni', '.']
# ['follow', '##up', 'instructions', ':']
# ['2018', '-', '05', '-', '31', 'pad', '-', 'word']
# ['temperature', '100', '.', '3', ',', 'heart', 'rate', '76', ',', 'blood', 'pressure', '100', '/', '78', ',', 'respiratory', 'rate', '16', ',', 'and', 'an', 'oxygen', 'sat', '##uration', 'of', '96', '%', 'on', 'two', 'liter', '##s', '.']
# ['discharge', 'summary']
# ['he', 'was', 'treated', 'with', 'broad', 'spectrum', 'anti', '##biotics', 'for', 'a', '14', 'day', 'course', 'for', 'clinical', 's', '##b', '##p', '.']
# ['3', '/', '17', '/', '1998', '12', ':', '00', ':', '00', 'am']
# ['he', 'is', 'continuing', 'on', 'the', 'radiation', 'therapy', 'to', 'date', '.']
# ['can', 'give', '40', 'las', '##ix', 'p', '##o', 'if', 'having', 'any', 'weight', 'gain', 'or', 'short', '##ness', 'of', 'breath', '.']
# ['di', '##ct', '##ating', 'for', ':']
# ['her', 'blood', 'pressures', 'and', 'all', 'of', 'her', 'vital', 'signs', 'are', 'stable', '.']
# ['admission', 'date', ':']
# ['cardiac', 'and', 'infectious', 'sources', 'of', 'h', '##y', '##pot', '##ens', '##ion', 'were', 'considered', ',', 'but', 'cardiac', 'enzymes', 'were', 'not', 'changed', 'from', 'prior', 'studies', 'and', 'he', 'had', 'no', 'local', '##izing', 'signs', 'of', 'infection', ';', 'blood', 'cultures', 'were', 'sent', 'and', 'a', 'ultra', '##sound', 'of', 'the', 'l', 'arm', 'a', '##v', '##f', 'ordered', 'to', 'rule', 'out', 'a', '##bs', '##cess', 'at', 'the', 'site', '.']
# ['h', '##yper', '##tens', '##ion', 'pad', '-', 'word']
# ['g', '##i', ':']
# ['6', '.', 'ch', '##f', 'with', 'e', '##f', '25', '%', 'on', 'last', 'echo', 'on', '2017', '-', '07', '-', '19']
# ['p', '##lt', 'count', '-', '247']
# ['12', '/', '13', '/', '2002', '12', ':', '00', ':', '00', 'am']
# ['3', '.', 'at', '##or', '##vas', '##tat', '##in', '10', 'mg', 'p', '.', 'o', '.', 'q', '.', 'day', '.']
# ['2013', '-', '05', '-', '23', '09', ':', '36', 'pm', '11', '.', '4', '*', '34', '73', '1', '1']
# ['b', '##h', 'pad', '-', 'word']
# ['c', '##k', '&', 'a', '##po', '##s', ';', 's', 'were', 'mildly', 'elevated', 'but', 'the', 'm', '##b', 'fraction', '##s', 'were', 'not', 'remarkable', '.']
# ['01', '/', '30', '/', '2001', 'pad', '-', 'word']
# ['she', 'will', 'need', 'follow', 'up', 'with', 'her', 'p', '##c', '##p', 'within', 'b', 'week', 'after', 'discharge', 'from', 'the', 'extended', 'care', 'facility', 'for', 'further', 'b', '##p', 't', '##it', '##ration', 'and', 'monitoring', 'of', 'her', 'electro', '##ly', '##tes', '.']
# ['there', 'was', 'some', 'concern', 'that', 'the', 'patient', 'may', 'have', 'a', 'partial', 'bi', '##lia', '##ry', 'o', '##bs', '##truction', 'and', 'the', 'patient', 'was', 'sent', 'for', 'an', 'magnetic', 'resonance', 'ch', '##ola', '##ng', '##io', '##pan', '##cre', '##ato', '##graphy', 'to', 'further', 'evaluate', 'the', 'bi', '##lia', '##ry', 'system', '.']
# ['her', 'diet', 'was', 'advanced', 'without', 'difficulty', 'and', 'the', 'patient', 'was', 'stable', 'for', 'discharge', '.']
# ['a', 'co', '##sy', '##nt', '##rop', '##in', 'stimulation', 'test', 'revealed', 'co', '##rt', '##is', '##ol', '32', '.', '1', '-', '-', '>', '36', '.', '4', '.']
# ['because', 'it', 'would', 'be', 'ideal', 'to', 'place', 'a', 'mechanical', 'valve', 'if', 'valve', 'replacement', 'rather', 'that', 'com', '##mis', '##su', '##rot', '##omy', 'is', 'needed', ',', 'she', 'was', 'seen', 'by', 'd', '##r', '.', 'ca', 's', '##hu', '##ff', 'of', 'en', '##t', 'for', 'her', 'history', 'of', 'e', '##pis', '##ta', '##xi', '##s', '.']
# ['test', '##es', 'descended', 'bilateral', '##ly', '.']
# ['there', 'was', 'no', 't', '##ric', '##us', '##pid', 'valve', 'gradient', '.']
# ['2014', '-', '04', '-', '23', '03', ':', '56', 'pm']
# ['di', '##s', 'pad', '-', 'word']
# ['flare', '-', 's', '##tero', '##ids', ',', 'con', '##t', 'pre', '##dn', '##ison', '##e', '60', ',', 'tape', '##r', 'slowly', 'as', 'tolerate', '##d', ',', 'duo', '##ne', '##bs', ',', 'ad', '##va', '##ir', ',', 'sing', '##ula', '##ir', ',', 's', '##pi', '##ri', '##va', ',', 'c', '##lar', '##iti', '##n', 'a', '##zi', '##th', '##rom', '##y', '##cin', 'for', 'at', '##y', '##pical', 'br', '##on', '##chi', '##tis', 'to', 'complete', 'a', '5', 'day', 'course', ',', 'keep', 'o', '##2', 'sat', '90', '-', '94', ',', 'home', 'no', '##cturnal', 'c', '##pa', '##p', 'not', 'tolerate', '##d', 'in', 'house', ',', 'does', 'well', 'on', 'n', '##c', ',', 'appears', 'at', '##o', 'be', 'at', 'base', '##line']
# ['discharge', 'diagnosis', ':']
# ['history', 'of', 'present', 'illness', ':']
# ['2012', '-', '06', '-', '07', 'pad', '-', 'word']
# ['her', 'number', 'is', '(', '512', ')', '67', '##7', '-', '65', '##47', '.']
# ['12', '.', 'pro', '##ton', '##ix', '20', 'mg', 'p', '.', 'o', '.', 'b', '.', 'i', '.', 'd', '.']
# ['a', 'ho', '##lter', 'showed', 'at', '##rial', 'fi', '##bri', '##lla', '##tion', 'with', 'period', 'of', 'vent', '##ric', '##ular', 'big', '##em', '##ini', '.']
# ['on', 'post', '##oper', '##ative', 'day', 'four', ',', 'the', 'patient', 'continued', 'to', 'have', 'na', '##so', '##gas', '##tric', 'tube', 'in', 'place', '.']
# ['this', 'was', 'significant', 'for', 'demonstrating', 'no', 'flow', '-', 'limited', 'disease', 'in', 'the', 'co', '##rona', '##ries', 'but', 'several', 'fist', '##ula', '##e']
# ['2', '.', 'war', '##fari', '##n', '3', 'mg', 'p', '.', 'o', '.', 'q', 'h', '.', 's', '.']
# ['09', '/', '16', '/', '2004', '17', ':', '48']
# ['1', '.', 'status', 'post', 'ca', '##da', '##ver', '##ic', 'pan', '##cre', '##as', 'transplant', '.']
# ['during', 'this', 'admission', 'you', 'have', 'been', 'treated', 'for', 'a', 'ch', '##f', 'ex', '##ace', '##rb', '##ation', '.']
# ['the', 'patient', 'was', 'continued', 'on', 'his', 's', '##tat', '##in', '.']
# ['12', '#', 'wound', 'care', ':']
# ['sex', ':']
# ['right', 'com', '##min', '##uted', 't', '##ibi', '##a', '/', 'fi', '##bula', 'fracture']
# ['209', '##9', '##8', '##7', 'pad', '-', 'word']
# ['failed', 'swallow', 'study', 'x', '2', 'in', 'early', 'no', '##ve', '##mber', '.']
# ['this', 'report', 'was', 'created', 'by', 'a', '##yre', '##ke', '##mp', '##e', ',', 'non', '##ok', '01', '/', '09', '/', '2002', '05', ':', '09', 'pm']
# ['di', '##sp', ':', '*', '60', 'capsule', '(', 's', ')', '*', 're', '##fill', '##s', ':', '*', '2', '*']
# ['12', '.', 'pace', '##maker', '-', 'd', '##dd', 'dual', 'chamber', 'rate', 'response', 'pace', '##maker', '2011', '-', '08', '-', '22', 'for', 's', '##ym', '##pt', '##oma', '##tic', 'bra', '##dy', '##card', '##ia']
# ['hospital', 'course', 'and', 'treatment', ':']
# ['emerge', '##nt', 'indication', '##s', ':']
# ['standardized', 'discharge', 'instructions', ':']
# ['mother', 'had', 'ad', '##rena', '##l', 'cancer', '.']
# ['notably', 'you', 'were', 'discharged', 'on', ':']
# ['3', '.', 'al', '##but', '##ero', '##l', '-', 'i', '##pra', '##tro', '##pi', '##um', '103', '-', '18', 'm', '##c', '##g', '/', 'act', '##uation', 'a', '##ero', '##sol', 'si', '##g', ':', '02', '-', '26', 'pu', '##ffs', 'in', '##hala', '##tion', 'q', '##6', '##h', '(', 'every', '6', 'hours', ')', 'as', 'needed', '.']
# ['for', 'follow', 'up', ',', 'the', 'patient', 'is', 'to', 'call', 'for', 'an', 'appointment', 'with', 'd', '##r', '.', 'sa', '##pm', '##al', '.']
# ['a', '.', 'instructions', ':', 'with', 'd', '##r', '.', 'mat', '##the', '##w', 'in', '2', '-', '3', 'weeks', 'with', 'd', '##r', '.', 'dell', '##inger', 'in', '2', '-', '3', 'weeks', 'with', 'd', '##r', '.', 'les', 'go', '##key', 'in', '4', 'weeks']
# ['m', '##rn', ':']
# ['he', 'received', 'multiple', 'treatments', 'for', 'this', 'over', 'the', 'succeeding', 'weeks', '.']
# ['history', 'of', 'present', 'illness', ':']
# ['w', '##iers', '##t', ',', 's', '##to', 'l', '.', ',', 'm', '.', 'd', '.', '(', 'r', '##r', '##86', ')', '10', '/', '01', '/', '00', '02', ':', '33', 'pm']
# ['signed', 'electronic', '##ally', 'by', ':', 'd', '##r', '.', 'br', '##end', '##a', 'j', '##m', '.', 'es', '##pin', '##osa', 'on', ':', 'ma', '##xin', '##e', '2015', '-', '09', '-', '10', '1', ':', '57', 'pm']
# ['you', 'may', 'shower', '.']
# ['un', '##signed', 'pad', '-', 'word']
# ['had', 'subsequent', 'abnormal', 'stress', 'test', 'and', 'p', '##ef', '##usion', 'imaging', 'showed', 'e', '##f', '38', '%', 'with', 'per', '##fusion', 'defects', '.']
# ['has', 'significant', 'cardiac']
# ['ne', '##uro', '##logical', 'exam', 'was', 'gross', '##ly', 'intact', '.']
# ['impression', ':', 'moderate', 'to', 'large', 'per', '##ica', '##rdi', '##al', 'e', '##ff', '##usion', '(', 'minimal', 'fluid', 'anterior', '##ly', '(', '1', '##c', '##m', ')', ',', '?', 'bloody', ')', '.']
# ['c', '##t', '##m', '##c', 'pad', '-', 'word']
# ['c', '##t', '##m', '##c', 'pad', '-', 'word']
# ['he', '##ent', 'exam', 'was', 'un', '##rem', '##ark', '##able', '.']
# ['present', 'illness', ':']
# ['discharge', 'medications', ':']
# ['di', '##cat', '##ated', 'by', ':']
# ['48', '##7', '##20', '##9', '##20', 'pad', '-', 'word']
# ['gentle', 'di', '##ures', '##is', 'and', 'beta', 'blockade', 'started', ',', 'and', 'he', 'was', 'transferred', 'to', 'the', 'floor', 'to', 'begin', 'increasing', 'his', 'activity', 'level', '.']
# ['and', 'it', 'is', 'noted', 'there', 'was', 'nod', '##ular', '##ity', 'in', 'the', 'common', 'bi', '##le', 'duct', 'which', 'is', 'w', '##or', '##ris', '##ome', 'for', 'ch', '##ola', '##ng', '##io', '##car', '##cin', '##oma', '.']
# ['09', '-', '08', '-', '93', 'pad', '-', 'word']
# ['u', '##rina', '##ry', 'in', '##con', '##tine', '##nce']
# ['01', '/', '09', '/', '2002', '17', ':', '02']
# ['the', 'patient', ',', 'during', 'this', 'admission', ',', 'required', 'trans', '##fusion', 'of', 'three', 'units', 'of', 'packed', 'red', 'blood', 'cells', 'to', 'maintain', 'adequate', 'hem', '##ato', '##c', '##rit', '.']
# ['2', '.', 'prior', 'history', 'of', 'anterior', 'my', '##oc', '##ard', '##ial', 'in', '##far', '##ction']
# ['he', '##ent', ':', 'n', '##cat', ',', 'per', '##rl', ',', 'e', '##omi', ',', 'no', 'i', '##cter', '##us', ',', 'op', 'clear', ',', 'mm', '##m', ',', 'no', 'tongue', 'f', '##as', '##ci', '##cula', '##tions']
# ['all', '##er', '##gies', ':']
# ['signed', 'pad', '-', 'word']
# ['please', 'note', 'that', 'evaluation', 'by', 'the', 'swallowing', 'therapist', ',', 'showed', 'that', 'the', 'patient', 'is', 'as', '##pi', '##rating', 'at', 'this', 'time', ',', 'but', 'there', 'is', 'great', 'hope', 'from', 'the', 'nature', 'of', 'her', 'deficit', 'and', 'the', 'good', 'movements', 'of', 'her', 'tongue', 'that', 'normal', 'swallowing', 'should', 'return', 'soon', '.']
# ['s', '##ys', '##to', '##lic', 'blood', 'pressure', 'in', 'the', '120', "'", 's', 'to', '130', "'", 's', '.']
# ['the', 'walk', 'was', 'par', '##etic', 'in', 'the', 'left', 'side', '.']
# ['respiratory', 'rate', '18', '.']
# ['he', 'remained', 'un', '##res', '##po', '##ns', '##ive', 'with', 'poor', 'air', '##way', 'protection', '.']
# ['333', '##8', '##8', '##7', 'pad', '-', 'word']
# ['2013', '-', '10', '-', '29', '01', ':', '09', 'pm', 'blood', 'glucose', '-', '172', '*', 'u', '##rea', '##n', '-', '11', 'c', '##rea', '##t', '-', '0', '.', '9', 'na', '-', '142', 'c', '##l', '-', '111', '*', 'h', '##co', '##3', '-', '22']
# ['#', '.', 'a', '##fi', '##b', '/', 's', '##ss', ':', 'she', 'was', 'a', '-', 'paced', ',', 'pace', '##r', 'placed', '05', '-', '08', 'in', 'd', '##dd', '##r', 'mode', ',', 'complicated', 'by', 'p', '##t', '##x', 'requiring', 'chest', 'tube', 'which', 'resolved', 'and', 'tube', 'was', 'removed', 'during', 'admit', 'for', 'pace', '##r', ',', 'no', 'evidence', 'of', 'p', '##t', '##x', 'on', 'most', 'recent', 'c', '##x', '##r', '.']
# ['320', '##5', '##8', '##20', 'pad', '-', 'word']
# ['sub', '##cut', '##aneous', 'ed', '##ema', 'is', 'noted', 'in', 'the', 'lower', 'abdomen', 'and', 'p', '##el', '##vis', '.']
# ['7', '/', '10', '/', '2002', '12', ':', '00', ':', '00', 'am']
# ['the', 'patient', 'denies', 'tobacco', 'and', '/', 'or', 'alcohol', 'use', '.']
# ['ed', 'discharge', 'not', '##ification', '/', 'summary']
# ['2018', '-', '03', '-', '04', '01', ':', '02', '##pm']
# ['12', '.', 'line', '##zo', '##lid', '600', 'mg', 'i', '##v', 'q', '##12', '##h']
# ['ne', '##uro', '##logy', 'was', 'consulted', 'due', 'to', 'the', 'concern', 'for', 'seizure', '##s', 'in', 'the', 'setting', 'of', 'dusk', '##y', 'episodes', '.']
# ['am', '##io', '##dar', '##one', '200', 'mg', 'daily']
# ['m', 'pad', '-', 'word']
# ['bi', '##pol', '##ar', 'disorder']
# ['takes', 'hub', '##by', '&', 'a', '##po', '##s', ';', 's', 's', '##l', 'n', '##t', '##g', 'bar', '##ium', 'swallow', '04', '/', '89', '(', '-', ')', 'u', '##gi', '06', '/', '91', '(', '-', ')']
# ['237', '##5', '##43', '##5', '##7', 'pad', '-', 'word']
# ['he', 'was', 'taken', 'to', 'ways', '##ke', '##med', '##cal', '##lt', '##own', 'ta', '##lm', '##i', 'and', 'transferred', 'to', 'he', '##ao', '##n', '##bo', '##burg', 'l', '##in', '##pack', 'grant', 'medical', 'center', 'with', 'a', 'computer', '##ized', 'to', '##mo', '##graphy', 'scan', 'showing', 'a', '1', '##x', '##2', 'th', '##ala', '##mic', 'caps', '##ular', 'hem', '##or', '##r', '##hage', 'without', 'superficial', 'mass', 'effect', '.']
# ['she', 'is', 'anti', '##coa', '##gu', '##lated', 'on', 'co', '##uma', '##din', 'and', 'this', 'has', 'been', 'stable', '.']
# ['sodium', '139', ';', 'potassium', '4', '.', '1', ';', 'b', '##un', '15', ';', 'c', '##rea', '##tin', '##ine', '1', '.', '1', ';', 'ma', '##gnesium', '1', '.', '6', ';', 's', '##g', '##pt', '19', ';', 's', '##got', '20', ';', 'al', '##kal', '##ine', 'p', '##hos', '##pha', '##tase', '66', ';', 'total', 'bi', '##li', '##ru', '##bin', '0', '.', '6', ';', 'direct', 'bi', '##li', '##ru', '##bin', '0', '.', '2', ';', 'total', 'ch', '##ole', '##ster', '##ol', '234', ';', 't', '##rig', '##ly', '##cer', '##ides', '27', '##4', ';', 'h', '##dl', '44', ';', 'l', '##dl', '135', ';', 'hem', '##og', '##lo', '##bin', 'a', '##1', '##c', '6', '.', '7', ';', 'white', 'cell', 'count', '6', '.', '1', ';', 'hem', '##ato', '##c', '##rit', '36', '.', '4', ';', 'plate', '##let', 'count', '201', '.']
# ['of', 'note', ',', 'this', 'is', 'the', 'second', 'time', 'the', 'patient', 'has', 'exercised', 'in', 'many', 'months', '.']
# ['principal', 'diagnosis', ':']
# ['39', '##45', '##21', 'pad', '-', 'word']
# ['blood', 'pressure', '162', '/', '76', '.']
# ['the', 'patient', 'became', 'h', '##y', '##pot', '##ens', '##ive', 'into', 'the', '70', 's', 'without', 'any', 'symptoms', '.']
# ['per', '##tinent', 'results', ':']
# ['feeds', 'are', 'breast', 'feeding', 'p', '.', 'o', '.', 'ad', 'l', '##ib', '.']
# ['there', 'were', 'no', 'vent', '##ric', '##ular', 'premature', 'contraction', '##s', '.']
# ['1', '.', 'diabetes', 'me', '##lli', '##tus', '.']
# ['there', 'was', 'mild', 'enhance', '##ment', 'of', 'the', 'p', '##ont', '##ine', 'hem', '##or', '##r', '##ha', '##gic', 'mass', 'but', 'none', 'elsewhere', '.']
# ['the', 'patient', "'", 's', 'surgical', 'in', '##cision', 'was', 'also', 'healing', 'well', 'by', 'the', 'time', 'of', 'discharge', 'with', 'no', 'evidence', 'of', 'infection', '.']
# ['di', '##sp', ':', '*', '5', 'bottles', '*', 're', '##fill', '##s', ':', '*', '2', '*']
# ['due', 'to', 'difficult', 'am', '##bula', '##tion', ',', 'the', 'patient', 'developed', 'a', 'small', 'ul', '##cer', 'in', 'the', 'sa', '##c', '##ral', 'area', ',', 'which', 'was', 'treated', 'with', 'duo', '##der', '##m', 'dressing', '.']
# ['an', 'echo', 'showed', 'that', 'she', 'had', 'preserved', 'e', '##f', 'and', 'no', 'wall', 'motion', 'abnormal', '##ities', '.']
# ['family', 'history', ':']
# ['o', '##m', '##r', 'pad', '-', 'word']
# ['the', 'or', '##op', '##har', '##ynx', 'was', 'ben', '##ign', '.']
# ['t', '##d', ':']
# ['provider', 'number', ':']
# ['discharge', 'date', ':']
# ['on', '5', '/', '14', '/', '05', 'man', '##ni', '##to', '##l', 'was', 'tape', '##red', 'and', 'then', 'd', '/', 'c', '&', 'a', '##po', '##s', ';', 'd', '.']
# ['7', '.', 'di', '##lau', '##di', '##d', 'p', '##rn', '.']
# ['discharge', 'medications', ':']
# ['the', 'abdomen', 'showed', 'a', '10', 'cm', 'liver', 'with', 'the', 'edge', 'p', '##al', '##pable', '2', 'finger', '##bre', '##ad', '##ths', 'below', 'the', 'right', 'costa', '##l', 'margin', '.']
# ['the', 'patient', 'is', 'in', 'no', 'acute', 'distress', '.']
# ['w', '##b', '##c', '-', '11', '.', '4', '*', 'r', '##b', '##c', '-', '3', '.', '61', '*', 'h', '##g', '##b', '-', '11', '.', '4', '*', 'h', '##ct', '-', '32', '.', '6', '*', 'm', '##c', '##v', '-', '90', 'm', '##ch', '-', '31', '.', '7']
# ['report', 'status', ':']
# ['a', '##c', '500', '/', '15', '/', '.', '50', '/', 'p', '##eep', '5']
# ['no', 'evidence', 'of', 'active', 'end', 'organ', 'damage', '.']
# ['none', 'pad', '-', 'word']
# ['it', 'is', 'hoped', 'that', 'when', 'he', 'is', 'transferred', 'to', 'a', 're', '##hab', 'facility', 'that', 'he', 'will', 'continue', 'with', 'physical', 'therapy', 'to', 'regain', 'his', 'strength', 'and', 'regain', 'independence', 'in', 'activities', 'of', 'daily', 'living', '.']
# ['during', 'her', 'labor', 'she', 'encountered', 'the', 'following', 'com', '##plication', '(', 's', ')', ':']
# ['2', '.', 'moderately', 'elevated', 'right', 'and', 'left', 'sided', 'filling', 'pressures', '.']
# ['05', '/', '26', '/', '2004', 'pad', '-', 'word']
# ['br', '##eu', '##nti', '##k', 'pad', '-', 'word']
# ['bone', 'ma', '##rrow', 'bio', '##psy', 'was', 'not', 'attempted', '.']
# ['28', '##9', '##65', '##3', 'pad', '-', 'word']
# ['tape', '/', 'ben', '##ad', '##ryl']
# ['principal', 'diagnosis', ':']
# ['the', 'abdomen', 'was', 'soft', 'and', 'non', '-', 'tender', 'with', 'no', 'masses', 'or', 'organ', '##ome', '##gal', '##y', '.']
# ['f', '##em', '##oral', '2', '+', 'bilateral', '##ly', ',', 'dorsal', '##is', 'p', '##ed', '##is', '1', '+', 'bilateral', '##ly', ',', 'posterior', 't', '##ibi', '##al', '1', '+', 'bilateral', '##ly', ',', 'and', 'radial', '2', '+', 'bilateral', '##ly', '.']
# ['600', '##13', '##5', '##6', 'pad', '-', 'word']
# ['major', 'surgical', 'or', 'invasive', 'procedure', ':']
# ['car', '##ot', '##ids', 'had', 'normal', 'ups', '##troke', 'and', 'normal', 'volume', 'with', 'bilateral', 'br', '##uit', '##s', '.']
# ['reason', 'for', 'this', 'examination', ':']
# ['she', 'was', 'worked', 'up', 'aggressively', 'with', 'the', 'physical', 'therapy', 'and', 'occupational', 'services', ',', 'made', 'good', 'progress', 'and', 'began', 'am', '##bula', '##ting', 'with', 'assistance', 'with', 'a', 'walk', '##er', 'but', 'with', 'minimal', 'assistance', 'from', 'an', 'aid', '.']
# ['provider', 'number', ':']
# ['me', '##d', '##quist', '##36', 'pad', '-', 'word']
# ['12', '/', '1', '/', '2003', '12', ':', '00', ':', '00', 'am']
# ['old', 't', '##wi', 'v', '##4', '-', '6', '.']
# ['27', '##17', '##35', 'pad', '-', 'word']
# ['further', 'evaluation', 'of', 'his', 're', '##nal', 'failure', 'showed', 'that', 'the', 'patient', 'has', 'bilateral', 'h', '##ydro', '##ne', '##ph', '##rosis', ',', 'most', 'likely', 'o', '##bs', '##truct', '##ive', 'u', '##rop', '##athy', 'due', 'to', 'pro', '##state', 'ca', 'in', 'the', 'p', '##el', '##vic', 'area', '.']
# ['neck', 'with', 'c', '##er', '##vic', '##al', 'collar', '.']
# ['p', '##hil', '##ip', 'g', '##len', '##n', 'm', '##d', '60', '-', '385']
# ['12', '/', '09', '/', '2005', 'pad', '-', 'word']
# ['non', '##ok', 'a', '##yre', '##ke', '##mp', '##e']
# ['he', '##ent', ':', 'e', '##omi', ',', 'per', '##rl', ',', 'n', '##c', '/', 'at']
# ['hospital', 'course', ':']
# ['#', 'a', '##rf', ':', 'c', '##rea', '##tin', '##ine', 'has', 'increased', 'from', '0', '.', '9', 'on', 'admission', 'to', '1', '.', '9', 'on', 'admission', 'to', 'i', '##cu', '.']
# ['on', 'day', 'of', 'life', '#', '1', ',', 'ca', '##ffe', '##ine', 'was', 'started', '.']
# ['(', 'end', 'of', 'report', ')']
# ['abdominal', 'pain', 'pre', '##dom', '##inal', '##ly', 'on', 'the', 'right', 'upper', 'q', '##uad', '##rant', ',', 'no', 'signs', 'of', 'per', '##ito', '##nea', '##l', 'irritation', '.']
# ['an', '##ga', '##p', '-', '12']
# ['c', '##t', 'scan', 'shows', 'o', '##var', '##ian', 'c', '##ys', '##t']
# ['s', '##cle', '##ra', 'mildly', 'i', '##cter', '##ic', '.']
# ['blood', 'pressure', 'most', 'recently', '60', '/', '37', 'with', 'a', 'mean', 'of', '44', '.']
# ['signed', 'pad', '-', 'word']
# ['past', 'medical', 'history', ':']
# ['3', '.', 'fl', '##ove', '##nt', '110', 'micro', '##gram', '##s', 'a', '##ero', '##sol', 'two', 'pu', '##ffs', 'b', '.', 'i', '.', 'd', '.']
# ['he', 'will', 'follow', 'up', 'with', 'd', '##r', '.', 'i', '##ech', '##alet', '##te', 'cancer', 'in', 'his', 'office', '.']
# ['me', '##d', '##quist', '##36', 'pad', '-', 'word']
# ['#', '.', 'an', '##emia', ':', 'unclear', 'source', '.']
# ['c', '##v', ':']
# ['00', '##14', '##6', '##33', 'pad', '-', 'word']
# ['cm', '##ed', 'c', '##s', '##ru']
# ['expired', 'pad', '-', 'word']
# ['81', '##9', '##5', '##7', '##9', 'pad', '-', 'word']
# ['room', ':']
# ['7', '.', 'c', '##lon', '##id', '##ine', '0', '.', '2', 'mg', 'tablet', 'si', '##g', ':', 'one', '(', '1', ')', 'tablet', 'p', '##o', 't', '##id', '(', '3', 'times', 'a', 'day', ')', '.']
# ['type', 'ii', 'diabetes', '.']
# ['on', 'an', 'office', 'visit', 'on', '01', '-', '14', ',', 'the', 'patient', 'was', 'found', 'to', 'have', 'significantly', 'elevated', 'al', '##kal', '##ine', 'p', '##hos', '##pha', '##tase', '.']
# ['no', 'p', '##al', '##pit', '##ations', ',', 'history', 'of', 'e', '##pi', '##gas', '##tric', 'pain', 'and', 'body', 'weight', 'loss', '.']
# ['echo', 'showed', 'e', '##f', '45', '-', '50', '%', ',', 'with', 'mild', 'di', '##lat', '##ation', 'and', 'no', 'significant', 'v', '##al', '##vu', '##lar', 'disease', ',', 'and', 'n', '##l', 'p', '##ap', '.']
# ['provider', ':']
# ['c', '##t', 'head', 'w', '/', 'o', 'contrast']
# ['e', '##p', 'pad', '-', 'word']
# ['discharge', 'date', ':']
# ['no', 'other', 'cultures', 'grew', 'out', 'and', 'the', 'patient', '&', 'a', '##po', '##s', ';', 's', 'clinical', 'status', 'deteriorated', '.']
# ['central', 've', '##nous', 'cat', '##he', '##ter', 'and', 's', '##wan', 'g', '##an', '##z', 'cat', '##he', '##ter', 'placement']
# ['anterior', 'font', '##ane', '##lle', ',', 'soft', 'and', 'flat', ',', 'p', '##ala', '##te', 'intact', ',', 'non', '##dy', '##smo', '##rp', '##hic', 'features', '.']
# ['past', 'medical', 'history', ':']
# ['ed', 'discharge', 'summary']
# ['administer', 'iron', 'products', 'a', 'minimum', 'of', '2', 'hours', 'before', 'or', 'after', 'a', 'le', '##vo', '##f', '##lo', '##xa', '##cin', 'or', 'c', '##ip', '##ro', '##f', '##lo', '##xa', '##cin', 'dose', 'dose']
# ['e', '##k', '##g', 'was', 'negative', 'for', 'is', '##che', '##mia', '.']
# ['on', 'admission', 'included', 'an', 'al', '##t', 'of', '108', ',', 'as', '##t', 'of', '286', '.']
# ['80', '##9', '##8', '##7', 'pad', '-', 'word']
# ['room', ':']
# ['70', 'y', '/', 'o', 'male', 'with', 'h', '/', 'o', 'ca', '##d', 's', '/', 'p', 'lad', 'p', '##t', '##ca', '33', 'y', '##rs', 'ago', ',', 'cop', '##d', ',', 't', '##2', '##d', '##m', ',', 'and', 'a', '##ic', '##d', 'pocket', 'infection', 'who', 'presented', 'to', 'the', 'j', '##uan', 'on', '2017', '-', '09', '-', '03', 'with', 'worse', '##ning', 'sob', 'x', '5', 'days', 'and', 'feeling', '"', 'cloud', '##y', '.', '"']
# ['03', '/', '31', '/', '97', '12', ':', '36', 'p']
# ['diet', 'as', 'tolerate', '##d', '.']
# ['delivery', 'date', ':']
# ['medications', 'at', 'home', ':']
# ['post', '##par', '##tum', 'other', 'diagnosis', ';']
# ['j', '##ose', '##ph', 'j', '##ud', '##y', 'm', '##d', '35', '-', '94', '##3']
# ['his', 'a', '##pical', 'p', '##ne', '##um', '##oth', '##orax', 'from', 'the', 'outside', 'hospital', 'had', 'resolved', '.']
# ['service', ':']
# ['associated', 'di', '##ag', '##nose', '##s', ':']
# ['he', '##ent', ':']
# ['1', '.', 'co', '##uma', '##din', '5', 'mg', 'p', '##o', 'q', '.', 'day', ',', 'then', 'she', 'will', 'follow', 'up', 'with', 'her', 'primary', 'care', 'physician', 'and', 'decide', 'the', 'dos', '##age', 'thereafter', ',']
# ['glucose', '-', '101', 'la', '##ct', '##ate', '-', '2', '.', '9', '*', 'na', '+', '-', '142', 'k', '+', '-', '3', '.', '6', 'c', '##l', '-', '-', '102', 't', '##co', '##2', '-', '26']
# ['r', '##ias', '##hwa', '##n', 'be', '##rl', '##ni', 'valley']
# ['service', ':']
# ['signed', 'electronic', '##ally', 'by', ':', 'd', '##r', '.', 'ka', '##thy', 'till', '##is', 'on', ':', 'mon', '2010', '-', '06', '-', '07', '4', ':', '00', 'pm']
# ['she', 'continued', 'to', 'have', 'a', 'dense', 'left', 'hem', '##iano', '##ps', '##ia', ',', 'but', 'otherwise', 'was', 'ne', '##uro', '##logical', '##ly', 'intact', '.']
# ['the', 'patient', 'was', 'given', 'printed', 'instructions', 'for', 's', '##pra', '##ins', ',', 'fracture', '##s', 'and', 'bruises', '(', 'en', '##gli', '##sh', ')', '.']
# ['again', 'seen', 'are', 'subtle', 'h', '##y', '##po', '##den', '##sities', 'within', 'the', 'per', '##ive', '##nt', '##ric', '##ular', 'white', 'matter', 'which', 'is', 'an', 'indication', 'of', 'chronic', 'micro', '##vas', '##cular', 'is', '##che', '##mic', 'changes', ',', 'stable', '.']
# ['he', '##pa', '##titis', 'se', '##rol', '##ogies', 'pending', '.']
# ['55', '##18', '##8', '##1', 'pad', '-', 'word']
# ['none', 'pad', '-', 'word']
# ['date', 'of', 'birth', ':']
# ['restraint', '##s', ',', 'for', 'the', 'safety', 'of', 'both', 'the', 'patient', 'and', 'the', 'staff', 'of', 'the', 'hospital', '.']
# ['the', 'plan', 'is', 'for', 'alternating', 'feeds', '.']
# ['hospital', 'course', ':']
# ['conditions', ',', 'infections', ',', 'complications', ',', 'affecting', 'treatment', '/', 'stay', 'post', '##par', '##tum']
# ['she', 'has', 'a', 's', '##t', '.', 'j', '##ude', '&', 'a', '##po', '##s', ';', 's', 'mechanical', 'valve', 'and', 'has', 'been', 'on', 'co', '##uma', '##din', 'since', 'then', ',']
# ['g', '##en', ':', 'na', '##d', ',', 'pleasant', 'speaking', 'in', 'full', 'sentences']
# ['is', '##tra', '##n', '##mu', '##na', 'b', '.', 'cord', ',', 'm', '.', 'd', '.', 'v', '##r', '##5', '##2', 'p', '##h', '##50', '##1', '/', '35', '##60']
# ['d', '##d', ':']
# ['instructions', ':']
# ['he', 'did', 'not', 'show', 'any', 'episodes', 'of', 'bra', '##dy', '##card', '##ia', 'throughout', 'the', 'remainder', 'of', 'his', 'hospital', 'course', '.']
# ['stable', 'pad', '-', 'word']
# ['g', '##ait', 'disorder', '.']
# ['per', '##co', '##ce', '##t', '5', 'mg', 'in', '325', 'mg', 'one', 'to', 'two', 'ta', '##bs', 'p', '##o', 'q', '##4', 'to', '6', 'p', '##rn', 'pain', '.']
# ['discharge', 'disposition', ':']
# ['43', '##36', '##51', '##38', '##9', 'pad', '-', 'word']
# ['no', 'mass', 'or', 'vegetation', 'is', 'seen', 'on', 'the', 'mit', '##ral', 'valve', '.']
# ['the', 'ascending', 'a', '##ort', '##a', 'is', 'mildly', 'di', '##lated', '.']
# ['the', 'right', 'p', '##le', '##ural', 'e', '##ff', '##usion', 'slowly', 're', '-', 'accumulated', 'after', 'tap', 'but', 'resolved', 'after', 'continued', 'di', '##ures', '##is', '.']
# ['in', 'addition', ',', 'she', 'is', 'to', 'follow', 'up', 'with', 'her', 'primary', 'care', 'physician', 'to', 'check', 'her', 'pro', '##th', '##rom', '##bin', 'time', '/', 'in', '##r', 'as', 'well', 'as', 'calcium', ',', 'album', '##in', 'and', 'phosphate', 'levels', '.']
# ['320', '##42', '##25', '##64', 'pad', '-', 'word']
# ['respiratory', ':']
# ['1', '.', 'co', '##rona', '##ry', 'artery', 'disease', ',']
# ['11', '/', '16', '/', '05', '02', ':', '21', 'pm']
# ['he', 'uses', 'condom', '##s', 'consistently', '.']
# ['49', '##5', '##9', '##43', '##3', 'pad', '-', 'word']
# ['2', '.', 'anxiety', '.']
# ['-', 'lower', 'ex', '##tre', '##mity', 'ed', '##ema', 'improved']
# ['over', 'the', '24', 'hours', 'of', 'in', 'house', 'hospital', '##ization', ',', 'he', 'did', 'not', 'have', 'any', 'further', 'ne', '##uro', '##log', '##ic', 'activity', 'and', 'was', 'able', 'to', 'am', '##bula', '##te', 'without', 'assistance', 'prior', 'to', 'discharge', '.']
# ['he', 'is', 'being', 'discharged', ',', 'most', 'likely', ',', 'to', 'f', '##al', '##mouth', 'hospital', '.']
# ['there', 'was', 'mild', 'finger', '-', 'to', '-', 'nose', 'd', '##ys', '##met', '##ria', 'on', 'the', 'left', '.']
# ['post', '##par', '##tum', 'disposition', ':']
# ['12', '.', 'cerebral', 'an', '##eur', '##ys', '##m', '.']
# ['in', '##fluenza', 'im', '##mu', '##ni', '##zation', 'should', 'be', 'considered', 'annually', 'in', 'the', 'fall', 'for', 'pre', '##ter', '##m', 'infants', 'with', 'chronic', 'lung', 'disease', 'once', 'they', 'reach', 'six', 'months', 'of', 'age', '.']
# ['3', '.', 'o', '##xy', '##co', '##don', '##e', '-', 'ace', '##tam', '##ino', '##phe', '##n', '5', '-', '325', 'mg', 'tablet', 'si', '##g', ':', '1', '-', '2', 'tablets', 'p', '##o', 'q', '##4', '##h', '(', 'every', '4', 'hours', ')', 'as', 'needed', 'for', 'pain', 'for', '30', 'doses', '.']
# ['m', '##rn', ':']
# ['attending', ':']
# ['6', '.', 'bus', '##pi', '##rone', '10', 'mg', 'p', '.', 'o', '.', 't', '.', 'i', '.', 'd', '.']
# ['2015', '-', '10', '-', '30', 'left', 'car', '##ot', '##id', 's', '##ten', '##ting']
# ['non', '##dy', '##smo', '##rp', '##hic', 'intact', 've', '##li', '##z', '.']
# ['short', '##ness', 'of', 'breath', '.']
# ['the', 'cardiac', 'index', 'was', 'preserved', 'at', '3', '.', '0', 'l', '/', 'min', '/', 'm', '##2', '.']
# ['this', 'is', 'a', '61', 'year', 'old', 'male', 'with', 'a', 'history', 'of', 'diabetes', ',', 'co', '##rona', '##ry', 'artery', 'disease', ',', 'he', '##pa', '##titis', 'c', ',', 'and', 'as', '##th', '##ma', 'who', 'was', 'diagnosed', 'recently', 'with', 'pan', '##cre', '##atic', 'cancer', 'after', 'he', 'presented', 'to', 'se', '##ph', '&', 'a', '##po', '##s', ';', 's', '##ju', 'memorial', 'after', 'a', 'motor', 'vehicle', 'accident', '.']
# ['past', 'g', '##yn', 'history', ':']
# ['di', '##sp', ':', '*', '50', 'tablet', '(', 's', ')', '*', 're', '##fill', '##s', ':', '*', '0', '*']
# ['e', '##k', '##g', 'revealed', 'a', 'normal', 'sin', '##us', 'rhythm', 'with', 'a', 'rate', 'of', '69', ',', 'left', 'vent', '##ric', '##ular', 'h', '##yper', '-', 'trophy', 'with', 'poor', 'anterior', 'progression', 'of', 'r', '-', 'waves', '.']
# ['hem', '##ato', '##c', '##rit', 'stable', '.']
# ['1', '.', 'f', '##ami', '##lial', 'cavern', '##ous', 'hem', '##ang', '##io', '##mas', ',', 'status', 'post', 'a', 'sub', '##ac', '##ute', 'p', '##ont', '##ine', 'hem', '##or', '##r', '##hage', '.']
# ['d', '##r', '.', 'f', '##red', '##dy', 'king', 'on', ':']
# ['on', 'hospital', 'day', 'number', 'three', ',', 'her', 'blood', 'cultures', 'came', 'back', 'positive', 'in', 'the', 'an', '##ae', '##ro', '##bic', 'culture', 'for', 'gram', '-', 'positive', 'co', '##cci', 'in', 'pairs', 'and', 'clusters', '.']
# ['family', 'history', ':']
# ['his', 'hem', '##ato', '##c', '##rit', 'increased', 'to', 'about', '30', ',', 'but', 'he', 'continued', 'to', 'have', 'hem', '##at', '##uria', 'and', 'his', 're', '##nal', 'function', 'only', 'improved', 'very', 'slowly', '.']
# ['he', 'was', 'sub', '##sque', '##ntly', 'admitted', 'to', 'the', 'i', '##cu', 'for', 'further', 'care', '.']
# ['they', 'were', 'taken', 'off', 'two', 'at', 'a', 'time', '.']
# ['significant', 'for', 'co', '##lon', 'car', '##cin', '##oma', '.']
# ['2015', '-', '06', '-', '10', 'pad', '-', 'word']
# ['2013', '-', '05', '-', '24', '12', ':', '52', 'am', '22', '65', '*', '73', '##9', '*', '52', '81', '1', '.', '0']
# ['p', '##t', 'was', '12', '.', '9', '.']
# ['m', '##rn', ':']
# ['5', '.', 'as', '##pi', '##rin', '81', 'mg', 'tablet', ',', 'ch', '##ew', '##able', 'si', '##g', ':', 'one', '(', '1', ')', 'tablet', ',', 'ch', '##ew', '##able', 'p', '##o', 'daily', '(', 'daily', ')', '.']
# ['the', 'left', 'at', '##rium', 'is', 'normal', 'in', 'size', '.']
# ['3', '.', 'aluminum', '-', 'ma', '##gnesium', 'h', '##ydro', '##xi', '##de', '225', '-', '200', 'mg', '/', '5', 'm', '##l', 'suspension', 'si', '##g', ':', '15', '-', '30', 'm', '##ls', 'p', '##o', 'q', '##id', '(', '4', 'times', 'a', 'day', ')', 'as', 'needed', '.']
# ['abdomen', 'was', 'g', '##ra', '##vid', '.']
# ['vitamin', 'c', '(', 'as', '##cor', '##bic', 'acid', ')', '1', ',', '000', 'mg', 'p', '##o', 'q', '##d', 'e', '##cas', '##a', '(', 'as', '##pi', '##rin', 'enter', '##ic', 'coated', ')', '81', 'mg', 'p', '##o', 'q', '##d', 'calcium', 'carbon', '##ate', '(', '500', 'mg', 'elemental', 'ca', '+', '+', ')', '500', 'mg', 'p', '##o', 'bid', 'pre', '##dn', '##ison', '##e', '20', 'mg', 'p', '##o', 'q', '##am', 'starting', 'today', '(', '12', '/', '09', ')']
# ['physical', 'examination', ':']
# ['admission', 'date', ':']
# ['transverse', 'pad', '-', 'word']
# ['9', ')', 'am', '##it', '##rip', '##ty', '##line', '10', 'mg', 'p', '.', 'o', '.', 'q', '.', 'h', '.', 's', '.']
# ['mouth', 'normal', 'neck', 'normal', 'thy', '##roid', 'w', '##n', '##l', 'breasts', 'normal', 'no', 'distinct', 'masses', 'nipple', '##s', 'normal', 'inverted', '[', 'b', ']', ',', 'ever', '##t', 'w', '/', 'stimulation', 'chest', 'normal', 'l', '##ct', '##a', 'co', '##r', 'normal', 'r', '##rr', 'abdomen', 'normal', 'g', '##ra', '##vid', 'ex', '##tre', '##m', 'normal', 'skin', 'normal', 'nodes', 'normal', 'v', '##ul', '##va', 'normal', 'no', 'lesions', ',', 'white', 'd', '/', 'c', 'at', 'intro', '##it', '##us', 'v', '##agi', '##na', 'normal', 's', '##m', '##l', 'am', '##t', 'thin', 'white', 'd', '/', 'c', 'p', '##h', '4', '.', '5', ',', 'k', '##oh', '+', 'am', '##ine', ',', 'n', '##s', '+', 'clue', ',', 'ne', '##g', 't', '##rich', 'c', '##er', '##vi', '##x', 'normal', '1', '/', '100', '/', '0', 's', '##rom', 'clear', 'o', '##s', 'normal', 'closed', 'ad', '##nex', '##ae', 'normal', 'no', 'p', '##al', '##p', 'masses', ',', 'n', '##t', 'u', '##ter', '##us', 'normal', 'g', '##ra', '##vid', 'u', '##ter', '##ine', 'size', 'in', 'weeks', 'normal', 'term', 're', '##ct', '##um', 'normal', 'no', 'ex', '##t', 'lesions']
# ['-', 'is', '##che', '##mic', 'co', '##lit', '##is', 'and', 'is', '##che', '##mic', 'liver', '2017', '-', '06', '-', '22', '(', 'post', 'air', 'em', '##bol', '##ism', 'from', 'post', 'media', '##st', '##inal', 'exploration', ')']
# ['he', 'was', 'admitted', 'to', 'the', 'cardiac', 'surgery', 'service', 'for', 'an', 'elected', 'bent', '##al', 'procedure', 'with', 'ho', '##mo', '##gra', '##ft', 'and', 'co', '##rona', '##ry', 'artery', 'bypass', 'g', '##raft', '.']
# ['chest', 'x', '-', 'ray', 'from', '02', '-', '07', 'had', 'linear', 'ate', '##lect', '##asis', 'in', 'right', 'lower', 'lobe', 'with', 'no', 'evidence', 'of', 'a', 'band', '-', 'like', 'op', '##acity', 'in', 'the', 'left', 'lower', 'lobe', 'which', 'was', 'evident', 'on', 'the', 'chest', 'x', '-', 'ray', 'on', '02', '-', '06', '.']
# ['discharge', 'instructions', ':']
# ['lap', '##aro', '##sco', '##py', 'with', 'bio', '##psy', 'for', 'diagnosis', '.']
# ['j', '##aco', '##b', 'u', '.', 'roll', '##and', ',', 'm', '.', 'd', '.']
# ['please', 'bring', 'your', 'out', '##patient', 'lab', 'results', 'to', 'your', 'p', '##c', '##p', '(', 'd', '##r', '.', 'hem', '##ler', ')']
# ['habits', ':']
# ['there', 'was', 'a', 'left', 'arm', 'pro', '##nat', '##or', '.']
# ['diagnosis', ':']
# ...
# ['history', 'of', 'present', 'illness', ':']
# ['on', 'h', '##d', '#', '6', ',', 'co', '##lons', '##copy', 'was', 'performed', 'for', 'de', '##com', '##press', '##ion', ',', 'and', 'revealed', 'pseudo', '##me', '##mb', '##rane', 'and', 'f', '##ria', '##ble', 'co', '##lon', '##ic', 'tissue', '.']
# ['active', 'labor']
# ['he', 'was', 'made', 'to', 'am', '##bula', '##te', 'on', 'post', '##oper', '##ative', 'day', 'one', '.']
# ['upper', 'ex', '##tre', '##mit', '##ies', 'are', 'very', 'br', '##isk', 'bilateral', '##ly', 'and', 'symmetrical', '3', '+', '.', 'there', 'is', 'positive', 't', '##rem', '##or', 'reflex', 'on', 'the', 'left', 'and', 'absent', 'on', 'the', 'right', '.']
# ['discharged', 'pad', '-', 'word']
# ['follow', '##up', 'instructions', ':']
# ['hospital', 'course', ':']
# ['sex', ':']
# ['hospital', 'course', 'by', 'systems', 'including', 'per', '##tinent', 'laboratory', 'data', ':']
# ['d', ':']
# ['he', 'should', 'also', 'follow', 'up', 'with', 'd', '##r', '.', 'rank', '##in', 'and', 'd', '##r', '.', 'la', '##ng', '##horn', '##e', '.']
# ['a', '##ista', '##ke', '##f', '##lich', '##ski', ',', 'ta', '##ine', 'd', '.', ',', 'm', '.', 'd', '.']
# ['d', '##d', ':']
# ['patient', 'states', 'complaint', ':']
# ['u', '##rina', '##ry', 'tract', 'infection']
# ['the', 'patient', 'was', 'alert', ',', 'awake', 'and', 'oriented', ',', 'pleasant', ',', 'and', 'in', 'no', 'acute', 'distress', '.']
# ['on', 'discharge', ',', 'the', 'patient', 'was', 'given', 'love', '##no', '##x', 'injection', '##s', 'which', 'should', 'be', 'continued', 'until', 'the', 'patient', 'reaches', 'a', 'therapeutic', 'dose', 'of', 'co', '##uma', '##din', '.']
# ['fever', ',', 'f', '/', 'u', 'in', '##fi', '##lt', '##rte']
# ['grade', 'ii', 'de', '##cre', '##s', '##cend', '##o', 'di', '##ast', '##olic', 'murmur', 'at', 'the', 'left', 'lower', 'stern', '##al', 'border', '.']
# ['co', '##rona', '##ry', 'artery', 'disease', ',', 'status', 'post', 'co', '##rona', '##ry', 'artery', 'bypass', 'g', '##raft', '.']
# ['1', '.', 'history', 'of', 'high', 'ch', '##ole', '##ster', '##ol', '.']
# ['1', '.', 'do', '##cus', '##ate', 'sodium', '100', 'mg', 'capsule', 'si', '##g', ':', 'one', '(', '1', ')', 'capsule', 'p', '##o', 'bid', '(', '2', 'times', 'a', 'day', ')', '.']
# ['brief', 'hospital', 'course', ':']
# ['a', 'left', 'breast', 'lump', '##ec', '##tom', '##y', 'was', 'reportedly', 'ben', '##ign', '.']
# ['the', 'patient', 'was', 'taken', 'to', 'the', 'op', '##ert', '##ing', 'room', 'on', '8', '/', '7', '/', '92', ',', 'where', 'a', 'right', 'modified', 'radical', 'mast', '##ec', '##tom', '##y', 'was', 'performed', '.']
# ['p', '##t', 'also', 'counsel', '##led', 're', ':']
# ['c', '##t', '##x', 'q', '6', '&', 'a', '##po', '##s', ';', '.']
# ['f', '/', 'u', 'with', 'd', '##r', '.', 'white']
# ['se', '##psis', '-', '?', 'source']
# ['d', ':']
# ['r', '##al', '##ph', 'ka', '##ther', '##ine', 'm', '##d', '31', '-', '164']
# ['the', 'liver', 'en', '##zi', '##mes', 'come', 'down', ',', 'no', 'signs', 'of', 'bi', '##lia', '##ry', 's', '##tas', '##is', '.']
# ['cardiac', 'exam', ';', 'she', 'has', 'positive', 's', '##1', ',', 's', '##2', 'without', 'murmur', ',', 'rub', 'or', 'gal', '##lop', '.']
# ['2019', '-', '06', '-', '19', '07', ':', '20', 'am', 'blood', 'glucose', '-', '73', 'u', '##rea', '##n', '-', '20', 'c', '##rea', '##t', '-', '1', '.', '1', 'na', '-', '136', 'k', '-', '5', '.', '0', 'c', '##l', '-', '101', 'h', '##co', '##3', '-', '27', 'an', '##ga', '##p', '-', '13']
# ['the', 'wound', 'had', 'a', 'beef', '##y', 'red', 'cell', '##uli', '##tic', 'area', 'surrounding', 'an', 'open', 'area', ',', 'b', '##lan', '##ching', 'to', 'touch', '.']
# ['ed', 'discharge', 'summary']
# ['unit', 'number', ':']
# ['you', 'were', 'diagnosed', 'with', 'an', 'e', '##pid', '##ural', 'a', '##bs', '##cess', '.']
# ['abdomen', ':', 'soft', ',', 'non', '##dis', '##tended', '.']
# ['4', '.', 'o', '##xy', '##co', '##don', '##e', '-', 'ace', '##tam', '##ino', '##phe', '##n', '5', '-', '325', 'mg', 'tablet', 'si', '##g', ':', '1', '-', '2', 'tablets', 'p', '##o', 'q', '##4', '##h', '(', 'every', '4', 'hours', ')', 'as', 'needed', 'for', 'pain', '.']
# ['*', '*', '*', '*', '*', '*', 'end', 'of', 'discharge', 'orders', '*', '*', '*', '*', '*', '*']
# ['vs', ':', 't', ',', 'b', '##p', '181', '/', '122', ',', 'h', '##r', '84', ',', 'r', '##r', '12', ',', 'o', '##2', '98', '%', '2', '##l', '/', 'm']
# ['over', 'the', 'next', 'three', 'days', 'he', 'increased', 'his', 'activity', 'gradually', ',', 'was', 'able', 'to', 'do', 'stairs', 'with', 'physical', 'therapy', 'and', 'had', 'pain', 'which', 'could', 'be', 'controlled', 'with', 'oral', 'anal', '##ges', '##ics', '.']
# ['additional', 'comments', ':']
# ['66', '##r', '-', '249', 'pad', '-', 'word']
# ['service', ':']
# ['d', ':', '2012', '-', '05', '-', '14', '19', ':', '24']
# ['hem', '##ato', '##log', '##ic', ':']
# ['1', '.', 't', '##rac', '##he', '##ost', '##omy', '.']
# ['ch', 'k', '##ote', '##ko', '##ll']
# ['job', '#', ':']
# ['from', 'sa', '##o', 'to', '##me', 'originally', '.']
# ['discharge', 'date', ':']
# ['weight', 'at', 'time', 'of', 'discharge', 'is', '3', '.', '13', 'kilograms', '.']
# ['b', '##zo', 'pad', '-', 'word']
# ['she', 'delivered', 'a', '35', '##50', 'gram', 'male', 'infant', 'on', '08', '/', '31', '/', '2004', 'at', '09', ':', '33', 'pm', 'with', 'a', '##p', '##gar', 'scores', 'of', '9', 'and', '9', 'at', 'one', 'and', 'five', 'minutes', 'respectively', 'at', '41', '.', '0', 'weeks', 'g', '##esta', '##tion', 'via', 'spontaneous', 'vertex', 'v', '##agi', '##nal', 'delivery', '.']
# ['4', '.', 'gas', '##tro', '##int', '##est', '##inal', ':', 'b', '##ost', '##on', 'required', 'treatment', 'for', 'un', '##con', '##jun', '##gated', 'h', '##yper', '##bil', '##ir', '##ubi', '##ne', '##mia', 'with', 'photo', '##ther', '##ap', '##y', '.']
# ['08', '/', '20', '/', '2000', '9', ':', '25', 'a']
# ['heart', 'sounds', 'were', 'normal', '.']
# ['past', 'surgical', 'history', ':']
# ['c', '##ta', '##b', ',', 'mildly', 'decreased', 'breath', 'sounds', 'b', '/', 'l']
# ['55', 'year', 'old', 'man', 'with', 'history', 'of', 'meta', '##static', 'bladder', 'cancer', 'and', 're', '##current', 'd', '##v', '##t', 's', 'on', 'love', '##no', '##x', 'admitted', 'with', 'lower', 'g', '##i', 'bleeding', '.']
# ['all', '##er', '##gies', ':']
# ['di', '##s', 'pad', '-', 'word']
# ['the', 'patient', 'did', 'fall', 'while', 'in', '##house', '.']
# ['2', '.', 's', '##ys', '##to', '##lic', 'and', 'di', '##ast', '##olic', 'con', '##ges', '##tive', 'heart', 'failure', '.']
# ['2015', '-', '10', '-', '26', 'pad', '-', 'word']
# ['number', 'of', 'doses', 'required', '(', 'approximate', ')', ':']
# ['the', 'patient', 'overall', 'continued', 'to', 'improve', ',', 'but', 'remained', 'physically', 'de', '##com', '##pen', '##sat', '##ed', 'and', 'the', 'patient', 'was', 'transferred', 'to', 'wa', '##lt', '##ham', '/', 'west', '##on', 'hospital', 'rehabilitation', 'hospital', 'for', 'intensive', 'physical', 'therapy', '.']
# ['y', 'pad', '-', 'word']
# ['food', '/', 'drug', 'interaction', 'instruction']
# ['the', 'patient', '&', 'a', '##po', '##s', ';', 's', 'mental', 'status', 'slowly', 'began', 'to', 'recover', ',', 'however', 'on', 'the', 'morning', 'of', 'the', 'first', 'day', 'of', 'admission', ',', 'au', '##gus', '##t', '16', ',', '1998', ',', 'the', 'patient', 'was', 'found', 'after', 'having', 'fallen', '.']
# ['no', 't', '##if', '##any', ',', 'et', '##oh', ',', 'or', 're', '##c', 'drug', 'use', '.']
# ['not', 'applicable']
# ['3', '.', 'p', '##ye', '##lone', '##ph', '##rit', '##is', '.']
# ['d', '##r', '.', 'g', '##ae', '##tz', '##f', '##re', '##ier', '##m', '1', '-', '2', 'weeks', ',']
# ['mi', '##cha', '##el', 'm', '##or', '##gan', 'm', '##d', '43', '-', '50', '##8']
# ['this', 'report', 'was', 'created', 'by', 'herd', '##es', ',', 'news', '##hali', '##e', '04', '/', '21', '/', '2005', '06', ':', '47', 'am']
# ['car', '##ot', '##id', 'pu', '##ls', '##ations', 'are', 'normal', 'without', 'br', '##uit', '.']
# ['active', ',', 'well', '-', 'developed', ',', 'well', '-', 'no', '##uri', '##shed', 'male', '.']
# ['please', 'see', 'detailed', 'operative', 'note', 'for', 'more', 'information', 'about', 'the', 'procedure', '.']
# ['follow', '##up', 'instructions', ':']
# ['it', 'is', 'possible', 'that', 'the', 'patient', 'is', 'self', 'me', '##dic', '##ating', 'for', 'underlying', 'psychiatric', 'disorder', '.']
# ['major', 'surgical', 'or', 'invasive', 'procedure', ':', 'none', 'this', 'admission']
# ['her', 'al', '##kal', '##ine', 'p', '##hos', '##pha', '##tase', 'was', '151', '##4', '.']
# ['3', '.', 'bilateral', 'le', '##ni', "'", 's']
# ['medicine', 'pad', '-', 'word']
# ['physical', 'therapy', 'has', 'been', 'seeing', 'the', 'patient', 'and', 'putting', 'him', 'through', 'passive', 'external', 'rotation', 'to', 'the', 'neutral', 'position', 'of', 'the', 'left', 'shoulder', 'and', 'forward', 'fl', '##ex', '##ion', 'with', 'physical', 'therapy', 'assistance', '.']
# ['should', 'this', 'become', 'available', ',', 'an', 'add', '##end', '##um', 'will', 'be', 'issued', 'to', 'this', 'report', 'following', 'the', 'comparison', 'with', 'the', 'outside', 'examination', '.']
# ['260', '##24', 'pad', '-', 'word']
# ['chief', 'complaint', ':']
# ['hospital', 'course', ':']
# ['he', 'is', 'now', 'living', 'with', 'his', 'son', 'and', 'daughter', ',', 'and', 'five', 'other', 'children', '.']
# ['head', 'computer', '##ized', 'to', '##mo', '##graphy', 'scan', 'of', '10', '/', '23', ':']
# ['principal', 'discharge', 'diagnosis', ';', 'responsible', 'after', 'study', 'for', 'causing', 'admission', ')', 'at', '##y', '##pical', 'chest', 'pain']
# ['her', 'co', '##agu', '##lation', 'parameters', 'were', 'normal', '.']
# ['there', 'was', 'no', 'obvious', 'segment', '##al', 'wall', '-', 'motion', 'abnormal', '##ity', '.']
# ['no', 'known', 'drug', 'all', '##er', '##gies', '.']
# ['sodium', 'of', '138', ';', 'potassium', '3', '.', '5', ';', '106', ',', '28', ',', '31', ',', '1', '.', '0', ',', 'glucose', '134', '.']
# ['they', 'recommended', 'that', 'the', 'patient', 'may', 'benefit', 'from', 'a', 'trial', 'of', 'continuous', 'positive', 'pressure', 'at', 'the', 'bedside', '.']
# ['11', '/', '26', '/', '2000', '06', ':', '47', 'pm']
# ['g', '##4', 't', '##2', 'p', '##0', 'a', '##1', 'l', '##2', 'estimated']
# ['6', '.', 'las', '##ix', '40', 'mg', 'p', '##o', 'q', '.', 'day', ',']
# ['her', 'c', '##rea', '##tin', '##ine', 'continued', 'to', 'increase', ',', 'likely', 'due', 'to', 'her', 'worse', '##ning', 'liver', 'failure', '.']
# ['none', '.']
# ['admission', 'date', ':']
# ['neck', ':']
# ['discharge', 'instructions', ':']
# ['q', '##g', 'pad', '-', 'word']
# ['she', 'is', 'to', 'contact', 'd', '##r', '.', 'warm', '&', 'a', '##po', '##s', ';', 's', 'office', 'to', 'schedule', 'a', 'follow', 'up', 'appointment', '.']
# ['care', 'and', 'recommendations', ':']
# ['medications', 'on', 'admission', ':']
# ['10', '/', '17', '/', '2001', '01', ':', '36', 'pm']
# ['past', 'medical', 'history', ':']
# ['no', 'or', '##th', '##op', '##nea', '.']
# ['chronic', 're', '##nal', 'ins', '##uff', '##iciency', '.']
# ['k', '##oter', '##ost', '##re', '##uk', '##ote', ',', 'a', '##ro', 'ma', 'o', '.', '96', '##5', '-', '81', '-', '64', '-', '6', 'u', '##9', '##4']
# ['1', '.', 'as', '##pi', '##rin', '81', 'mg', 'tablet', ',', 'delayed', 'release', '(', 'e', '.', 'c', '.', ')', 'si', '##g', ':', 'one', '(', '1', ')', 'tablet', ',', 'delayed', 'release', '(', 'e', '.', 'c', '.', ')', 'p', '##o', 'daily', '(', 'daily', ')', '.']
# ['trace', 'movement', 'of', 'the', 'right', 'elbow', 'and', '4', '-', 'strength', 'of', 'the', 'right', 'wrist', 'and', 'hand', '.']
# ['take', 'with', 'food', 'pre', '##nat', '##al', 'multi', '##vi', '##tam', '##ins', '(', 's', '##tu', '##art', '##nat', '##al', ')', '1', 'ta', '##b', 'p', '##o', 'q', '##d', 'ma', '##alo', '##x', '-', 'tablets', 'quick', 'dissolve', '/', 'ch', '##ew', '##able', '1', '-', '2', 'ta', '##b', 'p', '##o', 'q', '##6', '##h', 'p', '##rn', 'upset', 'stomach']
# ['in', '2003', ',', 'he', 'had', 'a', 'non', 's', '##t', 'elevation', 'mi', ',', 'came', 'to', 'the', 'r', '##w', '##h', ',', 'and', 'had', 'a', 'cat', '##h', 'done', ',', 'which', 'showed', 'a', '40', '%', 'r', '##ca', ',', 'which', 'was', 'ha', '##zy', '.']
# ['discharge', 'diagnosis', ':']
# ['1929', '-', '11', '-', '09', 'pad', '-', 'word']
# ['10', '/', '10', '/', '1997', '12', ':', '00', ':', '00', 'am']
# ['we', 'have', 'advised', 'a', 'bra', '##t', 'diet', '.']
# ['we', 'will', 'given', 'v', '##ali', '##um', '5', 'mg', 'p', '.', 'o', '.', 'q', '.', '3', 'hours', 'for', 'withdrawal', '.']
# ['goals', 'of', 'care', 'were', 'clarified', 'with', 'her', 'm', '##ur', '##phy', ',', 'robe', '##rt', 'sa', '##nch', '##ez', '.']
# ['the', 'patient', 'states', 'that', 'he', 'was', 'willing', 'to', 'speak', 'with', 'someone', 'from', 'addiction', 'services', '.']
# ['he', 'did', 'travel', 'to', 'the', 'ta', '##heim', '##p', '##rom', '##ong', ',', 'last', 'in', '01', '/', '2004', 'for', 'three', 'weeks', '.']
# ['the', 'telephone', 'number', 'at', 'his', 'office', 'is', '236', '-', '45', '##18', '.']
# ['medications', 'on', 'discharge', ':']
# ['disposition', ',', 'follow', 'up', 'and', 'instructions', 'to', 'patient', ':']
# ['neck', ':']
# ['2014', '-', '03', '-', '09', '02', ':', '59', 'am', 'blood', 'c', '##tro', '##p', '##nt', '-', '0', '.', '21', '*']
# ['fortunate', '##ly', ',', 'no', 'evidence', 'of', 'bar', '##at', '##roma', 'was', 'ever', 'disc', '##erne', '##d', '.']
# ['2', '.', 'l', '##isi', '##no', '##p', '##ril', '15', 'mg', 'tablet', 'si', '##g', ':', 'one', '(', '1', ')', 'tablet', 'p', '##o', 'daily', '(', 'daily', ')', '.']
# ['4', '.', 'c', '##lop', '##ido', '##g', '##rel', '75', 'mg', 'tablet', 'si', '##g', ':', 'one', '(', '1', ')', 'tablet', 'p', '##o', 'daily', '(', 'daily', ')', '.']
# ['2', '.', 'born', 'between', '32', 'and', '35', 'weeks', 'with', 'plans', 'for', 'day', '##care', 'during', 'respiratory', 's', '##ync', '##yt', '##ial', 'virus', 'season', ',', 'with', 'a', 'smoke', '##r', 'in', 'the', 'household', 'or', 'with', 'pre', '##school', 'siblings', ';', 'or']
# ['the', 'acute', 'onset', 'of', 'chest', 'pain', 'was', 'initially', 'very', 'concerning', 'for', 'a', 'p', '##e', ',', 'however', 'the', 'chest', 'c', '##t', 'demonstrated', 'multi', '##fo', '##cal', 'consolidation', 'consistent', 'with', 'a', 'bacterial', 'p', '##na', '.']
# ['no', 'ethanol', 'use', '.']
# ['he', 'was', 'continued', 'on', 'he', '##par', '##in', 'for', 'treatment', 'of', 'the', 'pulmonary', 'em', '##bol', '##i', '.']
# ['he', 'denies', 'any', 'et', '##oh', 'or', 'tobacco', 'use', '.']
# ['v', '##agi', '##nal', 'delivery', 'with', 'second', 'degree', 'lace', '##ration']
# ['she', 'came', 'to', 'the', 'emergency', 'department', 'on', 'the', '2011', '-', '03', '-', '10', ',', 'with', 'temperature', 'of', '99', '.', '0', 'f', '.', ';', 'blood', 'pressure', 'of', '97', '/', '50', ';', 'heart', 'rate', '100', ';', 're', '##spiration', '##s', '27', ';', 'o', '##2', 'sat', '##uration', '84', '%', 'on', 'room', 'air', 'and', '94', '%', 'on', 'two', 'liter', '##s', '.']
# ['s', '##rom', 'in', 'labor', '.']
# ['1', '.', 'no', 'evidence', 'of', 'pulmonary', 'em', '##bol', '##ism', '.']
# ['2013', '-', '05', '-', '23', '01', ':', '08', 'pm', '1', '.', '22']
# ['the', 'patient', 'was', 'taken', 'off', 'fluid', 'restriction', '.']
# ['3', '.', 'fluids', ',', 'electro', '##ly', '##tes', 'and', 'nutrition', '-', 'birth', '##weight', 'was', '1400', 'g', '##m', ',', '25th', 'percent', '##ile', '.']
# ['t', '##rac', '##he', '##ost', '##omy', '2014', '-', '11', '-', '11']
# ['follow', '##up', 'instructions', ':']
# ['date', 'of', 'birth', ':']
# ['2018', '-', '05', '-', '24', '08', ':', '55', 'pm']
# ['admission', 'date', ':']
# ['c', '##v', ':', 'r', '##rr', ',', 'no', 'm', '/', 'r', '/', 'g']
# ['laboratory', 'data', ':']
# ['peripheral', 'pulses', 'were', 'very', 'strong', 'and', 'bound', '##ing', '.']
# ['10', '/', '12', '/', '2004', '12', ':', '00', ':', '00', 'am']
# ['an', 'abdominal', 'm', '##ri', 'was', 'performed', 'to', 'assess', 'continued', 'elevated', 'liver', 'enzymes', ';', 'however', ',', 'the', 'm', '##ri', 'was', 'negative', '.']

# %% [markdown]
# # 9. Code snippets

# %%
# flatten1 = list(itertools.chain(*y_true))
# flatten2 = list(itertools.chain(*y_pred))
# tagsforf1 = []
# for tag in tags_vals[:-3]:
#     if tag != 'O':
#         tagsforf1.append(tag)

# %%
#https://datascience.stackexchange.com/questions/54907/model-cuda-in-pytorch
# if n_gpu >1:
#     model = torch.nn.DataParallel(model)
# model.cuda(device='cuda:0')
# model.to(torch.device('cuda:0'))

# %%
# params = list(model.named_parameters())
# print(len(params))
# for p in params[0:201]:
#     print(p[0], p[1].size())

# %%
# type(param_optimizer)
# type(optimizer_grouped_parameters)
# len(optimizer_grouped_parameters)

# type(optimizer_grouped_parameters[0])

# optimizer_grouped_parameters[1].keys()

# optimizer_grouped_parameters[0]['weight_decay_rate']

# optimizer_grouped_parameters[1]['weight_decay_rate']

# optimizer_grouped_parameters[0]['betas']

# optimizer_grouped_parameters[1]['betas']

# optimizer_grouped_parameters[1]['weight_decay']

# optimizer_grouped_parameters[1]['weight_decay']

# optimizer_grouped_parameters[0]['correct_bias']

# optimizer_grouped_parameters[1]['correct_bias']

# %%
# c =28
# print(list(attention_masks[c]))
# print(attention_masks_deprecated[c])
# for i in range(1,150):
#     if list(attention_masks[i]) != attention_masks_deprecated[i]:
#         print(i)

# %%
# tokenized_texts[0]
# tokenizer.tokenize(' '.join(sentences[0]))

# %%
# tokenizer.batch_encode_plus(sentences)['input_ids'][0]
# tokenizer.decode(tokenizer.batch_encode_plus(sentences)['input_ids'][0])
# tokenizer.decode(tokenizer.encode(' '.join(sentences[0])))
# tokenizer.decode(tokenizer.encode(sentences[0]))
# tokenizer.decode(tokenizer.encode('Diagnose revisie : ( Meerdere antwoorden mogelijk) Infectie'))

# %%
# def getmaxlength():
#     lowestcount =512
#     lowestcountindex = 0
#     for idx, onearray in enumerate(input_ids):
#         count=0
#         for number in reversed(onearray):
#             if number ==0:
#                 count += 1
#             else:
#                 if count < lowestcount:
#                     lowestcount = count
#                     lowestcountindex = idx
#                 break

#     maxlength = len(tokenized_texts[lowestcountindex])
#     return maxlength
