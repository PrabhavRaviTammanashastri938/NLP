# %% [markdown]
# #### Prabhav Ravi Tammanashastri - BL.EN.U4CSE21162
# #### Vijayakumar Soorya - BL.EN.U4CSE21220
# #### Kandukuri Jashwanth - BL.EN.U4CSE21088

# %% [markdown]
# <a href="https://colab.research.google.com/github/PieterDujardin/NER/blob/master/ColabNotebooks/i2b2_2010/BERT_on_i2b2_2010.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import statements

# %%
# %reload_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
# %pip install transformers
# %pip install seqeval
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.11.17)
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 1.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from seqeval) (1.23.5)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.10/dist-packages (from seqeval) (1.2.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval) (3.2.0)
# Building wheels for collected packages: seqeval
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16162 sha256=13a0c50f1460b9905bf8f0939a24b0c51c0efedbee7ab720e028ef5c311eb091
#   Stored in directory: /root/.cache/pip/wheels/1a/67/4a/ad4082dd7dfc30f2abfe4d80a2ed5926a506eb8a972b4767fa
# Successfully built seqeval
# Installing collected packages: seqeval
# Successfully installed seqeval-1.2.2

# %%
# %pip list | grep -E 'transformers|torch|Keras'

# %%
# %pip list

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import itertools
import csv
import time
import datetime
import io
import math
import os
import numpy as np
import torch
from sklearn.model_selection import train_test_split
from tqdm import tqdm,trange
from seqeval.metrics import f1_score
from seqeval.metrics import classification_report,accuracy_score,f1_score
# from sklearn.metrics import f1_score
from transformers import BertTokenizer, BertConfig, AutoConfig, AutoTokenizer
from transformers import BertForTokenClassification, AdamW, AutoModel, CamembertTokenizer, CamembertForTokenClassification
from keras.preprocessing.sequence import pad_sequences
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
from torch.optim import Adam
import torch.nn.functional as F
from transformers import get_linear_schedule_with_warmup

# %% [markdown]
# # Cuda

# %%
torch.cuda.is_available()
# Out:
# True

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
n_gpu = torch.cuda.device_count()

# %%
n_gpu
# Out:
# 1

# %%
# torch.cuda.get_device_name()
#tesla K80 is used by pytorch

# %%
torch.cuda.get_device_properties('cuda')
# Out:
# _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15102MB, multi_processor_count=40)

# %%
torch.cuda.current_device()
# Out:
# 0

# %%
torch.cuda.device(0)

# %%
#free memory
torch.cuda.empty_cache()

# %% [markdown]
# # 1. Functions

# %%
def loadandformat(datasets):

    # data=[]
    # for dataset in datasets:
    #   # the training, dev and test set in one file
    #   with open('drive/My Drive/Colab Notebooks/BERTwithNER3/conll2003format/{}'.format(dataset),'r') as f:
    #       data +=  f.readlines()
    sentence=[]
    sentences=[]
    for dataset in datasets:
      with open('/content/{}'.format(dataset),'r') as f:
        for line in f:
          if line == '\n':
              sentences.append(sentence)
              sentence=[]
          else:
              sentence.append(line)

    for sent in range(len(sentences)):
      for word in range(len(sentences[sent])):
          sentences[sent][word] = str(sentences[sent][word]).replace('\t',' ')
          sentences[sent][word] = str(sentences[sent][word]).rstrip('\n')
          sentences[sent][word]= str(sentences[sent][word]).split()

    sentenceslabels =[]
    sentencestext =[]

    placeholder0=[]
    placeholder1=[]

    for sent in range(len(sentences)):
      for word in range(len(sentences[sent])):
          placeholder0.append(sentences[sent][word][1])
          placeholder1.append(sentences[sent][word][0])

      sentenceslabels.append(placeholder0)
      sentencestext.append(placeholder1)
      placeholder0=[]
      placeholder1=[]

    joinedlist =[]
    for i in range(len(sentenceslabels)-1):
      joinedlist.extend(sentenceslabels[i])

    tags_vals = list(set(joinedlist))

    tags_vals.append('X')
    tags_vals.append('[CLS]')
    tags_vals.append('[SEP]')

    tag2idx = {t: i for i, t in enumerate(tags_vals)}
    tag2name={tag2idx[key] : key for key in tag2idx.keys()}


    return (sentencestext,sentenceslabels,tags_vals,tag2idx,tag2name)

# %%
def format_time(elapsed):
    '''
    Takes a time in seconds and returns a string hh:mm:ss
    '''
    # Round to the nearest second.
    elapsed_rounded = int(round((elapsed)))

    # Format as hh:mm:ss
    return str(datetime.timedelta(seconds=elapsed_rounded))

# %%
def extract_dict_with_frequency_of_UNKwords():
    '''return a dict with frequency of UNKwords that satisfy a condition'''

    my_list = []
    for word_list,label in (zip(sentences,labels)):
        for word,lab in zip(word_list,label):
            token_list = tokenizer.tokenize(word)
            if token_list == ['[UNK]'] and lab != 'O' and len(word)>= 6:
                my_list.append(word)
    freq = {}
    for item in my_list:
        if (item in freq):
            freq[item] += 1
        else:
            freq[item] = 1

    for key, value in freq.items():
        print ("% s : % d"%(key, value))
    return freq

# %%
def addUNKtokenstovocab(freqdict):
    '''add the words of freq dict to vocab'''
    list1 = list(freqdict.keys())
    for word in list1:
        tokenizer.add_tokens(word)
    print(list1)

# %%
def maketextuallyreadforinput(sentences,labels):
    tokenized_texts = []
    word_piece_labels = []

    i_inc = 0

    for word_list,label in (zip(sentences,labels)):
    #temp label and temp token are the 1 sentence labels and tokens

        temp_label = []
        temp_token = []

        # Add [CLS] at the front
        temp_label.append('[CLS]')
        temp_token.append('[CLS]')

        for word,lab in zip(word_list,label):
            token_list = tokenizer.tokenize(word)
            for m,token in enumerate(token_list):
                temp_token.append(token)
                if m==0:
                    temp_label.append(lab)
                else:
                    temp_label.append('X')

        # Add [SEP] at the end
        temp_label.append('[SEP]')
        temp_token.append('[SEP]')

        tokenized_texts.append(temp_token)
        word_piece_labels.append(temp_label)

        if 50 > i_inc >= 0:
            print("No.%d,len:%d"%(i_inc,len(temp_token)))
            print("texts:%s"%(" ".join(temp_token)))
            print("No.%d,len:%d"%(i_inc,len(temp_label)))
            print("lables:%s"%(" ".join(temp_label)))
        i_inc +=1

    return (tokenized_texts,word_piece_labels)

# %%
def convertokens(max_len,tokenized_texts,word_piece_labels,sentences):
    # Do-something if <condition>, else do-something else.
    input_ids = pad_sequences([tokenizer.convert_tokens_to_ids(txt) for txt in tokenized_texts],
                        maxlen=max_len, dtype="long", truncating="post", padding="post")

    tags = pad_sequences([[tag2idx.get(l) for l in lab] for lab in word_piece_labels],
                  maxlen=max_len, value=tag2idx["O"], padding="post",
                  dtype="long", truncating="post")


    attention_masks_deprecated = [[int(i>0) for i in ii] for ii in input_ids]
    segment_ids = [[0] * len(input_id) for input_id in input_ids]

    allsentences = []
    for sentence in sentences:
        sentence = ' '.join(sentence)
    #     print(sentence)
        allsentences.append(sentence)

    attention_masks = pad_sequences(tokenizer.batch_encode_plus(allsentences)['attention_mask'],
                            maxlen=max_len, dtype="long", truncating="post", padding="post")

#     print(pad_sequences(tokenizer.batch_encode_plus(sentences)['input_ids'][0:2],
#                             maxlen=max_len, dtype="long", truncating="post", padding="post"))

    return (input_ids,tags,attention_masks,segment_ids, attention_masks_deprecated)

# %%
def split_tensor_dataloader(input_ids, tags, attention_masks, segment_ids,batch_num, sizeoftest, sizeofdev):

    tr_inputs, test_inputs, tr_tags, test_tags,tr_masks, test_masks,tr_segs, test_segs = train_test_split(input_ids, tags, attention_masks, segment_ids,
                                                            random_state=1, test_size=sizeoftest)

    tr_inputs, val_inputs, tr_tags, val_tags,tr_masks, val_masks,tr_segs, val_segs = train_test_split(tr_inputs, tr_tags, tr_masks, tr_segs,
                                                            random_state=1, test_size=sizeofdev)

    tr_inputs = torch.tensor(tr_inputs)
    val_inputs = torch.tensor(val_inputs)
    test_inputs = torch.tensor(test_inputs)

    tr_tags = torch.tensor(tr_tags)
    val_tags = torch.tensor(val_tags)
    test_tags = torch.tensor(test_tags)

    tr_masks = torch.tensor(tr_masks)
    val_masks = torch.tensor(val_masks)
    test_masks = torch.tensor(test_masks)

    tr_segs = torch.tensor(tr_segs)
    val_segs = torch.tensor(val_segs)
    test_segs = torch.tensor(test_segs)




    # Only set token embedding, attention embedding, no segment embedding
    train_data = TensorDataset(tr_inputs, tr_masks, tr_tags)
    train_sampler = RandomSampler(train_data)
    # Drop last can make batch training better for the last one
    train_dataloader = DataLoader(train_data, sampler=train_sampler, batch_size=batch_num,drop_last=True)

    #same for validation data
    valid_data = TensorDataset(val_inputs, val_masks, val_tags)
    valid_sampler = SequentialSampler(valid_data)
    valid_dataloader = DataLoader(valid_data, sampler=valid_sampler, batch_size=batch_num)

    test_data = TensorDataset(test_inputs, test_masks, test_tags)
    test_sampler = RandomSampler(test_data)
    # Drop last can make batch training better for the last one
    test_dataloader = DataLoader(test_data, sampler=test_sampler, batch_size=batch_num,drop_last=True)



    return (train_dataloader,valid_dataloader,test_dataloader,tr_inputs,val_inputs,test_inputs)

# %%
def makemodelreadyfortraining(FULL_FINETUNING):


    # Cacluate train optimization num
    num_train_optimization_steps = int( math.ceil(len(tr_inputs) / batch_num) / 1) * epochs


    # True: fine tuning all the layers
    # False: only fine tuning the classifier layers
    if FULL_FINETUNING:
      # Fine tune model all layer parameters
        param_optimizer = list(model.named_parameters()) # list with named parameters and parameters themselves
        no_decay = ['bias', 'gamma', 'beta']

        # list of 2 dicts; only weight decay rate is different : dict_keys(['params', 'weight_decay_rate', 'lr', 'betas', 'eps', 'weight_decay', 'correct_bias'])
        optimizer_grouped_parameters = [
          {'params': [p for n, p in param_optimizer if not any(nd in n for nd in no_decay)],
          'weight_decay_rate': 0.01},
          {'params': [p for n, p in param_optimizer if any(nd in n for nd in no_decay)],
          'weight_decay_rate': 0.0}]

    else:
      # Only fine tune classifier parameters
        param_optimizer = list(model.classifier.named_parameters())
        optimizer_grouped_parameters = [{"params": [p for n, p in param_optimizer]}]

    return (optimizer_grouped_parameters, num_train_optimization_steps)

# %% [markdown]
# # 2. Load data, load model and parameter specification

# %%
#load data:
(sentences,labels,tags_vals,tag2idx,tag2name) = loadandformat(['train.txt','dev.txt','test.txt']) # 'train.txt' 'dev.txt','test.txt'

# %%
tag2name
# Out:
# {0: 'I-test',
#  1: 'B-treatment',
#  2: 'O',
#  3: 'I-treatment',
#  4: 'B-problem',
#  5: 'B-test',
#  6: 'I-problem',
#  7: 'X',
#  8: '[CLS]',
#  9: '[SEP]'}

# %%
#set parameters
epochs = 2
batch_num = 8
learningrate=5e-5

max_grad_norm = 1.0
sizeoftest =0.25#size of test set (first split)
sizeofdev =0.2 #size of dev set (second split)
FULL_FINETUNING = True #Whether to tune all or last layer(s)

# %%
#model

# Load model directly
from transformers import AutoTokenizer, AutoModelForTokenClassification

tokenizer = AutoTokenizer.from_pretrained("medical-ner-proj/albert-medical-ner-proj")
model = AutoModelForTokenClassification.from_pretrained("medical-ner-proj/albert-medical-ner-proj")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:72: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/495 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.27M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/286 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.27k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/44.4M [00:00<?, ?B/s]

# %%
import re

text = '''
Admission   O
Date   O
:   O

2012-10-31   O
PAD-WORD   O

Discharge   O
Date   O
:   O

2012-11-07   O
PAD-WORD   O

Date   O
of   O
Birth   O
:   O

1941-03-23   O
PAD-WORD   O

Sex   O
:   O

M   O
PAD-WORD   O

Service   O
:   O

MEDICINE   O
PAD-WORD   O

Allergies   O
:   O

Nsaids/Anti-Inflammatory   B-treatment
Classifier   I-treatment
/   O
Vancomycin   B-treatment

Attending   O
:   O

Kristie   O
R.   O
Hamby   O
,   O
M.D.   O

Chief   O
Complaint   O
:   O

CC   O
:   O
Antonio   O
M.   O
Z.   O
Eddings   O
,   O
M.D.   O

Major   O
Surgical   O
or   O
Invasive   O
Procedure   O
:   O

Mesenteric   B-test
angiograpm   I-test
w/   O
coil   B-treatment
embolization   I-treatment
of   O
bleeding   B-problem
vessel   I-problem
.   O

Sigmoidoscopy   B-test
.   O

Colonoscopy   B-test
.   O
'''

text = re.sub(r'\s+', ' ', text).strip()

tokens = text.split(' ')

result = []
for i in range(len(tokens)):
  if i % 2 == 0:
    result.append((tokens[i], 'O'))
  else:
    result.append((tokens[i], tokens[i-1]))

print(result)
# Out:
# [('Admission', 'O'), ('O', 'Admission'), ('Date', 'O'), ('O', 'Date'), (':', 'O'), ('O', ':'), ('2012-10-31', 'O'), ('O', '2012-10-31'), ('PAD-WORD', 'O'), ('O', 'PAD-WORD'), ('Discharge', 'O'), ('O', 'Discharge'), ('Date', 'O'), ('O', 'Date'), (':', 'O'), ('O', ':'), ('2012-11-07', 'O'), ('O', '2012-11-07'), ('PAD-WORD', 'O'), ('O', 'PAD-WORD'), ('Date', 'O'), ('O', 'Date'), ('of', 'O'), ('O', 'of'), ('Birth', 'O'), ('O', 'Birth'), (':', 'O'), ('O', ':'), ('1941-03-23', 'O'), ('O', '1941-03-23'), ('PAD-WORD', 'O'), ('O', 'PAD-WORD'), ('Sex', 'O'), ('O', 'Sex'), (':', 'O'), ('O', ':'), ('M', 'O'), ('O', 'M'), ('PAD-WORD', 'O'), ('O', 'PAD-WORD'), ('Service', 'O'), ('O', 'Service'), (':', 'O'), ('O', ':'), ('MEDICINE', 'O'), ('O', 'MEDICINE'), ('PAD-WORD', 'O'), ('O', 'PAD-WORD'), ('Allergies', 'O'), ('O', 'Allergies'), (':', 'O'), ('O', ':'), ('Nsaids/Anti-Inflammatory', 'O'), ('B-treatment', 'Nsaids/Anti-Inflammatory'), ('Classifier', 'O'), ('I-treatment', 'Classifier'), ('/', 'O'), ('O', '/'), ('Vancomycin', 'O'), ('B-treatment', 'Vancomycin'), ('Attending', 'O'), ('O', 'Attending'), (':', 'O'), ('O', ':'), ('Kristie', 'O'), ('O', 'Kristie'), ('R.', 'O'), ('O', 'R.'), ('Hamby', 'O'), ('O', 'Hamby'), (',', 'O'), ('O', ','), ('M.D.', 'O'), ('O', 'M.D.'), ('Chief', 'O'), ('O', 'Chief'), ('Complaint', 'O'), ('O', 'Complaint'), (':', 'O'), ('O', ':'), ('CC', 'O'), ('O', 'CC'), (':', 'O'), ('O', ':'), ('Antonio', 'O'), ('O', 'Antonio'), ('M.', 'O'), ('O', 'M.'), ('Z.', 'O'), ('O', 'Z.'), ('Eddings', 'O'), ('O', 'Eddings'), (',', 'O'), ('O', ','), ('M.D.', 'O'), ('O', 'M.D.'), ('Major', 'O'), ('O', 'Major'), ('Surgical', 'O'), ('O', 'Surgical'), ('or', 'O'), ('O', 'or'), ('Invasive', 'O'), ('O', 'Invasive'), ('Procedure', 'O'), ('O', 'Procedure'), (':', 'O'), ('O', ':'), ('Mesenteric', 'O'), ('B-test', 'Mesenteric'), ('angiograpm', 'O'), ('I-test', 'angiograpm'), ('w/', 'O'), ('O', 'w/'), ('coil', 'O'), ('B-treatment', 'coil'), ('embolization', 'O'), ('I-treatment', 'embolization'), ('of', 'O'), ('O', 'of'), ('bleeding', 'O'), ('B-problem', 'bleeding'), ('vessel', 'O'), ('I-problem', 'vessel'), ('.', 'O'), ('O', '.'), ('Sigmoidoscopy', 'O'), ('B-test', 'Sigmoidoscopy'), ('.', 'O'), ('O', '.'), ('Colonoscopy', 'O'), ('B-test', 'Colonoscopy'), ('.', 'O'), ('O', '.')]

# %%
a=[result[i] for i in range(0,len(result),2)]
a
# Out:
# [('Admission', 'O'),
#  ('Date', 'O'),
#  (':', 'O'),
#  ('2012-10-31', 'O'),
#  ('PAD-WORD', 'O'),
#  ('Discharge', 'O'),
#  ('Date', 'O'),
#  (':', 'O'),
#  ('2012-11-07', 'O'),
#  ('PAD-WORD', 'O'),
#  ('Date', 'O'),
#  ('of', 'O'),
#  ('Birth', 'O'),
#  (':', 'O'),
#  ('1941-03-23', 'O'),
#  ('PAD-WORD', 'O'),
#  ('Sex', 'O'),
#  (':', 'O'),
#  ('M', 'O'),
#  ('PAD-WORD', 'O'),
#  ('Service', 'O'),
#  (':', 'O'),
#  ('MEDICINE', 'O'),
#  ('PAD-WORD', 'O'),
#  ('Allergies', 'O'),
#  (':', 'O'),
#  ('Nsaids/Anti-Inflammatory', 'O'),
#  ('Classifier', 'O'),
#  ('/', 'O'),
#  ('Vancomycin', 'O'),
#  ('Attending', 'O'),
#  (':', 'O'),
#  ('Kristie', 'O'),
#  ('R.', 'O'),
#  ('Hamby', 'O'),
#  (',', 'O'),
#  ('M.D.', 'O'),
#  ('Chief', 'O'),
#  ('Complaint', 'O'),
#  (':', 'O'),
#  ('CC', 'O'),
#  (':', 'O'),
#  ('Antonio', 'O'),
#  ('M.', 'O'),
#  ('Z.', 'O'),
#  ('Eddings', 'O'),
#  (',', 'O'),
#  ('M.D.', 'O'),
#  ('Major', 'O'),
#  ('Surgical', 'O'),
#  ('or', 'O'),
#  ('Invasive', 'O'),
#  ('Procedure', 'O'),
#  (':', 'O'),
#  ('Mesenteric', 'O'),
#  ('angiograpm', 'O'),
#  ('w/', 'O'),
#  ('coil', 'O'),
#  ('embolization', 'O'),
#  ('of', 'O'),
#  ('bleeding', 'O'),
#  ('vessel', 'O'),
#  ('.', 'O'),
#  ('Sigmoidoscopy', 'O'),
#  ('.', 'O'),
#  ('Colonoscopy', 'O'),
#  ('.', 'O')]

# %% [markdown]
# # 3. Function calls

# %%
# extract frequent OOV words and add them to vocab of tokenizer
freq_dict = extract_dict_with_frequency_of_UNKwords()
addUNKtokenstovocab(freq_dict)
# Out:
# []

# %%
(tokenized_texts,word_piece_labels) = maketextuallyreadforinput(sentences,labels)
max_len  = len(max(tokenized_texts, key=len))
# max_len = 150
# Out:
# No.0,len:33
# texts:[CLS] ▁after ▁being ▁transferred ▁from ▁the ▁intervention al ▁radio logy ▁table ▁to ▁the ▁stretch er ▁ , ▁one ▁of ▁his ▁lateral ▁per cutaneous ▁drain s ▁had ▁been ▁pulled ▁out ▁inadvertently ▁ . [SEP]
# No.0,len:33
# lables:[CLS] O O O O O O X O X O O O O X O X O O B-treatment I-treatment I-treatment X I-treatment X O O O O O O X [SEP]
# No.1,len:29
# texts:[CLS] ▁he ▁was ▁admitted ▁to ▁the ▁re tel k ▁county ▁medical ▁center ▁at ▁that ▁time ▁and ▁was ▁treated ▁with ▁bac tri m ▁and ▁ steroid s ▁ . [SEP]
# No.1,len:29
# lables:[CLS] O O O O O O X X O O O O O O O O O O B-treatment X X O B-treatment X X O X [SEP]
# No.2,len:11
# texts:[CLS] ▁she ▁was ▁seen ▁by ▁the ▁psychiatry ▁service ▁ . [SEP]
# No.2,len:11
# lables:[CLS] O O O O O B-treatment I-treatment O X [SEP]
# No.3,len:10
# texts:[CLS] ▁1958 - 03 - 17 ▁pad - word [SEP]
# No.3,len:10
# lables:[CLS] O X X X X O X X [SEP]
# No.4,len:9
# texts:[CLS] ▁ 435 134 2 ▁pad - word [SEP]
# No.4,len:9
# lables:[CLS] O X X X O X X [SEP]
# No.5,len:17
# texts:[CLS] ▁ - ▁al but er ol ▁ / ▁at ro vent ▁neb s ▁q 4 [SEP]
# No.5,len:17
# lables:[CLS] O X B-treatment X X X O X B-treatment X X O X O X [SEP]
# No.6,len:21
# texts:[CLS] ▁patient ▁was ▁also ▁found ▁to ▁have ▁abnormal ▁ t ft s ▁on ▁sut ent ▁and ▁was ▁started ▁on ▁replacement [SEP]
# No.6,len:21
# lables:[CLS] O O O O O O B-problem I-problem X X X O B-treatment X O O O O B-treatment [SEP]
# No.7,len:22
# texts:[CLS] ▁she ▁has ▁on ▁her ▁right ▁ankle ▁anterior ly ▁a ▁four ▁cent i meter ▁ulcer ▁with ▁necro tic ▁base ▁ . [SEP]
# No.7,len:22
# lables:[CLS] O O O O O O O X B-problem I-problem I-problem X X I-problem I-problem I-problem X I-problem O X [SEP]
# No.8,len:6
# texts:[CLS] ▁signed ▁pad - word [SEP]
# No.8,len:6
# lables:[CLS] O O X X [SEP]
# No.9,len:26
# texts:[CLS] ▁he ▁had ▁a ▁left ▁pupil ▁that ▁was ▁in ▁unequal ▁in ▁size ▁with ▁a ▁key hole ▁appearance ▁consistent ▁with ▁a ▁co lobo ma ▁ . [SEP]
# No.9,len:26
# lables:[CLS] O O O O O O O O B-problem I-problem I-problem O B-problem I-problem X I-problem O O B-problem I-problem X X O X [SEP]
# No.10,len:8
# texts:[CLS] ▁38 385 56 ▁pad - word [SEP]
# No.10,len:8
# lables:[CLS] O X X O X X [SEP]
# No.11,len:8
# texts:[CLS] ▁reason ▁for ▁over ride ▁ : [SEP]
# No.11,len:8
# lables:[CLS] O O O X O X [SEP]
# No.12,len:22
# texts:[CLS] ▁the ▁was ▁trace ▁mi tral ▁re gur git ation ▁and ▁trace ▁tri cus pid ▁re gur git ation ▁ . [SEP]
# No.12,len:22
# lables:[CLS] O O B-problem I-problem X I-problem X X X O B-problem I-problem X X I-problem X X X O X [SEP]
# No.13,len:22
# texts:[CLS] ▁3 rd ▁floor ▁henderson ▁building ▁with ▁dr . ▁black ▁ ( ▁ 650 ▁ ) ▁8 66 - 136 1 [SEP]
# No.13,len:22
# lables:[CLS] O X O O O O O X O O X O X O X O X X X X [SEP]
# No.14,len:13
# texts:[CLS] ▁full ▁term ▁male ▁infant ▁with ▁c yan osis ▁episodes ▁ . [SEP]
# No.14,len:13
# lables:[CLS] O O O O O B-problem X X I-problem O X [SEP]
# No.15,len:17
# texts:[CLS] ▁the ▁patient ▁had ▁no ▁blood ▁cultures ▁to ▁grow ▁cory ne bacterium ▁while ▁hospitalized ▁ . [SEP]
# No.15,len:17
# lables:[CLS] O O O O B-test I-test O O B-problem X X O O O X [SEP]
# No.16,len:20
# texts:[CLS] ▁there ▁is ▁a ▁linear ▁right ▁temporal ▁cal vari al ▁fracture ▁extending ▁into ▁the ▁right ▁temporal ▁bones ▁ . [SEP]
# No.16,len:20
# lables:[CLS] O O B-problem I-problem I-problem I-problem I-problem X X I-problem O O O O O O O X [SEP]
# No.17,len:10
# texts:[CLS] ▁there ▁was ▁no ▁he a ve ▁ . [SEP]
# No.17,len:10
# lables:[CLS] O O O B-problem X X O X [SEP]
# No.18,len:13
# texts:[CLS] ▁4 . ▁non in s ulin ▁dependent ▁diabetes ▁me lli tus [SEP]
# No.18,len:13
# lables:[CLS] O X B-problem X X X I-problem I-problem I-problem X X [SEP]
# No.19,len:12
# texts:[CLS] ▁ 6/ 15 / 1994 ▁1 2:00 : 00 ▁am [SEP]
# No.19,len:12
# lables:[CLS] O X X X X O X X X O [SEP]
# No.20,len:37
# texts:[CLS] ▁on ▁2014 - 04 - 09 ▁ , ▁patient ▁continued ▁to ▁do ▁very ▁well ▁ , ▁ ambul ating ▁ , ▁to ler ating ▁a ▁diet ▁ , ▁u rin ating ▁without ▁difficulty ▁ . [SEP]
# No.20,len:37
# lables:[CLS] O O X X X X O X O O O O O O O X O X X O X O X X O O O X O X X O B-problem O X [SEP]
# No.21,len:25
# texts:[CLS] ▁c iwa ▁scale ▁over ▁night ▁was ▁1 ▁for ▁tremor ▁and ▁the ▁patient ▁did ▁not ▁require ▁any ▁val ium ▁for ▁alcohol ▁withdrawal ▁ . [SEP]
# No.21,len:25
# lables:[CLS] B-test X I-test O O O O O B-problem O O O O O O O B-treatment X O B-problem I-problem O X [SEP]
# No.22,len:17
# texts:[CLS] ▁patient ▁has ▁a ▁history ▁of ▁suicidal ▁idea tion s ▁and ▁self ▁muti lation ▁ . [SEP]
# No.22,len:17
# lables:[CLS] O O O O O B-problem I-problem X X O B-problem I-problem X O X [SEP]
# No.23,len:50
# texts:[CLS] ▁9 . ▁i pra trop ium ▁brom ide ▁17 ▁mcg ▁ / ▁a ctu ation ▁aero sol ▁sig ▁ : ▁two ▁ ( ▁2 ▁ ) ▁puff ▁in hal ation ▁q 4 - 6 h ▁ ( ▁every ▁4 ▁to ▁6 ▁hours ▁ ) ▁as ▁needed ▁ . [SEP]
# No.23,len:50
# lables:[CLS] O X B-treatment X X X I-treatment X O O O X O X X O X O O X O O X O O X O O X X O X X X X O X O O O O O O X O O O X [SEP]
# No.24,len:8
# texts:[CLS] ▁h / o ▁et oh ▁abuse [SEP]
# No.24,len:8
# lables:[CLS] O X X O X O [SEP]
# No.25,len:5
# texts:[CLS] ▁batch ▁ : [SEP]
# No.25,len:5
# lables:[CLS] O O X [SEP]
# No.26,len:5
# texts:[CLS] ▁provider ▁ : [SEP]
# No.26,len:5
# lables:[CLS] O O X [SEP]
# No.27,len:10
# texts:[CLS] ▁2013 - 12 - 24 ▁pad - word [SEP]
# No.27,len:10
# lables:[CLS] O X X X X O X X [SEP]
# No.28,len:56
# texts:[CLS] ▁the ▁patient ▁is ▁a ▁40 ▁year ▁old ▁male ▁with ▁a ▁history ▁of ▁prior ▁anterior ▁my o cardi al ▁in far c tion ▁and ▁insulin ▁dependent ▁diabetes ▁me lli tus ▁who ▁was ▁transferred ▁from ▁an ▁outside ▁hospital ▁after ▁an ▁episode ▁of ▁acute ▁short ness ▁of ▁breath ▁and ▁pul mon ary ▁ ed ema ▁ . [SEP]
# No.28,len:56
# lables:[CLS] O O O O O O O O O O O O B-problem I-problem I-problem X X X I-problem X X X O B-problem I-problem I-problem I-problem X X O O O O O O O O O O O B-problem I-problem X I-problem I-problem O B-problem X X I-problem X X O X [SEP]
# No.29,len:13
# texts:[CLS] ▁ 05 / 09 / 2004 ▁1 2:00 : 00 ▁am [SEP]
# No.29,len:13
# lables:[CLS] O X X X X X O X X X O [SEP]
# No.30,len:25
# texts:[CLS] ▁the ▁patient ▁was ▁corrected ▁to ▁a ▁normal ▁ph ▁of ▁7 . 41 ▁by ▁the ▁first ▁post operative ▁night ▁and ▁remained ▁stable ▁ . [SEP]
# No.30,len:25
# lables:[CLS] O O O O O O O O O O X X O O O O X O O O O O X [SEP]
# No.31,len:7
# texts:[CLS] ▁past ▁medical ▁history ▁ : [SEP]
# No.31,len:7
# lables:[CLS] O O O O X [SEP]
# No.32,len:11
# texts:[CLS] ▁64 2 - 07 - 90 ▁pad - word [SEP]
# No.32,len:11
# lables:[CLS] O X X X X X O X X [SEP]
# No.33,len:24
# texts:[CLS] ▁he ▁was ▁admitted ▁on ▁ 06 / 07 / 00 ▁for ▁a ▁matched ▁ , ▁unrelated ▁donor ▁bone ▁marrow ▁transplant ▁ . [SEP]
# No.33,len:24
# lables:[CLS] O O O O O X X X X X O B-treatment I-treatment I-treatment X I-treatment I-treatment I-treatment I-treatment I-treatment O X [SEP]
# No.34,len:27
# texts:[CLS] ▁abd ▁ : ▁soft ▁ , ▁+ dis tension ▁with ▁ty mp any ▁ , ▁no ▁h s m ▁ , ▁hyper active ▁b s [SEP]
# No.34,len:27
# lables:[CLS] O O X O O X B-problem X X O B-problem X X O X O B-problem X X O X B-problem X I-problem X [SEP]
# No.35,len:10
# texts:[CLS] ▁the ▁patient ▁is ▁hard ▁of ▁hearing ▁ . [SEP]
# No.35,len:10
# lables:[CLS] O O O B-problem I-problem I-problem O X [SEP]
# No.36,len:13
# texts:[CLS] ▁ d ▁ : ▁2016 - 11 - 10 ▁18 :28 [SEP]
# No.36,len:13
# lables:[CLS] O X O X O X X X X O X [SEP]
# No.37,len:9
# texts:[CLS] ▁ ( ▁end ▁of ▁report ▁ ) [SEP]
# No.37,len:9
# lables:[CLS] O X O O O O X [SEP]
# No.38,len:10
# texts:[CLS] ▁major ▁surgical ▁or ▁ invasive ▁procedure ▁ : [SEP]
# No.38,len:10
# lables:[CLS] O O O O X O O X [SEP]
# No.39,len:6
# texts:[CLS] ▁neuro logic ▁ : [SEP]
# No.39,len:6
# lables:[CLS] O X O X [SEP]
# No.40,len:5
# texts:[CLS] ▁general ▁ : [SEP]
# No.40,len:5
# lables:[CLS] O O X [SEP]
# No.41,len:44
# texts:[CLS] ▁he ▁had ▁a ▁past ▁history ▁of ▁ ische mic ▁cardio my opathy ▁with ▁an ▁eject ion ▁fraction ▁of ▁10 ▁ , ▁mild ▁a or tic ▁sten osis ▁and ▁a ▁right ▁middle ▁cerebral ▁artery ▁territory ▁stroke ▁in ▁ 07 / 94 ▁ . [SEP]
# No.41,len:44
# lables:[CLS] O O O O O O B-problem X X I-problem X X O B-test I-test X I-test O O O X B-problem I-problem X X I-problem X O B-problem I-problem I-problem I-problem I-problem I-problem I-problem O O X X X O X [SEP]
# No.42,len:18
# texts:[CLS] ▁the ▁patient ▁was ▁discharged ▁to ▁home ▁for ▁hospice ▁on ▁march ▁8 ▁ , ▁1999 ▁ . [SEP]
# No.42,len:18
# lables:[CLS] O O O O O O O B-treatment O O O O X O O X [SEP]
# No.43,len:24
# texts:[CLS] ▁the ▁cause ▁of ▁this ▁ ery the ma ▁is ▁not ▁know ▁at ▁this ▁time ▁but ▁has ▁not ▁shown ▁extensive ▁progression ▁ . [SEP]
# No.43,len:24
# lables:[CLS] O O O B-problem I-problem X X X O O O O O O O O O O O O O X [SEP]
# No.44,len:31
# texts:[CLS] ▁in ▁regards ▁to ▁his ▁rhythm ▁ , ▁he ▁has ▁an ▁underlying ▁right ▁bundle ▁branch ▁block ▁and ▁first - degree ▁av ▁block ▁which ▁were ▁stable ▁throughout ▁this ▁admission ▁ . [SEP]
# No.44,len:31
# lables:[CLS] O O O O O O X O O B-problem I-problem I-problem I-problem I-problem I-problem O B-problem X X I-problem I-problem O O O O O O O X [SEP]
# No.45,len:5
# texts:[CLS] ▁job ▁# : [SEP]
# No.45,len:5
# lables:[CLS] O O X [SEP]
# No.46,len:9
# texts:[CLS] ▁nancy ▁lois ▁md ▁88 - 4 49 [SEP]
# No.46,len:9
# lables:[CLS] O O O O X X X [SEP]
# No.47,len:15
# texts:[CLS] ▁ cranial ▁nerves ▁notable ▁for ▁bilateral ▁ es o trop ia ▁ . [SEP]
# No.47,len:15
# lables:[CLS] O X O O O B-problem I-problem X X X X O X [SEP]
# No.48,len:15
# texts:[CLS] ▁he ▁is ▁admitted ▁at ▁this ▁time ▁because ▁of ▁significant ▁gi ▁bleeding ▁ . [SEP]
# No.48,len:15
# lables:[CLS] O O O O O O O O B-problem I-problem I-problem O X [SEP]
# No.49,len:6
# texts:[CLS] ▁code ▁status ▁ : [SEP]
# No.49,len:6
# lables:[CLS] O O O X [SEP]

# %%
(input_ids,tags,attention_masks,segment_ids,attention_masks_deprecated) = convertokens(max_len,tokenized_texts,word_piece_labels,sentences)

# %%
(train_dataloader,valid_dataloader,test_dataloader,tr_inputs,val_inputs,test_inputs) = split_tensor_dataloader(input_ids, tags, attention_masks, segment_ids,batch_num, sizeoftest, sizeofdev)

# %%
optimizer = AdamW(model.parameters(), lr=learningrate)
total_steps = len(train_dataloader) * epochs
scheduler = get_linear_schedule_with_warmup(optimizer,
                                            num_warmup_steps = 0, # default
                                            num_training_steps = total_steps)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %% [markdown]
# # 4. Training

# %%
#extend embedding matrix with new vocab
model.resize_token_embeddings(len(tokenizer))
# Out:
# Embedding(30000, 128, padding_idx=0)

# %%
if n_gpu >1:
    model = torch.nn.DataParallel(model)

# %%
print("***** Training Info *****")
print("  Num examples = %d"%(len(tr_inputs)))
print("  Batch size = %d"%(batch_num))
print("  Num steps = %d"%(total_steps))
# Out:
# ***** Training Info *****
#   Num examples = 9800
#   Batch size = 8
#   Num steps = 2450

# %%
seed_val = 10
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)

loss_values = []
training_stats = []

total_t0 = time.time()
# for _ in trange(epochs,desc=" Epoch"):
for _ in range(epochs):

    print("")
    print('======== Epoch {:} / {:} ========'.format(_+1, epochs))
    print('\033[1m'+'Training...'+ '\033[0m')

    model.train()
    # Set model to GPU,if you are using GPU machine
    model.cuda()

    t0 = time.time()


    tr_loss = 0 # total training loss for one epoch
    nb_tr_examples, nb_tr_steps = 0, 0

    for step, batch in enumerate(train_dataloader):
        # add batch to gpu
        batch = tuple(t.to(device) for t in batch)
        b_input_ids, b_input_mask, b_labels = batch

        model.zero_grad()

        # forward pass
        outputs = model(b_input_ids, token_type_ids=None,
        attention_mask=b_input_mask, labels=b_labels)

        loss, scores = outputs[:2]
        if n_gpu>1:
            # When multi gpu, average it
            loss = loss.mean()

        # backward pass
        loss.backward()

        # track train loss:
        #Accumulate the training loss over all of the batches so that we can calculate the average loss at the end.
        tr_loss += loss.item()
        nb_tr_steps += 1

        # gradient clipping
        torch.nn.utils.clip_grad_norm_(parameters=model.parameters(), max_norm=max_grad_norm)

        # update parameters
        optimizer.step()
        # Update the learning rate.
        scheduler.step()

        optimizer.zero_grad()


    print("")
    print("Epoch finished (training progress):")
    # average the training loss
    avg_train_loss = tr_loss/nb_tr_steps
    print("   Train loss: {}".format(avg_train_loss))
    training_time = format_time(time.time() - t0)
    print("   Training epoch took: {:}".format(training_time))

    # Store the loss value for plotting the learning curve.
    loss_values.append(avg_train_loss)


    #eval LOOP
    total_eval_loss, eval_accuracy = 0, 0
    nb_eval_steps, nb_eval_examples = 0, 0
    y_true = []
    y_pred = []
    valdataset = []

    y_true_full = []
    y_pred_full = []
    valdataset_full = []

    t0 = time.time()

    model.eval()

    for step, batch in enumerate(valid_dataloader):
        batch = tuple(t.to(device) for t in batch)
        input_ids, input_mask, label_ids = batch #same as we did in training loop but only 1 epoch now


        with torch.no_grad(): #means we don't care about gradients and updating tensors
            outputs = model(input_ids, token_type_ids=None,
            attention_mask=input_mask,labels=label_ids)
            # For eval mode, the first result of outputs is logits (for training mode this was loss)
#             logits = outputs[0]
            loss, logits = outputs[:2]#  In context of deep learning the logits layer means the layer that feeds in to softmax (or other such normalization).

        loss = loss.mean()
        total_eval_loss += loss.item()


        # Get NER predict result
        logits = torch.argmax(F.log_softmax(logits,dim=2),dim=2)#feed logits into softmax and take the prediction that is maximal
        logits = logits.detach().cpu().numpy()

        # Get NER true result
        label_ids = label_ids.to('cpu').numpy()

        # Only predict the real word, mark=0, will not calculate
        input_mask = input_mask.to('cpu').numpy()


        # Compare the valuable predict result
        for i,mask in enumerate(input_mask):
            # Real one
            temp_1 = []
            # Predicted one
            temp_2 = []
            valtemp = []

            temp_1_full = []
            # Predicted one
            temp_2_full = []
            valtemp_full = []

            for j, m in enumerate(mask):
                # Mark=0, meaning its a pad word, dont compare
                if m :
                    if tag2name[label_ids[i][j]] != "X" and tag2name[label_ids[i][j]] != "[CLS]" and tag2name[label_ids[i][j]] != "[SEP]" : # Exclude the X label
                        temp_1.append(tag2name[label_ids[i][j]])
                        temp_2.append(tag2name[logits[i][j]])
                        valtemp.append(input_ids[i][j].item())

                    if tag2name[label_ids[i][j]] != "[CLS]" and tag2name[label_ids[i][j]] != "[SEP]" : # Exclude the X label
                        temp_1_full.append(tag2name[label_ids[i][j]])
                        temp_2_full.append(tag2name[logits[i][j]])
                        valtemp_full.append(input_ids[i][j].item())

                else:
                    break

            #here are the two lists that contain true and pred labels.
            y_true.append(temp_1)
            y_pred.append(temp_2)
            valdataset.append(valtemp)


            y_true_full.append(temp_1_full)
            y_pred_full.append(temp_2_full)
            valdataset_full.append(valtemp_full)


    avg_val_loss = total_eval_loss / len(valid_dataloader)
    validation_time = format_time(time.time() - t0)

    print("")
    print('\033[1m'+"Running Validation..."+ '\033[0m')
    print("  (Num examples ={})".format(len(val_inputs)))
    print("  (Batch size = {})\n".format(batch_num))
    print("   Validation loss: {}".format(avg_val_loss))
    print("   F1-score: %f"%(f1_score(y_true, y_pred)))
    print("   Accuracy: %f"%(accuracy_score(y_true, y_pred)))
    print("   Validation took: {:}".format(validation_time))

    training_stats.append(
        {   'epoch': _ + 1,
            'Training Loss': avg_train_loss,
            'Valid. Loss': avg_val_loss,
            'Valid. Accur.': accuracy_score(y_true, y_pred),
            'Training Time' : training_time,
            'Validation Time' : validation_time })


print('Training complete')
print("Total training took {:} (h:mm:ss)".format(format_time(time.time()-total_t0)))
# Out:
# ======== Epoch 1 / 2 ========
# Training...
#
# Epoch finished (training progress):
#    Train loss: 0.047773986810483324
#    Training epoch took: 0:09:11
#
# Running Validation...
#   (Num examples =2450)
#   (Batch size = 8)
#
#    Validation loss: 0.005124279195669369
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: X seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: [SEP] seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
#    F1-score: 0.805053
#    Accuracy: 0.950039
#    Validation took: 0:00:54
#
# ======== Epoch 2 / 2 ========
# Training...
#
# Epoch finished (training progress):
#    Train loss: 0.003309713959648174
#    Training epoch took: 0:09:18
#
# Running Validation...
#   (Num examples =2450)
#   (Batch size = 8)
#
#    Validation loss: 0.00451744579390019
#    F1-score: 0.838267
#    Accuracy: 0.955981
#    Validation took: 0:00:53
# Training complete
# Total training took 0:20:17 (h:mm:ss)

# %% [markdown]
# # 5. Evaluation on Validation set

# %%
report = classification_report(y_true, y_pred,digits=4)
print(report)
# Out:
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            _     0.0000    0.0000    0.0000         0
#      problem     0.8250    0.8676    0.8458      1065
#         test     0.8428    0.8338    0.8383       746
#    treatment     0.8291    0.8257    0.8274       717
#
#    micro avg     0.8309    0.8457    0.8383      2528
#    macro avg     0.6242    0.6318    0.6279      2528
# weighted avg     0.8314    0.8457    0.8383      2528

# %%
# without 'O' label
f1_score(y_true,y_pred, average='micro')
# Out:
# 0.8382670064693196

# %%
#table

#pd.set_option('precision', 2)
df_stats = pd.DataFrame(data=training_stats)

# use epoch as row index
df_stats = df_stats.set_index('epoch')

# hack to force the column headers to wrap.
#df = df.style.set_table_styles([dict(selector="th",props=[('max-width', '70px')])])

df_stats
# Out:
#        Training Loss  Valid. Loss  Valid. Accur. Training Time Validation Time
# epoch
# 1           0.047774     0.005124       0.950039       0:09:11         0:00:54
# 2           0.003310     0.004517       0.955981       0:09:18         0:00:53

# %%
#plotting
sns.set(style='darkgrid')
sns.set_palette('plasma')
sns.set(font_scale=1.5)
plt.rcParams["figure.figsize"] = (12,6)


plt.plot(df_stats['Training Loss'], 'b-o', label="Training",marker = 's',markerfacecolor='green',linestyle='--',color='blue')
plt.plot(df_stats['Valid. Loss'], 'g-o', label="Validation",marker = 's',markerfacecolor='green',linestyle='--',color='orange')

plt.title("Training & Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

ls=[]
for i in range(epochs):
    ls.append(i+1)
plt.xticks(ls)

plt.show()
# Out:
# <ipython-input-40-cd185a1fcfb6>:8: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "b-o" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(df_stats['Training Loss'], 'b-o', label="Training",marker = 's',markerfacecolor='green',linestyle='--',color='blue')
# <ipython-input-40-cd185a1fcfb6>:8: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "b-o" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot(df_stats['Training Loss'], 'b-o', label="Training",marker = 's',markerfacecolor='green',linestyle='--',color='blue')
# <ipython-input-40-cd185a1fcfb6>:8: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-o" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(df_stats['Training Loss'], 'b-o', label="Training",marker = 's',markerfacecolor='green',linestyle='--',color='blue')
# <ipython-input-40-cd185a1fcfb6>:9: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "g-o" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(df_stats['Valid. Loss'], 'g-o', label="Validation",marker = 's',markerfacecolor='green',linestyle='--',color='orange')
# <ipython-input-40-cd185a1fcfb6>:9: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "g-o" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot(df_stats['Valid. Loss'], 'g-o', label="Validation",marker = 's',markerfacecolor='green',linestyle='--',color='orange')
# <ipython-input-40-cd185a1fcfb6>:9: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "g-o" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(df_stats['Valid. Loss'], 'g-o', label="Validation",marker = 's',markerfacecolor='green',linestyle='--',color='orange')

# %% [markdown]
# # 6. Evaluation on test set

# %%
print("")
print('\033[1m'+"Running Test..."+ '\033[0m')
t0 = time.time()

y_test_true = []
y_test_pred = []
testdataset = []

y_test_true_full = []
y_test_pred_full = []
testdataset_full = []

model.eval()

for step, batch in enumerate(test_dataloader):
    batch = tuple(t.to(device) for t in batch)
    input_ids, input_mask, label_ids = batch #same as we did in training loop but only 1 epoch now


    with torch.no_grad(): #means we don't care about gradients and updating tensors
        outputs = model(input_ids, token_type_ids=None,
        attention_mask=input_mask,labels=label_ids)
        # For eval mode, the first result of outputs is logits (for training mode this was loss)
#             logits = outputs[0]
        loss, logits = outputs[:2]#  In context of deep learning the logits layer means the layer that feeds in to softmax (or other such normalization).

    loss = loss.mean()
    total_eval_loss += loss.item()


    # Get NER predict result
    logits = torch.argmax(F.log_softmax(logits,dim=2),dim=2)#feed logits into softmax and take the prediction that is maximal
    logits = logits.detach().cpu().numpy()

    # Get NER true result
    label_ids = label_ids.to('cpu').numpy()

    # Only predict the real word, mark=0, will not calculate
    input_mask = input_mask.to('cpu').numpy()


    # Compare the valuable predict result
    for i,mask in enumerate(input_mask):
        # Real one
        temp_1 = []
        # Predicted one
        temp_2 = []
        valtemp = []

        temp_1_full = []
        # Predicted one
        temp_2_full = []
        valtemp_full = []

        for j, m in enumerate(mask):
            # Mark=0, meaning its a pad word, dont compare
            if m :
                if tag2name[label_ids[i][j]] != "X" and tag2name[label_ids[i][j]] != "[CLS]" and tag2name[label_ids[i][j]] != "[SEP]" : # Exclude the X label
                    temp_1.append(tag2name[label_ids[i][j]])
                    temp_2.append(tag2name[logits[i][j]])
                    valtemp.append(input_ids[i][j].item())

                if tag2name[label_ids[i][j]] != "[CLS]" and tag2name[label_ids[i][j]] != "[SEP]" : # Exclude the X label
                    temp_1_full.append(tag2name[label_ids[i][j]])
                    temp_2_full.append(tag2name[logits[i][j]])
                    valtemp_full.append(input_ids[i][j].item())

            else:
                break

        #here are the two lists that contain true and pred labels.
        y_test_true.append(temp_1)
        y_test_pred.append(temp_2)
        testdataset.append(valtemp)

        y_test_true_full.append(temp_1_full)
        y_test_pred_full.append(temp_2_full)
        testdataset_full.append(valtemp_full)


avg_test_loss = total_eval_loss / len(test_dataloader)
test_time = format_time(time.time() - t0)

print("  (Num examples ={})".format(len(test_inputs)))
print("  (Batch size = {})\n".format(batch_num))
print("   Test loss: {}".format(avg_test_loss))
print("   F1-score: %f"%(f1_score(y_test_true, y_test_pred)))
print("   Accuracy: %f"%(accuracy_score(y_test_true, y_test_pred)))
print("   Test took: {:}".format(test_time))
# Out:
# Running Test...
#   (Num examples =4084)
#   (Batch size = 8)
#
#    Test loss: 0.00696951716690819
#    F1-score: 0.846298
#    Accuracy: 0.957639
#    Test took: 0:01:29
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: X seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))

# %%
# classification report is meant for evaluation of tasks like NER (see doc)
# difference between f1_score of scikit-learn and classification_report is that classification_report
# merges B and I, resulting in lower f1
report = classification_report(y_test_true, y_test_pred)
print(report)
# Out:
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            _       0.00      0.00      0.00         0
#      problem       0.84      0.86      0.85      1824
#         test       0.85      0.86      0.86      1182
#    treatment       0.82      0.84      0.83      1233
#
#    micro avg       0.84      0.85      0.85      4239
#    macro avg       0.63      0.64      0.63      4239
# weighted avg       0.84      0.85      0.85      4239

# %%
from sklearn.preprocessing import MultiLabelBinarizer

# %%
mlb = MultiLabelBinarizer()
binary_labels = mlb.fit_transform(labels)

# %%
y_test_true_binary = mlb.fit_transform(y_test_true)

# %%
y_test_true_binary.shape
# Out:
# (4080, 7)

# %%
y_test_pred_binary = mlb.fit_transform(y_test_pred)

# %%
y_test_pred_binary.shape
# Out:
# (4080, 8)

# %%
y_test_pred_binary = y_test_pred_binary[:, :7]

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test_true_binary, y_test_pred_binary))
# Out:
# 0.9107843137254902

# %% [markdown]
# # 7. Predictions of test set - examples

# %%
len(y_test_true[0]),len(y_test_pred[0]), len(testdataset[0])
# Out:
# (19, 19, 19)

# %%
text= [tokenizer.decode(test) for test in testdataset]
tokenized_text_converted = [tokenizer.convert_ids_to_tokens(test) for test in testdataset]

# %%
text_full= [tokenizer.decode(test) for test in testdataset_full]
tokenized_text_converted_full = [tokenizer.convert_ids_to_tokens(test) for test in testdataset_full]

# %%
a = 2
print( '\n' + text_full[a])
print('\033[1m' + "Labels:      " + '\033[0m', y_test_true[a])
print('\033[1m' + "Predictions: "+ '\033[0m',y_test_pred[a])
print('\n')

print(tokenized_text_converted_full[a])
# Out:
# 2019-06-18 07:55 am blood caltibc - 229 ferritn - greater th trf - 176 *
# Labels:       ['O', 'O', 'O', 'O', 'B-test', 'O', 'O', 'B-test', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Predictions:  ['O', 'O', 'O', 'B-test', 'B-test', 'O', 'O', 'B-test', 'O', 'O', 'O', 'B-test', 'O', 'O', 'O']
#
#
# ['▁2019', '-', '06', '-', '18', '▁', '07', ':55', '▁am', '▁blood', '▁cal', 'ti', 'bc', '▁', '-', '▁', '229', '▁', 'ferri', 't', 'n', '▁', '-', '▁greater', '▁', 'th', '▁', 't', 'rf', '▁', '-', '▁', '176', '▁*']

# %%
a = 7
print( '\n' +text_full[a])
print('\033[1m' + "Labels:      " + '\033[0m', y_test_true[a])
print('\033[1m' + "Predictions: "+ '\033[0m',y_test_pred[a])
print('\n')

print(tokenized_text_converted_full[a])
# Out:
# sigmoidoscopy.
# Labels:       ['B-test', 'O']
# Predictions:  ['B-test', 'O']
#
#
# ['▁sig', 'mo', 'ido', 's', 'copy', '▁', '.']

# %%
a = 11
print( '\n' +text_full[a])
print('\033[1m' + "Labels:      " + '\033[0m', y_test_true[a])
print('\033[1m' + "Predictions: "+ '\033[0m',y_test_pred[a])
print('\n')

print(tokenized_text_converted_full[a])
# Out:
# initial newborn exam :
# Labels:       ['B-test', 'I-test', 'I-test', 'O']
# Predictions:  ['O', 'O', 'O', 'O']
#
#
# ['▁initial', '▁new', 'born', '▁exam', '▁', ':']

# %%
a = 12
print( '\n' +text_full[a])
print('\033[1m' + "Labels:      " + '\033[0m', y_test_true[a])
print('\033[1m' + "Predictions: "+ '\033[0m',y_test_pred[a])
print('\n')

print(tokenized_text_converted_full[a])
# Out:
# 64-year-old g5p5 postmenopausal for 10 years with a history of two months of progressive abdominal distention, crampy abdominal pain, urinary frequency and diarrhea.
# Labels:       ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-problem', 'I-problem', 'I-problem', 'O', 'B-problem', 'I-problem', 'I-problem', 'O', 'B-problem', 'I-problem', 'O', 'B-problem', 'O']
# Predictions:  ['O', 'B-problem', 'B-problem', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-problem', 'I-problem', 'I-problem', 'O', 'B-problem', 'I-problem', 'I-problem', 'O', 'B-problem', 'I-problem', 'O', 'B-problem', 'O']
#
#
# ['▁64', '-', 'year', '-', 'old', '▁g', '5', 'p', '5', '▁post', 'men', 'opa', 'us', 'al', '▁for', '▁10', '▁years', '▁with', '▁a', '▁history', '▁of', '▁two', '▁months', '▁of', '▁progressive', '▁abdominal', '▁dis', 'ten', 'tion', '▁', ',', '▁cramp', 'y', '▁abdominal', '▁pain', '▁', ',', '▁u', 'rina', 'ry', '▁frequency', '▁and', '▁diarrhea', '▁', '.']

# %%
a = 14
print( '\n' +text_full[a])
print('\033[1m' + "Labels:      " + '\033[0m', y_test_true[a])
print('\033[1m' + "Predictions: "+ '\033[0m',y_test_pred[a])
print('\n')

print(tokenized_text_converted_full[a])
# Out:
# the patient was given printed instructions for motor vehicle accident - trauma ( english ).
# Labels:       ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-problem', 'O', 'O', 'O', 'O']
# Predictions:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-problem', 'O', 'O', 'O', 'O']
#
#
# ['▁the', '▁patient', '▁was', '▁given', '▁printed', '▁instructions', '▁for', '▁motor', '▁vehicle', '▁accident', '▁', '-', '▁trauma', '▁', '(', '▁english', '▁', ')', '▁', '.']

# %%
a = 17
print( '\n' +text_full[a])
print('\033[1m' + "Labels:      " + '\033[0m', y_test_true[a])
print('\033[1m' + "Predictions: "+ '\033[0m',y_test_pred[a])
print('\n')

print(tokenized_text_converted_full[a])
# Out:
# 3. hydrochlorothiazide question of dosage.
# Labels:       ['O', 'B-treatment', 'O', 'O', 'O', 'O']
# Predictions:  ['O', 'B-problem', 'O', 'O', 'B-problem', 'O']
#
#
# ['▁3', '.', '▁hydro', 'chloro', 'thia', 'z', 'ide', '▁question', '▁of', '▁do', 's', 'age', '▁', '.']

# %%
a = 25
print( '\n' +text_full[a])
print('\033[1m' + "Labels:      " + '\033[0m', y_test_true[a])
print('\033[1m' + "Predictions: "+ '\033[0m',y_test_pred[a])
print('\n')

print(tokenized_text_converted_full[a])
# Out:
# 3. acetaminophen 500 mg tablet sig : two ( 2 ) tablet po q6h ( every 6 hours ).
# Labels:       ['O', 'B-treatment', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Predictions:  ['O', 'B-treatment', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
# ['▁3', '.', '▁a', 'cet', 'amino', 'phen', '▁500', '▁mg', '▁tablet', '▁sig', '▁', ':', '▁two', '▁', '(', '▁2', '▁', ')', '▁tablet', '▁po', '▁q', '6', 'h', '▁', '(', '▁every', '▁6', '▁hours', '▁', ')', '.']

# %%
a = 37
print( '\n' +text_full[a])
print('\033[1m' + "Labels:      " + '\033[0m', y_test_true[a])
print('\033[1m' + "Predictions: "+ '\033[0m',y_test_pred[a])
print('\n')

print(tokenized_text_converted_full[a])
# Out:
# please refer to the previously dictated operative note of 2016-12-30 by dr. lawrence.
# Labels:       ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Predictions:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
# ['▁please', '▁refer', '▁to', '▁the', '▁previously', '▁dictated', '▁', 'operative', '▁note', '▁of', '▁2016', '-', '12', '-', '30', '▁by', '▁dr', '.', '▁lawrence', '▁', '.']

# %%
# text = [tokenizer.convert_tokens_to_string(i) for i in tokenized_text_converted]

# %%
for a in range(1,len(y_test_pred)):
    print(tokenized_text_converted_full[a])
# Out:
# ['▁reason', '▁for', '▁this', '▁examination', '▁', ':']
# ['▁2019', '-', '06', '-', '18', '▁', '07', ':55', '▁am', '▁blood', '▁cal', 'ti', 'bc', '▁', '-', '▁', '229', '▁', 'ferri', 't', 'n', '▁', '-', '▁greater', '▁', 'th', '▁', 't', 'rf', '▁', '-', '▁', '176', '▁*']
# ['▁he', 'mo', 'dynamic', 's', '▁', ':']
# ['▁mr', '.', '▁bre', 'utz', 'far', 'st', 'xe', 'i', '▁was', '▁recently', '▁diagnosed', '▁with', '▁acquired', '▁im', 'mun', 'ode', 'fic', 'i', 'ency', '▁syndrome', '▁when', '▁he', '▁had', '▁p', 'neu', 'mo', 'cy', 's', 'tis', '▁car', 'ini', 'i', '▁pneumonia', '▁on', '▁', '01', '/1', '7/', '91', '▁', '.']
# ['▁cbc', '▁', ':', '▁white', '▁blood', '▁cell', '▁count', '▁is', '▁8', '.', '8', '▁', ',', '▁he', 'mato', 'crit', '▁35', '.', '5', '▁plate', 'lets', '▁', '266', '▁', ',', '▁pt', '▁13', '▁', ',', '▁pt', '-', 't', '▁23', '.', '3', '▁', ',', '▁in', 'r', '▁was', '▁1', '.', '1', '▁', '.']
# ['▁diagnosis', '▁', ':']
# ['▁sig', 'mo', 'ido', 's', 'copy', '▁', '.']
# ['▁discharge', '▁instructions', '▁', ':']
# ['▁dictated', '▁by', '▁', ':', '▁sherry', '▁g', '▁christie', '▁', ',', '▁m', '.', 'd', '.']
# ['▁the', '▁patient', '▁was', '▁continued', '▁on', '▁his', '▁stat', 'in', '▁', '.']
# ['▁12', '#', '▁wound', '▁care', '▁', ':']
# ['▁sex', '▁', ':']
# ['▁right', '▁', 'com', 'minute', 'd', '▁ti', 'bia', '▁', '/', '▁fib', 'ula', '▁fracture']
# ['▁20', '99', '87', '▁pad', '-', 'word']
# ['▁failed', '▁swallow', '▁study', '▁x', '▁2', '▁in', '▁early', '▁november', '▁', '.']
# ['▁this', '▁report', '▁was', '▁created', '▁by', '▁a', 'y', 'rek', 'em', 'pe', '▁', ',', '▁non', 'ok', '▁', '01', '/', '09', '/', '2002', '▁', '05', ':', '09', '▁pm']
# ['▁dis', 'p', '▁', ':', '*', '▁60', '▁capsule', '▁', '(', '▁', 's', '▁', ')', '*', '▁refill', 's', '▁', ':', '*', '▁2', '▁*']
# ['▁12', '.', '▁pace', 'maker', '▁', '-', '▁', 'd', 'dd', '▁dual', '▁chamber', '▁rate', '▁response', '▁pace', 'maker', '▁2011', '-', '08', '-', '22', '▁for', '▁symptom', 'atic', '▁brady', 'cardi', 'a']
# ['▁hospital', '▁course', '▁and', '▁treatment', '▁', ':']
# ['▁emerge', 'nt', '▁indication', 's', '▁', ':']
# ['▁standardized', '▁discharge', '▁instructions', '▁', ':']
# ['▁mother', '▁had', '▁a', 'dren', 'al', '▁cancer', '▁', '.']
# ['▁notably', '▁you', '▁were', '▁discharged', '▁on', '▁', ':']
# ['▁3', '.', '▁al', 'but', 'er', 'ol', '-', 'i', 'pra', 'trop', 'ium', '▁103', '-', '18', '▁mcg', '▁', '/', '▁a', 'ctu', 'ation', '▁aero', 'sol', '▁sig', '▁', ':', '▁', '02', '-', '26', '▁puff', 's', '▁in', 'hal', 'ation', '▁q', '6', 'h', '▁', '(', '▁every', '▁6', '▁hours', '▁', ')', '▁as', '▁needed', '▁', '.']
# ['▁for', '▁follow', '▁up', '▁', ',', '▁the', '▁patient', '▁is', '▁to', '▁call', '▁for', '▁an', '▁appointment', '▁with', '▁dr', '.', '▁sap', 'mal', '▁', '.']
# ['▁a', '.', '▁instructions', '▁', ':', '▁with', '▁dr', '.', '▁matthew', '▁in', '▁2', '-', '3', '▁weeks', '▁with', '▁dr', '.', '▁de', 'llinger', '▁in', '▁2', '-', '3', '▁weeks', '▁with', '▁dr', '.', '▁les', '▁go', 'key', '▁in', '▁4', '▁weeks']
# ['▁mr', 'n', '▁', ':']
# ['▁he', '▁received', '▁multiple', '▁treatments', '▁for', '▁this', '▁over', '▁the', '▁succeeding', '▁weeks', '▁', '.']
# ['▁history', '▁of', '▁present', '▁illness', '▁', ':']
# ['▁wi', 'ers', 't', '▁', ',', '▁sto', '▁l', '.', '▁', ',', '▁m', '.', 'd', '.', '▁', '(', '▁', 'rr', '86', '▁', ')', '▁10', '/', '01', '/', '00', '▁', '02', ':33', '▁pm']
# ['▁signed', '▁electronically', '▁by', '▁', ':', '▁dr', '.', '▁brenda', '▁j', 'm', '.', '▁esp', 'in', 'osa', '▁on', '▁', ':', '▁max', 'ine', '▁2015', '-', '09', '-', '10', '▁1', ':57', '▁pm']
# ['▁you', '▁may', '▁shower', '▁', '.']
# ['▁unsigned', '▁pad', '-', 'word']
# ['▁had', '▁subsequent', '▁abnormal', '▁stress', '▁test', '▁and', '▁pe', 'fusion', '▁imaging', '▁showed', '▁ef', '▁', '38%', '▁with', '▁per', 'fusion', '▁defects', '▁', '.']
# ['▁has', '▁significant', '▁cardiac']
# ['▁neurological', '▁exam', '▁was', '▁gross', 'ly', '▁intact', '▁', '.']
# ['▁impression', '▁', ':', '▁moderate', '▁to', '▁large', '▁peri', 'cardi', 'al', '▁ef', 'fusion', '▁', '(', '▁minimal', '▁fluid', '▁anterior', 'ly', '▁', '(', '▁1', 'cm', '▁', ')', ',', '▁', '?', '▁bloody', '▁', ')', '.']
# ['▁', 'ct', 'mc', '▁pad', '-', 'word']
# ['▁', 'ct', 'mc', '▁pad', '-', 'word']
# ['▁he', 'ent', '▁exam', '▁was', '▁un', 're', 'mark', 'able', '▁', '.']
# ['▁present', '▁illness', '▁', ':']
# ['▁discharge', '▁medication', 's', '▁', ':']
# ['▁di', 'cat', 'ated', '▁by', '▁', ':']
# ['▁48', '720', '920', '▁pad', '-', 'word']
# ['▁gentle', '▁di', 'ure', 'sis', '▁and', '▁beta', '▁blockade', '▁started', '▁', ',', '▁and', '▁he', '▁was', '▁transferred', '▁to', '▁the', '▁floor', '▁to', '▁begin', '▁increasing', '▁his', '▁activity', '▁level', '▁', '.']
# ['▁and', '▁it', '▁is', '▁noted', '▁there', '▁was', '▁nod', 'ular', 'ity', '▁in', '▁the', '▁common', '▁', 'bile', '▁', 'duct', '▁which', '▁is', '▁', 'wor', 'ri', 'some', '▁for', '▁chola', 'n', 'gio', 'car', 'cino', 'ma', '▁', '.']
# ['▁', '09', '-', '08', '-', '93', '▁pad', '-', 'word']
# ['▁u', 'rina', 'ry', '▁in', 'contin', 'ence']
# ['▁', '01', '/', '09', '/', '2002', '▁17', ':02']
# ['▁the', '▁patient', '▁', ',', '▁during', '▁this', '▁admission', '▁', ',', '▁required', '▁trans', 'fusion', '▁of', '▁three', '▁units', '▁of', '▁packed', '▁red', '▁blood', '▁cells', '▁to', '▁maintain', '▁adequate', '▁he', 'mato', 'crit', '▁', '.']
# ['▁2', '.', '▁prior', '▁history', '▁of', '▁anterior', '▁my', 'o', 'cardi', 'al', '▁in', 'far', 'c', 'tion']
# ['▁he', 'ent', '▁', ':', '▁', 'n', 'cat', '▁', ',', '▁per', 'rl', '▁', ',', '▁', 'e', 'omi', '▁', ',', '▁no', '▁', 'ic', 'ter', 'us', '▁', ',', '▁op', '▁clear', '▁', ',', '▁', 'mmm', '▁', ',', '▁no', '▁tongue', '▁fasci', 'cul', 'ations']
# ['▁all', 'er', 'gies', '▁', ':']
# ['▁signed', '▁pad', '-', 'word']
# ['▁', '237', '54', '357', '▁pad', '-', 'word']
# ['▁he', '▁was', '▁taken', '▁to', '▁way', 'ske', 'med', 'call', 'town', '▁tal', 'mi', '▁and', '▁transferred', '▁to', '▁he', 'a', 'on', 'bo', 'burg', '▁lin', 'pack', '▁grant', '▁medical', '▁center', '▁with', '▁a', '▁computer', 'ized', '▁tom', 'ography', '▁scan', '▁showing', '▁a', '▁1', 'x', '2', '▁', 'thala', 'mic', '▁caps', 'ular', '▁he', 'mo', 'rrh', 'age', '▁without', '▁superficial', '▁mass', '▁effect', '▁', '.']
# ['▁she', '▁is', '▁anti', 'co', 'ag', 'ulated', '▁on', '▁co', 'uma', 'din', '▁and', '▁this', '▁has', '▁been', '▁stable', '▁', '.']
# ['▁sodium', '▁', '139', '▁', ';', '▁potassium', '▁4', '.', '1', '▁', ';', '▁bun', '▁15', '▁', ';', '▁cre', 'ati', 'nine', '▁1', '.', '1', '▁', ';', '▁magnesium', '▁1', '.', '6', '▁', ';', '▁', 's', 'gp', 't', '▁19', '▁', ';', '▁', 's', 'got', '▁20', '▁', ';', '▁alkaline', '▁', 'phos', 'pha', 't', 'ase', '▁66', '▁', ';', '▁total', '▁', 'bili', 'rub', 'in', '▁0', '.', '6', '▁', ';', '▁direct', '▁', 'bili', 'rub', 'in', '▁0', '.', '2', '▁', ';', '▁total', '▁cho', 'leste', 'rol', '▁', '234', '▁', ';', '▁tri', 'glyc', 'er', 'ides', '▁', '274', '▁', ';', '▁hd', 'l', '▁44', '▁', ';', '▁l', 'dl', '▁135', '▁', ';', '▁he', 'mog', 'lob', 'in', '▁a', '1', 'c', '▁6', '.', '7', '▁', ';', '▁white', '▁cell', '▁count', '▁6', '.', '1', '▁', ';', '▁he', 'mato', 'crit', '▁36', '.', '4', '▁', ';', '▁plate', 'let', '▁count', '▁', '201', '▁', '.']
# ['▁of', '▁note', '▁', ',', '▁this', '▁is', '▁the', '▁second', '▁time', '▁the', '▁patient', '▁has', '▁exercised', '▁in', '▁many', '▁months', '▁', '.']
# ['▁principal', '▁diagnosis', '▁', ':']
# ['▁', '394', '521', '▁pad', '-', 'word']
# ['▁blood', '▁pressure', '▁16', '2/', '76', '▁', '.']
# ['▁the', '▁patient', '▁became', '▁hypo', 'tens', 'ive', '▁into', '▁the', '▁70', '▁', 's', '▁without', '▁any', '▁symptoms', '▁', '.']
# ['▁per', 'tin', 'ent', '▁results', '▁', ':']
# ['▁feeds', '▁are', '▁breast', '▁feeding', '▁p', '.', 'o', '.', '▁a', 'd', '▁', 'lib', '▁', '.']
# ['▁there', '▁were', '▁no', '▁vent', 'r', 'icular', '▁premature', '▁contraction', 's', '▁', '.']
# ['▁1', '.', '▁diabetes', '▁me', 'lli', 'tus', '▁', '.']
# ['▁there', '▁was', '▁mild', '▁enhancement', '▁of', '▁the', '▁pont', 'ine', '▁he', 'mor', 'rha', 'gic', '▁mass', '▁but', '▁none', '▁elsewhere', '▁', '.']
# ['▁2', '.', '▁moderately', '▁elevated', '▁right', '▁and', '▁left', '▁side', 'd', '▁filling', '▁pressure', 's', '▁', '.']
# ['▁', '05', '/2', '6/', '2004', '▁pad', '-', 'word']
# ['▁bre', 'un', 'tik', '▁pad', '-', 'word']
# ['▁bone', '▁marrow', '▁bio', 'psy', '▁was', '▁not', '▁attempted', '▁', '.']
# ['▁28', '96', '53', '▁pad', '-', 'word']
# ['▁tape', '▁', '/', '▁be', 'na', 'dry', 'l']
# ['▁principal', '▁diagnosis', '▁', ':']
# ['▁the', '▁abdomen', '▁was', '▁soft', '▁and', '▁non', '-', 't', 'ender', '▁with', '▁no', '▁masses', '▁or', '▁organ', 'o', 'mega', 'ly', '▁', '.']
# ['▁fe', 'moral', '▁2', '▁+', '▁bilateral', 'ly', '▁', ',', '▁dorsal', 'is', '▁ped', 'is', '▁1', '▁+', '▁bilateral', 'ly', '▁', ',', '▁posterior', '▁', 't', 'ibi', 'al', '▁1', '▁+', '▁bilateral', 'ly', '▁', ',', '▁and', '▁radial', '▁2', '▁+', '▁bilateral', 'ly', '▁', '.']
# ['▁600', '13', '56', '▁pad', '-', 'word']
# ['▁major', '▁surgical', '▁or', '▁', 'invasive', '▁procedure', '▁', ':']
# ['▁car', 'ot', 'ids', '▁had', '▁normal', '▁up', 'stroke', '▁and', '▁normal', '▁volume', '▁with', '▁bilateral', '▁bru', 'its', '▁', '.']
# ['▁reason', '▁for', '▁this', '▁examination', '▁', ':']
# ['▁she', '▁was', '▁worked', '▁up', '▁aggressively', '▁with', '▁the', '▁physical', '▁therapy', '▁and', '▁occupational', '▁services', '▁', ',', '▁made', '▁good', '▁progress', '▁and', '▁began', '▁', 'ambul', 'ating', '▁with', '▁assistance', '▁with', '▁a', '▁walker', '▁but', '▁with', '▁minimal', '▁assistance', '▁from', '▁an', '▁aid', '▁', '.']
# ['▁provider', '▁number', '▁', ':']
# ['▁med', 'quist', '36', '▁pad', '-', 'word']
# ['▁12', '/', '1/', '2003', '▁1', '2:00', ':', '00', '▁am']
# ['▁old', '▁twi', '▁v', '4', '-', '6', '▁', '.']
# ['▁27', '17', '35', '▁pad', '-', 'word']
# ['▁further', '▁evaluation', '▁of', '▁his', '▁renal', '▁failure', '▁showed', '▁that', '▁the', '▁patient', '▁has', '▁bilateral', '▁hydro', 'ne', 'phr', 'osis', '▁', ',', '▁most', '▁likely', '▁obstruct', 'ive', '▁', 'ur', 'opathy', '▁due', '▁to', '▁prostate', '▁ca', '▁in', '▁the', '▁pelvic', '▁area', '▁', '.']
# ['▁neck', '▁with', '▁cervical', '▁collar', '▁', '.']
# ['▁philip', '▁glenn', '▁md', '▁60', '-', '385']
# ['▁12', '/', '09', '/', '2005', '▁pad', '-', 'word']
# ['▁non', 'ok', '▁a', 'y', 'rek', 'em', 'pe']
# ['▁he', 'ent', '▁', ':', '▁', 'e', 'omi', '▁', ',', '▁per', 'rl', '▁', ',', '▁nc', '/', 'at']
# ['▁hospital', '▁course', '▁', ':']
# ['▁#', '▁a', 'rf', '▁', ':', '▁cre', 'ati', 'nine', '▁has', '▁increased', '▁from', '▁0', '.', '9', '▁on', '▁admission', '▁to', '▁1', '.', '9', '▁on', '▁admission', '▁to', '▁', 'icu', '▁', '.']
# ['▁on', '▁day', '▁of', '▁life', '▁#1', '▁', ',', '▁caffeine', '▁was', '▁started', '▁', '.']
# ['▁', '(', '▁end', '▁of', '▁report', '▁', ')']
# ['▁abdominal', '▁pain', '▁pre', 'dom', 'in', 'ally', '▁on', '▁the', '▁right', '▁upper', '▁quadrant', '▁', ',', '▁no', '▁signs', '▁of', '▁peri', 'tone', 'al', '▁irritation', '▁', '.']
# ['▁', 'anga', 'p', '▁', '-', '▁12']
# ['▁', 'ct', '▁scan', '▁shows', '▁', 'ov', 'arian', '▁cyst']
# ['▁', 's', 'cler', 'a', '▁mildly', '▁i', 'ct', 'eric', '▁', '.']
# ['▁blood', '▁pressure', '▁most', '▁recently', '▁60', '/', '37', '▁with', '▁a', '▁mean', '▁of', '▁44', '▁', '.']
# ['▁signed', '▁pad', '-', 'word']
# ['▁past', '▁medical', '▁history', '▁', ':']
# ['▁3', '.', '▁flo', 'vent', '▁110', '▁micro', 'gram', 's', '▁aero', 'sol', '▁two', '▁puff', 's', '▁b', '.', 'i', '.', 'd', '.']
# ['▁he', '▁will', '▁follow', '▁up', '▁with', '▁dr', '.', '▁', 'ie', 'cha', 'lette', '▁cancer', '▁in', '▁his', '▁office', '▁', '.']
# ['▁med', 'quist', '36', '▁pad', '-', 'word']
# ['▁#', '.', '▁an', 'emia', '▁', ':', '▁unclear', '▁source', '▁', '.']
# ['▁', 'cv', '▁', ':']
# ['▁', '00', '146', '33', '▁pad', '-', 'word']
# ['▁cm', 'ed', '▁c', 's', 'ru']
# ['▁expired', '▁pad', '-', 'word']
# ['▁8', '1957', '9', '▁pad', '-', 'word']
# ['▁room', '▁', ':']
# ['▁7', '.', '▁clon', 'idine', '▁0', '.', '2', '▁mg', '▁tablet', '▁sig', '▁', ':', '▁one', '▁', '(', '▁1', '▁', ')', '▁tablet', '▁po', '▁', 'tid', '▁', '(', '▁3', '▁times', '▁a', '▁day', '▁', ')', '.']
# ['▁type', '▁ii', '▁diabetes', '▁', '.']
# ['▁on', '▁an', '▁office', '▁visit', '▁on', '▁', '01', '-', '14', '▁', ',', '▁the', '▁patient', '▁was', '▁found', '▁to', '▁have', '▁significantly', '▁elevated', '▁alkaline', '▁', 'phos', 'pha', 't', 'ase', '▁', '.']
# ['▁no', '▁pal', 'pit', 'ations', '▁', ',', '▁history', '▁of', '▁epi', 'gas', 'tric', '▁pain', '▁and', '▁body', '▁weight', '▁loss', '▁', '.']
# ['▁echo', '▁showed', '▁ef', '▁45', '-', '50%', '▁', ',', '▁with', '▁mild', '▁di', 'la', 'tation', '▁and', '▁no', '▁significant', '▁val', 'v', 'ular', '▁disease', '▁', ',', '▁and', '▁', 'nl', '▁pap', '▁', '.']
# ['▁provider', '▁', ':']
# ['▁', 'ct', '▁head', '▁w', '/', 'o', '▁contrast']
# ['▁significant', '▁for', '▁colon', '▁carcinoma', '▁', '.']
# ['▁2015', '-', '06', '-', '10', '▁pad', '-', 'word']
# ['▁2013', '-', '05', '-', '24', '▁12', ':52', '▁am', '▁22', '▁65', '▁*', '▁7', '39', '▁*', '▁52', '▁81', '▁1', '.', '0']
# ['▁pt', '▁was', '▁12', '.', '9', '▁', '.']
# ['▁mr', 'n', '▁', ':']
# ['▁5', '.', '▁as', 'pir', 'in', '▁81', '▁mg', '▁tablet', '▁', ',', '▁chew', 'able', '▁sig', '▁', ':', '▁one', '▁', '(', '▁1', '▁', ')', '▁tablet', '▁', ',', '▁chew', 'able', '▁po', '▁daily', '▁', '(', '▁daily', '▁', ')', '.']
# ['▁the', '▁left', '▁at', 'rium', '▁is', '▁normal', '▁in', '▁size', '▁', '.']
# ['▁3', '.', '▁aluminum', '-', 'mag', 'nes', 'ium', '▁', 'hydr', 'oxide', '▁22', '5', '-', '200', '▁mg', '▁', '/', '▁5', '▁', 'ml', '▁suspension', '▁sig', '▁', ':', '▁15', '-', '30', '▁mls', '▁po', '▁qi', 'd', '▁', '(', '▁4', '▁times', '▁a', '▁day', '▁', ')', '▁as', '▁needed', '▁', '.']
# ['▁abdomen', '▁was', '▁gravi', 'd', '▁', '.']
# ['▁vitamin', '▁c', '▁', '(', '▁as', 'cor', 'bic', '▁acid', '▁', ')', '▁1,000', '▁mg', '▁po', '▁q', 'd', '▁ec', 'asa', '▁', '(', '▁as', 'pir', 'in', '▁enter', 'ic', '▁coat', 'ed', '▁', ')', '▁81', '▁mg', '▁po', '▁q', 'd', '▁calcium', '▁carbonate', '▁', '(', '▁500', '▁mg', '▁elemental', '▁ca', '++', '▁', ')', '▁500', '▁mg', '▁po', '▁bid', '▁pre', 'd', 'nis', 'one', '▁20', '▁mg', '▁po', '▁qa', 'm', '▁starting', '▁today', '▁', '(', '▁12', '/', '09', '▁', ')']
# ['▁physical', '▁examination', '▁', ':']
# ['▁admission', '▁date', '▁', ':']
# ['▁transverse', '▁pad', '-', 'word']
# ['▁9', ')', '▁', 'ami', 'trip', 'ty', 'line', '▁10', '▁mg', '▁p', '.', 'o', '.', '▁q', '.', 'h', '.', 's', '.']
# ...
# ['▁neck', '▁was', '▁sup', 'ple', '▁', '.']
# ['▁', '09', '47', '56', '▁pad', '-', 'word']
# ['▁5', '-', '28', '-', '93', '▁pad', '-', 'word']
# ['▁last', '▁colon', 'os', 'copy', '▁', ',', '▁five', '▁years', '▁ago', '▁', '.']
# ['▁shoulder', '▁shrug', '▁was', '▁5', '/5', '▁power', '▁', '.']
# ['▁86', '94', '367', '18', '▁sc']
# ['▁the', '▁patient', '▁smoke', 's', '▁two', '▁packs', '▁per', '▁day', '▁and', '▁has', '▁an', '▁approximately', '▁a', '▁75', '-', 'pack', '-', 'year', '▁history', '▁of', '▁smoking', '▁', '.']
# ['▁provider', '▁number', '▁', ':']
# ['▁no', '▁history', '▁of', '▁head', '▁trauma', '▁or', '▁seizure', '▁disorder']
# ['▁ta', '▁k', '.', '▁je', 'sc', '▁', ',', '▁m', '.', 'd', '.']
# ['▁all', 'er', 'gies', '▁', ':']
# ['▁', 'ela', 'vil', '▁50', '▁mg', '▁p', '.', 'o', '.', '▁q', '.', 'h', '.', 's', '.', '▁', ',', '▁coat', 'ed', '▁as', 'pir', 'in', '▁', '325', '▁mg', '▁p', '.', 'o', '.', '▁p', '.', 'day', '▁', ',', '▁teg', 're', 'tol', '▁100', '▁mg', '▁p', '.', 'o', '.', '▁b', '.', 'i', '.', 'd', '.', '▁', ',', '▁', 'ance', 'f', '▁1', '▁gm', '▁iv', '▁q', '.', '12', 'h', '.', '▁times', '▁seven', '▁days', '▁', ',', '▁vas', 'o', 'tec', '▁5', '▁mg', '▁p', '.', 'o', '.', '▁q', '.', 'day', '▁', ',', '▁synth', 'roid', '▁0', '.', '0', '25', '▁mg', '▁p', '.', 'o', '.', '▁q', '.', 'day', '▁', ',', '▁as', 'a', 'col', '▁400', '▁mg', '▁q', '.', 'a', '.', 'm', '.', '▁and', '▁800', '▁mg', '▁q', '.', 'p', '.', 'm', '.', '▁', ',', '▁lo', 'press', 'or', '▁25', '▁mg', '▁p', '.', 'o', '.', '▁b', '.', 'i', '.', 'd', '.', '▁', ',', '▁pri', 'los', 'ec', '▁20', '▁mg', '▁p', '.', 'o', '.', '▁q', '.', 'day', '▁', ',', '▁and', '▁insulin', '▁70', '/', '30', '▁26', '▁units', '▁in', '▁the', '▁morning', '▁and', '▁12', '▁units', '▁at', '▁night', '▁', '.']
# ['▁review', '▁of', '▁systems', '▁shows', '▁that', '▁the', '▁patient', '▁denies', '▁any', '▁ortho', 'p', 'nea', '▁', ',', '▁par', 'oxy', 's', 'mal', '▁nocturnal', '▁dys', 'p', 'nea', '▁', '.']
# ['▁age', '▁', ':']
# ['▁attending', '▁', ':']
# ['▁complications', '▁', '.']
# ['▁history', '▁of', '▁present', '▁illness', '▁', ':']
# ['▁dictated', '▁by', '▁', ':', '▁ellen', '▁v', '▁wise', '▁', ',', '▁m', '.', 'd', '.']
# ['▁gen', 'to', '▁yan', 'es', 'l', 'aunt', '▁', '03', '/1', '7/', '06', '▁scheduled', '▁', ',']
# ['▁dis', '▁pad', '-', 'word']
# ['▁ap', 'nea', '▁and', '▁brady', 'cardi', 'a', '▁of', '▁pre', 'ma', 'tur', 'ity', '▁', '.']
# ['▁were', '▁un', 're', 'mark', 'able', '▁with', '▁normal', '▁electro', 'ly', 'tes', '▁and', '▁complete', '▁blood', '▁count', '▁parameters', '▁', '.']
# ['▁her', '▁bowel', '▁regime', 'n', '▁is', '▁pr', 'n', '▁', '.']
# ['▁headache', '▁pad', '-', 'word']
# ['▁2012', '-', '06', '-', '07', '▁', '09', ':55', '▁pm', '▁blood', '▁neu', 't', 's', '▁', '-', '▁49', '.', '9', '▁*', '▁lymph', 's', '▁', '-', '▁42', '.', '4', '▁*', '▁mono', 's', '▁', '-', '▁5', '.', '5', '▁', 'eo', 's', '▁', '-', '▁1', '.', '6', '▁bas', 'o', '▁', '-', '▁0', '.', '6']
# ['▁there', '▁was', '▁a', '▁left', '▁central', '▁facial', '▁par', 'esis', '▁', '.']
# ['▁the', '▁patient', '▁is', '▁a', '▁jaun', 'dic', 'ed', '▁looking', '▁gentlemen', '▁in', '▁no', '▁acute', '▁distress', '▁', '.']
# ['▁he', '▁appeared', '▁to', '▁be', '▁doing', '▁well', '▁and', '▁was', '▁transferred', '▁to', '▁the', '▁', 's', 'du', '▁on', '▁this', '▁day', '▁', '.']
# ['▁8', '.', '▁ferro', 'us', '▁gluco', 'nate', '▁300', '▁mg', '▁tablet', '▁sig', '▁', ':', '▁one', '▁', '(', '▁1', '▁', ')', '▁tablet', '▁po', '▁daily', '▁', '(', '▁daily', '▁', ')', '.']
# ['▁abdomen', '▁is', '▁soft', '▁', ',', '▁non', 't', 'ender', '▁', ',', '▁and', '▁non', 'd', 'ist', 'ended', '▁', '.']
# ['▁the', '▁patient', '▁&', 'apo', 's', ';', 's', '▁pain', '▁has', '▁not', '▁been', '▁relieved', '▁by', '▁dar', 'vo', 'cet', '▁and', '▁a', 'd', 'vil', '▁', '.']
# ['▁discharge', '▁instructions', '▁', ':']
# ['▁1', ')', '▁syn', 'agi', 's', '▁', 'rs', 'v', '▁pro', 'phy', 'l', 'axis', '▁should', '▁be', '▁considered', '▁from', '▁october', '▁through', '▁april', '▁for', '▁infants', '▁who', '▁meet', '▁any', '▁of', '▁the', '▁following', '▁three', '▁criteria', '▁', ':']
# ['▁4', '.', '▁do', 'cus', 'ate', '▁sodium', '▁100', '▁mg', '▁capsule', '▁sig', '▁', ':', '▁one', '▁', '(', '▁1', '▁', ')', '▁capsule', '▁po', '▁bid', '▁', '(', '▁2', '▁times', '▁a', '▁day', '▁', ')', '▁as', '▁needed', '▁', ':', '▁cons', 'tip', 'ation', '▁', '.']
# ['▁her', '▁blood', '▁pressure', '▁was', '▁19', '0/', '90', '▁when', '▁i', '▁first', '▁saw', '▁her', '▁on', '▁her', '▁second', '▁hospital', '▁day', '▁', '.']
# ['▁significant', '▁for', '▁fatigue', '▁and', '▁increased', '▁abdominal', '▁discomfort', '▁', '.']
# ['▁', '09', '/', '30', '/', '2000', '▁1', '2:00', ':', '00', '▁am']
# ['▁5', ')', '▁za', 'rox', 'o', 'lyn', '▁2', '.', '5', '▁mg', '▁p', '.', 'o', '.', '▁q', '.', '▁day', '▁', '.']
# ['▁2', '.', '▁please', '▁keep', '▁all', '▁follow', '▁up', '▁appointments', '▁', '.']
# ['▁treatment', '▁rendered', '▁', ':']
# ['▁', '01', '-', '11', '▁mr', 'i', '▁left', '▁knee', '▁w', '/', 'o', '▁contrast']
# ['▁no', '▁retina', 'l', '▁he', 'mor', 'rha', 'ges', '▁', '.']
# ['▁without', '▁he', 'pat', 'os', 'ple', 'no', 'mega', 'ly', '▁', ',', '▁without', '▁masses', '▁', '.']
# ['▁principal', '▁diagnosis', '▁', ':']
# ['▁history', '▁of', '▁present', '▁illness', '▁', ':']
# ['▁sex', '▁', ':']
# ['▁potentially', '▁serious', '▁interaction', '▁', ':']
# ['▁', 't', '▁96', '.', '0', '▁bp', '▁17', '7/', '61', '▁p', '▁70', '▁r', '▁18', '▁o', '2', '▁97', '▁on', '▁', 'ra']
# ['▁2', '.', '▁ag', 'gren', 'ox', '▁', '.']
# ['▁erin', '▁ken', 'ge', 'ko', 'te', '▁', ',', '▁m', '.', 'd', '.']
# ['▁neck', '▁was', '▁sup', 'ple', '▁with', '▁no', '▁thy', 'ro', 'mega', 'ly', '▁', '.']
# ['▁', '06', '/', '04', '/', '93', '▁pad', '-', 'word']
# ['▁discharge', '▁date', '▁', ':']
# ['▁family', '▁history', '▁', ':']
# ['▁', '08', '/', '07', '/', '1992', '▁pad', '-', 'word']
# ['▁there', '▁was', '▁a', '▁right', '▁groin', '▁a', '▁line', '▁and', '▁a', '▁left', '▁groin', '▁ven', 'ous', '▁sheath', '▁with', '▁a', '▁swan', '▁', '.']
# ['▁date', '▁of', '▁birth', '▁', ':']
# ['▁mr', 'n', '▁', ':']
# ['▁pt', '▁initially', '▁with', '▁mild', '▁ari', '▁', ',', '▁this', '▁was', '▁thought', '▁to', '▁be', '▁due', '▁to', '▁de', 'hydr', 'ation', '▁', ',', '▁after', '▁initial', '▁volume', '▁re', 'ple', 'tion', '▁her', '▁renal', '▁function', '▁improved', '▁to', '▁her', '▁baseline', '▁', '.']
# ['▁the', '▁patient', '▁was', '▁in', '▁mild', '▁to', '▁moderate', '▁respiratory', '▁distress', '▁', '.']
# ['▁her', '▁neck', '▁showed', '▁no', '▁j', 'v', 'd', '▁', ',', '▁there', '▁was', '▁a', '▁slow', '▁car', 'oti', 'd', '▁up', 'stroke', '▁bilateral', 'ly', '▁', ',', '▁there', '▁were', '▁bilateral', '▁car', 'oti', 'd', '▁bru', 'its', '▁versus', '▁transmitted', '▁murmur', '▁', '.']
# ['▁a', '▁cath', 'eter', '▁is', '▁seen', '▁entering', '▁the', '▁left', '▁in', 'guin', 'al', '▁region', '▁and', '▁', 'cour', 's', 'ing', '▁along', '▁the', '▁', 'ilia', 'c', '▁vessels', '▁', ',', '▁terminating', '▁in', '▁the', '▁left', '▁pelvis', '▁', '.']
# ['▁decision', '▁was', '▁made', '▁by', '▁the', '▁family', '▁and', '▁the', '▁medical', '▁team', '▁to', '▁withdraw', '▁care', '▁', '.']
# ['▁therapy', '▁', '.']
# ['▁condition', '▁on', '▁discharge', '▁', ':']
# ['▁discharge', '▁diagnosis', '▁', ':']
# ['▁mr', 'n', '▁', ':']
# ['▁the', '▁left', '▁anterior', '▁descending', '▁had', '▁a', '▁severe', '▁80%', '▁proxim', 'al', '▁sten', 'osis', '▁with', '▁a', '▁filling', '▁defect', '▁consistent', '▁with', '▁intra', 'lumina', 'l', '▁', 'thromb', 'us', '▁', '.']
# ['▁do', '▁not', '▁drive', '▁if', '▁taking', '▁flex', 'er', 'il', '▁and', '▁code', 'ine', '▁', '.']
# ['▁1', '1/2', '4/', '1994', '▁1', '2:00', ':', '00', '▁am']
# ['▁her', '▁abdomen', '▁remained', '▁tender', '▁and', '▁dis', 't', 'ended', '▁despite', '▁attempted', '▁de', 'com', 'press', 'ion', '▁', '.']
# ['▁the', '▁estimated', '▁blood', '▁loss', '▁was', '▁minimal', '▁and', '▁the', '▁patient', '▁received', '▁600', '▁cc', '.', '▁of', '▁intra', 'ven', 'ous', '▁fluid', '▁', '.']
# ['▁dis', '▁pad', '-', 'word']
# ['▁past', '▁medical', '▁history', '▁', ':']
# ['▁mr', 'n', '▁', ':']
# ['▁the', '▁patient', '▁was', '▁discharged', '▁to', '▁home', '▁on', '▁', 'ami', 'oda', 'rone', '▁200', '▁mg', '▁daily', '▁on', '▁12', '/2', '9/', '96', '▁', '.']
# ['▁reason', '▁', ':', '▁stuck', '▁by', '▁auto']
# ['▁her', '▁extrem', 'ities', '▁are', '▁without', '▁', 'ed', 'ema', '▁and', '▁are', '▁warm', '▁', '.']
# ['▁pt', '▁was', '▁then', '▁initiated', '▁on', '▁the', '▁sep', 'sis', '▁protocol', '▁', '.']
# ['▁he', '▁is', '▁married', '▁', '.']
# ['▁dis', '▁pad', '-', 'word']
# ['▁f', '▁pad', '-', 'word']
# ['▁he', '▁should', '▁follow', '▁up', '▁with', '▁his', '▁cardio', 'logist', '▁in', '▁two', '▁to', '▁three', '▁weeks', '▁and', '▁he', '▁should', '▁follow', '▁up', '▁with', '▁his', '▁primary', '▁care', '▁physician', '▁in', '▁one', '▁to', '▁two', '▁weeks', '▁', '.']
# ['▁4', '.', '▁hyper', 'chol', 'ester', 'ol', 'emia']
# ['▁1957', '-', '08', '-', '17', '▁pad', '-', 'word']
# ['▁associated', '▁diagnose', 's', '▁', ':']
# ['▁name', '▁', ':']
# ['▁age', '▁shu', 'ff']
# ['▁he', '▁denied', '▁cp', '▁', ',', '▁sob', '▁', ',', '▁ha', '▁', ',', '▁vision', '▁changes', '▁', ',', '▁neck', '▁stiff', 'ness', '▁', ',', '▁dys', 'uria', '▁', ',', '▁or', '▁other', '▁symptoms', '▁', '.']
# ['▁2013', '-', '05', '-', '24', '▁', '07', ':40', '▁am', '▁15', '▁*', '▁2', '.', '4']
# ['▁principal', '▁procedure', '▁', ':']
# ['▁hypertension', '▁', '.']
# ['▁', 'cta', '/', 'ct', '▁abd', '▁', '03', '-', '07', '▁', ':']
# ['▁', 'dict', 'ating', '▁for', '▁', ':']
# ['▁discharge', '▁medication', 's', '▁', ':']
# ['▁patient', '▁recorded', '▁as', '▁having', '▁no', '▁known', '▁all', 'er', 'gies', '▁to', '▁drugs']
# ['▁tap', 'er', '▁over', '▁2', '▁weeks', '▁multi', 'vita', 'min', '▁', 'therapeutic', '▁', '(', '▁', 'therapeutic', '▁multi', 'vi', '▁', '.', '.', '.', '▁', ')', '▁5', '▁milli', 'liter', 's', '▁po', '▁q', 'd']
# ['▁physical', '▁exam', ':']
# ['▁comparison', '▁', ':', '▁none', '▁', '.']
# ['▁he', 'mat', 'ologic', '▁', '.']
# ['▁106', '15', '/', '26', '46', '▁pad', '-', 'word']
# ['▁discharge', '▁medication', 's', '▁', ':']
# ['▁1', '.', '▁left', '▁middle', '▁cerebral', '▁artery', '▁territory', '▁cerebral', '▁in', 'far', 'c', 'tion', '▁', '.']
# ['▁expired', '▁pad', '-', 'word']
# ['▁1964', '-', '04', '-', '26', '▁pad', '-', 'word']
# ['▁mi', 'tral', '▁valve', '▁repair', '▁', '.']
# ['▁discharge', '▁status', '▁', ':', '▁to', '▁home', '▁', '.']
# ['▁the', '▁patient', '▁had', '▁a', '▁pic', 'c', '▁line', '▁placed', '▁and', '▁will', '▁continue', '▁a', '▁8', '▁week', '▁course', '▁of', '▁antibiotic', 's', '▁', '.']
# ['▁8', '.', '▁', 'ator', 'va', 'stat', 'in', '▁10', '▁mg', '▁p', '.', 'o', '.', '▁q', '.', 'h', '.', 's', '.']
# ['▁', '<unk>', '▁sant', 'del', '▁', 'glo', 'tz', 'r', 'hal', 't', '▁', ',', '▁m', '.', 'd', '.']
# ['▁neuro', 'logy', '▁follow', '▁up', '▁with', '▁dr', '.', '▁work', 'man', '▁is', '▁scheduled', '▁for', '▁2017', '-', '10', '-', '20', '▁at', '▁12', ':', '30', '▁pm', '▁at', '▁the', '▁addison', '▁gilbert', '▁hospital', '▁of', '▁oak', '▁bluff', 's', '▁', ',', '▁is', 'on', '▁11', '▁', '.']
# ['▁there', '▁was', '▁pitt', 'ing', '▁', 'ed', 'ema', '▁of', '▁both', '▁lower', '▁extrem', 'ities', '▁but', '▁no', '▁evidence', '▁of', '▁cell', 'ul', 'itis', '▁of', '▁the', '▁left', '▁lower', '▁extrem', 'ity', '▁', '.']
# ['▁43', '79', '2', '▁pad', '-', 'word']
# ['▁she', '▁received', '▁36', 'gm', '▁of', '▁album', 'in', '▁following', '▁the', '▁tap', '▁', '.']
# ['▁5', '.', '▁', 'cele', 'xa', '▁10', '▁mg', '▁daily', '▁', '.']
# ['▁', '01', '/', '30', '/', '01', '▁pad', '-', 'word']
# ['▁the', '▁patient', '▁was', '▁instructed', '▁to', '▁take', '▁20', '▁mg', '▁at', '▁11', '▁pm', '▁the', '▁night', '▁before', '▁her', '▁next', '▁chemotherapy', '▁and', '▁8', '▁am', '▁on', '▁the', '▁morning', '▁of', '▁chemotherapy', '▁', '.']
# ['▁post', 'part', 'um', '▁care', '▁site', '▁', ':']
# ['▁2', ')', '▁right', '▁lower', '▁extrem', 'ity', '▁cell', 'ul', 'itis', '▁', ':']
# ['▁currently', '▁a', 'a', 'ox', '3', '▁', '.']
# ['▁abdomen', 's', '▁of', 't', '▁with', '▁positive', '▁bowel', '▁sounds', '▁', '.']
# ['▁', '09', '167', '▁pad', '-', 'word']
# ['▁report', '▁status', '▁', ':']
# ['▁the', '▁patient', '▁will', '▁be', '▁discharged', '▁in', '▁stable', '▁condition', '▁', '.']
# ['▁discharge', '▁diagnose', 's', '▁', ':']
# ['▁the', '▁patient', '▁was', '▁admitted', '▁to', '▁the', '▁hospital', '▁and', '▁on', '▁2016', '-', '04', '-', '06', '▁the', '▁patient', '▁underwent', '▁corona', 'ry', '▁artery', '▁bypass', '▁graft', 'ing', '▁x', '▁4', '▁with', '▁left', '▁internal', '▁mam', 'mary', '▁artery', '▁to', '▁the', '▁left', '▁anterior', '▁descending', '▁corona', 'ry', '▁artery', '▁', ',', '▁sa', 'pheno', 'us', '▁vein', '▁graft', '▁to', '▁the', '▁diagonal', '▁', ',', '▁sa', 'pheno', 'us', '▁vein', '▁graft', '▁to', '▁ob', 't', 'use', '▁marginal', '▁', ',', '▁sa', 'pheno', 'us', '▁vein', '▁graft', '▁to', '▁right', '▁corona', 'ry', '▁artery', '▁', ',', '▁posterior', '▁descending', '▁corona', 'ry', '▁artery', '▁', '.']
# ['▁name', '▁', ':']
# ['▁', 'vita', '▁tho', 'ster', 'wen', '▁link', 'e', 'kot', 'emon', 'es', '▁', ',', '▁m', '.', 'd', '.']
# ['▁cc', '▁', ':']
# ['▁2', ')', '▁meta', 'static', '▁r', 'cc', '▁', ':', '▁sut', 'ent', '▁was', '▁held', '▁on', '▁admission', '▁in', '▁light', '▁of', '▁acute', '▁infection', '▁', '.']
# ['▁lac', 'tul', 'ose', '▁30', '▁mg', '▁q', '.', 'i', '.', 'd', '.']
# ['▁since', '▁that', '▁time', '▁', ',', '▁she', '▁has', '▁used', '▁a', '▁cane', '▁and', '▁she', '▁was', '▁referred', '▁to', '▁dr', '.', '▁koo', 'rs', '▁', '.']
# ['▁m', '▁pad', '-', 'word']
# ['▁', '09', '/', '20', '/', '2000', '▁12', ':41', '▁pm']
# ['▁12', '.', '▁regular', '▁insulin', '▁5', '▁units', '▁q', '.', '▁a', '.', 'm', '.', '▁and', '▁3', '▁to', '▁5', '▁units', '▁q', '.', '▁p', '.', 'm', '.']
# ['▁', '04', '/', '04', '/', '2002', '▁', '01', ':', '09', '▁am']
# ['▁laboratory', '▁data', '▁', ':']
# ['▁dis', '▁pad', '-', 'word']
# ['▁cc', '▁', ':']
# ['▁44', 'y', '▁pad', '-', 'word']
# ['▁notable', '▁for', '▁her', '▁diffuse', '▁ex', 'pir', 'atory', '▁', 'whee', 'ze', 's', '▁and', '▁scattered', '▁ex', 'pir', 'atory', '▁crack', 'les', '▁', '.']
# ['▁on', '▁admission', '▁she', '▁was', '▁taking', '▁que', 'tia', 'pine', '▁300', '▁mg', '▁q', 'h', 's', '▁and', '▁clon', 'az', 'epa', 'm', '▁1', '▁mg', '▁qa', 'm', '▁', ',', '▁1', '▁mg', '▁q', '3', 'pm', '▁', ',', '▁2', '▁mg', '▁po', '▁q', 'h', 's', '▁', '.']
# ['▁cor', 'neal', 's', '▁diminished', '▁on', '▁the', '▁left', '▁side', '▁', '.']
# ['▁the', '▁patient', '▁is', '▁a', '▁74', '-', 'year', '-', 'old', '▁woman', '▁', ',', '▁well', '▁known', '▁to', '▁the', '▁cardiac', '▁surgery', '▁service', '▁', ',', '▁read', 'mitte', 'd', '▁from', '▁gla', 's', 'm', 'if', '/', 'put', 'di', '▁health', '▁network', '▁with', '▁stern', 'al', '▁wound', '▁infection', '▁', '.']
# ['▁will', '▁', 'd', '▁', '/', '▁c', '▁order', '▁be', '▁used', '▁as', '▁the', '▁', 'd', '▁', '/', '▁c', '▁summary', '▁', ':']
# ['▁this', '▁prompted', '▁further', '▁staging', '▁work', '-', 'up', '▁', '.']
# ['▁2017', '-', '09', '-', '27', '▁pad', '-', 'word']
# ['▁36', '79', '▁pad', '-', 'word']
# ['▁this', '▁triple', 't', '▁#3', '▁emerged', '▁with', '▁spontaneous', '▁re', 'spira', 'tion', 's', '▁', ',', '▁and', '▁required', '▁blow', '-', 'by', '▁oxygen', '▁in', '▁the', '▁delivery', '▁room', '▁', '.']
# ['▁59', '242', '403', '▁pad', '-', 'word']
# ['▁', 'd', '▁', ':', '▁2010', '-', '06', '-', '30', '▁17', ':', '18']
# ['▁his', '▁co', 'uma', 'din', '▁was', '▁transition', 'ed', '▁to', '▁2', '▁mg', '▁and', '▁then', '▁1', '▁mg', '▁', '.']
# ['▁transfer', '▁from', '▁rehab', '▁hospital', '▁of', '▁the', '▁cape', '▁&', '▁islands', '▁hospital', '▁for', '▁an', '▁end', 'oscopic', '▁retro', 'gram', '▁chola', 'n', 'gio', 'pan', 'crea', 't', 'ography', '▁', '.']
# ['▁going', 'net', 'hb', 'ump', 's', '▁', ',', '▁nan', 'so', '▁r', '.', '▁', ',', '▁m', '.', 'd', '.', '▁', '(', '▁', 'hk', '18', '▁', ')', '▁', '02', '/1', '4/', '02', '▁', '08', ':39', '▁am']
# ['▁basil', 'ar', '▁artery', '▁sten', 'osis', '▁with', '▁basil', 'ar', '▁', 'thromb', 'osis', '▁and', '▁&', 'quo', 't', ';', '▁top', '▁of', '▁the', '▁basil', 'ar', '▁&', 'quo', 't', ';', '▁syndrome', '▁', '.']
# ['▁', '01', '-', '23', '▁pic', 'c', '▁placement', '▁', '.']
# ['▁', ',', '▁other', '▁', '-', '▁brady', 'cardi', 'a']
# ['▁the', '▁ti', 'car', 'cil', 'lin', '▁was', '▁stopped', '▁after', '▁two', '▁days', '▁when', '▁it', '▁was', '▁felt', '▁that', '▁he', '▁did', '▁not', '▁have', '▁a', '▁serious', '▁pneumonia', '▁', '.']
# ['▁liver', '▁function', '▁test', '▁showed', '▁as', 't', '▁21', '▁', ',', '▁alkaline', '▁', 'phos', 'pha', 't', 'ase', '▁70', '▁', ',', '▁total', '▁', 'bili', 'rub', 'in', '▁0', '.', '3', '▁', ',', '▁total', '▁protein', '▁6', '.', '5', '▁', ',', '▁album', 'in', '▁3', '.', '9', '▁', ',', '▁glob', 'ulin', '▁2', '.', '6', '▁', '.']
# ['▁chest', '▁was', '▁clear', '▁to', '▁percussion', '▁and', '▁a', 'us', 'cult', 'ation', '▁', '.']
# ['▁', '02', '/2', '3/', '2005', '▁', '05', ':41', '▁am']
# ['▁this', '▁is', '▁an', '▁85', '▁year', '▁old', '▁man', '▁initially', '▁admitted', '▁to', '▁the', '▁plastic', '▁surgery', '▁service', '▁for', '▁evaluation', '▁of', '▁a', '▁left', '▁facial', '▁mass', '▁', '.']
# ['▁chief', '▁complaint', '▁', ':']
# ['▁weight', '▁', ':']
# ['▁report', '▁status', '▁', ':']
# ['▁', '4/', '16', '/', '93', '▁pad', '-', 'word']
# ['▁the', '▁patient', '▁recovered', '▁well', '▁status', '▁post', '▁these', '▁two', '▁procedures', '▁', '.']
# ['▁4', '.', '▁', 'ator', 'va', 'stat', 'in', '▁calcium', '▁10', '▁mg', '▁tablet', '▁sig', '▁', ':', '▁one', '▁', '(', '▁1', '▁', ')', '▁tablet', '▁po', '▁daily', '▁', '(', '▁daily', '▁', ')', '.']
# ['▁', 'd', '-', 'di', 'mer', '▁', '-', '▁79', '98', '▁*']
# ['▁service', '▁', ':']
# ['▁chief', '▁complaint', '▁', ':']
# ['▁for', '▁the', '▁past', '▁several', '▁years', '▁', ',', '▁the', '▁patient', '▁has', '▁continued', '▁to', '▁have', '▁significant', '▁exercise', '▁into', 'ler', 'ance', '▁which', '▁has', '▁limited', '▁his', '▁ability', '▁to', '▁work', '▁', '.']
# ['▁8', '245', '338', '▁pad', '-', 'word']
# ['▁44', '-', '7', '25', '▁pad', '-', 'word']
# ['▁she', '▁was', '▁promptly', '▁in', 't', 'ub', 'ated', '▁for', '▁air', 'way', '▁protection', '▁and', '▁in', '▁order', '▁to', '▁administer', '▁charcoal', '▁', '.']
# ['▁discharge', '▁medication', 's', '▁', ':']
# ['▁on', '▁hospital', '▁day', '▁2', '▁she', '▁experienced', '▁a', 'trial', '▁fib', 'rill', 'ation', '▁with', '▁', 'hr', '▁in', '▁the', '▁140', 's', '▁', '.']
# ['▁mr', 'n', '▁', ':']
# ['▁77', 'y', '▁pad', '-', 'word']
# ['▁there', '▁is', '▁a', '▁very', '▁small', '▁circum', 'fer', 'ential', '▁peri', 'cardi', 'al', '▁ef', 'fusion', '▁', '.']
# ['▁1', '.', '▁hypertension', '▁', '.']
# ['▁', '<unk>', '▁o', 'ie', '▁limo', 'r', '▁warm', '▁', ',', '▁m', '.', 'd', '.']
# ['▁****', '**', '▁final', '▁discharge', '▁orders', '▁****', '**']
# ['▁brief', '▁resume', '▁of', '▁hospital', '▁course', '▁', ':']
# ['▁1', '.', '▁as', 'pir', 'in', '▁', '325', '▁mg', '▁tablet', '▁sig', '▁', ':', '▁one', '▁', '(', '▁1', '▁', ')', '▁tablet', '▁po', '▁daily', '▁', '(', '▁daily', '▁', ')', '.']
# ['▁2016', '-', '11', '-', '21', '▁pad', '-', 'word']
# ['▁the', '▁patient', '▁then', '▁was', '▁given', '▁void', 'ing', '▁trials', '▁but', '▁eventually', '▁he', '▁needed', '▁to', '▁be', '▁straight', '▁cath', 'ed', '▁pr', 'n', '▁', '.']
# ['▁pen', 'ici', 'll', 'in', 's', '▁pad', '-', 'word']
# ['▁2', '.', '▁', 'compa', 'zine', '▁10', '▁mg', '▁p', '.', 'o', '.', '▁q', '▁6', 'hour', 's', '▁p', '.', 'r', '.', 'n', '.', '▁nausea', '▁', '.']
# ['▁date', '▁of', '▁birth', '▁', ':']
# ['▁1', '.', '▁history', '▁of', '▁high', '▁cho', 'leste', 'rol', '▁', '.']
# ['▁1', '.', '▁do', 'cus', 'ate', '▁sodium', '▁100', '▁mg', '▁capsule', '▁sig', '▁', ':', '▁one', '▁', '(', '▁1', '▁', ')', '▁capsule', '▁po', '▁bid', '▁', '(', '▁2', '▁times', '▁a', '▁day', '▁', ')', '.']
# ['▁brief', '▁hospital', '▁course', '▁', ':']
# ['▁a', '▁left', '▁breast', '▁lump', 'ectomy', '▁was', '▁reportedly', '▁benign', '▁', '.']
# ['▁the', '▁patient', '▁was', '▁taken', '▁to', '▁the', '▁', 'oper', 'ting', '▁room', '▁on', '▁', '8/', '7/', '92', '▁', ',', '▁where', '▁a', '▁right', '▁modified', '▁radical', '▁mast', 'ectomy', '▁was', '▁performed', '▁', '.']
# ['▁pt', '▁also', '▁counsel', 'led', '▁re', '▁', ':']
# ['▁', 'ct', 'x', '▁q', '▁6', '▁&', 'apo', 's', ';', '▁', '.']
# ['▁f', '▁', '/', '▁u', '▁with', '▁dr', '.', '▁white']
# ['▁sep', 'sis', '▁', '-', '?', '▁source']
# ['▁', 'd', '▁', ':']
# ['▁ralph', '▁katherine', '▁md', '▁31', '-', '164']
# ['▁the', '▁liver', '▁en', 'zim', 'es', '▁come', '▁down', '▁', ',', '▁no', '▁signs', '▁of', '▁', 'bili', 'ary', '▁', 'stasis', '▁', '.']
# ['▁cardiac', '▁exam', '▁', ';', '▁she', '▁has', '▁positive', '▁', 's', '1', '▁', ',', '▁', 's', '2', '▁without', '▁murmur', '▁', ',', '▁rub', '▁or', '▁gallop', '▁', '.']
# ['▁2019', '-', '06', '-', '19', '▁', '07', ':', '20', '▁am', '▁blood', '▁gluco', 'se', '▁', '-', '▁73', '▁', 'ure', 'an', '▁', '-', '▁20', '▁cre', 'at', '▁', '-', '▁1', '.', '1', '▁na', '▁', '-', '▁', '136', '▁k', '▁', '-', '▁5', '.', '0', '▁cl', '▁', '-', '▁101', '▁h', 'co', '3', '▁', '-', '▁27', '▁', 'anga', 'p', '▁', '-', '▁13']
# ['▁the', '▁wound', '▁had', '▁a', '▁beef', 'y', '▁red', '▁cell', 'uli', 'tic', '▁area', '▁surrounding', '▁an', '▁open', '▁area', '▁', ',', '▁', 'blanc', 'h', 'ing', '▁to', '▁touch', '▁', '.']
# ['▁', 'ed', '▁discharge', '▁summary']
# ['▁unit', '▁number', '▁', ':']
# ['▁you', '▁were', '▁diagnosed', '▁with', '▁an', '▁epi', 'd', 'ural', '▁abs', 'ces', 's', '▁', '.']
# ['▁abdomen', '▁', ':', '▁soft', '▁', ',', '▁non', 'd', 'ist', 'ended', '▁', '.']
# ['▁4', '.', '▁', 'oxy', 'co', 'd', 'one', '▁', '-', '▁a', 'cet', 'amino', 'phen', '▁5', '-', '325', '▁mg', '▁tablet', '▁sig', '▁', ':', '▁1', '-', '2', '▁tablets', '▁po', '▁q', '4', 'h', '▁', '(', '▁every', '▁4', '▁hours', '▁', ')', '▁as', '▁needed', '▁for', '▁pain', '▁', '.']
# ['▁****', '**', '▁end', '▁of', '▁discharge', '▁orders', '▁****', '**']
# ['▁vs', '▁', ':', '▁', 't', ',', '▁bp', '▁', '181', '/1', '22', '▁', ',', '▁', 'hr', '▁84', '▁', ',', '▁', 'rr', '▁12', '▁', ',', '▁o', '2', '▁', '98%', '▁2', 'l', '/', 'm']
# ['▁over', '▁the', '▁next', '▁three', '▁days', '▁he', '▁increased', '▁his', '▁activity', '▁gradually', '▁', ',', '▁was', '▁able', '▁to', '▁do', '▁stairs', '▁with', '▁physical', '▁therapy', '▁and', '▁had', '▁pain', '▁which', '▁could', '▁be', '▁controlled', '▁with', '▁oral', '▁an', 'alge', 'sic', 's', '▁', '.']
# ['▁additional', '▁comments', '▁', ':']
# ['▁66', 'r', '-', '249', '▁pad', '-', 'word']
# ['▁service', '▁', ':']
# ['▁', 'd', '▁', ':', '▁2012', '-', '05', '-', '14', '▁19', ':24']
# ['▁he', 'mat', 'ologic', '▁', ':']
# ['▁1', '.', '▁trach', 'eo', 's', 'to', 'my', '▁', '.']
# ['▁ch', '▁ko', 'te', 'ko', 'll']
# ['▁job', '▁#', ':']
# ['▁from', '▁sao', '▁to', 'me', '▁originally', '▁', '.']
# ['▁discharge', '▁date', '▁', ':']
# ['▁weight', '▁at', '▁time', '▁of', '▁discharge', '▁is', '▁3', '.', '13', '▁kilograms', '▁', '.']
# ['▁b', 'zo', '▁pad', '-', 'word']
# ['▁she', '▁delivered', '▁a', '▁3', '550', '▁gram', '▁male', '▁infant', '▁on', '▁', '08', '/3', '1/', '2004', '▁at', '▁', '09', ':33', '▁pm', '▁with', '▁ap', 'gar', '▁scores', '▁of', '▁9', '▁and', '▁9', '▁at', '▁one', '▁and', '▁five', '▁minutes', '▁respectively', '▁at', '▁41', '.', '0', '▁weeks', '▁gestation', '▁via', '▁spontaneous', '▁vertex', '▁vagina', 'l', '▁delivery', '▁', '.']
# ['▁4', '.', '▁', 'gastrointestinal', '▁', ':', '▁boston', '▁required', '▁treatment', '▁for', '▁un', 'con', 'jung', 'ated', '▁hyper', 'bili', 'rub', 'in', 'emia', '▁with', '▁photo', 'therapy', '▁', '.']
# ['▁', '08', '/', '20', '/', '2000', '▁9', ':', '25', '▁a']
# ['▁heart', '▁sounds', '▁were', '▁normal', '▁', '.']
# ['▁past', '▁surgical', '▁history', '▁', ':']
# ['▁c', 'tab', '▁', ',', '▁mildly', '▁decreased', '▁breath', '▁sounds', '▁b', '/', 'l']
# ['▁55', '▁year', '▁old', '▁man', '▁with', '▁history', '▁of', '▁meta', 'static', '▁bladder', '▁cancer', '▁and', '▁recurrent', '▁', 'dv', 't', '▁', 's', '▁on', '▁love', 'no', 'x', '▁admitted', '▁with', '▁lower', '▁gi', '▁bleeding', '▁', '.']
# ['▁all', 'er', 'gies', '▁', ':']
# ['▁dis', '▁pad', '-', 'word']
# ['▁the', '▁patient', '▁did', '▁fall', '▁while', '▁in', 'house', '▁', '.']
# ['▁should', '▁this', '▁become', '▁available', '▁', ',', '▁an', '▁add', 'end', 'um', '▁will', '▁be', '▁issued', '▁to', '▁this', '▁report', '▁following', '▁the', '▁comparison', '▁with', '▁the', '▁outside', '▁examination', '▁', '.']
# ['▁', '260', '24', '▁pad', '-', 'word']
# ['▁chief', '▁complaint', '▁', ':']
# ['▁hospital', '▁course', '▁', ':']
# ['▁he', '▁is', '▁now', '▁living', '▁with', '▁his', '▁son', '▁and', '▁daughter', '▁', ',', '▁and', '▁five', '▁other', '▁children', '▁', '.']
# ['▁head', '▁computer', 'ized', '▁tom', 'ography', '▁scan', '▁of', '▁10', '/', '23', '▁', ':']
# ['▁principal', '▁discharge', '▁diagnosis', '▁', ';', '▁responsible', '▁after', '▁study', '▁for', '▁causing', '▁admission', '▁', ')', '▁a', 'typical', '▁chest', '▁pain']
# ['▁her', '▁co', 'ag', 'ulation', '▁parameters', '▁were', '▁normal', '▁', '.']
# ['▁there', '▁was', '▁no', '▁obvious', '▁segment', 'al', '▁wall', '-', 'motion', '▁abnormal', 'ity', '▁', '.']
# ['▁no', '▁known', '▁drug', '▁all', 'er', 'gies', '▁', '.']
# ['▁sodium', '▁of', '▁', '138', '▁', ';', '▁potassium', '▁3', '.', '5', '▁', ';', '▁106', '▁', ',', '▁28', '▁', ',', '▁31', '▁', ',', '▁1', '.', '0', '▁', ',', '▁gluco', 'se', '▁', '134', '▁', '.']
# ['▁they', '▁recommended', '▁that', '▁the', '▁patient', '▁may', '▁benefit', '▁from', '▁a', '▁trial', '▁of', '▁continuous', '▁positive', '▁pressure', '▁at', '▁the', '▁bedside', '▁', '.']
# ['▁1', '1/2', '6/', '2000', '▁', '06', ':47', '▁pm']
# ['▁g', '4', '▁', 't', '2', '▁p', '0', '▁a', '1', '▁l', '2', '▁estimated']
# ['▁6', '.', '▁la', 'six', '▁40', '▁mg', '▁po', '▁q', '.', 'day', '▁', ',']
# ['▁her', '▁cre', 'ati', 'nine', '▁continued', '▁to', '▁increase', '▁', ',', '▁likely', '▁due', '▁to', '▁her', '▁worse', 'ning', '▁liver', '▁failure', '▁', '.']
# ['▁none', '▁', '.']
# ['▁admission', '▁date', '▁', ':']
# ['▁neck', '▁', ':']
# ['▁discharge', '▁instructions', '▁', ':']
# ['▁q', 'g', '▁pad', '-', 'word']
# ['▁she', '▁is', '▁to', '▁contact', '▁dr', '.', '▁warm', '▁&', 'apo', 's', ';', 's', '▁office', '▁to', '▁schedule', '▁a', '▁follow', '▁up', '▁appointment', '▁', '.']
# ['▁care', '▁and', '▁recommendations', '▁', ':']
# ['▁medication', 's', '▁on', '▁admission', '▁', ':']
# ['▁10', '/1', '7/', '2001', '▁', '01', ':36', '▁pm']
# ['▁past', '▁medical', '▁history', '▁', ':']
# ['▁no', '▁ortho', 'p', 'nea', '▁', '.']
# ['▁chronic', '▁renal', '▁in', 'sufficiency', '▁', '.']
# ['▁ko', 'tero', 'stre', 'uko', 'te', '▁', ',', '▁a', 'ro', '▁ma', '▁o', '.', '▁9', '65', '-', '81', '-', '64', '-', '6', '▁u', '94']
# ['▁1', '.', '▁as', 'pir', 'in', '▁81', '▁mg', '▁tablet', '▁', ',', '▁delayed', '▁release', '▁', '(', '▁', 'e', '.', 'c', '.', '▁', ')', '▁sig', '▁', ':', '▁one', '▁', '(', '▁1', '▁', ')', '▁tablet', '▁', ',', '▁delayed', '▁release', '▁', '(', '▁', 'e', '.', 'c', '.', '▁', ')', '▁po', '▁daily', '▁', '(', '▁daily', '▁', ')', '.']
# ['▁trace', '▁movement', '▁of', '▁the', '▁right', '▁elbow', '▁and', '▁4', '-', 'strength', '▁of', '▁the', '▁right', '▁wrist', '▁and', '▁hand', '▁', '.']
# ['▁take', '▁with', '▁food', '▁pre', 'natal', '▁multi', 'vita', 'min', 's', '▁', '(', '▁stuart', 'natal', '▁', ')', '▁1', '▁tab', '▁po', '▁q', 'd', '▁ma', 'al', 'ox', '-', 'table', 't', 's', '▁quick', '▁dissolve', '▁', '/', '▁chew', 'able', '▁1', '-', '2', '▁tab', '▁po', '▁q', '6', 'h', '▁pr', 'n', '▁upset', '▁stomach']
# ['▁in', '▁2003', '▁', ',', '▁he', '▁had', '▁a', '▁non', '▁st', '▁elevation', '▁mi', '▁', ',', '▁came', '▁to', '▁the', '▁r', 'wh', '▁', ',', '▁and', '▁had', '▁a', '▁cath', '▁done', '▁', ',', '▁which', '▁showed', '▁a', '▁40%', '▁rca', '▁', ',', '▁which', '▁was', '▁hazy', '▁', '.']
# ['▁discharge', '▁diagnosis', '▁', ':']
# ['▁1929', '-', '11', '-', '09', '▁pad', '-', 'word']
# ['▁10', '/', '10', '/', '1997', '▁1', '2:00', ':', '00', '▁am']
# ['▁we', '▁have', '▁advised', '▁a', '▁brat', '▁diet', '▁', '.']
# ['▁we', '▁will', '▁given', '▁val', 'ium', '▁5', '▁mg', '▁p', '.', 'o', '.', '▁q', '.', '▁3', '▁hours', '▁for', '▁withdrawal', '▁', '.']
# ['▁goals', '▁of', '▁care', '▁were', '▁clarified', '▁with', '▁her', '▁murphy', '▁', ',', '▁robert', '▁sanchez', '▁', '.']
# ['▁the', '▁patient', '▁states', '▁that', '▁he', '▁was', '▁willing', '▁to', '▁speak', '▁with', '▁someone', '▁from', '▁addiction', '▁services', '▁', '.']
# ['▁he', '▁did', '▁travel', '▁to', '▁the', '▁ta', 'heim', 'pro', 'm', 'ong', '▁', ',', '▁last', '▁in', '▁', '01', '/', '2004', '▁for', '▁three', '▁weeks', '▁', '.']
# ['▁the', '▁telephone', '▁number', '▁at', '▁his', '▁office', '▁is', '▁', '236', '-', '45', '18', '▁', '.']
# ['▁medication', 's', '▁on', '▁discharge', '▁', ':']
# ['▁disposition', '▁', ',', '▁follow', '▁up', '▁and', '▁instructions', '▁to', '▁patient', '▁', ':']
# ['▁neck', '▁', ':']
# ['▁2014', '-', '03', '-', '09', '▁', '02', ':59', '▁am', '▁blood', '▁c', 'trop', 'nt', '▁', '-', '▁0', '.', '21', '▁*']
# ['▁fortunately', '▁', ',', '▁no', '▁evidence', '▁of', '▁bara', 'tro', 'ma', '▁was', '▁ever', '▁discern', 'ed', '▁', '.']
# ['▁2', '.', '▁', 'lis', 'in', 'op', 'ril', '▁15', '▁mg', '▁tablet', '▁sig', '▁', ':', '▁one', '▁', '(', '▁1', '▁', ')', '▁tablet', '▁po', '▁daily', '▁', '(', '▁daily', '▁', ')', '.']
# ['▁4', '.', '▁clo', 'pi', 'dog', 'rel', '▁75', '▁mg', '▁tablet', '▁sig', '▁', ':', '▁one', '▁', '(', '▁1', '▁', ')', '▁tablet', '▁po', '▁daily', '▁', '(', '▁daily', '▁', ')', '▁', '.']
# ['▁2', '.', '▁born', '▁between', '▁32', '▁and', '▁35', '▁weeks', '▁with', '▁plans', '▁for', '▁day', 'care', '▁during', '▁respiratory', '▁syn', 'cy', 't', 'ial', '▁virus', '▁season', '▁', ',', '▁with', '▁a', '▁smoke', 'r', '▁in', '▁the', '▁household', '▁or', '▁with', '▁preschool', '▁siblings', '▁', ';', '▁or']
# ['▁the', '▁acute', '▁onset', '▁of', '▁chest', '▁pain', '▁was', '▁initially', '▁very', '▁concerning', '▁for', '▁a', '▁pe', '▁', ',', '▁however', '▁the', '▁chest', '▁', 'ct', '▁demonstrated', '▁multi', 'fo', 'cal', '▁consolidation', '▁consistent', '▁with', '▁a', '▁bacterial', '▁p', 'na', '▁', '.']
# ['▁no', '▁ethanol', '▁use', '▁', '.']
# ['▁he', '▁was', '▁continued', '▁on', '▁he', 'par', 'in', '▁for', '▁treatment', '▁of', '▁the', '▁pul', 'mon', 'ary', '▁emb', 'oli', '▁', '.']
# ['▁he', '▁denies', '▁any', '▁et', 'oh', '▁or', '▁tobacco', '▁use', '▁', '.']
# ['▁vagina', 'l', '▁delivery', '▁with', '▁second', '▁degree', '▁lace', 'ration']
# ['▁she', '▁came', '▁to', '▁the', '▁emergency', '▁department', '▁on', '▁the', '▁2011', '-', '03', '-', '10', '▁', ',', '▁with', '▁temperature', '▁of', '▁99', '.', '0', '▁f', '▁', '.', ';', '▁blood', '▁pressure', '▁of', '▁97', '/', '50', '▁', ';', '▁heart', '▁rate', '▁100', '▁', ';', '▁re', 'spira', 'tion', 's', '▁27', '▁', ';', '▁o', '2', '▁', 'saturation', '▁', '84%', '▁on', '▁room', '▁air', '▁and', '▁9', '4%', '▁on', '▁two', '▁', 'liter', 's', '▁', '.']
# ['▁', 's', 'rom', '▁in', '▁labor', '▁', '.']
# ['▁1', '.', '▁no', '▁evidence', '▁of', '▁pul', 'mon', 'ary', '▁emb', 'ol', 'ism', '▁', '.']
# ['▁2013', '-', '05', '-', '23', '▁', '01', ':08', '▁pm', '▁1', '.', '22']
# ['▁the', '▁patient', '▁was', '▁taken', '▁off', '▁fluid', '▁restriction', '▁', '.']
# ['▁3', '.', '▁fluid', 's', '▁', ',', '▁electro', 'ly', 'tes', '▁and', '▁nutrition', '▁', '-', '▁birth', 'weight', '▁was', '▁1400', '▁gm', '▁', ',', '▁25', 'th', '▁percent', 'ile', '▁', '.']
# ['▁trach', 'eo', 's', 'to', 'my', '▁2014', '-', '11', '-', '11']
# ['▁follow', 'up', '▁instructions', '▁', ':']
# ['▁date', '▁of', '▁birth', '▁', ':']
# ['▁2018', '-', '05', '-', '24', '▁', '08', ':55', '▁pm']
# ['▁admission', '▁date', '▁', ':']
# ['▁', 'cv', '▁', ':', '▁r', 'rr', '▁', ',', '▁no', '▁m', '/', 'r', '/', 'g']
# ['▁laboratory', '▁data', '▁', ':']
# ['▁peripheral', '▁pulse', 's', '▁were', '▁very', '▁strong', '▁and', '▁bound', 'ing', '▁', '.']
# ['▁10', '/1', '2/', '2004', '▁1', '2:00', ':', '00', '▁am']
# ['▁an', '▁abdominal', '▁mr', 'i', '▁was', '▁performed', '▁to', '▁assess', '▁continued', '▁elevated', '▁liver', '▁enzymes', '▁', ';', '▁however', '▁', ',', '▁the', '▁mr', 'i', '▁was', '▁negative', '▁', '.']

# %% [markdown]
# # 9. Code snippets

# %%
# flatten1 = list(itertools.chain(*y_true))
# flatten2 = list(itertools.chain(*y_pred))
# tagsforf1 = []
# for tag in tags_vals[:-3]:
#     if tag != 'O':
#         tagsforf1.append(tag)

# %%
#https://datascience.stackexchange.com/questions/54907/model-cuda-in-pytorch
# if n_gpu >1:
#     model = torch.nn.DataParallel(model)
# model.cuda(device='cuda:0')
# model.to(torch.device('cuda:0'))

# %%
# params = list(model.named_parameters())
# print(len(params))
# for p in params[0:201]:
#     print(p[0], p[1].size())

# %%
# type(param_optimizer)
# type(optimizer_grouped_parameters)
# len(optimizer_grouped_parameters)

# type(optimizer_grouped_parameters[0])

# optimizer_grouped_parameters[1].keys()

# optimizer_grouped_parameters[0]['weight_decay_rate']

# optimizer_grouped_parameters[1]['weight_decay_rate']

# optimizer_grouped_parameters[0]['betas']

# optimizer_grouped_parameters[1]['betas']

# optimizer_grouped_parameters[1]['weight_decay']

# optimizer_grouped_parameters[1]['weight_decay']

# optimizer_grouped_parameters[0]['correct_bias']

# optimizer_grouped_parameters[1]['correct_bias']

# %%
# c =28
# print(list(attention_masks[c]))
# print(attention_masks_deprecated[c])
# for i in range(1,150):
#     if list(attention_masks[i]) != attention_masks_deprecated[i]:
#         print(i)

# %%
# tokenized_texts[0]
# tokenizer.tokenize(' '.join(sentences[0]))

# %%
# tokenizer.batch_encode_plus(sentences)['input_ids'][0]
# tokenizer.decode(tokenizer.batch_encode_plus(sentences)['input_ids'][0])
# tokenizer.decode(tokenizer.encode(' '.join(sentences[0])))
# tokenizer.decode(tokenizer.encode(sentences[0]))
# tokenizer.decode(tokenizer.encode('Diagnose revisie : ( Meerdere antwoorden mogelijk) Infectie'))

# %%
# def getmaxlength():
#     lowestcount =512
#     lowestcountindex = 0
#     for idx, onearray in enumerate(input_ids):
#         count=0
#         for number in reversed(onearray):
#             if number ==0:
#                 count += 1
#             else:
#                 if count < lowestcount:
#                     lowestcount = count
#                     lowestcountindex = idx
#                 break

#     maxlength = len(tokenized_texts[lowestcountindex])
#     return maxlength
