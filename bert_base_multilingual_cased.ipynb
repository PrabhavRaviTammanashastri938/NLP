# %% [markdown]
# <a href="https://colab.research.google.com/github/PieterDujardin/NER/blob/master/ColabNotebooks/i2b2_2010/BERT_on_i2b2_2010.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import statements

# %%
# %reload_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
# %pip install transformers
# %pip install seqeval
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.11.17)
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 687.5 kB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from seqeval) (1.23.5)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.10/dist-packages (from seqeval) (1.2.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval) (3.2.0)
# Building wheels for collected packages: seqeval
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16162 sha256=b53404abcf4beef230252f211084f5f8bc80a5fff92ae26ed6e7fa7df67d72af
#   Stored in directory: /root/.cache/pip/wheels/1a/67/4a/ad4082dd7dfc30f2abfe4d80a2ed5926a506eb8a972b4767fa
# Successfully built seqeval
# Installing collected packages: seqeval
# Successfully installed seqeval-1.2.2

# %%
# %pip list | grep -E 'transformers|torch|Keras'

# %%
# %pip list

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import itertools
import csv
import time
import datetime
import io
import math
import os
import numpy as np
import torch
from sklearn.model_selection import train_test_split
from tqdm import tqdm,trange
from seqeval.metrics import f1_score
from seqeval.metrics import classification_report,accuracy_score,f1_score
# from sklearn.metrics import f1_score
from transformers import BertTokenizer, BertConfig, AutoConfig, AutoTokenizer
from transformers import BertForTokenClassification, AdamW, AutoModel, CamembertTokenizer, CamembertForTokenClassification
from keras.preprocessing.sequence import pad_sequences
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
from torch.optim import Adam
import torch.nn.functional as F
from transformers import get_linear_schedule_with_warmup

# %% [markdown]
# # Cuda

# %%
torch.cuda.is_available()
# Out:
# True

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
n_gpu = torch.cuda.device_count()

# %%
n_gpu
# Out:
# 1

# %%
# torch.cuda.get_device_name()
#tesla K80 is used by pytorch

# %%
torch.cuda.get_device_properties('cuda')
# Out:
# _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15102MB, multi_processor_count=40)

# %%
torch.cuda.current_device()
# Out:
# 0

# %%
torch.cuda.device(0)

# %%
#free memory
torch.cuda.empty_cache()

# %% [markdown]
# # 1. Functions

# %%
def loadandformat(datasets):

    # data=[]
    # for dataset in datasets:
    #   # the training, dev and test set in one file
    #   with open('drive/My Drive/Colab Notebooks/BERTwithNER3/conll2003format/{}'.format(dataset),'r') as f:
    #       data +=  f.readlines()
    sentence=[]
    sentences=[]
    for dataset in datasets:
      with open('/content/{}'.format(dataset),'r') as f:
        for line in f:
          if line == '\n':
              sentences.append(sentence)
              sentence=[]
          else:
              sentence.append(line)

    for sent in range(len(sentences)):
      for word in range(len(sentences[sent])):
          sentences[sent][word] = str(sentences[sent][word]).replace('\t',' ')
          sentences[sent][word] = str(sentences[sent][word]).rstrip('\n')
          sentences[sent][word]= str(sentences[sent][word]).split()

    sentenceslabels =[]
    sentencestext =[]

    placeholder0=[]
    placeholder1=[]

    for sent in range(len(sentences)):
      for word in range(len(sentences[sent])):
          placeholder0.append(sentences[sent][word][1])
          placeholder1.append(sentences[sent][word][0])

      sentenceslabels.append(placeholder0)
      sentencestext.append(placeholder1)
      placeholder0=[]
      placeholder1=[]

    joinedlist =[]
    for i in range(len(sentenceslabels)-1):
      joinedlist.extend(sentenceslabels[i])

    tags_vals = list(set(joinedlist))

    tags_vals.append('X')
    tags_vals.append('[CLS]')
    tags_vals.append('[SEP]')

    tag2idx = {t: i for i, t in enumerate(tags_vals)}
    tag2name={tag2idx[key] : key for key in tag2idx.keys()}


    return (sentencestext,sentenceslabels,tags_vals,tag2idx,tag2name)

# %%
def format_time(elapsed):
    '''
    Takes a time in seconds and returns a string hh:mm:ss
    '''
    # Round to the nearest second.
    elapsed_rounded = int(round((elapsed)))

    # Format as hh:mm:ss
    return str(datetime.timedelta(seconds=elapsed_rounded))

# %%
def extract_dict_with_frequency_of_UNKwords():
    '''return a dict with frequency of UNKwords that satisfy a condition'''

    my_list = []
    for word_list,label in (zip(sentences,labels)):
        for word,lab in zip(word_list,label):
            token_list = tokenizer.tokenize(word)
            if token_list == ['[UNK]'] and lab != 'O' and len(word)>= 6:
                my_list.append(word)
    freq = {}
    for item in my_list:
        if (item in freq):
            freq[item] += 1
        else:
            freq[item] = 1

    for key, value in freq.items():
        print ("% s : % d"%(key, value))
    return freq

# %%
def addUNKtokenstovocab(freqdict):
    '''add the words of freq dict to vocab'''
    list1 = list(freqdict.keys())
    for word in list1:
        tokenizer.add_tokens(word)
    print(list1)

# %%
def maketextuallyreadforinput(sentences,labels):
    tokenized_texts = []
    word_piece_labels = []

    i_inc = 0

    for word_list,label in (zip(sentences,labels)):
    #temp label and temp token are the 1 sentence labels and tokens

        temp_label = []
        temp_token = []

        # Add [CLS] at the front
        temp_label.append('[CLS]')
        temp_token.append('[CLS]')

        for word,lab in zip(word_list,label):
            token_list = tokenizer.tokenize(word)
            for m,token in enumerate(token_list):
                temp_token.append(token)
                if m==0:
                    temp_label.append(lab)
                else:
                    temp_label.append('X')

        # Add [SEP] at the end
        temp_label.append('[SEP]')
        temp_token.append('[SEP]')

        tokenized_texts.append(temp_token)
        word_piece_labels.append(temp_label)

        if 50 > i_inc >= 0:
            print("No.%d,len:%d"%(i_inc,len(temp_token)))
            print("texts:%s"%(" ".join(temp_token)))
            print("No.%d,len:%d"%(i_inc,len(temp_label)))
            print("lables:%s"%(" ".join(temp_label)))
        i_inc +=1

    return (tokenized_texts,word_piece_labels)

# %%
def convertokens(max_len,tokenized_texts,word_piece_labels,sentences):
    # Do-something if <condition>, else do-something else.
    input_ids = pad_sequences([tokenizer.convert_tokens_to_ids(txt) for txt in tokenized_texts],
                        maxlen=max_len, dtype="long", truncating="post", padding="post")

    tags = pad_sequences([[tag2idx.get(l) for l in lab] for lab in word_piece_labels],
                  maxlen=max_len, value=tag2idx["O"], padding="post",
                  dtype="long", truncating="post")


    attention_masks_deprecated = [[int(i>0) for i in ii] for ii in input_ids]
    segment_ids = [[0] * len(input_id) for input_id in input_ids]

    allsentences = []
    for sentence in sentences:
        sentence = ' '.join(sentence)
    #     print(sentence)
        allsentences.append(sentence)

    attention_masks = pad_sequences(tokenizer.batch_encode_plus(allsentences)['attention_mask'],
                            maxlen=max_len, dtype="long", truncating="post", padding="post")

#     print(pad_sequences(tokenizer.batch_encode_plus(sentences)['input_ids'][0:2],
#                             maxlen=max_len, dtype="long", truncating="post", padding="post"))

    return (input_ids,tags,attention_masks,segment_ids, attention_masks_deprecated)

# %%
def split_tensor_dataloader(input_ids, tags, attention_masks, segment_ids,batch_num, sizeoftest, sizeofdev):

    tr_inputs, test_inputs, tr_tags, test_tags,tr_masks, test_masks,tr_segs, test_segs = train_test_split(input_ids, tags, attention_masks, segment_ids,
                                                            random_state=1, test_size=sizeoftest)

    tr_inputs, val_inputs, tr_tags, val_tags,tr_masks, val_masks,tr_segs, val_segs = train_test_split(tr_inputs, tr_tags, tr_masks, tr_segs,
                                                            random_state=1, test_size=sizeofdev)

    tr_inputs = torch.tensor(tr_inputs)
    val_inputs = torch.tensor(val_inputs)
    test_inputs = torch.tensor(test_inputs)

    tr_tags = torch.tensor(tr_tags)
    val_tags = torch.tensor(val_tags)
    test_tags = torch.tensor(test_tags)

    tr_masks = torch.tensor(tr_masks)
    val_masks = torch.tensor(val_masks)
    test_masks = torch.tensor(test_masks)

    tr_segs = torch.tensor(tr_segs)
    val_segs = torch.tensor(val_segs)
    test_segs = torch.tensor(test_segs)




    # Only set token embedding, attention embedding, no segment embedding
    train_data = TensorDataset(tr_inputs, tr_masks, tr_tags)
    train_sampler = RandomSampler(train_data)
    # Drop last can make batch training better for the last one
    train_dataloader = DataLoader(train_data, sampler=train_sampler, batch_size=batch_num,drop_last=True)

    #same for validation data
    valid_data = TensorDataset(val_inputs, val_masks, val_tags)
    valid_sampler = SequentialSampler(valid_data)
    valid_dataloader = DataLoader(valid_data, sampler=valid_sampler, batch_size=batch_num)

    test_data = TensorDataset(test_inputs, test_masks, test_tags)
    test_sampler = RandomSampler(test_data)
    # Drop last can make batch training better for the last one
    test_dataloader = DataLoader(test_data, sampler=test_sampler, batch_size=batch_num,drop_last=True)



    return (train_dataloader,valid_dataloader,test_dataloader,tr_inputs,val_inputs,test_inputs)

# %%
def makemodelreadyfortraining(FULL_FINETUNING):


    # Cacluate train optimization num
    num_train_optimization_steps = int( math.ceil(len(tr_inputs) / batch_num) / 1) * epochs


    # True: fine tuning all the layers
    # False: only fine tuning the classifier layers
    if FULL_FINETUNING:
      # Fine tune model all layer parameters
        param_optimizer = list(model.named_parameters()) # list with named parameters and parameters themselves
        no_decay = ['bias', 'gamma', 'beta']

        # list of 2 dicts; only weight decay rate is different : dict_keys(['params', 'weight_decay_rate', 'lr', 'betas', 'eps', 'weight_decay', 'correct_bias'])
        optimizer_grouped_parameters = [
          {'params': [p for n, p in param_optimizer if not any(nd in n for nd in no_decay)],
          'weight_decay_rate': 0.01},
          {'params': [p for n, p in param_optimizer if any(nd in n for nd in no_decay)],
          'weight_decay_rate': 0.0}]

    else:
      # Only fine tune classifier parameters
        param_optimizer = list(model.classifier.named_parameters())
        optimizer_grouped_parameters = [{"params": [p for n, p in param_optimizer]}]

    return (optimizer_grouped_parameters, num_train_optimization_steps)

# %% [markdown]
# # 2. Load data, load model and parameter specification

# %%
#load data:
(sentences,labels,tags_vals,tag2idx,tag2name) = loadandformat(['train.txt','dev.txt','test.txt']) # 'train.txt' 'dev.txt','test.txt'

# %%
tag2name
# Out:
# {0: 'I-treatment',
#  1: 'B-test',
#  2: 'I-test',
#  3: 'I-problem',
#  4: 'O',
#  5: 'B-problem',
#  6: 'B-treatment',
#  7: 'X',
#  8: '[CLS]',
#  9: '[SEP]'}

# %%
#set parameters
epochs = 2
batch_num = 8
learningrate=5e-5

max_grad_norm = 1.0
sizeoftest =0.25#size of test set (first split)
sizeofdev =0.2 #size of dev set (second split)
FULL_FINETUNING = True #Whether to tune all or last layer(s)

# %%
#model

tokenizer = BertTokenizer.from_pretrained("bert-base-multilingual-cased")
model = BertForTokenClassification.from_pretrained('bert-base-multilingual-cased',num_labels=len(tag2idx))
# Out:
# model.safetensors:   0%|          | 0.00/714M [00:00<?, ?B/s]
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
import re

text = '''
Admission   O
Date   O
:   O

2012-10-31   O
PAD-WORD   O

Discharge   O
Date   O
:   O

2012-11-07   O
PAD-WORD   O

Date   O
of   O
Birth   O
:   O

1941-03-23   O
PAD-WORD   O

Sex   O
:   O

M   O
PAD-WORD   O

Service   O
:   O

MEDICINE   O
PAD-WORD   O

Allergies   O
:   O

Nsaids/Anti-Inflammatory   B-treatment
Classifier   I-treatment
/   O
Vancomycin   B-treatment

Attending   O
:   O

Kristie   O
R.   O
Hamby   O
,   O
M.D.   O

Chief   O
Complaint   O
:   O

CC   O
:   O
Antonio   O
M.   O
Z.   O
Eddings   O
,   O
M.D.   O

Major   O
Surgical   O
or   O
Invasive   O
Procedure   O
:   O

Mesenteric   B-test
angiograpm   I-test
w/   O
coil   B-treatment
embolization   I-treatment
of   O
bleeding   B-problem
vessel   I-problem
.   O

Sigmoidoscopy   B-test
.   O

Colonoscopy   B-test
.   O
'''

text = re.sub(r'\s+', ' ', text).strip()

tokens = text.split(' ')

result = []
for i in range(len(tokens)):
  if i % 2 == 0:
    result.append((tokens[i], 'O'))
  else:
    result.append((tokens[i], tokens[i-1]))

print(result)
# Out:
# [('Admission', 'O'), ('O', 'Admission'), ('Date', 'O'), ('O', 'Date'), (':', 'O'), ('O', ':'), ('2012-10-31', 'O'), ('O', '2012-10-31'), ('PAD-WORD', 'O'), ('O', 'PAD-WORD'), ('Discharge', 'O'), ('O', 'Discharge'), ('Date', 'O'), ('O', 'Date'), (':', 'O'), ('O', ':'), ('2012-11-07', 'O'), ('O', '2012-11-07'), ('PAD-WORD', 'O'), ('O', 'PAD-WORD'), ('Date', 'O'), ('O', 'Date'), ('of', 'O'), ('O', 'of'), ('Birth', 'O'), ('O', 'Birth'), (':', 'O'), ('O', ':'), ('1941-03-23', 'O'), ('O', '1941-03-23'), ('PAD-WORD', 'O'), ('O', 'PAD-WORD'), ('Sex', 'O'), ('O', 'Sex'), (':', 'O'), ('O', ':'), ('M', 'O'), ('O', 'M'), ('PAD-WORD', 'O'), ('O', 'PAD-WORD'), ('Service', 'O'), ('O', 'Service'), (':', 'O'), ('O', ':'), ('MEDICINE', 'O'), ('O', 'MEDICINE'), ('PAD-WORD', 'O'), ('O', 'PAD-WORD'), ('Allergies', 'O'), ('O', 'Allergies'), (':', 'O'), ('O', ':'), ('Nsaids/Anti-Inflammatory', 'O'), ('B-treatment', 'Nsaids/Anti-Inflammatory'), ('Classifier', 'O'), ('I-treatment', 'Classifier'), ('/', 'O'), ('O', '/'), ('Vancomycin', 'O'), ('B-treatment', 'Vancomycin'), ('Attending', 'O'), ('O', 'Attending'), (':', 'O'), ('O', ':'), ('Kristie', 'O'), ('O', 'Kristie'), ('R.', 'O'), ('O', 'R.'), ('Hamby', 'O'), ('O', 'Hamby'), (',', 'O'), ('O', ','), ('M.D.', 'O'), ('O', 'M.D.'), ('Chief', 'O'), ('O', 'Chief'), ('Complaint', 'O'), ('O', 'Complaint'), (':', 'O'), ('O', ':'), ('CC', 'O'), ('O', 'CC'), (':', 'O'), ('O', ':'), ('Antonio', 'O'), ('O', 'Antonio'), ('M.', 'O'), ('O', 'M.'), ('Z.', 'O'), ('O', 'Z.'), ('Eddings', 'O'), ('O', 'Eddings'), (',', 'O'), ('O', ','), ('M.D.', 'O'), ('O', 'M.D.'), ('Major', 'O'), ('O', 'Major'), ('Surgical', 'O'), ('O', 'Surgical'), ('or', 'O'), ('O', 'or'), ('Invasive', 'O'), ('O', 'Invasive'), ('Procedure', 'O'), ('O', 'Procedure'), (':', 'O'), ('O', ':'), ('Mesenteric', 'O'), ('B-test', 'Mesenteric'), ('angiograpm', 'O'), ('I-test', 'angiograpm'), ('w/', 'O'), ('O', 'w/'), ('coil', 'O'), ('B-treatment', 'coil'), ('embolization', 'O'), ('I-treatment', 'embolization'), ('of', 'O'), ('O', 'of'), ('bleeding', 'O'), ('B-problem', 'bleeding'), ('vessel', 'O'), ('I-problem', 'vessel'), ('.', 'O'), ('O', '.'), ('Sigmoidoscopy', 'O'), ('B-test', 'Sigmoidoscopy'), ('.', 'O'), ('O', '.'), ('Colonoscopy', 'O'), ('B-test', 'Colonoscopy'), ('.', 'O'), ('O', '.')]

# %%
a=[result[i] for i in range(0,len(result),2)]
a
# Out:
# [('Admission', 'O'),
#  ('Date', 'O'),
#  (':', 'O'),
#  ('2012-10-31', 'O'),
#  ('PAD-WORD', 'O'),
#  ('Discharge', 'O'),
#  ('Date', 'O'),
#  (':', 'O'),
#  ('2012-11-07', 'O'),
#  ('PAD-WORD', 'O'),
#  ('Date', 'O'),
#  ('of', 'O'),
#  ('Birth', 'O'),
#  (':', 'O'),
#  ('1941-03-23', 'O'),
#  ('PAD-WORD', 'O'),
#  ('Sex', 'O'),
#  (':', 'O'),
#  ('M', 'O'),
#  ('PAD-WORD', 'O'),
#  ('Service', 'O'),
#  (':', 'O'),
#  ('MEDICINE', 'O'),
#  ('PAD-WORD', 'O'),
#  ('Allergies', 'O'),
#  (':', 'O'),
#  ('Nsaids/Anti-Inflammatory', 'O'),
#  ('Classifier', 'O'),
#  ('/', 'O'),
#  ('Vancomycin', 'O'),
#  ('Attending', 'O'),
#  (':', 'O'),
#  ('Kristie', 'O'),
#  ('R.', 'O'),
#  ('Hamby', 'O'),
#  (',', 'O'),
#  ('M.D.', 'O'),
#  ('Chief', 'O'),
#  ('Complaint', 'O'),
#  (':', 'O'),
#  ('CC', 'O'),
#  (':', 'O'),
#  ('Antonio', 'O'),
#  ('M.', 'O'),
#  ('Z.', 'O'),
#  ('Eddings', 'O'),
#  (',', 'O'),
#  ('M.D.', 'O'),
#  ('Major', 'O'),
#  ('Surgical', 'O'),
#  ('or', 'O'),
#  ('Invasive', 'O'),
#  ('Procedure', 'O'),
#  (':', 'O'),
#  ('Mesenteric', 'O'),
#  ('angiograpm', 'O'),
#  ('w/', 'O'),
#  ('coil', 'O'),
#  ('embolization', 'O'),
#  ('of', 'O'),
#  ('bleeding', 'O'),
#  ('vessel', 'O'),
#  ('.', 'O'),
#  ('Sigmoidoscopy', 'O'),
#  ('.', 'O'),
#  ('Colonoscopy', 'O'),
#  ('.', 'O')]

# %% [markdown]
# # 3. Function calls

# %%
# extract frequent OOV words and add them to vocab of tokenizer
freq_dict = extract_dict_with_frequency_of_UNKwords()
addUNKtokenstovocab(freq_dict)
# Out:
# []

# %%
(tokenized_texts,word_piece_labels) = maketextuallyreadforinput(sentences,labels)
max_len  = len(max(tokenized_texts, key=len))
# max_len = 150
# Out:
# No.0,len:36
# texts:[CLS] After being transferred from the intervention ##al radio ##logy table to the stretch ##er , one of his lateral per ##cut ##ane ##ous dra ##ins had been pulled out ina ##d ##verte ##ntly . [SEP]
# No.0,len:36
# lables:[CLS] O O O O O O X O X O O O O X O O O B-treatment I-treatment I-treatment X X X I-treatment X O O O O O X X X O [SEP]
# No.1,len:28
# texts:[CLS] He was admitted to the Re ##tel ##k County Medical Center at that time and was treated with Ba ##ct ##rim and ster ##oid ##s . [SEP]
# No.1,len:28
# lables:[CLS] O O O O O O X X O O O O O O O O O O B-treatment X X O B-treatment X X O [SEP]
# No.2,len:10
# texts:[CLS] She was seen by the Psychiatry Service . [SEP]
# No.2,len:10
# lables:[CLS] O O O O O B-treatment I-treatment O [SEP]
# No.3,len:13
# texts:[CLS] 1958 - 03 - 17 PA ##D - W ##OR ##D [SEP]
# No.3,len:13
# lables:[CLS] O X X X X O X X X X X [SEP]
# No.4,len:11
# texts:[CLS] 435 ##13 ##42 PA ##D - W ##OR ##D [SEP]
# No.4,len:11
# lables:[CLS] O X X O X X X X X [SEP]
# No.5,len:15
# texts:[CLS] - Al ##but ##ero ##l / At ##rove ##nt ne ##bs q ##4 [SEP]
# No.5,len:15
# lables:[CLS] O B-treatment X X X O B-treatment X X O X O X [SEP]
# No.6,len:23
# texts:[CLS] Pat ##ient was also found to have ab ##normal T ##F ##T ##s on Su ##tent and was started on replacement [SEP]
# No.6,len:23
# lables:[CLS] O X O O O O O B-problem X I-problem X X X O B-treatment X O O O O B-treatment [SEP]
# No.7,len:22
# texts:[CLS] She has on her right an ##kle anterior ##ly a four centimeter ul ##cer with ne ##cro ##tic base . [SEP]
# No.7,len:22
# lables:[CLS] O O O O O O X O X B-problem I-problem I-problem I-problem X I-problem I-problem X X I-problem O [SEP]
# No.8,len:10
# texts:[CLS] Sign ##ed PA ##D - W ##OR ##D [SEP]
# No.8,len:10
# lables:[CLS] O X O X X X X X [SEP]
# No.9,len:26
# texts:[CLS] He had a left pupil that was in une ##qual in size with a key ##hole appearance consistent with a col ##ob ##oma . [SEP]
# No.9,len:26
# lables:[CLS] O O O O O O O O B-problem X I-problem I-problem O B-problem I-problem X I-problem O O B-problem I-problem X X O [SEP]
# No.10,len:12
# texts:[CLS] 383 ##85 ##5 ##6 PA ##D - W ##OR ##D [SEP]
# No.10,len:12
# lables:[CLS] O X X X O X X X X X [SEP]
# No.11,len:7
# texts:[CLS] Reason for over ##ride : [SEP]
# No.11,len:7
# lables:[CLS] O O O X O [SEP]
# No.12,len:21
# texts:[CLS] The was trace mit ##ral re ##gur ##git ##ation and trace tri ##cus ##pid re ##gur ##git ##ation . [SEP]
# No.12,len:21
# lables:[CLS] O O B-problem I-problem X I-problem X X X O B-problem I-problem X X I-problem X X X O [SEP]
# No.13,len:16
# texts:[CLS] 3rd floor Henderson Building with Dr . Black ( 650 ) 866 - 1361 [SEP]
# No.13,len:16
# lables:[CLS] O O O O O O X O O O O O X X [SEP]
# No.14,len:12
# texts:[CLS] Full term male infant with c ##yano ##sis episodes . [SEP]
# No.14,len:12
# lables:[CLS] O O O O O B-problem X X I-problem O [SEP]
# No.15,len:19
# texts:[CLS] The patient had no blood cultures to grow cor ##yne ##ba ##cter ##ium while hospital ##ized . [SEP]
# No.15,len:19
# lables:[CLS] O O O O B-test I-test O O B-problem X X X X O O X O [SEP]
# No.16,len:20
# texts:[CLS] There is a linear right temporal cal ##vari ##al frac ##ture extending into the right temporal bones . [SEP]
# No.16,len:20
# lables:[CLS] O O B-problem I-problem I-problem I-problem I-problem X X I-problem X O O O O O O O [SEP]
# No.17,len:8
# texts:[CLS] There was no he ##ave . [SEP]
# No.17,len:8
# lables:[CLS] O O O B-problem X O [SEP]
# No.18,len:12
# texts:[CLS] 4 . Non ##ins ##ulin dependent diabetes me ##lli ##tus [SEP]
# No.18,len:12
# lables:[CLS] O X B-problem X X I-problem I-problem I-problem X X [SEP]
# No.19,len:13
# texts:[CLS] 6 / 15 / 1994 12 : 00 : 00 AM [SEP]
# No.19,len:13
# lables:[CLS] O X X X X O X X X X O [SEP]
# No.20,len:31
# texts:[CLS] On 2014 - 04 - 09 , patient continued to do very well , amb ##ulat ##ing , tol ##erat ##ing a diet , uri ##nating without difficulty . [SEP]
# No.20,len:31
# lables:[CLS] O O X X X X O O O O O O O O O X X O O X X O O O O X O B-problem O [SEP]
# No.21,len:26
# texts:[CLS] C ##I ##WA scale over night was 1 for tre ##mor and the patient did not require any Val ##ium for alcohol withdrawal . [SEP]
# No.21,len:26
# lables:[CLS] B-test X X I-test O O O O O B-problem X O O O O O O O B-treatment X O B-problem I-problem O [SEP]
# No.22,len:19
# texts:[CLS] Pat ##ient has a history of sui ##cida ##l idea ##tions and self mu ##tila ##tion . [SEP]
# No.22,len:19
# lables:[CLS] O X O O O O B-problem X X I-problem X O B-problem I-problem X X O [SEP]
# No.23,len:47
# texts:[CLS] 9 . I ##pra ##tro ##pi ##um Bro ##mide 17 m ##c ##g / Act ##uation Aero ##sol Si ##g : Two ( 2 ) P ##uff In ##hala ##tion Q ##4 - 6 ##H ( every 4 to 6 hours ) as needed . [SEP]
# No.23,len:47
# lables:[CLS] O X B-treatment X X X X I-treatment X O O X X O O X O X O X O O O O O O X O X X O X X X X O O O O O O O O O O [SEP]
# No.24,len:8
# texts:[CLS] h / o Et ##OH abuse [SEP]
# No.24,len:8
# lables:[CLS] O X X O X O [SEP]
# No.25,len:5
# texts:[CLS] Bat ##ch : [SEP]
# No.25,len:5
# lables:[CLS] O X O [SEP]
# No.26,len:6
# texts:[CLS] Pro ##vide ##r : [SEP]
# No.26,len:6
# lables:[CLS] O X X O [SEP]
# No.27,len:13
# texts:[CLS] 2013 - 12 - 24 PA ##D - W ##OR ##D [SEP]
# No.27,len:13
# lables:[CLS] O X X X X O X X X X X [SEP]
# No.28,len:56
# texts:[CLS] The patient is a 40 year old male with a history of prior anterior my ##oca ##rdia ##l in ##far ##ction and ins ##ulin dependent diabetes me ##lli ##tus who was transferred from an outside hospital after an episode of acute short ##ness of br ##eath and pu ##lm ##onar ##y ede ##ma . [SEP]
# No.28,len:56
# lables:[CLS] O O O O O O O O O O O O B-problem I-problem I-problem X X X I-problem X X O B-problem X I-problem I-problem I-problem X X O O O O O O O O O O O B-problem I-problem X I-problem I-problem X O B-problem X X X I-problem X O [SEP]
# No.29,len:13
# texts:[CLS] 05 / 09 / 2004 12 : 00 : 00 AM [SEP]
# No.29,len:13
# lables:[CLS] O X X X X O X X X X O [SEP]
# No.30,len:26
# texts:[CLS] The patient was correct ##ed to a normal pH of 7 . 41 by the first posto ##pera ##tive night and remained stable . [SEP]
# No.30,len:26
# lables:[CLS] O O O O X O O O O O O X X O O O O X X O O O O O [SEP]
# No.31,len:6
# texts:[CLS] Past Medical History : [SEP]
# No.31,len:6
# lables:[CLS] O O O O [SEP]
# No.32,len:13
# texts:[CLS] 642 - 07 - 90 PA ##D - W ##OR ##D [SEP]
# No.32,len:13
# lables:[CLS] O X X X X O X X X X X [SEP]
# No.33,len:27
# texts:[CLS] He was admitted on 06 / 07 / 00 for a match ##ed , un ##rela ##ted dono ##r bone mar ##row trans ##plant . [SEP]
# No.33,len:27
# lables:[CLS] O O O O O X X X X O B-treatment I-treatment X I-treatment I-treatment X X I-treatment X I-treatment I-treatment X I-treatment X O [SEP]
# No.34,len:23
# texts:[CLS] Abd : soft , + dis ##tens ##ion with tym ##pan ##y , no HS ##M , hy ##pera ##ctive BS [SEP]
# No.34,len:23
# lables:[CLS] O O O O B-problem X X X O B-problem X X O O B-problem X O B-problem X X I-problem [SEP]
# No.35,len:9
# texts:[CLS] The patient is hard of hearing . [SEP]
# No.35,len:9
# lables:[CLS] O O O B-problem I-problem I-problem O [SEP]
# No.36,len:12
# texts:[CLS] D : 2016 - 11 - 10 18 : 28 [SEP]
# No.36,len:12
# lables:[CLS] O O O X X X X O X X [SEP]
# No.37,len:7
# texts:[CLS] ( End of Report ) [SEP]
# No.37,len:7
# lables:[CLS] O O O O O [SEP]
# No.38,len:13
# texts:[CLS] Major Sur ##gical or In ##vasi ##ve Proc ##edu ##re : [SEP]
# No.38,len:13
# lables:[CLS] O O X O O X X O X X O [SEP]
# No.39,len:7
# texts:[CLS] Neu ##rol ##ogi ##c : [SEP]
# No.39,len:7
# lables:[CLS] O X X X O [SEP]
# No.40,len:4
# texts:[CLS] General : [SEP]
# No.40,len:4
# lables:[CLS] O O [SEP]
# No.41,len:45
# texts:[CLS] He had a past history of is ##chem ##ic card ##io ##my ##opa ##thy with an eje ##ction fraction of 10 , mild ao ##rti ##c st ##enos ##is and a right middle cerebral arter ##y territory stroke in 07 / 94 . [SEP]
# No.41,len:45
# lables:[CLS] O O O O O O B-problem X X I-problem X X X X O B-test I-test X I-test O O O B-problem I-problem X X I-problem X X O B-problem I-problem I-problem I-problem I-problem X I-problem I-problem O O X X O [SEP]
# No.42,len:19
# texts:[CLS] The patient was disc ##harge ##d to home for hos ##pice on March 8 , 1999 . [SEP]
# No.42,len:19
# lables:[CLS] O O O O X X O O O B-treatment X O O O O O O [SEP]
# No.43,len:22
# texts:[CLS] The cause of this er ##yth ##ema is not know at this time but has not shown extensive progression . [SEP]
# No.43,len:22
# lables:[CLS] O O O B-problem I-problem X X O O O O O O O O O O O O O [SEP]
# No.44,len:31
# texts:[CLS] In regard ##s to his rhythm , he has an underlying right bun ##dle branch block and first - degree AV block which were stable throughout this admission . [SEP]
# No.44,len:31
# lables:[CLS] O O X O O O O O O B-problem I-problem I-problem I-problem X I-problem I-problem O B-problem X X I-problem I-problem O O O O O O O [SEP]
# No.45,len:7
# texts:[CLS] J ##O ##B # : [SEP]
# No.45,len:7
# lables:[CLS] O X X O X [SEP]
# No.46,len:8
# texts:[CLS] Nancy Lois MD 88 - 449 [SEP]
# No.46,len:8
# lables:[CLS] O O O O X X [SEP]
# No.47,len:15
# texts:[CLS] C ##rania ##l nerve ##s notable for bila ##teral eso ##tro ##pia . [SEP]
# No.47,len:15
# lables:[CLS] O X X O X O O B-problem X I-problem X X O [SEP]
# No.48,len:16
# texts:[CLS] He is admitted at this time because of significant G ##I ble ##eding . [SEP]
# No.48,len:16
# lables:[CLS] O O O O O O O O B-problem I-problem X I-problem X O [SEP]
# No.49,len:8
# texts:[CLS] CO ##DE ST ##AT ##US : [SEP]
# No.49,len:8
# lables:[CLS] O X O X X O [SEP]

# %%
(input_ids,tags,attention_masks,segment_ids,attention_masks_deprecated) = convertokens(max_len,tokenized_texts,word_piece_labels,sentences)

# %%
(train_dataloader,valid_dataloader,test_dataloader,tr_inputs,val_inputs,test_inputs) = split_tensor_dataloader(input_ids, tags, attention_masks, segment_ids,batch_num, sizeoftest, sizeofdev)

# %%
optimizer = AdamW(model.parameters(), lr=learningrate)
total_steps = len(train_dataloader) * epochs
scheduler = get_linear_schedule_with_warmup(optimizer,
                                            num_warmup_steps = 0, # default
                                            num_training_steps = total_steps)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %% [markdown]
# # 4. Training

# %%
#extend embedding matrix with new vocab
model.resize_token_embeddings(len(tokenizer))
# Out:
# Embedding(119547, 768, padding_idx=0)

# %%
if n_gpu >1:
    model = torch.nn.DataParallel(model)

# %%
print("***** Training Info *****")
print("  Num examples = %d"%(len(tr_inputs)))
print("  Batch size = %d"%(batch_num))
print("  Num steps = %d"%(total_steps))
# Out:
# ***** Training Info *****
#   Num examples = 9800
#   Batch size = 8
#   Num steps = 2450

# %%
seed_val = 10
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)

loss_values = []
training_stats = []

total_t0 = time.time()
# for _ in trange(epochs,desc=" Epoch"):
for _ in range(epochs):

    print("")
    print('======== Epoch {:} / {:} ========'.format(_+1, epochs))
    print('\033[1m'+'Training...'+ '\033[0m')

    model.train()
    # Set model to GPU,if you are using GPU machine
    model.cuda()

    t0 = time.time()


    tr_loss = 0 # total training loss for one epoch
    nb_tr_examples, nb_tr_steps = 0, 0

    for step, batch in enumerate(train_dataloader):
        # add batch to gpu
        batch = tuple(t.to(device) for t in batch)
        b_input_ids, b_input_mask, b_labels = batch

        model.zero_grad()

        # forward pass
        outputs = model(b_input_ids, token_type_ids=None,
        attention_mask=b_input_mask, labels=b_labels)

        loss, scores = outputs[:2]
        if n_gpu>1:
            # When multi gpu, average it
            loss = loss.mean()

        # backward pass
        loss.backward()

        # track train loss:
        #Accumulate the training loss over all of the batches so that we can calculate the average loss at the end.
        tr_loss += loss.item()
        nb_tr_steps += 1

        # gradient clipping
        torch.nn.utils.clip_grad_norm_(parameters=model.parameters(), max_norm=max_grad_norm)

        # update parameters
        optimizer.step()
        # Update the learning rate.
        scheduler.step()

        optimizer.zero_grad()


    print("")
    print("Epoch finished (training progress):")
    # average the training loss
    avg_train_loss = tr_loss/nb_tr_steps
    print("   Train loss: {}".format(avg_train_loss))
    training_time = format_time(time.time() - t0)
    print("   Training epoch took: {:}".format(training_time))

    # Store the loss value for plotting the learning curve.
    loss_values.append(avg_train_loss)


    #eval LOOP
    total_eval_loss, eval_accuracy = 0, 0
    nb_eval_steps, nb_eval_examples = 0, 0
    y_true = []
    y_pred = []
    valdataset = []

    y_true_full = []
    y_pred_full = []
    valdataset_full = []

    t0 = time.time()

    model.eval()

    for step, batch in enumerate(valid_dataloader):
        batch = tuple(t.to(device) for t in batch)
        input_ids, input_mask, label_ids = batch #same as we did in training loop but only 1 epoch now


        with torch.no_grad(): #means we don't care about gradients and updating tensors
            outputs = model(input_ids, token_type_ids=None,
            attention_mask=input_mask,labels=label_ids)
            # For eval mode, the first result of outputs is logits (for training mode this was loss)
#             logits = outputs[0]
            loss, logits = outputs[:2]#  In context of deep learning the logits layer means the layer that feeds in to softmax (or other such normalization).

        loss = loss.mean()
        total_eval_loss += loss.item()


        # Get NER predict result
        logits = torch.argmax(F.log_softmax(logits,dim=2),dim=2)#feed logits into softmax and take the prediction that is maximal
        logits = logits.detach().cpu().numpy()

        # Get NER true result
        label_ids = label_ids.to('cpu').numpy()

        # Only predict the real word, mark=0, will not calculate
        input_mask = input_mask.to('cpu').numpy()


        # Compare the valuable predict result
        for i,mask in enumerate(input_mask):
            # Real one
            temp_1 = []
            # Predicted one
            temp_2 = []
            valtemp = []

            temp_1_full = []
            # Predicted one
            temp_2_full = []
            valtemp_full = []

            for j, m in enumerate(mask):
                # Mark=0, meaning its a pad word, dont compare
                if m :
                    if tag2name[label_ids[i][j]] != "X" and tag2name[label_ids[i][j]] != "[CLS]" and tag2name[label_ids[i][j]] != "[SEP]" : # Exclude the X label
                        temp_1.append(tag2name[label_ids[i][j]])
                        temp_2.append(tag2name[logits[i][j]])
                        valtemp.append(input_ids[i][j].item())

                    if tag2name[label_ids[i][j]] != "[CLS]" and tag2name[label_ids[i][j]] != "[SEP]" : # Exclude the X label
                        temp_1_full.append(tag2name[label_ids[i][j]])
                        temp_2_full.append(tag2name[logits[i][j]])
                        valtemp_full.append(input_ids[i][j].item())

                else:
                    break

            #here are the two lists that contain true and pred labels.
            y_true.append(temp_1)
            y_pred.append(temp_2)
            valdataset.append(valtemp)


            y_true_full.append(temp_1_full)
            y_pred_full.append(temp_2_full)
            valdataset_full.append(valtemp_full)


    avg_val_loss = total_eval_loss / len(valid_dataloader)
    validation_time = format_time(time.time() - t0)

    print("")
    print('\033[1m'+"Running Validation..."+ '\033[0m')
    print("  (Num examples ={})".format(len(val_inputs)))
    print("  (Batch size = {})\n".format(batch_num))
    print("   Validation loss: {}".format(avg_val_loss))
    print("   F1-score: %f"%(f1_score(y_true, y_pred)))
    print("   Accuracy: %f"%(accuracy_score(y_true, y_pred)))
    print("   Validation took: {:}".format(validation_time))

    training_stats.append(
        {   'epoch': _ + 1,
            'Training Loss': avg_train_loss,
            'Valid. Loss': avg_val_loss,
            'Valid. Accur.': accuracy_score(y_true, y_pred),
            'Training Time' : training_time,
            'Validation Time' : validation_time })


print('Training complete')
print("Total training took {:} (h:mm:ss)".format(format_time(time.time()-total_t0)))
# Out:
# ======== Epoch 1 / 2 ========
# Training...
#
# Epoch finished (training progress):
#    Train loss: 0.020075594248102825
#    Training epoch took: 0:08:58
#
# Running Validation...
#   (Num examples =2450)
#   (Batch size = 8)
#
#    Validation loss: 0.007519423711649825
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: X seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
#    F1-score: 0.764028
#    Accuracy: 0.931434
#    Validation took: 0:00:46
#
# ======== Epoch 2 / 2 ========
# Training...
#
# Epoch finished (training progress):
#    Train loss: 0.004894045208549906
#    Training epoch took: 0:09:05
#
# Running Validation...
#   (Num examples =2450)
#   (Batch size = 8)
#
#    Validation loss: 0.006431559868656889
#    F1-score: 0.809734
#    Accuracy: 0.943317
#    Validation took: 0:00:45
# Training complete
# Total training took 0:19:35 (h:mm:ss)

# %% [markdown]
# # 5. Evaluation on Validation set

# %%
report = classification_report(y_true, y_pred,digits=4)
print(report)
# Out:
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            _     0.0000    0.0000    0.0000         0
#      problem     0.7807    0.8488    0.8133      1065
#         test     0.8132    0.8284    0.8207       746
#    treatment     0.7859    0.8243    0.8046       717
#
#    micro avg     0.7852    0.8358    0.8097      2528
#    macro avg     0.5949    0.6254    0.6097      2528
# weighted avg     0.7917    0.8358    0.8130      2528

# %%
# without 'O' label
f1_score(y_true,y_pred, average='micro')
# Out:
# 0.8097336654531518

# %%
#table

#pd.set_option('precision', 2)
df_stats = pd.DataFrame(data=training_stats)

# use epoch as row index
df_stats = df_stats.set_index('epoch')

# hack to force the column headers to wrap.
#df = df.style.set_table_styles([dict(selector="th",props=[('max-width', '70px')])])

df_stats
# Out:
#        Training Loss  Valid. Loss  Valid. Accur. Training Time Validation Time
# epoch
# 1           0.020076     0.007519       0.931434       0:08:58         0:00:46
# 2           0.004894     0.006432       0.943317       0:09:05         0:00:45

# %%
#plotting
sns.set(style='darkgrid')
sns.set_palette('plasma')
sns.set(font_scale=1.5)
plt.rcParams["figure.figsize"] = (12,6)


plt.plot(df_stats['Training Loss'], 'b-o', label="Training",marker = 's',markerfacecolor='green',linestyle='--',color='blue')
plt.plot(df_stats['Valid. Loss'], 'g-o', label="Validation",marker = 's',markerfacecolor='green',linestyle='--',color='orange')

plt.title("Training & Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

ls=[]
for i in range(epochs):
    ls.append(i+1)
plt.xticks(ls)

plt.show()
# Out:
# <ipython-input-48-cd185a1fcfb6>:8: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "b-o" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(df_stats['Training Loss'], 'b-o', label="Training",marker = 's',markerfacecolor='green',linestyle='--',color='blue')
# <ipython-input-48-cd185a1fcfb6>:8: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "b-o" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot(df_stats['Training Loss'], 'b-o', label="Training",marker = 's',markerfacecolor='green',linestyle='--',color='blue')
# <ipython-input-48-cd185a1fcfb6>:8: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-o" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(df_stats['Training Loss'], 'b-o', label="Training",marker = 's',markerfacecolor='green',linestyle='--',color='blue')
# <ipython-input-48-cd185a1fcfb6>:9: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "g-o" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(df_stats['Valid. Loss'], 'g-o', label="Validation",marker = 's',markerfacecolor='green',linestyle='--',color='orange')
# <ipython-input-48-cd185a1fcfb6>:9: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "g-o" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot(df_stats['Valid. Loss'], 'g-o', label="Validation",marker = 's',markerfacecolor='green',linestyle='--',color='orange')
# <ipython-input-48-cd185a1fcfb6>:9: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "g-o" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(df_stats['Valid. Loss'], 'g-o', label="Validation",marker = 's',markerfacecolor='green',linestyle='--',color='orange')

# %% [markdown]
# # 6. Evaluation on test set

# %%
print("")
print('\033[1m'+"Running Test..."+ '\033[0m')
t0 = time.time()

y_test_true = []
y_test_pred = []
testdataset = []

y_test_true_full = []
y_test_pred_full = []
testdataset_full = []

model.eval()

for step, batch in enumerate(test_dataloader):
    batch = tuple(t.to(device) for t in batch)
    input_ids, input_mask, label_ids = batch #same as we did in training loop but only 1 epoch now


    with torch.no_grad(): #means we don't care about gradients and updating tensors
        outputs = model(input_ids, token_type_ids=None,
        attention_mask=input_mask,labels=label_ids)
        # For eval mode, the first result of outputs is logits (for training mode this was loss)
#             logits = outputs[0]
        loss, logits = outputs[:2]#  In context of deep learning the logits layer means the layer that feeds in to softmax (or other such normalization).

    loss = loss.mean()
    total_eval_loss += loss.item()


    # Get NER predict result
    logits = torch.argmax(F.log_softmax(logits,dim=2),dim=2)#feed logits into softmax and take the prediction that is maximal
    logits = logits.detach().cpu().numpy()

    # Get NER true result
    label_ids = label_ids.to('cpu').numpy()

    # Only predict the real word, mark=0, will not calculate
    input_mask = input_mask.to('cpu').numpy()


    # Compare the valuable predict result
    for i,mask in enumerate(input_mask):
        # Real one
        temp_1 = []
        # Predicted one
        temp_2 = []
        valtemp = []

        temp_1_full = []
        # Predicted one
        temp_2_full = []
        valtemp_full = []

        for j, m in enumerate(mask):
            # Mark=0, meaning its a pad word, dont compare
            if m :
                if tag2name[label_ids[i][j]] != "X" and tag2name[label_ids[i][j]] != "[CLS]" and tag2name[label_ids[i][j]] != "[SEP]" : # Exclude the X label
                    temp_1.append(tag2name[label_ids[i][j]])
                    temp_2.append(tag2name[logits[i][j]])
                    valtemp.append(input_ids[i][j].item())

                if tag2name[label_ids[i][j]] != "[CLS]" and tag2name[label_ids[i][j]] != "[SEP]" : # Exclude the X label
                    temp_1_full.append(tag2name[label_ids[i][j]])
                    temp_2_full.append(tag2name[logits[i][j]])
                    valtemp_full.append(input_ids[i][j].item())

            else:
                break

        #here are the two lists that contain true and pred labels.
        y_test_true.append(temp_1)
        y_test_pred.append(temp_2)
        testdataset.append(valtemp)

        y_test_true_full.append(temp_1_full)
        y_test_pred_full.append(temp_2_full)
        testdataset_full.append(valtemp_full)


avg_test_loss = total_eval_loss / len(test_dataloader)
test_time = format_time(time.time() - t0)

print("  (Num examples ={})".format(len(test_inputs)))
print("  (Batch size = {})\n".format(batch_num))
print("   Test loss: {}".format(avg_test_loss))
print("   F1-score: %f"%(f1_score(y_test_true, y_test_pred)))
print("   Accuracy: %f"%(accuracy_score(y_test_true, y_test_pred)))
print("   Test took: {:}".format(test_time))
# Out:
# Running Test...
#   (Num examples =4084)
#   (Batch size = 8)
#
#    Test loss: 0.010141794781271064
#    F1-score: 0.807337
#    Accuracy: 0.944993
#    Test took: 0:01:07
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: X seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))

# %%
# classification report is meant for evaluation of tasks like NER (see doc)
# difference between f1_score of scikit-learn and classification_report is that classification_report
# merges B and I, resulting in lower f1
report = classification_report(y_test_true, y_test_pred)
print(report)
# Out:
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            _       0.00      0.00      0.00         0
#      problem       0.79      0.83      0.81      1824
#         test       0.81      0.86      0.83      1182
#    treatment       0.75      0.83      0.79      1233
#
#    micro avg       0.78      0.84      0.81      4239
#    macro avg       0.59      0.63      0.61      4239
# weighted avg       0.78      0.84      0.81      4239

# %%
from sklearn.preprocessing import MultiLabelBinarizer

# %%
mlb = MultiLabelBinarizer()
binary_labels = mlb.fit_transform(labels)

# %%
y_test_true_binary = mlb.fit_transform(y_test_true)

# %%
y_test_true_binary.shape
# Out:
# (4080, 7)

# %%
y_test_pred_binary = mlb.fit_transform(y_test_pred)

# %%
y_test_pred_binary.shape
# Out:
# (4080, 8)

# %%
y_test_pred_binary = y_test_pred_binary[:, :7]

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test_true_binary, y_test_pred_binary))
# Out:
# 0.8889705882352941

# %% [markdown]
# # 7. Predictions of test set - examples

# %%
len(y_test_true[0]),len(y_test_pred[0]), len(testdataset[0])
# Out:
# (19, 19, 19)

# %%
text= [tokenizer.decode(test) for test in testdataset]
tokenized_text_converted = [tokenizer.convert_ids_to_tokens(test) for test in testdataset]

# %%
text_full= [tokenizer.decode(test) for test in testdataset_full]
tokenized_text_converted_full = [tokenizer.convert_ids_to_tokens(test) for test in testdataset_full]

# %%
a = 2
print( '\n' + text_full[a])
print('\033[1m' + "Labels:      " + '\033[0m', y_test_true[a])
print('\033[1m' + "Predictions: "+ '\033[0m',y_test_pred[a])
print('\n')

print(tokenized_text_converted_full[a])
# Out:
# 2019 - 06 - 18 07 : 55 AM BLOOD calTIBC - 229 Ferritn - GREATER TH TRF - 176 *
# Labels:       ['O', 'O', 'O', 'O', 'B-test', 'O', 'O', 'B-test', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Predictions:  ['O', 'O', 'O', 'B-test', 'B-test', 'O', 'O', 'B-test', 'O', 'O', 'B-test', 'I-test', 'O', 'O', 'O']
#
#
# ['2019', '-', '06', '-', '18', '07', ':', '55', 'AM', 'BL', '##O', '##OD', 'cal', '##TI', '##BC', '-', '229', 'Fe', '##rri', '##tn', '-', 'GR', '##EA', '##TER', 'T', '##H', 'TR', '##F', '-', '176', '*']

# %%
a = 7
print( '\n' +text_full[a])
print('\033[1m' + "Labels:      " + '\033[0m', y_test_true[a])
print('\033[1m' + "Predictions: "+ '\033[0m',y_test_pred[a])
print('\n')

print(tokenized_text_converted_full[a])
# Out:
# Sigmoidoscopy.
# Labels:       ['B-test', 'O']
# Predictions:  ['B-treatment', 'O']
#
#
# ['Si', '##g', '##mo', '##idos', '##co', '##py', '.']

# %%
a = 11
print( '\n' +text_full[a])
print('\033[1m' + "Labels:      " + '\033[0m', y_test_true[a])
print('\033[1m' + "Predictions: "+ '\033[0m',y_test_pred[a])
print('\n')

print(tokenized_text_converted_full[a])
# Out:
# Initial newborn exam :
# Labels:       ['B-test', 'I-test', 'I-test', 'O']
# Predictions:  ['O', 'O', 'I-test', 'O']
#
#
# ['Ini', '##tial', 'new', '##born', 'ex', '##am', ':']

# %%
a = 12
print( '\n' +text_full[a])
print('\033[1m' + "Labels:      " + '\033[0m', y_test_true[a])
print('\033[1m' + "Predictions: "+ '\033[0m',y_test_pred[a])
print('\n')

print(tokenized_text_converted_full[a])
# Out:
# 64 - year - old G5P5 postmenopausal for 10 years with a history of two months of progressive abdominal distention, crampy abdominal pain, urinary frequency and diarrhea.
# Labels:       ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-problem', 'I-problem', 'I-problem', 'O', 'B-problem', 'I-problem', 'I-problem', 'O', 'B-problem', 'I-problem', 'O', 'B-problem', 'O']
# Predictions:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-problem', 'I-problem', 'I-problem', 'O', 'B-problem', 'I-problem', 'I-problem', 'O', 'B-problem', 'I-problem', 'O', 'B-problem', 'O']
#
#
# ['64', '-', 'year', '-', 'old', 'G', '##5', '##P', '##5', 'post', '##meno', '##pa', '##usal', 'for', '10', 'years', 'with', 'a', 'history', 'of', 'two', 'months', 'of', 'progressive', 'ab', '##dom', '##inal', 'dis', '##tention', ',', 'c', '##ram', '##py', 'ab', '##dom', '##inal', 'pain', ',', 'uri', '##nary', 'frequency', 'and', 'dia', '##rr', '##hea', '.']

# %%
a = 14
print( '\n' +text_full[a])
print('\033[1m' + "Labels:      " + '\033[0m', y_test_true[a])
print('\033[1m' + "Predictions: "+ '\033[0m',y_test_pred[a])
print('\n')

print(tokenized_text_converted_full[a])
# Out:
# The patient was given printed instructions for motor vehicle accident - trauma ( English ).
# Labels:       ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-problem', 'O', 'O', 'O', 'O']
# Predictions:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-problem', 'I-problem', 'I-problem', 'X', 'X', 'O', 'O', 'O', 'O']
#
#
# ['The', 'patient', 'was', 'given', 'printed', 'instructions', 'for', 'motor', 'vehicle', 'accident', '-', 'trauma', '(', 'English', ')', '.']

# %%
a = 17
print( '\n' +text_full[a])
print('\033[1m' + "Labels:      " + '\033[0m', y_test_true[a])
print('\033[1m' + "Predictions: "+ '\033[0m',y_test_pred[a])
print('\n')

print(tokenized_text_converted_full[a])
# Out:
# 3. Hydrochlorothiazide question of dosage.
# Labels:       ['O', 'B-treatment', 'O', 'O', 'O', 'O']
# Predictions:  ['O', 'B-treatment', 'O', 'O', 'O', 'O']
#
#
# ['3', '.', 'Hy', '##dro', '##ch', '##lor', '##oth', '##ia', '##zid', '##e', 'question', 'of', 'dos', '##age', '.']

# %%
a = 25
print( '\n' +text_full[a])
print('\033[1m' + "Labels:      " + '\033[0m', y_test_true[a])
print('\033[1m' + "Predictions: "+ '\033[0m',y_test_pred[a])
print('\n')

print(tokenized_text_converted_full[a])
# Out:
# 3. Acetaminophen 500 mg Tablet Sig : Two ( 2 ) Tablet PO Q6H ( every 6 hours ).
# Labels:       ['O', 'B-treatment', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Predictions:  ['O', 'B-treatment', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
# ['3', '.', 'Ace', '##tami', '##no', '##phen', '500', 'mg', 'Table', '##t', 'Si', '##g', ':', 'Two', '(', '2', ')', 'Table', '##t', 'P', '##O', 'Q', '##6', '##H', '(', 'every', '6', 'hours', ')', '.']

# %%
a = 37
print( '\n' +text_full[a])
print('\033[1m' + "Labels:      " + '\033[0m', y_test_true[a])
print('\033[1m' + "Predictions: "+ '\033[0m',y_test_pred[a])
print('\n')

print(tokenized_text_converted_full[a])
# Out:
# Please refer to the previously dictated operative note of 2016 - 12 - 30 by Dr. Lawrence.
# Labels:       ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Predictions:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
# ['Please', 'refer', 'to', 'the', 'previously', 'di', '##ctat', '##ed', 'operative', 'note', 'of', '2016', '-', '12', '-', '30', 'by', 'Dr', '.', 'Lawrence', '.']

# %%
# text = [tokenizer.convert_tokens_to_string(i) for i in tokenized_text_converted]

# %%
for a in range(1,len(y_test_pred)):
    print(tokenized_text_converted_full[a])
# Out:
# ['RE', '##AS', '##ON', 'FOR', 'T', '##HI', '##S', 'EX', '##AM', '##IN', '##AT', '##ION', ':']
# ['2019', '-', '06', '-', '18', '07', ':', '55', 'AM', 'BL', '##O', '##OD', 'cal', '##TI', '##BC', '-', '229', 'Fe', '##rri', '##tn', '-', 'GR', '##EA', '##TER', 'T', '##H', 'TR', '##F', '-', '176', '*']
# ['He', '##mo', '##dyn', '##ami', '##cs', ':']
# ['Mr', '.', 'Br', '##eu', '##tz', '##far', '##st', '##xe', '##i', 'was', 'recently', 'diagnosed', 'with', 'acquired', 'im', '##mun', '##ode', '##ficie', '##ncy', 'syndrome', 'when', 'he', 'had', 'P', '##ne', '##umo', '##cy', '##stis', 'car', '##inii', 'pne', '##umon', '##ia', 'on', '01', '/', '17', '/', '91', '.']
# ['CBC', ':', 'White', 'blood', 'cell', 'count', 'is', '8', '.', '8', ',', 'hem', '##ato', '##crit', '35', '.', '5', 'plate', '##lets', '266', ',', 'PT', '13', ',', 'PT', '-', 'T', '23', '.', '3', ',', 'IN', '##R', 'was', '1', '.', '1', '.']
# ['Dia', '##gno', '##sis', ':']
# ['Si', '##g', '##mo', '##idos', '##co', '##py', '.']
# ['Disc', '##harge', 'Inst', '##ru', '##ctions', ':']
# ['Di', '##ctat', '##ed', 'By', ':', 'She', '##rry', 'G', 'Christie', ',', 'M', '.', 'D', '.']
# ['RE', '##AS', '##ON', 'FOR', 'T', '##HI', '##S', 'EX', '##AM', '##IN', '##AT', '##ION', ':']
# ['Ini', '##tial', 'new', '##born', 'ex', '##am', ':']
# ['64', '-', 'year', '-', 'old', 'G', '##5', '##P', '##5', 'post', '##meno', '##pa', '##usal', 'for', '10', 'years', 'with', 'a', 'history', 'of', 'two', 'months', 'of', 'progressive', 'ab', '##dom', '##inal', 'dis', '##tention', ',', 'c', '##ram', '##py', 'ab', '##dom', '##inal', 'pain', ',', 'uri', '##nary', 'frequency', 'and', 'dia', '##rr', '##hea', '.']
# ['PE', '##R', '##R', '##L', ',', 'E', '##OM', '##I', '.']
# ['The', 'patient', 'was', 'given', 'printed', 'instructions', 'for', 'motor', 'vehicle', 'accident', '-', 'trauma', '(', 'English', ')', '.']
# ['Ex', '##trem', '##ities', ':']
# ['White', 'blood', 'cell', 'count', '7', '.', '8', 'with', '86', '%', 'pol', '##ymo', '##rp', '##hon', '##uc', '##lea', '##r', 'cells', ',', '11', '.', '1', 'ly', '##mp', '##ho', '##cy', '##tes', ',', 'hem', '##og', '##lob', '##in', '14', '.', '3', ',', 'hem', '##ato', '##crit', '40', '.', '5', ',', 'MC', '##V', '88', ',', 'IN', '##R', '1', '.', '0', ',', 'PTT', '24', '.', '7', ',', 'PT', '12', '.', '3', ',', 'plate', '##let', 'count', '295', ',', '000', ',', 'g', '##lucose', '81', ',', 'B', '##UN', '15', ',', 'creat', '##inin', '##e', '0', '.', '8', ',', 'sodium', '142', ',', 'pot', '##ass', '##ium', '4', '.', '2', ',', 'ch', '##loride', '104', ',', 'CO', '##2', '26', ',', 'calcium', '9', '.', '3', ',', 'ph', '##osphate', '4', '.', '8', ',', 'mag', '##nesi', '##um', '2', '.', '3', '.']
# ['3', '.', 'Hy', '##dro', '##ch', '##lor', '##oth', '##ia', '##zid', '##e', 'question', 'of', 'dos', '##age', '.']
# ['Going', 'to', 'U', '##M', '##ass', 'Memorial', 'Medical', 'Center', '4', '.']
# ['-', 'Cl', '##ari', '##tin', 'pr', '##n']
# ['DI', '##SC', '##HA', '##R', '##GE', 'DA', '##TE', ':']
# ['DI', '##S', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['Date', 'of', 'Birth', ':']
# ['Cat', '##ara', '##cts', ',', 's', '/', 'p', 'cat', '##ara', '##ct', 'surgery']
# ['Her', 'white', 'blood', 'cell', 'count', 'was', '12', '.', '8', ',', 'with', 'a', 'normal', 'differential', '.']
# ['3', '.', 'Ace', '##tami', '##no', '##phen', '500', 'mg', 'Table', '##t', 'Si', '##g', ':', 'Two', '(', '2', ')', 'Table', '##t', 'P', '##O', 'Q', '##6', '##H', '(', 'every', '6', 'hours', ')', '.']
# ['Her', 'epi', '##dura', '##l', 'cat', '##heter', 'was', 'removed', 'on', '6', '/', '29', '.']
# ['The', 'cause', 'of', 'death', 'was', 'a', 'combination', 'of', 'G', '##I', 'ble', '##eding', 'felt', 'to', 'be', 'ultimately', 'related', 'to', 'his', 'known', 'meta', '##stati', '##c', 'pan', '##cre', '##atic', 'cancer', '.']
# ['7', '.', 'Follow', 'up', '-', 'Follow', 'up', 'appointment', 'with', 'primary', 'pe', '##diat', '##rici', '##an', 'within', 'five', 'days', 'of', 'disc', '##harge', '.']
# ['Dis', '##p', ':', '*', '30', 'Table', '##t', '(', 's', ')', '*', 'Re', '##fil', '##ls', ':', '*', '0', '*']
# ['Den', '##ies', 'any', 'recent', 'use', 'of', 'Et', '##OH', 'or', 'ill', '##ici', '##t', 'drugs', '.']
# ['6', '.', 'h', '##x', 'of', 'Foot', 'U', '##lce', '##r']
# ['PT', '-', '12', '.', '7', 'PTT', '-', '23', '.', '8', 'IN', '##R', '(', 'PT', ')', '-', '1', '.', '1']
# ['3', '.', 'Met', '##op', '##rol', '##ol', 'Ta', '##rt', '##rate', '50', 'mg', 'Table', '##t', 'Si', '##g', ':', 'One', '(', '1', ')', 'Table', '##t', 'P', '##O', 'B', '##ID', '(', '2', 'times', 'a', 'day', ')', '.']
# ['2', '.', 'Expo', '##sure', 'and', 'wide', 'drainage', 'of', 'per', '##fora', '##ted', 'posterior', 'duo', '##dena', '##l', 'ul', '##cer', 'with', 'internal', 'and', 'external', 'drainage', '.']
# ['11', '.', 'Cola', '##ce', '100', 'mg', 'p', '.', 'o', '.', 'b', '.', 'i', '.', 'd', '.']
# ['UN', '##DE', '##R', '##L', '##Y', '##ING', 'ME', '##DI', '##CA', '##L', 'CO', '##ND', '##IT', '##ION', ':']
# ['Please', 'refer', 'to', 'the', 'previously', 'di', '##ctat', '##ed', 'operative', 'note', 'of', '2016', '-', '12', '-', '30', 'by', 'Dr', '.', 'Lawrence', '.']
# ['Tag', '##ged', 'RB', '##C', '+', 'activity', 'in', 'RL', '##Q', '.']
# ['General', ':', 'Pat', '##ient', 'is', 'in', 'no', 'acute', 'dis', '##tress', '.']
# ['1', '#', 'Card', '##iac', ':']
# ['Un', '##sig', '##ned', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['Card', '##io', '##vas', '##cular', ':', 'Com', '##plained', 'of', 'chest', 'pain', 'during', 'first', 'few', 'days', 'of', 'admission', ',', 'a', 'card', '##iology', 'consul', '##t', 'was', 'obtained', '.']
# ['Medi', '##cations', 'on', 'Ad', '##mission', ':']
# ['PC', '##P', 'Name', ':']
# ['BR', '##IE', '##F', 'RE', '##SU', '##ME', 'OF', 'H', '##OS', '##P', '##IT', '##AL', 'CO', '##UR', '##SE', ':']
# ['Brief', 'Hospital', 'Course', ':']
# ['Plate', '##let', 'count', 'was', '759', ',', '000', '.']
# ['Ne', '##ck', ':', 'Suppl', '##e', ',', 'no', 'J', '##V', '##D']
# ['Post', '##part', '##um', 'she', 'encountered', 'the', 'following', 'com', '##plication', '(', 's', ')', ':']
# ['The', 'patient', 'is', 'a', '1', ',', '770', 'gram', 'male', 'infant', 'born', 'by', 'stat', 'ces', '##area', '##n', 'section', 'for', 'fet', '##al', 'bra', '##dy', '##card', '##ia', 'at', '30', '-', '6', '/', '7', 'weeks', 'ge', '##station', 'to', 'a', '29', '-', 'year', '-', 'old', 'gravi', '##da', '3', ',', 'para', '0', 'now', '1', 'mother', '.']
# ['Pat', '##ient', 'was', 'also', 'found', 'to', 'have', 'ab', '##normal', 'T', '##F', '##T', '##s', 'on', 'Su', '##tent', 'and', 'was', 'started', 'on', 'replacement']
# ['The', 'patient', 'tol', '##erated', 'this', 'procedure', 'well', 'and', 'had', 'no', 'com', '##plications', '.']
# ['For', 'sur', '##gical', 'in', '##cision', 'and', 'left', 'arm']
# ['2015', '-', '10', '-', '05', '09', ':', '00', '##PM', 'BL', '##O', '##OD']
# ['Chr', '##onic', 'Kid', '##ney', 'disease', '-', 'on', 'hem', '##odia', '##lys', '##is', 'type', '2', 'diabetes', 'hy', '##per', '##cho', '##les', '##tro', '##lem', '##ia', 'ane', '##mia', 'of', 'cho', '##rni', '##c', 'disease', 'h', '/', 'o', 'PE', ',', 's', '/', 'p', 'PE', '##A', 'arrest', '11', '-', '14']
# ['His', 'temperature', 'was', '98', '##F', '.']
# ['SU', '##MM', '##AR', '##Y', 'OF', 'H', '##OS', '##P', '##IT', '##AL', 'CO', '##UR', '##SE', ':']
# ['AS', '##T', '82', '.']
# ['There', 'are', 'simple', 'at', '##her', '##oma', 'in', 'the', 'as', '##cend', '##ing', 'ao', '##rta', '.']
# ['Pat', '##ient', 'recorded', 'as', 'having', 'No', 'Known', 'Alle', '##rgie', '##s', 'to', 'Drugs']
# ['Di', '##ffi', '##cul', '##ty', 'with', 'word', 'finding', 'at', 'times', '.']
# ['Vita', '##l', 'Sign', '##s', ':']
# ['Finger', 'stick', '##s', 'were', 'in', 'the', '150', 's', 'when', 'acute', '##ly', 'agit', '##ated', ',', 'therefore', ',', 'it', 'was', 'not', 'determined', 'that', 'g', '##lucose', 'levels', 'were', 'contributo', '##ry', '.']
# ['Family', 'History', ':']
# ['06', '/', '05', '/', '2002', '02', ':', '46', 'PM']
# ['LA', '##B', '##OR', '##AT', '##OR', '##IE', '##S', ':']
# ['11', '/', '02', '/', '99', 'K', '##E', '##9']
# ['There', 'is', 'a', 'small', 'amount', 'of', 'blood', 'layer', '##ing', 'in', 'both', 'lateral', 'vent', '##ric', '##les', ',', 'and', 'this', 'has', 'decreased', 'since', 'the', 'previous', 'study', '.']
# ['also', 'has', 'h', '/', 'o', 'an', '##xie', '##ty', 'and', 'GE', '##RD', '.']
# ['4', '.', 'New', 'jej', '##una', '##l', 'wall', 'thick', '##ening', 'with', 'pers', '##istent', 'dis', '##tal', 'ile', '##al', 'wall', 'thick', '##ening', 'and', 'diffuse', 'mese', '##nter', '##ic', 'strand', '##ing', ',', 'most', 'likely', 'reflect', '##ing', 'an', 'in', '##fect', '##ious', 'et', '##iology', '.']
# ['1', ')', 'Al', '##but', '##ero', '##l', 'in', '##hale', '##r', 'two', 'pu', '##ffs', 'q', '.', 'i', '.', 'd', '.', 'p', '.', 'r', '.', 'n', '.', 'br', '##eath', '##ing', 'difficulties', '.']
# ['On', 'admission', 'the', 'patient', '&', 'apo', '##s', ';', 's', 'bio', '##chem', '##ist', '##ry', 'showed', 'sodium', 'of', '140', ',', 'pot', '##ass', '##ium', '4', '.', '0', ',', 'ch', '##loride', '107', ',', 'bi', '##car', '##b', '14', ',', 'B', '##UN', '63', ',', 'creat', '##inin', '##e', '5', '.', '8', ',', 'blood', 'sugar', '133', '.']
# ['T', '##EC', '##H', '##NI', '##Q', '##UE', ':', 'A', '##xia', '##l', 'non', '##contra', '##st', 'CT', 's', '##cans', 'of', 'the', 'brain', 'were', 'obtained', '.']
# ['Dia', '##bet', '##ic', 'reti', '##no', '##pat', '##hy', 'with', 'the', 'patient', 'blind', 'in', 'right', 'eye', '.']
# ['Alle', '##rgie', '##s', ':']
# ['Full', 'term', 'well', 'appearing', 'infant', 'with', 'some', 'fac', '##ial', 'jau', '##ndi', '##ce', ',', 'overall', 'pink', ',', 'warm', 'and', 'well', 'per', '##fus', '##ed', ',', 'ale', '##rt', 'and', 'resp', '##ons', '##ive', '.']
# ['EX', '##T', ':', 'Without', 'ede', '##ma', '.']
# ['Due', 'to', 'pers', '##istent', 'gas', '##tric', 'secret', '##ions', ',', 'an', 'nas', '##oga', '##stri', '##c', 'tube', 'was', 'placed', 'for', 'de', '##com', '##pression', '.']
# ['He', 'underwent', 'a', 'joint', 'procedure', 'by', 'O', '##tola', '##ryn', '##gol', '##ogy', 'and', 'Plastic', 'Surgery', '.']
# ['2013', '-', '05', '-', '11', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['Rep', '##eat', '##ed', 'three', 'times', 'and', 'remained', 'flat', '.']
# ['Lev', '##of', '##lo', '##xa', '##cin', '500', 'mg', 'P', '##O', 'Q', '##24', '##H']
# ['SC', '##O', '##B', '##E', ',', 'R', '##Y', '##LA', '##L', '##ON']
# ['No', 'sp', '##onta', '##neous', 'e', '##cho', 'contrast', 'or', 'th', '##rom', '##bus', 'is', 'seen', 'in', 'the', 'body', 'of', 'the', 'left', 'at', '##rium', 'or', 'left', 'at', '##rial', 'app', '##enda', '##ge', '.']
# ['The', 'patient', 'is', 'admitted', 'for', 'pre', '##operative', 'and', 'ort', '##hop', '##edi', '##c', 'evaluation', '##s', '.']
# ['Van', '##com', '##y', '##cin', 'and', 'Zo', '##syn', 'were', 'started', '.']
# ['O', '##TH', '##ER', 'DI', '##AG', '##NO', '##SI', '##S', ';', 'Con', '##ditions', ',', 'Inf', '##ection', '##s', ',', 'Com', '##plications', ',', 'affect', '##ing', 'Treatment', '/', 'Stay', 's', '/', 'p', 'ces', '##area', '##n']
# ['DI', '##SC', '##HA', '##R', '##GE', 'SU', '##MM', '##AR', '##Y']
# ['Ao', '##rta', 'is', 'un', '##chang', '##ed', '.']
# ['661', '##82', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['Blood', 'type', 'A', 'positive', ',', 'anti', '##body', 'negative', ',', 'ru', '##bella', 'immune', ',', 'RP', '##R', 'non', '##rea', '##ctive', ',', 'hep', '##ati', '##tis', 'B', 'surface', 'anti', '##gen', 'negative', ',', 'group', 'beta', 'St', '##re', '##p', 'status', 'unknown', '.']
# ['She', 'was', 'maintained', 'on', 'hep', '##arin', 'therapy', 'initially', 'but', 'this', 'was', 'quickly', 'switched', 'over', 'to', 'Co', '##uma', '##din', 'antico', '##agu', '##lation', 'therapy', 'which', 'she', 'will', 'need', 'to', 'be', 'on', 'long', '-', 'term', 'for', 'her', 'ao', '##rti', '##c', 'valve', 'replacement', '.']
# ['In', 'emergency', 'room', ',', 'he', 'was', 'noted', 'to', 'be', 'af', '##eb', '##rile', 'with', 'stable', 'vital', 'signs', ',', 'was', 'treated', 'with', 'IV', 'fluid', '##s', ',', 'az', '##ith', '##rom', '##y', '##cin', ',', 'and', 'ce', '##fur', '##ox', '##ime', '.']
# ['TD', ':']
# ['RE', '##GI', '##ST', '##RA', '##TION', 'DA', '##TE', ':']
# ['Un', '##sig', '##ned', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['11', '.', 'Bis', '##aco', '##dy', '##l', '5', 'mg', 'Table', '##t', 'Si', '##g', ':', 'One', '(', '1', ')', 'Table', '##t', 'P', '##O', 'once', 'a', 'day', 'as', 'needed', 'for', 'con', '##sti', '##pati', '##on', '.']
# ['7', '.', 'Cl', '##oza', '##pine', '25', 'mg', 'Table', '##t', 'Si', '##g', ':', 'One', '(', '1', ')', 'Table', '##t', 'P', '##O', 'HS', '(', 'at', 'bed', '##time', ')', '.']
# ['MR', '##I', 'showed', 'a', 'large', 'fluid', 'filled', 'abdomen', 'with', 'a', 'relatively', 'small', 'mass', 'measuring', 'about', '5', 'to', '6', 'cm', 'in', 'the', 'right', 'pel', '##vis', '.']
# ['ED', 'Disc', '##harge', 'Summary']
# ['P', '##H', '##YS', '##IC', '##AL', 'EX', '##AM', '##IN', '##AT', '##ION', ':']
# ['At', '##rial', 'fi', '##bri', '##llat', '##ion', '.']
# ['He', 'was', 'we', '##ane', '##d', 'from', 'his', 'vas', '##oa', '##ctive', 'dr', '##ips', 'and', 'transferred', 'to', 'the', 'floor', 'on', 'P', '##OD', '#', '2', '.']
# ['Complete', '##d', 'by', ':', 'MA', '##R', '##K', 'Yvonne', 'NP', '80', '-', 'AU', '##O', '2018', '-', '05', '-', '29', '@', '1552']
# ['T', '##EL', '##SH', '##E', '##Y', 'K', '.', 'SW', '##AT', '##LL', '##EE', '##B', '##TI', '##K', ',', 'M', '.', 'D', '.', 'NJ', '##38', 'ME', '##0', '##8', '##9', '/', '692', '##2']
# ['12', '/', '26', '/', '1996', '12', ':', '00', ':', '00', 'AM']
# ['ME', '##DI', '##CA', '##TION', '##S', 'ON', 'DI', '##SC', '##HA', '##R', '##GE', ':']
# ['Report', 'Status', ':']
# ['The', 'patient', 'is', 'hard', 'of', 'hearing', '.']
# ['A', 'nit', '##ro', 'dr', '##ip', 'was', 'started', 'in', 'an', 'effort', 'to', 'decrease', 'her', 'pre', '##load', 'and', 'after', '##load', '.']
# ['H', '##OS', '##P', '##IT', '##AL', 'CO', '##UR', '##SE', ':']
# ['Con', '##dition', 'on', 'Disc', '##harge', ':']
# ['Sc', '##hed', '##ule', '##d', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['Food', '/', 'Drug', 'Inter', '##action', 'Inst', '##ru', '##ction']
# ['It', 'initially', 'started', 'one', 'day', 'previously', 'but', 'has', 'got', '##ten', 'significantly', 'worse', 'over', 'last', '12', 'hours', '.']
# ['PR', '##G', '##H', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['li', '##sino', '##pri', '##l', '5', 'mg', 'q', '##day']
# ['Follow', 'up', 'Service', ':']
# ['Kathy', 'Till', '##is', ',', 'M', '.', 'D', '.']
# ['L', '##UN', '##GS', ':']
# ['42', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['Code', 'status', '-', 'the', 'patient', 'is', 'a', 'D', '##NR', '/', 'D', '##NI', '.']
# ['Follow', '##up', 'Inst', '##ru', '##ctions', ':']
# ['2018', '-', '05', '-', '31', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['Temperatur', '##e', '100', '.', '3', ',', 'heart', 'rate', '76', ',', 'blood', 'pressure', '100', '/', '78', ',', 'resp', '##irat', '##ory', 'rate', '16', ',', 'and', 'an', 'oxygen', 'satu', '##ration', 'of', '96', '%', 'on', 'two', 'liter', '##s', '.']
# ['Disc', '##harge', 'Summary']
# ['He', 'was', 'treated', 'with', 'broad', 'spectrum', 'anti', '##bio', '##tics', 'for', 'a', '14', 'day', 'course', 'for', 'clinical', 'SB', '##P', '.']
# ['3', '/', '17', '/', '1998', '12', ':', '00', ':', '00', 'AM']
# ['He', 'is', 'continuing', 'on', 'the', 'radiation', 'therapy', 'to', 'date', '.']
# ['Can', 'give', '40', 'las', '##ix', 'P', '##O', 'if', 'having', 'any', 'weight', 'gain', 'or', 'short', '##ness', 'of', 'br', '##eath', '.']
# ['DI', '##CT', '##AT', '##ING', 'FOR', ':']
# ['Her', 'blood', 'pressure', '##s', 'and', 'all', 'of', 'her', 'vital', 'signs', 'are', 'stable', '.']
# ['Ad', '##mission', 'Date', ':']
# ['Card', '##iac', 'and', 'in', '##fect', '##ious', 'sources', 'of', 'hy', '##pot', '##ension', 'were', 'considered', ',', 'but', 'card', '##iac', 'enzyme', '##s', 'were', 'not', 'changed', 'from', 'prior', 'studies', 'and', 'he', 'had', 'no', 'locali', '##zing', 'signs', 'of', 'infection', ';', 'blood', 'cultures', 'were', 'sent', 'and', 'a', 'ultra', '##sou', '##nd', 'of', 'the', 'L', 'arm', 'AV', '##F', 'ordered', 'to', 'rule', 'out', 'ab', '##sce', '##ss', 'at', 'the', 'site', '.']
# ['Hy', '##pert', '##ension', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['G', '##I', ':']
# ['6', '.', 'CH', '##F', 'with', 'EF', '25', '%', 'on', 'last', 'e', '##cho', 'on', '2017', '-', '07', '-', '19']
# ['PL', '##T', 'CO', '##UN', '##T', '-', '247']
# ['12', '/', '13', '/', '2002', '12', ':', '00', ':', '00', 'AM']
# ['3', '.', 'At', '##or', '##vas', '##tati', '##n', '10', 'mg', 'p', '.', 'o', '.', 'q', '.', 'day', '.']
# ['2013', '-', '05', '-', '23', '09', ':', '36', 'PM', '11', '.', '4', '*', '34', '73', '1', '1']
# ['B', '##H', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['CK', '&', 'apo', '##s', ';', 's', 'were', 'mild', '##ly', 'elevated', 'but', 'the', 'MB', 'fraction', '##s', 'were', 'not', 'remarkable', '.']
# ['01', '/', '30', '/', '2001', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['She', 'will', 'need', 'follow', 'up', 'with', 'her', 'PC', '##P', 'within', 'B', 'week', 'after', 'disc', '##harge', 'from', 'the', 'extended', 'care', 'facility', 'for', 'further', 'BP', 'ti', '##tration', 'and', 'monitoring', 'of', 'her', 'elect', '##rol', '##yte', '##s', '.']
# ['There', 'was', 'some', 'concern', 'that', 'the', 'patient', 'may', 'have', 'a', 'partial', 'bili', '##ary', 'ob', '##stru', '##ction', 'and', 'the', 'patient', 'was', 'sent', 'for', 'an', 'magnetic', 'reso', '##nance', 'cho', '##lang', '##io', '##pan', '##cre', '##ato', '##graphy', 'to', 'further', 'eva', '##luat', '##e', 'the', 'bili', '##ary', 'system', '.']
# ['Her', 'diet', 'was', 'advanced', 'without', 'difficulty', 'and', 'the', 'patient', 'was', 'stable', 'for', 'disc', '##harge', '.']
# ['A', 'cos', '##ynt', '##rop', '##in', 'st', '##imu', '##lation', 'test', 'revealed', 'cort', '##iso', '##l', '32', '.', '1', '-', '-', '>', '36', '.', '4', '.']
# ['Because', 'it', 'would', 'be', 'ideal', 'to', 'place', 'a', 'mechanical', 'valve', 'if', 'valve', 'replacement', 'rather', 'that', 'com', '##mis', '##sur', '##oto', '##my', 'is', 'needed', ',', 'she', 'was', 'seen', 'by', 'Dr', '.', 'Ca', 'Shu', '##ff', 'of', 'EN', '##T', 'for', 'her', 'history', 'of', 'epi', '##sta', '##xis', '.']
# ['Test', '##es', 'des', '##cended', 'bila', '##teral', '##ly', '.']
# ['There', 'was', 'no', 'tri', '##cus', '##pid', 'valve', 'gradi', '##ent', '.']
# ['2014', '-', '04', '-', '23', '03', ':', '56', 'PM']
# ['DI', '##S', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['fl', '##are', '-', 'ster', '##oid', '##s', ',', 'cont', 'pred', '##nis', '##one', '60', ',', 'tape', '##r', 'slowly', 'as', 'tol', '##erated', ',', 'duo', '##neb', '##s', ',', 'ad', '##vai', '##r', ',', 'sing', '##ula', '##ir', ',', 'sp', '##iri', '##va', ',', 'clar', '##iti', '##n', 'az', '##ith', '##rom', '##y', '##cin', 'for', 'at', '##y', '##pica', '##l', 'bron', '##chi', '##tis', 'to', 'complete', 'a', '5', 'day', 'course', ',', 'keep', 'o', '##2', 'sat', '90', '-', '94', ',', 'home', 'no', '##ct', '##urn', '##al', 'CP', '##AP', 'not', 'tol', '##erated', 'in', 'house', ',', 'does', 'well', 'on', 'n', '##c', ',', 'appears', 'ato', 'be', 'at', 'base', '##line']
# ['Disc', '##harge', 'Dia', '##gno', '##sis', ':']
# ['H', '##IS', '##TO', '##R', '##Y', 'OF', 'PR', '##ES', '##EN', '##T', 'IL', '##L', '##NE', '##SS', ':']
# ['2012', '-', '06', '-', '07', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['Her', 'number', 'is', '(', '512', ')', '677', '-', '654', '##7', '.']
# ['12', '.', 'Proto', '##ni', '##x', '20', 'mg', 'p', '.', 'o', '.', 'b', '.', 'i', '.', 'd', '.']
# ['A', 'Holt', '##er', 'showed', 'at', '##rial', 'fi', '##bri', '##llat', '##ion', 'with', 'period', 'of', 'vent', '##ricu', '##lar', 'big', '##emi', '##ni', '.']
# ['On', 'posto', '##pera', '##tive', 'day', 'four', ',', 'the', 'patient', 'continued', 'to', 'have', 'nas', '##oga', '##stri', '##c', 'tube', 'in', 'place', '.']
# ['This', 'was', 'significant', 'for', 'demo', '##nst', '##rating', 'no', 'flow', '-', 'limited', 'disease', 'in', 'the', 'corona', '##ries', 'but', 'several', 'fi', '##stu', '##lae']
# ['2', '.', 'War', '##fari', '##n', '3', 'mg', 'p', '.', 'o', '.', 'q', 'h', '.', 's', '.']
# ['09', '/', '16', '/', '2004', '17', ':', '48']
# ['1', '.', 'Status', 'post', 'cada', '##veri', '##c', 'pan', '##cre', '##as', 'trans', '##plant', '.']
# ['During', 'this', 'admission', 'you', 'have', 'been', 'treated', 'for', 'a', 'CH', '##F', 'ex', '##ace', '##rba', '##tion', '.']
# ['The', 'patient', 'was', 'continued', 'on', 'his', 'stati', '##n', '.']
# ['12', '#', 'Wo', '##und', 'Care', ':']
# ['Sex', ':']
# ['Right', 'com', '##min', '##uted', 'ti', '##bia', '/', 'fi', '##bula', 'frac', '##ture']
# ['209', '##9', '##8', '##7', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['Fa', '##iled', 's', '##wall', '##ow', 'study', 'x', '2', 'in', 'early', 'November', '.']
# ['This', 'report', 'was', 'created', 'by', 'A', '##Y', '##RE', '##K', '##EM', '##P', '##E', ',', 'NO', '##NO', '##K', '01', '/', '09', '/', '2002', '05', ':', '09', 'PM']
# ['Dis', '##p', ':', '*', '60', 'Cap', '##sul', '##e', '(', 's', ')', '*', 'Re', '##fil', '##ls', ':', '*', '2', '*']
# ['12', '.', 'Pace', '##maker', '-', 'DD', '##D', 'dual', 'chamber', 'rate', 'response', 'pace', '##maker', '2011', '-', '08', '-', '22', 'for', 'sy', '##mpt', '##oma', '##tic', 'bra', '##dy', '##card', '##ia']
# ['H', '##OS', '##P', '##IT', '##AL', 'CO', '##UR', '##SE', 'AND', 'TR', '##EA', '##TM', '##EN', '##T', ':']
# ['Em', '##erg', '##ent', 'In', '##dication', '##s', ':']
# ['Standard', '##ized', 'Disc', '##harge', 'Inst', '##ru', '##ctions', ':']
# ['Mother', 'had', 'ad', '##rena', '##l', 'cancer', '.']
# ['Nota', '##bly', 'you', 'were', 'disc', '##harge', '##d', 'on', ':']
# ['3', '.', 'Al', '##but', '##ero', '##l', '-', 'I', '##pra', '##tro', '##pi', '##um', '103', '-', '18', 'm', '##c', '##g', '/', 'Act', '##uation', 'Aero', '##sol', 'Si', '##g', ':', '02', '-', '26', 'P', '##uff', '##s', 'In', '##hala', '##tion', 'Q', '##6', '##H', '(', 'every', '6', 'hours', ')', 'as', 'needed', '.']
# ['For', 'follow', 'up', ',', 'the', 'patient', 'is', 'to', 'call', 'for', 'an', 'appointment', 'with', 'Dr', '.', 'Sa', '##pm', '##al', '.']
# ['A', '.', 'Inst', '##ru', '##ctions', ':', 'with', 'Dr', '.', 'Matthew', 'in', '2', '-', '3', 'weeks', 'with', 'Dr', '.', 'Dell', '##inger', 'in', '2', '-', '3', 'weeks', 'with', 'Dr', '.', 'les', 'Go', '##key', 'in', '4', 'weeks']
# ['MR', '##N', ':']
# ['He', 'received', 'multiple', 'treatment', '##s', 'for', 'this', 'over', 'the', 'succeed', '##ing', 'weeks', '.']
# ['H', '##IS', '##TO', '##R', '##Y', 'OF', 'PR', '##ES', '##EN', '##T', 'IL', '##L', '##NE', '##SS', ':']
# ['W', '##IE', '##RS', '##T', ',', 'ST', '##O', 'L', '.', ',', 'M', '.', 'D', '.', '(', 'RR', '##86', ')', '10', '/', '01', '/', '00', '02', ':', '33', 'PM']
# ['Sign', '##ed', 'electronic', '##ally', 'by', ':', 'DR', '.', 'Brenda', 'J', '##M', '.', 'Espinosa', 'on', ':', 'Maxi', '##ne', '2015', '-', '09', '-', '10', '1', ':', '57', 'PM']
# ['You', 'may', 'show', '##er', '.']
# ['Un', '##sig', '##ned', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['Had', 'subsequent', 'ab', '##normal', 'stress', 'test', 'and', 'pe', '##fus', '##ion', 'imaging', 'showed', 'EF', '38', '%', 'with', 'per', '##fus', '##ion', 'def', '##ect', '##s', '.']
# ['Has', 'significant', 'card', '##iac']
# ['Neu', '##rol', '##ogical', 'ex', '##am', 'was', 'gross', '##ly', 'intact', '.']
# ['IM', '##PR', '##ESS', '##ION', ':', 'Mode', '##rate', 'to', 'large', 'per', '##ica', '##rdia', '##l', 'ef', '##fus', '##ion', '(', 'minimal', 'fluid', 'anterior', '##ly', '(', '1', '##cm', ')', ',', '?', 'blood', '##y', ')', '.']
# ['CT', '##MC', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['CT', '##MC', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['H', '##EE', '##NT', 'ex', '##am', 'was', 'un', '##rema', '##rka', '##ble', '.']
# ['PR', '##ES', '##EN', '##T', 'IL', '##L', '##NE', '##SS', ':']
# ['Disc', '##harge', 'Medi', '##cations', ':']
# ['Di', '##cata', '##ted', 'By', ':']
# ['487', '##20', '##9', '##20', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['Gent', '##le', 'diu', '##resi', '##s', 'and', 'beta', 'block', '##ade', 'started', ',', 'and', 'he', 'was', 'transferred', 'to', 'the', 'floor', 'to', 'begin', 'increasing', 'his', 'activity', 'level', '.']
# ['and', 'it', 'is', 'noted', 'there', 'was', 'no', '##dula', '##rity', 'in', 'the', 'common', 'bile', 'duc', '##t', 'which', 'is', 'wo', '##rri', '##some', 'for', 'cho', '##lang', '##ioca', '##rci', '##noma', '.']
# ['09', '-', '08', '-', '93', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['uri', '##nary', 'in', '##con', '##tinen', '##ce']
# ['01', '/', '09', '/', '2002', '17', ':', '02']
# ['The', 'patient', ',', 'during', 'this', 'admission', ',', 'required', 'trans', '##fus', '##ion', 'of', 'three', 'units', 'of', 'pack', '##ed', 'red', 'blood', 'cells', 'to', 'maintain', 'ad', '##e', '##quate', 'hem', '##ato', '##crit', '.']
# ['2', '.', 'PR', '##IO', '##R', 'H', '##IS', '##TO', '##R', '##Y', 'OF', 'AN', '##TER', '##IO', '##R', 'MY', '##OC', '##AR', '##DI', '##AL', 'IN', '##FA', '##RC', '##TION']
# ['H', '##EE', '##NT', ':', 'NC', '##AT', ',', 'PE', '##R', '##R', '##L', ',', 'E', '##OM', '##I', ',', 'no', 'i', '##cter', '##us', ',', 'OP', 'clear', ',', 'MM', '##M', ',', 'no', 'tongue', 'fa', '##sci', '##cula', '##tions']
# ['AL', '##LE', '##R', '##GI', '##ES', ':']
# ['Sign', '##ed', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['Please', 'note', 'that', 'evaluation', 'by', 'the', 's', '##wall', '##owi', '##ng', 'the', '##rap', '##ist', ',', 'showed', 'that', 'the', 'patient', 'is', 'asp', '##irat', '##ing', 'at', 'this', 'time', ',', 'but', 'there', 'is', 'great', 'hope', 'from', 'the', 'nature', 'of', 'her', 'deficit', 'and', 'the', 'good', 'movements', 'of', 'her', 'tongue', 'that', 'normal', 's', '##wall', '##owi', '##ng', 'should', 'return', 'soon', '.']
# ['Syst', '##oli', '##c', 'blood', 'pressure', 'in', 'the', '120', "'", 's', 'to', '130', "'", 's', '.']
# ['The', 'walk', 'was', 'pareti', '##c', 'in', 'the', 'left', 'side', '.']
# ['Res', '##pira', '##tory', 'rate', '18', '.']
# ['He', 'remained', 'un', '##res', '##pon', '##sive', 'with', 'poor', 'air', '##way', 'protection', '.']
# ['333', '##8', '##8', '##7', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['2013', '-', '10', '-', '29', '01', ':', '09', 'PM', 'BL', '##O', '##OD', 'G', '##lucose', '-', '172', '*', 'Ur', '##ea', '##N', '-', '11', 'C', '##reat', '-', '0', '.', '9', 'Na', '-', '142', 'Cl', '-', '111', '*', 'HC', '##O', '##3', '-', '22']
# ['#', '.', 'Af', '##ib', '/', 'SS', '##S', ':', 'She', 'was', 'A', '-', 'pace', '##d', ',', 'pace', '##r', 'placed', '05', '-', '08', 'in', 'DD', '##D', '##R', 'mode', ',', 'complicated', 'by', 'PT', '##X', 'requiring', 'chest', 'tube', 'which', 'resolved', 'and', 'tube', 'was', 'removed', 'during', 'ad', '##mit', 'for', 'pace', '##r', ',', 'no', 'evidence', 'of', 'PT', '##X', 'on', 'most', 'recent', 'CX', '##R', '.']
# ['320', '##58', '##20', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['Sub', '##cut', '##ane', '##ous', 'ede', '##ma', 'is', 'noted', 'in', 'the', 'lower', 'abdomen', 'and', 'pel', '##vis', '.']
# ['7', '/', '10', '/', '2002', '12', ':', '00', ':', '00', 'AM']
# ['The', 'patient', 'den', '##ies', 'tobacco', 'and', '/', 'or', 'alcohol', 'use', '.']
# ['ED', 'DI', '##SC', '##HA', '##R', '##GE', 'NO', '##TI', '##F', '##IC', '##AT', '##ION', '/', 'SU', '##MM', '##AR', '##Y']
# ['2018', '-', '03', '-', '04', '01', ':', '02', '##PM']
# ['12', '.', 'Line', '##zo', '##lid', '600', 'mg', 'IV', 'Q', '##12', '##H']
# ['Neu', '##rology', 'was', 'consul', '##ted', 'due', 'to', 'the', 'concern', 'for', 'sei', '##zur', '##es', 'in', 'the', 'setting', 'of', 'dus', '##ky', 'episodes', '.']
# ['ami', '##oda', '##rone', '200', 'mg', 'daily']
# ['M', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['B', '##IP', '##OL', '##AR', 'DI', '##S', '##OR', '##DE', '##R']
# ['Takes', 'hub', '##by', '&', 'apo', '##s', ';', 's', 'sl', 'nt', '##g', 'Bari', '##um', 'S', '##wall', '##ow', '04', '/', '89', '(', '-', ')', 'U', '##GI', '06', '/', '91', '(', '-', ')']
# ['237', '##5', '##43', '##57', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['He', 'was', 'taken', 'to', 'Ways', '##kem', '##ed', '##cal', '##lto', '##wn', 'Tal', '##mi', 'and', 'transferred', 'to', 'He', '##ao', '##n', '##bo', '##burg', 'Lin', '##pac', '##k', 'Grant', 'Medical', 'Center', 'with', 'a', 'computer', '##ized', 'tom', '##ography', 's', '##can', 'showing', 'a', '1x', '##2', 'tha', '##lami', '##c', 'caps', '##ular', 'hem', '##or', '##r', '##ha', '##ge', 'without', 'superficial', 'mass', 'effect', '.']
# ['She', 'is', 'antico', '##agu', '##lated', 'on', 'Co', '##uma', '##din', 'and', 'this', 'has', 'been', 'stable', '.']
# ['So', '##dium', '139', ';', 'pot', '##ass', '##ium', '4', '.', '1', ';', 'B', '##UN', '15', ';', 'creat', '##inin', '##e', '1', '.', '1', ';', 'mag', '##nesi', '##um', '1', '.', '6', ';', 'SG', '##P', '##T', '19', ';', 'SG', '##OT', '20', ';', 'al', '##kali', '##ne', 'ph', '##os', '##pha', '##tase', '66', ';', 'total', 'bili', '##rub', '##in', '0', '.', '6', ';', 'direct', 'bili', '##rub', '##in', '0', '.', '2', ';', 'total', 'cho', '##les', '##tero', '##l', '234', ';', 'tri', '##gly', '##cer', '##ides', '274', ';', 'HD', '##L', '44', ';', 'LDL', '135', ';', 'hem', '##og', '##lob', '##in', 'A1', '##c', '6', '.', '7', ';', 'white', 'cell', 'count', '6', '.', '1', ';', 'hem', '##ato', '##crit', '36', '.', '4', ';', 'plate', '##let', 'count', '201', '.']
# ['Of', 'note', ',', 'this', 'is', 'the', 'second', 'time', 'the', 'patient', 'has', 'exercise', '##d', 'in', 'many', 'months', '.']
# ['PR', '##IN', '##CI', '##PA', '##L', 'DI', '##AG', '##NO', '##SI', '##S', ':']
# ['394', '##52', '##1', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['Blood', 'pressure', '162', '/', '76', '.']
# ['The', 'patient', 'became', 'hy', '##pot', '##ensive', 'into', 'the', '70', 's', 'without', 'any', 'symptoms', '.']
# ['Per', '##tinent', 'Results', ':']
# ['Fe', '##eds', 'are', 'breast', 'feeding', 'P', '.', 'O', '.', 'ad', 'lib', '.']
# ['There', 'were', 'no', 'vent', '##ricu', '##lar', 'prema', '##ture', 'contract', '##ions', '.']
# ['1', '.', 'Dia', '##bet', '##es', 'me', '##lli', '##tus', '.']
# ['There', 'was', 'mild', 'en', '##hance', '##ment', 'of', 'the', 'pont', '##ine', 'hem', '##or', '##r', '##ha', '##gic', 'mass', 'but', 'none', 'elsewhere', '.']
# ['The', 'patient', "'", 's', 'sur', '##gical', 'in', '##cision', 'was', 'also', 'he', '##aling', 'well', 'by', 'the', 'time', 'of', 'disc', '##harge', 'with', 'no', 'evidence', 'of', 'infection', '.']
# ['Dis', '##p', ':', '*', '5', 'bot', '##tles', '*', 'Re', '##fil', '##ls', ':', '*', '2', '*']
# ['Due', 'to', 'difficult', 'amb', '##ulation', ',', 'the', 'patient', 'developed', 'a', 'small', 'ul', '##cer', 'in', 'the', 'sacra', '##l', 'area', ',', 'which', 'was', 'treated', 'with', 'Duo', '##der', '##m', 'dress', '##ing', '.']
# ['An', 'EC', '##H', '##O', 'showed', 'that', 'she', 'had', 'preserved', 'EF', 'and', 'no', 'wall', 'motion', 'ab', '##normal', '##ities', '.']
# ['FA', '##MI', '##L', '##Y', 'H', '##IS', '##TO', '##R', '##Y', ':']
# ['OM', '##R', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['The', 'oro', '##pha', '##ryn', '##x', 'was', 'beni', '##gn', '.']
# ['TD', ':']
# ['Pro', '##vide', '##r', 'Number', ':']
# ['DI', '##SC', '##HA', '##R', '##GE', 'DA', '##TE', ':']
# ['On', '5', '/', '14', '/', '05', 'Mann', '##ito', '##l', 'was', 'tape', '##red', 'and', 'then', 'd', '/', 'c', '&', 'apo', '##s', ';', 'd', '.']
# ['7', '.', 'Dil', '##aud', '##id', 'pr', '##n', '.']
# ['Disc', '##harge', 'Medi', '##cations', ':']
# ['The', 'abdomen', 'showed', 'a', '10', 'cm', 'liver', 'with', 'the', 'edge', 'pal', '##pa', '##ble', '2', 'finger', '##bre', '##adt', '##hs', 'below', 'the', 'right', 'costa', '##l', 'margin', '.']
# ['The', 'patient', 'is', 'in', 'no', 'acute', 'dis', '##tress', '.']
# ['WBC', '-', '11', '.', '4', '*', 'RB', '##C', '-', '3', '.', '61', '*', 'Hg', '##b', '-', '11', '.', '4', '*', 'H', '##ct', '-', '32', '.', '6', '*', 'MC', '##V', '-', '90', 'MC', '##H', '-', '31', '.', '7']
# ['Report', 'Status', ':']
# ['AC', '500', '/', '15', '/', '.', '50', '/', 'PE', '##EP', '5']
# ['No', 'evidence', 'of', 'active', 'end', 'organ', 'damage', '.']
# ['None', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['It', 'is', 'hoped', 'that', 'when', 'he', 'is', 'transferred', 'to', 'a', 're', '##hab', 'facility', 'that', 'he', 'will', 'continue', 'with', 'physical', 'therapy', 'to', 're', '##gain', 'his', 'strength', 'and', 're', '##gain', 'independence', 'in', 'activities', 'of', 'daily', 'living', '.']
# ['During', 'her', 'labor', 'she', 'encountered', 'the', 'following', 'com', '##plication', '(', 's', ')', ':']
# ['2', '.', 'Mode', '##rate', '##ly', 'elevated', 'right', 'and', 'left', 'side', '##d', 'fill', '##ing', 'pressure', '##s', '.']
# ['05', '/', '26', '/', '2004', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['BR', '##E', '##UN', '##TI', '##K', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['Bone', 'mar', '##row', 'bio', '##ps', '##y', 'was', 'not', 'attempted', '.']
# ['289', '##65', '##3', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['Ta', '##pe', '/', 'Ben', '##ad', '##ryl']
# ['PR', '##IN', '##CI', '##PA', '##L', 'DI', '##AG', '##NO', '##SI', '##S', ':']
# ['The', 'abdomen', 'was', 'soft', 'and', 'non', '-', 'tender', 'with', 'no', 'masses', 'or', 'organo', '##me', '##gal', '##y', '.']
# ['Fe', '##mora', '##l', '2', '+', 'bila', '##teral', '##ly', ',', 'dorsal', '##is', 'pe', '##dis', '1', '+', 'bila', '##teral', '##ly', ',', 'posterior', 'ti', '##bia', '##l', '1', '+', 'bila', '##teral', '##ly', ',', 'and', 'radial', '2', '+', 'bila', '##teral', '##ly', '.']
# ['600', '##13', '##5', '##6', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['Major', 'Sur', '##gical', 'or', 'In', '##vasi', '##ve', 'Proc', '##edu', '##re', ':']
# ['Caro', '##tid', '##s', 'had', 'normal', 'ups', '##tro', '##ke', 'and', 'normal', 'volume', 'with', 'bila', '##teral', 'br', '##uit', '##s', '.']
# ['RE', '##AS', '##ON', 'FOR', 'T', '##HI', '##S', 'EX', '##AM', '##IN', '##AT', '##ION', ':']
# ['She', 'was', 'worked', 'up', 'aggressive', '##ly', 'with', 'the', 'physical', 'therapy', 'and', 'occupation', '##al', 'services', ',', 'made', 'good', 'progress', 'and', 'began', 'amb', '##ulat', '##ing', 'with', 'assistance', 'with', 'a', 'walk', '##er', 'but', 'with', 'minimal', 'assistance', 'from', 'an', 'aid', '.']
# ['Pro', '##vide', '##r', 'Number', ':']
# ['ME', '##D', '##Q', '##UI', '##ST', '##36', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['12', '/', '1', '/', '2003', '12', ':', '00', ':', '00', 'AM']
# ['Old', 'T', '##W', '##I', 'V', '##4', '-', '6', '.']
# ['271', '##7', '##35', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['Further', 'evaluation', 'of', 'his', 'ren', '##al', 'failure', 'showed', 'that', 'the', 'patient', 'has', 'bila', '##teral', 'hyd', '##rone', '##ph', '##ros', '##is', ',', 'most', 'likely', 'ob', '##stru', '##ctive', 'ur', '##opa', '##thy', 'due', 'to', 'pro', '##state', 'CA', 'in', 'the', 'pel', '##vic', 'area', '.']
# ['Ne', '##ck', 'with', 'ce', '##rvi', '##cal', 'coll', '##ar', '.']
# ['Philip', 'Glenn', 'MD', '60', '-', '385']
# ['12', '/', '09', '/', '2005', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['NO', '##NO', '##K', 'A', '##Y', '##RE', '##K', '##EM', '##P', '##E']
# ['H', '##EE', '##NT', ':', 'E', '##OM', '##I', ',', 'PE', '##R', '##R', '##L', ',', 'NC', '/', 'AT']
# ['H', '##OS', '##P', '##IT', '##AL', 'CO', '##UR', '##SE', ':']
# ['#', 'AR', '##F', ':', 'C', '##reat', '##inin', '##e', 'has', 'increased', 'from', '0', '.', '9', 'on', 'admission', 'to', '1', '.', '9', 'on', 'admission', 'to', 'IC', '##U', '.']
# ['On', 'day', 'of', 'life', '#', '1', ',', 'ca', '##ffe', '##ine', 'was', 'started', '.']
# ['(', 'End', 'of', 'Report', ')']
# ['Abd', '##omina', '##l', 'pain', 'pred', '##omina', '##lly', 'on', 'the', 'right', 'upper', 'qua', '##dran', '##t', ',', 'no', 'signs', 'of', 'per', '##iton', '##eal', 'ir', '##rita', '##tion', '.']
# ['An', '##G', '##ap', '-', '12']
# ['C', '##t', 's', '##can', 'shows', 'ova', '##rian', 'c', '##yst']
# ['Sc', '##lera', 'mild', '##ly', 'i', '##cter', '##ic', '.']
# ['Blood', 'pressure', 'most', 'recently', '60', '/', '37', 'with', 'a', 'mean', 'of', '44', '.']
# ['Sign', '##ed', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['PA', '##ST', 'ME', '##DI', '##CA', '##L', 'H', '##IS', '##TO', '##R', '##Y', ':']
# ['3', '.', 'Fl', '##oven', '##t', '110', 'micro', '##gram', '##s', 'ae', '##ros', '##ol', 'two', 'pu', '##ffs', 'b', '.', 'i', '.', 'd', '.']
# ['He', 'will', 'follow', 'up', 'with', 'Dr', '.', 'I', '##echa', '##lette', 'Cancer', 'in', 'his', 'office', '.']
# ['ME', '##D', '##Q', '##UI', '##ST', '##36', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['#', '.', 'An', '##emia', ':', 'Uncle', '##ar', 'source', '.']
# ['CV', ':']
# ['001', '##46', '##33', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['CM', '##ED', 'CS', '##R', '##U']
# ['Ex', '##pired', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['819', '##57', '##9', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['Room', ':']
# ['7', '.', 'Cl', '##oni', '##dine', '0', '.', '2', 'mg', 'Table', '##t', 'Si', '##g', ':', 'One', '(', '1', ')', 'Table', '##t', 'P', '##O', 'T', '##ID', '(', '3', 'times', 'a', 'day', ')', '.']
# ['Type', 'II', 'diabetes', '.']
# ['On', 'an', 'office', 'visit', 'on', '01', '-', '14', ',', 'the', 'patient', 'was', 'found', 'to', 'have', 'significantly', 'elevated', 'al', '##kali', '##ne', 'ph', '##os', '##pha', '##tase', '.']
# ['No', 'pal', '##pita', '##tions', ',', 'history', 'of', 'epi', '##gast', '##ric', 'pain', 'and', 'body', 'weight', 'loss', '.']
# ['Echo', 'showed', 'ef', '45', '-', '50', '%', ',', 'with', 'mild', 'dil', '##ata', '##tion', 'and', 'no', 'significant', 'val', '##vul', '##ar', 'disease', ',', 'and', 'nl', 'PA', '##P', '.']
# ['Pro', '##vide', '##r', ':']
# ['CT', 'H', '##EA', '##D', 'W', '/', 'O', 'CO', '##NT', '##RA', '##ST']
# ['ep', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['Disc', '##harge', 'Date', ':']
# ['No', 'other', 'cultures', 'grew', 'out', 'and', 'the', 'patient', '&', 'apo', '##s', ';', 's', 'clinical', 'status', 'det', '##eri', '##orat', '##ed', '.']
# ['Central', 'Ve', '##nou', '##s', 'Cat', '##heter', 'and', 'Swan', 'Gan', '##z', 'cat', '##heter', 'placement']
# ['Ante', '##rior', 'font', '##ane', '##lle', ',', 'soft', 'and', 'flat', ',', 'pala', '##te', 'intact', ',', 'non', '##dy', '##smo', '##rp', '##hic', 'features', '.']
# ['PA', '##ST', 'ME', '##DI', '##CA', '##L', 'H', '##IS', '##TO', '##R', '##Y', ':']
# ['ED', 'Disc', '##harge', 'Summary']
# ['Ad', '##minister', 'iron', 'products', 'a', 'minimum', 'of', '2', 'hours', 'before', 'or', 'after', 'a', 'le', '##vo', '##f', '##lo', '##xa', '##cin', 'or', 'ci', '##pro', '##f', '##lo', '##xa', '##cin', 'dose', 'dose']
# ['EK', '##G', 'was', 'negative', 'for', 'is', '##chem', '##ia', '.']
# ['On', 'admission', 'included', 'an', 'ALT', 'of', '108', ',', 'AS', '##T', 'of', '286', '.']
# ['809', '##8', '##7', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['Room', ':']
# ['70', 'y', '/', 'o', 'male', 'with', 'h', '/', 'o', 'CAD', 's', '/', 'p', 'LA', '##D', 'PT', '##CA', '33', 'yr', '##s', 'ago', ',', 'CO', '##PD', ',', 'T2', '##DM', ',', 'and', 'AI', '##CD', 'poc', '##ket', 'infection', 'who', 'presented', 'to', 'the', 'Juan', 'on', '2017', '-', '09', '-', '03', 'with', 'worse', '##ning', 'SO', '##B', 'x', '5', 'days', 'and', 'feeling', '"', 'cloud', '##y', '.', '"']
# ['03', '/', '31', '/', '97', '12', ':', '36', 'P']
# ['Die', '##t', 'as', 'tol', '##erated', '.']
# ['Del', '##iver', '##y', 'date', ':']
# ['ME', '##DI', '##CA', '##TION', '##S', 'AT', 'H', '##OM', '##E', ':']
# ['P', '##OS', '##TP', '##AR', '##T', '##UM', 'O', '##TH', '##ER', 'DI', '##AG', '##NO', '##SI', '##S', ';']
# ['Joseph', 'Judy', 'MD', '35', '-', '943']
# ['His', 'api', '##cal', 'pne', '##umo', '##th', '##orax', 'from', 'the', 'outside', 'hospital', 'had', 'resolved', '.']
# ['Service', ':']
# ['AS', '##S', '##OC', '##IA', '##TE', '##D', 'DI', '##AG', '##NO', '##SE', '##S', ':']
# ['H', '##EE', '##NT', ':']
# ['1', '.', 'Co', '##uma', '##din', '5', 'mg', 'P', '##O', 'q', '.', 'day', ',', 'then', 'she', 'will', 'follow', 'up', 'with', 'her', 'primary', 'care', 'physician', 'and', 'decide', 'the', 'dos', '##age', 'thereafter', ',']
# ['GL', '##UC', '##OS', '##E', '-', '101', 'LA', '##CT', '##AT', '##E', '-', '2', '.', '9', '*', 'NA', '+', '-', '142', 'K', '+', '-', '3', '.', '6', 'CL', '-', '-', '102', 'TC', '##O', '##2', '-', '26']
# ['RI', '##AS', '##H', '##WA', '##N', 'BE', '##R', '##L', '##NI', 'VA', '##LL', '##E', '##Y']
# ['Service', ':']
# ['Sign', '##ed', 'electronic', '##ally', 'by', ':', 'DR', '.', 'Kathy', 'Till', '##is', 'on', ':', 'MO', '##N', '2010', '-', '06', '-', '07', '4', ':', '00', 'PM']
# ['She', 'continued', 'to', 'have', 'a', 'dense', 'left', 'hem', '##iano', '##psia', ',', 'but', 'otherwise', 'was', 'neu', '##rol', '##ogical', '##ly', 'intact', '.']
# ['The', 'patient', 'was', 'given', 'printed', 'instructions', 'for', 'sp', '##rain', '##s', ',', 'frac', '##tures', 'and', 'br', '##uise', '##s', '(', 'English', ')', '.']
# ['Again', 'seen', 'are', 'sub', '##tle', 'hy', '##pod', '##ensi', '##ties', 'within', 'the', 'per', '##ivent', '##ricu', '##lar', 'white', 'matter', 'which', 'is', 'an', 'indication', 'of', 'chronic', 'micro', '##vas', '##cular', 'is', '##chem', '##ic', 'changes', ',', 'stable', '.']
# ['He', '##pati', '##tis', 'ser', '##ologie', '##s', 'pen', '##ding', '.']
# ['551', '##8', '##8', '##1', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['NO', '##NE', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['Date', 'of', 'Birth', ':']
# ['rest', '##rain', '##ts', ',', 'for', 'the', 'safety', 'of', 'both', 'the', 'patient', 'and', 'the', 'staff', 'of', 'the', 'hospital', '.']
# ['The', 'plan', 'is', 'for', 'alter', '##nating', 'feed', '##s', '.']
# ['H', '##OS', '##P', '##IT', '##AL', 'CO', '##UR', '##SE', ':']
# ['Con', '##ditions', ',', 'Inf', '##ection', '##s', ',', 'Com', '##plications', ',', 'affect', '##ing', 'Treatment', '/', 'Stay', 'post', '##part', '##um']
# ['She', 'has', 'a', 'St', '.', 'Jude', '&', 'apo', '##s', ';', 's', 'mechanical', 'valve', 'and', 'has', 'been', 'on', 'Co', '##uma', '##din', 'since', 'then', ',']
# ['GE', '##N', ':', 'NA', '##D', ',', 'pl', '##eas', '##ant', 'speaking', 'in', 'full', 'sentence', '##s']
# ['IS', '##T', '##RA', '##N', '##M', '##UN', '##A', 'B', '.', 'CO', '##RD', ',', 'M', '.', 'D', '.', 'VR', '##52', 'P', '##H', '##50', '##1', '/', '356', '##0']
# ['DD', ':']
# ['Inst', '##ru', '##ctions', ':']
# ['He', 'did', 'not', 'show', 'any', 'episodes', 'of', 'bra', '##dy', '##card', '##ia', 'throughout', 'the', 'remainder', 'of', 'his', 'hospital', 'course', '.']
# ['Stab', '##le', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['GA', '##IT', 'DI', '##S', '##OR', '##DE', '##R', '.']
# ['Per', '##co', '##cet', '5', 'mg', 'in', '325', 'mg', 'one', 'to', 'two', 'tab', '##s', 'po', 'q', '##4', 'to', '6', 'pr', '##n', 'pain', '.']
# ['Disc', '##harge', 'Dis', '##position', ':']
# ['433', '##65', '##13', '##8', '##9', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['No', 'mass', 'or', 'vegetation', 'is', 'seen', 'on', 'the', 'mit', '##ral', 'valve', '.']
# ['The', 'as', '##cend', '##ing', 'ao', '##rta', 'is', 'mild', '##ly', 'dil', '##ated', '.']
# ['The', 'right', 'pl', '##eur', '##al', 'ef', '##fus', '##ion', 'slowly', 're', '-', 'ac', '##cum', '##ulated', 'after', 'tap', 'but', 'resolved', 'after', 'continued', 'diu', '##resi', '##s', '.']
# ['In', 'addition', ',', 'she', 'is', 'to', 'follow', 'up', 'with', 'her', 'primary', 'care', 'physician', 'to', 'check', 'her', 'pro', '##th', '##rom', '##bin', 'time', '/', 'IN', '##R', 'as', 'well', 'as', 'calcium', ',', 'albumin', 'and', 'ph', '##osphate', 'levels', '.']
# ['320', '##42', '##25', '##64', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['Res', '##pira', '##tory', ':']
# ['1', '.', 'Corona', '##ry', 'arter', '##y', 'disease', ',']
# ['11', '/', '16', '/', '05', '02', ':', '21', 'PM']
# ['He', 'uses', 'con', '##dom', '##s', 'consistently', '.']
# ['495', '##9', '##43', '##3', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['2', '.', 'An', '##xie', '##ty', '.']
# ['-', 'lower', 'extrem', '##ity', 'ede', '##ma', 'improved']
# ['Over', 'the', '24', 'hours', 'of', 'in', 'house', 'hospital', '##ization', ',', 'he', 'did', 'not', 'have', 'any', 'further', 'neu', '##rol', '##ogi', '##c', 'activity', 'and', 'was', 'able', 'to', 'amb', '##ulate', 'without', 'assistance', 'prior', 'to', 'disc', '##harge', '.']
# ['He', 'is', 'being', 'disc', '##harge', '##d', ',', 'most', 'likely', ',', 'to', 'Fa', '##lm', '##out', '##h', 'Hospital', '.']
# ['There', 'was', 'mild', 'finger', '-', 'to', '-', 'nose', 'dy', '##sme', '##tria', 'on', 'the', 'left', '.']
# ['P', '##OS', '##TP', '##AR', '##T', '##UM', 'DI', '##SP', '##OS', '##IT', '##ION', ':']
# ['12', '.', 'Ce', '##re', '##bral', 'ane', '##ury', '##sm', '.']
# ['Inf', '##lue', '##nza', 'im', '##mun', '##ization', 'should', 'be', 'considered', 'annually', 'in', 'the', 'fall', 'for', 'pret', '##erm', 'infant', '##s', 'with', 'chronic', 'lung', 'disease', 'once', 'they', 'reach', 'six', 'months', 'of', 'age', '.']
# ['3', '.', 'O', '##xy', '##co', '##done', '-', 'Ace', '##tami', '##no', '##phen', '5', '-', '325', 'mg', 'Table', '##t', 'Si', '##g', ':', '1', '-', '2', 'Table', '##ts', 'P', '##O', 'Q', '##4', '##H', '(', 'every', '4', 'hours', ')', 'as', 'needed', 'for', 'pain', 'for', '30', 'dose', '##s', '.']
# ['MR', '##N', ':']
# ['At', '##tend', '##ing', ':']
# ['6', '.', 'Bus', '##piro', '##ne', '10', 'mg', 'p', '.', 'o', '.', 't', '.', 'i', '.', 'd', '.']
# ['2015', '-', '10', '-', '30', 'Left', 'Caro', '##tid', 'Sten', '##ting']
# ['Non', '##dy', '##smo', '##rp', '##hic', 'intact', 'Ve', '##liz', '.']
# ['Short', '##ness', 'of', 'br', '##eath', '.']
# ['The', 'card', '##iac', 'index', 'was', 'preserved', 'at', '3', '.', '0', 'L', '/', 'min', '/', 'm2', '.']
# ['This', 'is', 'a', '61', 'year', 'old', 'male', 'with', 'a', 'history', 'of', 'diabetes', ',', 'corona', '##ry', 'arter', '##y', 'disease', ',', 'hep', '##ati', '##tis', 'C', ',', 'and', 'as', '##th', '##ma', 'who', 'was', 'diagnosed', 'recently', 'with', 'pan', '##cre', '##atic', 'cancer', 'after', 'he', 'presented', 'to', 'Sep', '##h', '&', 'apo', '##s', ';', 'sju', 'Memorial', 'after', 'a', 'motor', 'vehicle', 'accident', '.']
# ['PA', '##ST', 'G', '##Y', '##N', 'H', '##IS', '##TO', '##R', '##Y', ':']
# ['Dis', '##p', ':', '*', '50', 'Table', '##t', '(', 's', ')', '*', 'Re', '##fil', '##ls', ':', '*', '0', '*']
# ['EK', '##G', 'revealed', 'a', 'normal', 'sin', '##us', 'rhythm', 'with', 'a', 'rate', 'of', '69', ',', 'left', 'vent', '##ricu', '##lar', 'hy', '##per', '-', 'trophy', 'with', 'poor', 'anterior', 'progression', 'of', 'R', '-', 'waves', '.']
# ['He', '##mat', '##oc', '##rit', 'stable', '.']
# ['1', '.', 'Familia', '##l', 'cave', '##rno', '##us', 'hem', '##ang', '##io', '##mas', ',', 'status', 'post', 'a', 'suba', '##cute', 'pont', '##ine', 'hem', '##or', '##r', '##ha', '##ge', '.']
# ['DR', '.', 'Freddy', 'King', 'on', ':']
# ['On', 'hospital', 'day', 'number', 'three', ',', 'her', 'blood', 'cultures', 'came', 'back', 'positive', 'in', 'the', 'ana', '##ero', '##bic', 'culture', 'for', 'gram', '-', 'positive', 'co', '##cci', 'in', 'pairs', 'and', 'cluster', '##s', '.']
# ['Family', 'History', ':']
# ['His', 'hem', '##ato', '##crit', 'increased', 'to', 'about', '30', ',', 'but', 'he', 'continued', 'to', 'have', 'hem', '##atur', '##ia', 'and', 'his', 'ren', '##al', 'function', 'only', 'improved', 'very', 'slowly', '.']
# ['He', 'was', 'sub', '##sque', '##ntly', 'admitted', 'to', 'the', 'IC', '##U', 'for', 'further', 'care', '.']
# ['They', 'were', 'taken', 'off', 'two', 'at', 'a', 'time', '.']
# ['Sign', '##ifica', '##nt', 'for', 'col', '##on', 'car', '##cino', '##ma', '.']
# ['2015', '-', '06', '-', '10', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['2013', '-', '05', '-', '24', '12', ':', '52', 'AM', '22', '65', '*', '739', '*', '52', '81', '1', '.', '0']
# ['PT', 'was', '12', '.', '9', '.']
# ['MR', '##N', ':']
# ['5', '.', 'As', '##pir', '##in', '81', 'mg', 'Table', '##t', ',', 'Che', '##wa', '##ble', 'Si', '##g', ':', 'One', '(', '1', ')', 'Table', '##t', ',', 'Che', '##wa', '##ble', 'P', '##O', 'DA', '##IL', '##Y', '(', 'Daily', ')', '.']
# ['The', 'left', 'at', '##rium', 'is', 'normal', 'in', 'size', '.']
# ...
# ['On', 'disc', '##harge', ',', 'the', 'patient', 'was', 'given', 'Love', '##no', '##x', 'injection', '##s', 'which', 'should', 'be', 'continued', 'until', 'the', 'patient', 'reaches', 'a', 'the', '##rap', '##eu', '##tic', 'dose', 'of', 'Co', '##uma', '##din', '.']
# ['Fever', ',', 'f', '/', 'u', 'in', '##fil', '##tr', '##te']
# ['Grade', 'II', 'de', '##cre', '##sce', '##ndo', 'dias', '##tol', '##ic', 'mur', '##mur', 'at', 'the', 'left', 'lower', 'ster', '##nal', 'border', '.']
# ['Corona', '##ry', 'arter', '##y', 'disease', ',', 'status', 'post', 'corona', '##ry', 'arter', '##y', 'by', '##pass', 'graf', '##t', '.']
# ['1', '.', 'History', 'of', 'high', 'cho', '##les', '##tero', '##l', '.']
# ['1', '.', 'Doc', '##usa', '##te', 'So', '##dium', '100', 'mg', 'Cap', '##sul', '##e', 'Si', '##g', ':', 'One', '(', '1', ')', 'Cap', '##sul', '##e', 'P', '##O', 'B', '##ID', '(', '2', 'times', 'a', 'day', ')', '.']
# ['Brief', 'Hospital', 'Course', ':']
# ['A', 'left', 'breast', 'lu', '##mpe', '##cto', '##my', 'was', 'reportedly', 'beni', '##gn', '.']
# ['The', 'patient', 'was', 'taken', 'to', 'the', 'Oper', '##ting', 'Room', 'on', '8', '/', '7', '/', '92', ',', 'where', 'a', 'right', 'modified', 'radical', 'mas', '##tec', '##tom', '##y', 'was', 'performed', '.']
# ['Pt', 'also', 'co', '##unsel', '##led', 're', ':']
# ['C', '##t', '##x', 'q', '6', '&', 'apo', '##s', ';', '.']
# ['f', '/', 'u', 'with', 'dr', '.', 'white']
# ['Sep', '##sis', '-', '?', 'source']
# ['D', ':']
# ['Ralph', 'Katherine', 'MD', '31', '-', '164']
# ['The', 'liver', 'enzim', '##es', 'come', 'down', ',', 'no', 'signs', 'of', 'bili', '##ary', 'sta', '##sis', '.']
# ['Card', '##iac', 'ex', '##am', ';', 'she', 'has', 'positive', 'S1', ',', 'S2', 'without', 'mur', '##mur', ',', 'ru', '##b', 'or', 'gallo', '##p', '.']
# ['2019', '-', '06', '-', '19', '07', ':', '20', 'AM', 'BL', '##O', '##OD', 'G', '##lucose', '-', '73', 'Ur', '##ea', '##N', '-', '20', 'C', '##reat', '-', '1', '.', '1', 'Na', '-', '136', 'K', '-', '5', '.', '0', 'Cl', '-', '101', 'HC', '##O', '##3', '-', '27', 'An', '##G', '##ap', '-', '13']
# ['The', 'wound', 'had', 'a', 'be', '##efy', 'red', 'cell', '##uli', '##tic', 'area', 'surrounding', 'an', 'open', 'area', ',', 'blanc', '##hing', 'to', 'touch', '.']
# ['ED', 'Disc', '##harge', 'Summary']
# ['UN', '##IT', 'N', '##UM', '##B', '##ER', ':']
# ['You', 'were', 'diagnosed', 'with', 'an', 'epi', '##dura', '##l', 'ab', '##sce', '##ss', '.']
# ['Abd', '##omen', ':', 'soft', ',', 'non', '##dis', '##tende', '##d', '.']
# ['4', '.', 'O', '##xy', '##co', '##done', '-', 'Ace', '##tami', '##no', '##phen', '5', '-', '325', 'mg', 'Table', '##t', 'Si', '##g', ':', '1', '-', '2', 'Table', '##ts', 'P', '##O', 'Q', '##4', '##H', '(', 'every', '4', 'hours', ')', 'as', 'needed', 'for', 'pain', '.']
# ['*', '*', '*', '*', '*', '*', 'EN', '##D', 'OF', 'DI', '##SC', '##HA', '##R', '##GE', 'OR', '##DE', '##RS', '*', '*', '*', '*', '*', '*']
# ['VS', ':', 'T', ',', 'BP', '181', '/', '122', ',', 'HR', '84', ',', 'RR', '12', ',', 'O', '##2', '98', '%', '2', '##L', '/', 'm']
# ['Over', 'the', 'next', 'three', 'days', 'he', 'increased', 'his', 'activity', 'gradually', ',', 'was', 'able', 'to', 'do', 'sta', '##irs', 'with', 'Physical', 'Therapy', 'and', 'had', 'pain', 'which', 'could', 'be', 'controlled', 'with', 'oral', 'anal', '##gesi', '##cs', '.']
# ['AD', '##DI', '##TION', '##AL', 'COM', '##ME', '##NT', '##S', ':']
# ['66', '##R', '-', '249', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['Service', ':']
# ['D', ':', '2012', '-', '05', '-', '14', '19', ':', '24']
# ['He', '##mat', '##ologic', ':']
# ['1', '.', 'Tra', '##che', '##osto', '##my', '.']
# ['CH', 'KO', '##TE', '##KO', '##LL']
# ['J', '##O', '##B', '#', ':']
# ['From', 'Sao', 'Tome', 'originally', '.']
# ['DI', '##SC', '##HA', '##R', '##GE', 'DA', '##TE', ':']
# ['Wei', '##ght', 'at', 'time', 'of', 'disc', '##harge', 'is', '3', '.', '13', 'kilo', '##gram', '##s', '.']
# ['b', '##zo', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['She', 'delivered', 'a', '355', '##0', 'gram', 'male', 'infant', 'on', '08', '/', '31', '/', '2004', 'at', '09', ':', '33', 'pm', 'with', 'ap', '##gar', 'scores', 'of', '9', 'and', '9', 'at', 'one', 'and', 'five', 'minutes', 'respectively', 'at', '41', '.', '0', 'weeks', 'ge', '##station', 'via', 'sp', '##onta', '##neous', 'verte', '##x', 'va', '##ginal', 'delivery', '.']
# ['4', '.', 'Gast', '##roi', '##ntes', '##tina', '##l', ':', 'Boston', 'required', 'treatment', 'for', 'un', '##con', '##jung', '##ated', 'hy', '##per', '##bilir', '##ubi', '##nem', '##ia', 'with', 'photo', '##ther', '##ap', '##y', '.']
# ['08', '/', '20', '/', '2000', '9', ':', '25', 'A']
# ['Heart', 'sounds', 'were', 'normal', '.']
# ['PA', '##ST', 'SU', '##R', '##GI', '##CA', '##L', 'H', '##IS', '##TO', '##R', '##Y', ':']
# ['CT', '##A', '##B', ',', 'mild', '##ly', 'decreased', 'br', '##eath', 'sounds', 'b', '/', 'l']
# ['55', 'year', 'old', 'man', 'with', 'history', 'of', 'meta', '##stati', '##c', 'blad', '##der', 'cancer', 'and', 're', '##cu', '##rren', '##t', 'D', '##V', '##T', 's', 'on', 'Love', '##no', '##x', 'admitted', 'with', 'lower', 'G', '##I', 'ble', '##eding', '.']
# ['AL', '##LE', '##R', '##GI', '##ES', ':']
# ['DI', '##S', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['The', 'patient', 'did', 'fall', 'while', 'in', '##house', '.']
# ['2', '.', 'Syst', '##oli', '##c', 'and', 'dias', '##tol', '##ic', 'con', '##gest', '##ive', 'heart', 'failure', '.']
# ['2015', '-', '10', '-', '26', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['Number', 'of', 'Dos', '##es', 'Re', '##quire', '##d', '(', 'app', '##rox', '##imate', ')', ':']
# ['The', 'patient', 'overall', 'continued', 'to', 'improve', ',', 'but', 'remained', 'physically', 'de', '##com', '##pensa', '##ted', 'and', 'the', 'patient', 'was', 'transferred', 'to', 'Walt', '##ham', '/', 'Weston', 'Hospital', 'Re', '##habilitation', 'Hospital', 'for', 'intensive', 'physical', 'therapy', '.']
# ['Y', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['Food', '/', 'Drug', 'Inter', '##action', 'Inst', '##ru', '##ction']
# ['The', 'patient', '&', 'apo', '##s', ';', 's', 'mental', 'status', 'slowly', 'began', 'to', 'recover', ',', 'however', 'on', 'the', 'morning', 'of', 'the', 'first', 'day', 'of', 'admission', ',', 'August', '16', ',', '1998', ',', 'the', 'patient', 'was', 'found', 'after', 'having', 'fallen', '.']
# ['NO', 'Ti', '##fan', '##y', ',', 'ET', '##OH', ',', 'OR', 'RE', '##C', 'DR', '##U', '##G', 'US', '##E', '.']
# ['Not', 'App', '##lica', '##ble']
# ['3', '.', 'P', '##yel', '##one', '##ph', '##ritis', '.']
# ['Dr', '.', 'Ga', '##etz', '##fre', '##ier', '##m', '1', '-', '2', 'weeks', ',']
# ['Michael', 'Morgan', 'MD', '43', '-', '508']
# ['This', 'report', 'was', 'created', 'by', 'H', '##ER', '##DE', '##S', ',', 'NEWS', '##HA', '##L', '##IE', '04', '/', '21', '/', '2005', '06', ':', '47', 'AM']
# ['Caro', '##tid', 'pu', '##ls', '##ations', 'are', 'normal', 'without', 'br', '##uit', '.']
# ['Active', ',', 'well', '-', 'developed', ',', 'well', '-', 'nou', '##rish', '##ed', 'male', '.']
# ['Please', 'see', 'detailed', 'operative', 'note', 'for', 'more', 'information', 'about', 'the', 'procedure', '.']
# ['Follow', '##up', 'Inst', '##ru', '##ctions', ':']
# ['It', 'is', 'possible', 'that', 'the', 'patient', 'is', 'self', 'med', '##ica', '##ting', 'for', 'underlying', 'ps', '##ych', '##iat', '##ric', 'disorder', '.']
# ['Major', 'Sur', '##gical', 'or', 'In', '##vasi', '##ve', 'Proc', '##edu', '##re', ':', 'none', 'this', 'admission']
# ['Her', 'al', '##kali', '##ne', 'ph', '##os', '##pha', '##tase', 'was', '1514', '.']
# ['3', '.', 'B', '##IL', '##AT', '##ER', '##AL', 'LE', '##NI', "'", 's']
# ['ME', '##DI', '##CI', '##NE', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['Physical', 'Therapy', 'has', 'been', 'seeing', 'the', 'patient', 'and', 'putting', 'him', 'through', 'passive', 'external', 'rotation', 'to', 'the', 'neutral', 'position', 'of', 'the', 'left', 'shoulder', 'and', 'forward', 'fl', '##ex', '##ion', 'with', 'physical', 'therapy', 'assistance', '.']
# ['Should', 'this', 'become', 'available', ',', 'an', 'add', '##end', '##um', 'will', 'be', 'issued', 'to', 'this', 'report', 'following', 'the', 'comparison', 'with', 'the', 'outside', 'examination', '.']
# ['260', '##24', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['Chief', 'Com', '##plain', '##t', ':']
# ['H', '##OS', '##P', '##IT', '##AL', 'CO', '##UR', '##SE', ':']
# ['He', 'is', 'now', 'living', 'with', 'his', 'son', 'and', 'daughter', ',', 'and', 'five', 'other', 'children', '.']
# ['Head', 'computer', '##ized', 'tom', '##ography', 's', '##can', 'of', '10', '/', '23', ':']
# ['PR', '##IN', '##CI', '##PA', '##L', 'DI', '##SC', '##HA', '##R', '##GE', 'DI', '##AG', '##NO', '##SI', '##S', ';', 'Res', '##pon', '##sible', 'After', 'Study', 'for', 'Ca', '##using', 'Ad', '##mission', ')', 'at', '##y', '##pica', '##l', 'chest', 'pain']
# ['Her', 'coa', '##gula', '##tion', 'parameters', 'were', 'normal', '.']
# ['There', 'was', 'no', 'obvious', 'segment', '##al', 'wall', '-', 'motion', 'ab', '##normal', '##ity', '.']
# ['NO', 'K', '##NO', '##WN', 'DR', '##U', '##G', 'AL', '##LE', '##R', '##GI', '##ES', '.']
# ['So', '##dium', 'of', '138', ';', 'pot', '##ass', '##ium', '3', '.', '5', ';', '106', ',', '28', ',', '31', ',', '1', '.', '0', ',', 'g', '##lucose', '134', '.']
# ['They', 'recommended', 'that', 'the', 'patient', 'may', 'benefit', 'from', 'a', 'trial', 'of', 'continuous', 'positive', 'pressure', 'at', 'the', 'bed', '##side', '.']
# ['11', '/', '26', '/', '2000', '06', ':', '47', 'PM']
# ['G', '##4', 'T2', 'P', '##0', 'A1', 'L2', 'Esti', '##mated']
# ['6', '.', 'Las', '##ix', '40', 'mg', 'P', '##O', 'q', '.', 'day', ',']
# ['Her', 'creat', '##inin', '##e', 'continued', 'to', 'increase', ',', 'likely', 'due', 'to', 'her', 'worse', '##ning', 'liver', 'failure', '.']
# ['None', '.']
# ['Ad', '##mission', 'Date', ':']
# ['Ne', '##ck', ':']
# ['Disc', '##harge', 'Inst', '##ru', '##ctions', ':']
# ['q', '##g', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['She', 'is', 'to', 'contact', 'Dr', '.', 'War', '##m', '&', 'apo', '##s', ';', 's', 'office', 'to', 'schedule', 'a', 'follow', 'up', 'appointment', '.']
# ['CA', '##RE', 'AND', 'RE', '##CO', '##MM', '##EN', '##DA', '##TION', '##S', ':']
# ['Medi', '##cations', 'on', 'Ad', '##mission', ':']
# ['10', '/', '17', '/', '2001', '01', ':', '36', 'PM']
# ['PA', '##ST', 'ME', '##DI', '##CA', '##L', 'H', '##IS', '##TO', '##R', '##Y', ':']
# ['No', 'ort', '##hop', '##nea', '.']
# ['Chr', '##onic', 'ren', '##al', 'ins', '##uff', '##iciency', '.']
# ['KO', '##TER', '##OS', '##T', '##RE', '##U', '##KO', '##TE', ',', 'AR', '##O', 'MA', 'O', '.', '965', '-', '81', '-', '64', '-', '6', 'U', '##9', '##4']
# ['1', '.', 'As', '##pir', '##in', '81', 'mg', 'Table', '##t', ',', 'Del', '##aye', '##d', 'Release', '(', 'E', '.', 'C', '.', ')', 'Si', '##g', ':', 'One', '(', '1', ')', 'Table', '##t', ',', 'Del', '##aye', '##d', 'Release', '(', 'E', '.', 'C', '.', ')', 'P', '##O', 'DA', '##IL', '##Y', '(', 'Daily', ')', '.']
# ['Tra', '##ce', 'movement', 'of', 'the', 'right', 'el', '##bow', 'and', '4', '-', 'strength', 'of', 'the', 'right', 'w', '##rist', 'and', 'hand', '.']
# ['Take', 'with', 'food', 'PR', '##EN', '##AT', '##AL', 'M', '##UL', '##TI', '##VI', '##TA', '##MI', '##NS', '(', 'ST', '##U', '##AR', '##T', '##NA', '##TA', '##L', ')', '1', 'TA', '##B', 'P', '##O', 'Q', '##D', 'MA', '##AL', '##OX', '-', 'TA', '##BL', '##ET', '##S', 'Q', '##UI', '##C', '##K', 'DI', '##SS', '##OL', '##VE', '/', 'CH', '##E', '##WA', '##BL', '##E', '1', '-', '2', 'TA', '##B', 'P', '##O', 'Q', '##6', '##H', 'PR', '##N', 'Up', '##set', 'St', '##oma', '##ch']
# ['In', '2003', ',', 'he', 'had', 'a', 'non', 'ST', 'elevation', 'MI', ',', 'came', 'to', 'the', 'RW', '##H', ',', 'and', 'had', 'a', 'cat', '##h', 'done', ',', 'which', 'showed', 'a', '40', '%', 'RCA', ',', 'which', 'was', 'ha', '##zy', '.']
# ['Disc', '##harge', 'Dia', '##gno', '##sis', ':']
# ['1929', '-', '11', '-', '09', 'PA', '##D', '-', 'W', '##OR', '##D']
# ['10', '/', '10', '/', '1997', '12', ':', '00', ':', '00', 'AM']
# ['We', 'have', 'advised', 'a', 'BR', '##AT', 'diet', '.']
# ['We', 'will', 'given', 'val', '##ium', '5', 'mg', 'p', '.', 'o', '.', 'q', '.', '3', 'hours', 'for', 'withdrawal', '.']
# ['Goals', 'of', 'care', 'were', 'clar', '##ified', 'with', 'her', 'Murphy', ',', 'Robert', 'Sanchez', '.']
# ['The', 'patient', 'states', 'that', 'he', 'was', 'willing', 'to', 'speak', 'with', 'someone', 'from', 'add', '##ict', '##ion', 'services', '.']
# ['He', 'did', 'travel', 'to', 'the', 'Ta', '##heim', '##pro', '##mon', '##g', ',', 'last', 'in', '01', '/', '2004', 'for', 'three', 'weeks', '.']
# ['The', 'telephone', 'number', 'at', 'his', 'office', 'is', '236', '-', '451', '##8', '.']
# ['ME', '##DI', '##CA', '##TION', '##S', 'ON', 'DI', '##SC', '##HA', '##R', '##GE', ':']
# ['Dis', '##position', ',', 'Follow', 'up', 'and', 'Inst', '##ru', '##ctions', 'to', 'Pat', '##ient', ':']
# ['Ne', '##ck', ':']
# ['2014', '-', '03', '-', '09', '02', ':', '59', 'AM', 'BL', '##O', '##OD', 'c', '##T', '##rop', '##n', '##T', '-', '0', '.', '21', '*']
# ['Fortuna', '##tely', ',', 'no', 'evidence', 'of', 'barat', '##roma', 'was', 'ever', 'disc', '##erne', '##d', '.']
# ['2', '.', 'Li', '##sino', '##pri', '##l', '15', 'mg', 'Table', '##t', 'Si', '##g', ':', 'One', '(', '1', ')', 'Table', '##t', 'P', '##O', 'DA', '##IL', '##Y', '(', 'Daily', ')', '.']
# ['4', '.', 'Cl', '##op', '##ido', '##gre', '##l', '75', 'mg', 'Table', '##t', 'Si', '##g', ':', 'One', '(', '1', ')', 'Table', '##t', 'P', '##O', 'DA', '##IL', '##Y', '(', 'Daily', ')', '.']
# ['2', '.', 'Born', 'between', '32', 'and', '35', 'weeks', 'with', 'plans', 'for', 'day', '##care', 'during', 'resp', '##irat', '##ory', 'syn', '##cy', '##tial', 'virus', 'season', ',', 'with', 'a', 'smoke', '##r', 'in', 'the', 'household', 'or', 'with', 'pre', '##school', 'siblings', ';', 'or']
# ['The', 'acute', 'ons', '##et', 'of', 'chest', 'pain', 'was', 'initially', 'very', 'concerning', 'for', 'a', 'PE', ',', 'however', 'the', 'Che', '##st', 'CT', 'demonstrated', 'multi', '##fo', '##cal', 'con', '##sol', '##idat', '##ion', 'consistent', 'with', 'a', 'bacteria', '##l', 'P', '##NA', '.']
# ['No', 'et', '##hanol', 'use', '.']
# ['He', 'was', 'continued', 'on', 'hep', '##arin', 'for', 'treatment', 'of', 'the', 'pu', '##lm', '##onar', '##y', 'em', '##bol', '##i', '.']
# ['He', 'den', '##ies', 'any', 'ET', '##OH', 'or', 'tobacco', 'use', '.']
# ['Va', '##ginal', 'Del', '##iver', '##y', 'With', 'Second', 'De', '##gree', 'Lac', '##eration']
# ['She', 'came', 'to', 'the', 'Emergency', 'Department', 'on', 'the', '2011', '-', '03', '-', '10', ',', 'with', 'temperature', 'of', '99', '.', '0', 'F', '.', ';', 'blood', 'pressure', 'of', '97', '/', '50', ';', 'heart', 'rate', '100', ';', 'resp', '##iration', '##s', '27', ';', 'O', '##2', 'satu', '##ration', '84', '%', 'on', 'room', 'air', 'and', '94', '%', 'on', 'two', 'liter', '##s', '.']
# ['s', '##rom', 'in', 'labor', '.']
# ['1', '.', 'No', 'evidence', 'of', 'pu', '##lm', '##onar', '##y', 'em', '##bolism', '.']
# ['2013', '-', '05', '-', '23', '01', ':', '08', 'PM', '1', '.', '22']
# ['The', 'patient', 'was', 'taken', 'off', 'fluid', 'rest', '##ric', '##tion', '.']
# ['3', '.', 'Fl', '##uid', '##s', ',', 'elect', '##rol', '##yte', '##s', 'and', 'nu', '##trition', '-', 'Birth', '##weight', 'was', '1400', 'g', '##m', ',', '25th', 'percent', '##ile', '.']
# ['Tra', '##che', '##osto', '##my', '2014', '-', '11', '-', '11']
# ['Follow', '##up', 'Inst', '##ru', '##ctions', ':']
# ['Date', 'of', 'Birth', ':']
# ['2018', '-', '05', '-', '24', '08', ':', '55', 'PM']
# ['AD', '##MI', '##SS', '##ION', 'DA', '##TE', ':']
# ['CV', ':', 'RR', '##R', ',', 'no', 'M', '/', 'R', '/', 'G']
# ['LA', '##B', '##OR', '##AT', '##OR', '##Y', 'DA', '##TA', ':']
# ['Per', '##ip', '##hera', '##l', 'pu', '##lse', '##s', 'were', 'very', 'strong', 'and', 'bound', '##ing', '.']
# ['10', '/', '12', '/', '2004', '12', ':', '00', ':', '00', 'AM']
# ['An', 'ab', '##dom', '##inal', 'MR', '##I', 'was', 'performed', 'to', 'ass', '##ess', 'continued', 'elevated', 'liver', 'enzyme', '##s', ';', 'however', ',', 'the', 'MR', '##I', 'was', 'negative', '.']

# %% [markdown]
# # 9. Code snippets

# %%
# flatten1 = list(itertools.chain(*y_true))
# flatten2 = list(itertools.chain(*y_pred))
# tagsforf1 = []
# for tag in tags_vals[:-3]:
#     if tag != 'O':
#         tagsforf1.append(tag)

# %%
#https://datascience.stackexchange.com/questions/54907/model-cuda-in-pytorch
# if n_gpu >1:
#     model = torch.nn.DataParallel(model)
# model.cuda(device='cuda:0')
# model.to(torch.device('cuda:0'))

# %%
# params = list(model.named_parameters())
# print(len(params))
# for p in params[0:201]:
#     print(p[0], p[1].size())

# %%
# type(param_optimizer)
# type(optimizer_grouped_parameters)
# len(optimizer_grouped_parameters)

# type(optimizer_grouped_parameters[0])

# optimizer_grouped_parameters[1].keys()

# optimizer_grouped_parameters[0]['weight_decay_rate']

# optimizer_grouped_parameters[1]['weight_decay_rate']

# optimizer_grouped_parameters[0]['betas']

# optimizer_grouped_parameters[1]['betas']

# optimizer_grouped_parameters[1]['weight_decay']

# optimizer_grouped_parameters[1]['weight_decay']

# optimizer_grouped_parameters[0]['correct_bias']

# optimizer_grouped_parameters[1]['correct_bias']

# %%
# c =28
# print(list(attention_masks[c]))
# print(attention_masks_deprecated[c])
# for i in range(1,150):
#     if list(attention_masks[i]) != attention_masks_deprecated[i]:
#         print(i)

# %%
# tokenized_texts[0]
# tokenizer.tokenize(' '.join(sentences[0]))

# %%
# tokenizer.batch_encode_plus(sentences)['input_ids'][0]
# tokenizer.decode(tokenizer.batch_encode_plus(sentences)['input_ids'][0])
# tokenizer.decode(tokenizer.encode(' '.join(sentences[0])))
# tokenizer.decode(tokenizer.encode(sentences[0]))
# tokenizer.decode(tokenizer.encode('Diagnose revisie : ( Meerdere antwoorden mogelijk) Infectie'))

# %%
# def getmaxlength():
#     lowestcount =512
#     lowestcountindex = 0
#     for idx, onearray in enumerate(input_ids):
#         count=0
#         for number in reversed(onearray):
#             if number ==0:
#                 count += 1
#             else:
#                 if count < lowestcount:
#                     lowestcount = count
#                     lowestcountindex = idx
#                 break

#     maxlength = len(tokenized_texts[lowestcountindex])
#     return maxlength
